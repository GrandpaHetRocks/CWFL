# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import numpy as np
from Dataset import load_dataset, getImage
from utils import averageModels
from utils import averageModelscluster
import random
import math
import matplotlib.pyplot as plt
from ipynb.fs.full.K_clusters import cluster_former
from copy import deepcopy
# Out:
# 0.718348503112793
# {'Cluster Head': 'client19', 'Members': ['client1', 'client6', 'client7', 'client13', 'client14', 'client25', 'client28', 'client43', 'client53', 'client63'], 'SNR': [34.91440538052105, 29.96225829445205, 36.386430595766264, 30.13398936162998, 28.431503557614523, 28.896771241884558, 27.586041912221337, 38.999261633900666, 25.634339058007793, 30.166339868300106], 'CSI': [0.9389609511028716, 0.7201346217506998, 0.23709906094634725, 0.38687465613054817, 0.2811755620575802, 0.4823780405541228, 0.10262897962687678, 0.6609044419195066, 0.3786879807472243, 0.7909428439024928]}

# %%
P=2 #signal power threshold
#stream = BitStream()
#random.seed(10)
key=[]
for i in range (10000): #generating a random password to activate training (Pilot signal)
    temp=random.randint(0,1)
    key.append(temp)

key1=[0]*len(key)
for i in range (len(key)):   #bpsk modulation
    if(key[i]==1):
        #print("yay")
        key1[i]=-math.sqrt(P)
    else:
        key1[i]=math.sqrt(P)

#print(key)
        
key_np=np.array(key1)

# %%
class Arguments():
    def __init__(self):
        self.images = 10000
        self.clients = 50
        self.rounds = 200
        self.epochs = 4 
        self.local_batches = 64
        self.lr = 0.01
        self.C = 1 #fraction of clients used in the round
        self.drop_rate = 0 #fraction of devices in the selected set to be dropped for various reasons
        self.torch_seed = 0 #same weights and parameters whenever the program is run
        self.log_interval = 64
        self.iid = 'noniid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = True
        self.numclusters=4

args = Arguments()

# %%
#checking if gpu is available
#use_cuda = args.use_cuda and torch.cuda.is_available()
use_cuda=False
device = torch.device("cuda:0" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

hook = sy.TorchHook(torch)
me = hook.local_worker
clients = []

#generating virtual clients
for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})
#print(clients)

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid) #load data

for inx, client in enumerate(clients):  #return actual image set for each client
    trainset_ind_list = list(train_group[inx]) 
    client['trainset'] = getImage(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getImage(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images #useful while taking weighted average
# Out:
# /home/test/anaconda3/lib/python3.7/site-packages/torchvision/datasets/mnist.py:45: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")

# %%
#load dataset for global model (to compare accuracies)
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.MNIST('./', train=False, download=True, transform=transform)
# global_test_dataset = torch.utils.data.random_split(global_test_dataset, [10000, len(global_test_dataset)-10000])[0]
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
"""class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        #self.quant = torch.quantization.QuantStub()
        self.conv1 = nn.Conv2d(1, 5, 5, 1)
        self.conv2 = nn.Conv2d(5, 10, 5, 1)
        self.fc1 = nn.Linear(4*4*10, 50) #10 iid #50 non iid
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        #x=self.quant(x)
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*10
                   )
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1) """

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x)

# %%
def fedprox(params,global_params):
    global_param=[]
    ind=0
    for gp in global_params:
        global_param.append(gp)
    for p in params:
    #                 print(p.grad)
        lr=0.001
        mu=0.1
        if(p.grad is None):
            continue
        grad=p.grad.data #batch gradients
        p.data.sub_(lr,(grad+mu*(p.data.clone()-global_param[ind].data.clone())))
        ind+=1
    return(p)

# %%
def ClientUpdate(args, device, client,key_np,key,snr,csi,mu,head):
    gc=False
    client['model'].train()
    #simulating a wireless channel
    poptim=max((1/mu-1/csi),0)
    #print(mu,csi)
    print("Power Allocated=",poptim)
    print("CSI=",csi)
    
    snr__=10**(snr/10)
    
    absh=csi*poptim/snr__
    x=random.uniform(0,absh)
    #print(x)
    y=math.sqrt(absh*absh-x*x)
    #x=x*100
    #y=y*100
    #x=random.random()
    #y=random.random()
    #snr=10*math.log(poptim/(std*std),10)
    std=math.sqrt(poptim/snr__*absh*absh) #channel noise
    
    #print(x,y)
    h=complex(x,y)
    #std=math.sqrt(abs(h)/csi)
    #snr=poptim/(std*std)
    #print(std)
    print("SNR=",snr)
    #print("csi",abs(h)/(std*std))
    
    
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data

    
    #print(client['model'].conv1.weight.size)
    client['model'].send(client['hook'])
    head['model'].send(client['hook'])
    print("Client:",client['hook'].id)
    
    key_np_received=h*key_np+(np.random.randn(len(key_np))*std*2)
    #print(key_np_received)
    key_np_received=(key_np_received/(h)).real
    
    for o in range (len(key_np_received)):  #demodulation bpsk
        if(key_np_received[o]>=0):
            key_np_received[o]=0
        else:
            key_np_received[o]=1
    
    key_np_received=key_np_received.tolist()
    key_np_received = [int(item) for item in key_np_received]
    #key_np=key_np.tolist()
    
    
    if(sum(np.bitwise_xor(key,key_np_received))/len(key)==0 and poptim>0): #...............................................checking if channel is good enough for transmission by checking BER..................................#
        gc=True #considering the client model for training
        for epoch in range(1, args.epochs + 1):
            for batch_idx, (data, target) in enumerate(client['trainset']): 
                data = data.send(client['hook'])
                target = target.send(client['hook'])
                #client['optim'].zero_grad()
                #train model on client
                data, target = data.to(device), target.to(device) #send data to cpu/gpu (data is stored locally)
                output = client['model'](data)
                loss = F.nll_loss(output, target)
                loss.backward()
                #client['optim'].step()
                params=client['model'].parameters()
                gp=head['model'].parameters()
                params=fedprox(params,gp) 
                
                if batch_idx % args.log_interval == 0:
                    loss = loss.get() 
                    print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                        client['hook'].id,
                        epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                        100. * batch_idx / len(client['trainset']), loss))
    else:
        print("Poor Channel, client not taken for averaging in this round")
            
                    
    client['model'].get()
    head['model'].get()
    # print()
         #CHANGE
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
    #CHANGE ENDS
    print()
    return gc

# %%
def test(args, model, device, test_loader, name,fed_round):
    model.eval()    #no need to train the model while testing
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            if(use_cuda and fed_round==0):
                data,target=data.cuda(),target.cuda()
                #model.cuda()
            else:
                data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    return([100. * correct / len(test_loader.dataset),test_loss])

# %%
torch.manual_seed(args.torch_seed)

# %%
def distort(neighbours,snrs):
    ind=0
    poptim=2
    csi=random.random()
    distorted_models=[]
    for client in neighbours:
        snr=snrs[ind]
        ind+=1
        snr__=10**(snr/10)
        absh=csi*poptim/snr__
        x=random.uniform(0,absh)
        y=math.sqrt(absh*absh-x*x)
        std=math.sqrt(poptim/snr__*absh*absh) #channel noise
        h=complex(x,y)
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
        
        distorted_models.append(client)
    return(distorted_models)

# %%
def decentralized(clients,snrs,weights):
    big_daddy_of_distorted_models=[]
    for client in clients:
        distorted_models=[]
        snr_list=[]
        for snr in snrs:
            if(client['hook'].id in snr):
                snr_list.append(snr[2])
        neighbours_c = [x for x in clients if x != client]
        neighbours={}
        jjj=[jkl for jkl in range(len(neighbours_c))]
        
        dictionary = dict(zip(jjj, neighbours_c))
        #for jjj in range(len(neighbours_c)):
        #   neighbours[jjj].append(neighbours_c[jjj])
        distorted_models=distort(neighbours,snr_list)
        distorted_models.append(client)
        big_daddy_of_distorted_models.append(distorted_models)
    
    
    weight_final1=[]
    for oho in big_daddy_of_distorted_models:
        weight_final=[]
        for comeon in oho:
            for w in weights:
                if(comeon['hook'].id==w[0]):
                    weight_final.append(w[1])
        weight_final1.append(weight_final)
    
    final_heads=[]
    nets=[]
    ind=0
    for client in clients:
        for oof in big_daddy_of_distorted_models:
            if(client==oof[0]):
#                 print(client)
#                 print("shut up")
#                 print(distorted_models)
#                 print("shut up")
#                 print(weight_final1)
                
                overall=Net()
                overall=averageModelscluster(overall,distorted_models,weight_final1[ind])
                client['model'].load_state_dict(overall.state_dict())
                ind+=1
                final_heads.append(client)
                nets.append(overall)
    
    return(final_heads,nets)

# %%
for client in clients: #give the model and optimizer to every client
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    #client['model'] = torch.quantization.quantize_dynamic(
    #client['model'],  # the original model
    #{torch.nn.Linear},  # a set of layers to dynamically quantize
    #dtype=torch.fp)  # the target dtype for quantized weights
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)

final_acc=[]
final_loss=[]
    
for fed_round in range(args.rounds):
    overall=Net()
    if(fed_round==0): #fed_round==0
        arranged_clusters,head_snr_list=cluster_former(args.numclusters,args.clients)
        temp=deepcopy(arranged_clusters)
        temp2=deepcopy(head_snr_list)
    else:
        #print(temp)
        arranged_clusters=deepcopy(temp)
        head_snr_list=deepcopy(temp2)
#     print(arranged_clusters)
    
    no=1
    heads_list=[]
    weights=[]
    weight_head_list=[]
    head_acc=[]
    head_loss=[]
    for cluster in arranged_clusters:
        
        head=cluster['Cluster Head']
        members=cluster['Members']
        snrs=cluster['SNR']
        csis=cluster['CSI']
        weights.append(sum(snrs))
        weight_head_list.append([head,sum(snrs)])
        new_members=[]
        
        for ij in members:
        #print(ij)
            cl_no=int(ij[6:])
            new_members.append(clients[cl_no-1])
#         print(head)
        head=clients[int(head[6:])-1]
        cluster['Members']=new_members
#         print(head)

        smallmu1=0
        gsmall1=3.402823466E+38 
        
        #water filling algorithm
        mu=1e-15
        while(mu<=1):
            g1=0
            pn1=0
            for jj in csis:
                pn=max(1/mu-1/jj,0)
                g1+=math.log(1+pn*jj) #capacity of a channel (shannon's law)
                pn1+=pn
            g=g1-mu*(pn1-P*30)
            if(g<gsmall1):
                smallmu1=mu
                gsmall1=g
            mu+=0.00002
        
        print(smallmu1)
        good_mem=[]
#         print(len(snrs))
#         print(len(csis))
#         print(len(new_members))
        index=0
        for client in new_members:
            goodchannel=ClientUpdate(args, device, client,key_np,key,snrs[index],csis[index],smallmu1,head)
            index+=1
            if(goodchannel):
                good_mem.append(client)
        
        head['model']=averageModels(head['model'], good_mem)
        arr=test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)
        ac=arr[0]#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[0]
        no+=1
        heads_list.append(head)
        head_acc.append(ac)
        head_loss.append(arr[1])#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[1])
    
    final_acc.append(head_acc)
    final_loss.append(head_loss)
    fig,ax=plt.subplots()
    clor = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(args.numclusters)]
    #ax.plot([i for i in range(fed_round)],head_acc[0])
    for jj in range(0,args.numclusters):
        
        ax.plot([i for i in range(len(final_acc))],[final_acc[j][jj] for j in range(len(final_acc))], color = clor[jj])
        
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][0] for j in range(len(final_acc))], color ="red")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][1] for j in range(len(final_acc))],color ="blue")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][2] for j in range(len(final_acc))],color ="green")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][3] for j in range(len(final_acc))],color ="black")
    #ax.plot([i for i in range(len(final_acc))],head_acc[1], fed_round, color ="blue")
    #ax.plot([i for i in range(len(final_acc))],head_acc[2], fed_round, color ="green")
    #ax.plot([i for i in range(len(final_acc))],head_acc[3], fed_round, color ="black")
    
    
    plt.show()
    weightsum=sum(weights)
    
    weights[:] = [x / weightsum for x in weights]
    for aah in range(len(weight_head_list)):
        weight_head_list[aah][1]=weights[aah]
    final_heads,nets=decentralized(heads_list,head_snr_list,weight_head_list)
    
    for head in range(len(final_heads)):
        for cluster in arranged_clusters:
            head1=cluster['Cluster Head']
            if(head1==final_heads[head]['hook'].id):
                for mem in cluster['Members']:
                    mem['model'].load_state_dict(nets[head].state_dict())
    print("ROUND",fed_round)
# Out:
# 0.11778000000001572
# Power Allocated= 5.342621967858911
# CSI= 0.3176838182589903
# SNR= 24.776274703436403
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.369125
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/generic/frameworks/hook/hook.py:165: UserWarning: This overload of sub_ is deprecated:
# 	sub_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	sub_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   response = method(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.307109
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.088702
# Model client11 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.680095
#
# Power Allocated= 7.207846961426169
# CSI= 0.7796912996476977
# SNR= 26.96472013684797
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.284905
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.207455
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.124330
# Model client14 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.857731
#
# Power Allocated= 6.485227856829772
# CSI= 0.4987088466439976
# SNR= 30.323138255413753
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.340486
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292143
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.240593
# Model client15 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.173811
#
# Power Allocated= 2.314982604390001
# CSI= 0.16193222093786197
# SNR= 32.169404484190316
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.286663
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288670
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.242485
# Model client16 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.105472
#
# Power Allocated= 7.31176857263765
# CSI= 0.8484374510333382
# SNR= 32.28020007484866
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.276860
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.284652
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.197089
# Model client17 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.149632
#
# Power Allocated= 7.223786738447949
# CSI= 0.7895033302994222
# SNR= 41.0786055003276
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.306397
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293051
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.215353
# Model client22 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.213444
#
# Power Allocated= 3.666875445958765
# CSI= 0.20731703089204256
# SNR= 45.94326377605648
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.372923
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.349358
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.243730
# Model client30 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.064568
#
# Power Allocated= 2.4814940597690427
# CSI= 0.16641948431615938
# SNR= 39.458734935449264
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.327446
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302560
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.244062
# Model client37 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.216821
#
# Power Allocated= 3.932648552317734
# CSI= 0.21940615451284295
# SNR= 19.8992279562447
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.500417
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.259576
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.084933
# Model client44 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.805514
#
# Power Allocated= 6.970639649444516
# CSI= 0.6579959504919366
# SNR= 21.744198828660373
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.322472
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.238370
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.215665
# Model client45 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.053288
#
# Power Allocated= 7.062397937126022
# CSI= 0.7002762358726271
# SNR= 23.532700318907576
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.311240
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.328662
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.236448
# Model client50 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.035191
#
#
# Test set: Average loss for Cluster1 model: 2.3383, Accuracy: 1115/10000 (11%)
#
# 0.12890000000001642
# Power Allocated= 6.404034440879716
# CSI= 0.7385974623111705
# SNR= 30.044046166152498
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.232812
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.149572
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.996301
# Model client2 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.862294
#
# Power Allocated= 6.4330257416135055
# CSI= 0.7547590430938197
# SNR= 27.652557291922168
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295594
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286681
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.194276
# Model client12 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.197192
#
# Power Allocated= 5.658421378762288
# CSI= 0.4762969576066912
# SNR= 28.176975960156817
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.345020
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292232
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.211310
# Model client18 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.092767
#
# Power Allocated= 2.8085144825636963
# CSI= 0.20204316481227624
# SNR= 31.184404325748485
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295017
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.257768
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.102185
# Model client21 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.795239
#
# Power Allocated= 3.149200357101745
# CSI= 0.21697850069389024
# SNR= 31.96566355530362
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.309164
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.308249
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.240733
# Model client23 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.101278
#
# Power Allocated= 6.736539638679467
# CSI= 0.979036611548543
# SNR= 30.324781871853
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.355855
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.317750
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285554
# Model client24 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.234602
#
# Power Allocated= 5.4492165380039435
# CSI= 0.4331375592711664
# SNR= 24.549228851143056
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298885
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.213781
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.211178
# Model client25 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.987768
#
# Power Allocated= 6.104512405404552
# CSI= 0.6047998749558054
# SNR= 25.36606534665926
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.270946
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.141160
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.924300
# Model client26 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.465965
#
# Power Allocated= 4.400126257211217
# CSI= 0.29781177052475694
# SNR= 19.713455219599112
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.328794
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.277205
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.147953
# Model client36 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.075119
#
# Power Allocated= 6.3739720302044915
# CSI= 0.7225538617436481
# SNR= 26.680710504545665
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.274001
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294919
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.233485
# Model client40 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.139252
#
# Power Allocated= 6.481896187779557
# CSI= 0.7836648430604369
# SNR= 24.804687812485835
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.248106
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.278378
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.253970
# Model client49 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.081911
#
#
# Test set: Average loss for Cluster2 model: 2.3520, Accuracy: 1336/10000 (13%)
#
# 0.11716000000001553
# Power Allocated= 6.584227467544903
# CSI= 0.5125290744106856
# SNR= 29.957880861231335
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.338368
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.323389
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.235894
# Model client3 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.168886
#
# Power Allocated= 7.30435827228831
# CSI= 0.8123621898887446
# SNR= 27.54982444872212
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.337671
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.279559
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.293967
# Model client5 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.216264
#
# Power Allocated= 7.294576557140373
# CSI= 0.8059578109315635
# SNR= 34.74673767210371
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.347298
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296358
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.252834
# Model client6 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.092969
#
# Power Allocated= 7.187931779259251
# CSI= 0.742167619567539
# SNR= 27.444065912994617
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300405
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.276084
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.184943
# Model client9 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.902002
#
# Power Allocated= 6.682629964691962
# CSI= 0.5397509498003974
# SNR= 34.6744222985515
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.280063
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.247921
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.128897
# Model client28 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.996441
#
# Power Allocated= 0
# CSI= 0.03474053729871218
# SNR= 27.375415893233534
# Client: client29
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.841732177650893
# CSI= 0.27073827323502064
# SNR= 25.899415537480245
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.288564
# /home/test/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: RuntimeWarning: invalid value encountered in true_divide
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.241626
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.215510
# Model client31 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.144878
#
# Power Allocated= 0
# CSI= 0.10225011198741485
# SNR= 30.63500327753379
# Client: client33
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.126678708826221
# CSI= 0.7098957275126709
# SNR= 27.529005806652897
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.416080
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.397976
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.300131
# Model client34 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.158433
#
# Power Allocated= 5.927652261275342
# CSI= 0.38348204311651324
# SNR= 23.977475843169202
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.424764
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.375904
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.237763
# Model client39 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.211803
#
# Power Allocated= 0
# CSI= 0.015495244143939768
# SNR= 23.511083363796878
# Client: client43
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.052522006700542
# CSI= 0.6743932869720568
# SNR= 41.57311731589153
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.375344
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.388272
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.292243
# Model client48 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.178632
#
#
# Test set: Average loss for Cluster3 model: 2.2968, Accuracy: 1206/10000 (12%)
#
# 0.11828000000001587
# Power Allocated= 7.169108571167056
# CSI= 0.7779642317899512
# SNR= 28.645052716069564
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.325095
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286660
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.267790
# Model client4 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.174178
#
# Power Allocated= 7.121984823620183
# CSI= 0.750452210926046
# SNR= 24.920586236955778
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.255651
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.241824
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.170382
# Model client7 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.065984
#
# Power Allocated= 0
# CSI= 0.11447499504437864
# SNR= 28.761380224862293
# Client: client8
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.856034760839213
# CSI= 0.27789511512930953
# SNR= 29.057064155241278
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.274219
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.232629
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.151493
# Model client10 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.002960
#
# Power Allocated= 6.82728008147674
# CSI= 0.6145395273344287
# SNR= 23.795893641190798
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.414460
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.376192
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.239536
# Model client20 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.131515
#
# Power Allocated= 6.193605529354793
# CSI= 0.442299942068746
# SNR= 52.911470801015646
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.318429
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.269246
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.266759
# Model client27 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.207989
#
# Power Allocated= 7.206196601207019
# CSI= 0.8010778600996379
# SNR= 23.38763871547513
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302345
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.206815
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.923130
# Model client32 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.371915
#
# Power Allocated= 2.0688116811655792
# CSI= 0.15659982860943045
# SNR= 26.42859931038003
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.319460
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.252735
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.150197
# Model client35 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.023987
#
# Power Allocated= 6.20442612256438
# CSI= 0.44442694621189704
# SNR= 28.605062366613755
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.317216
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298466
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289458
# Model client38 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.201784
#
# Power Allocated= 0
# CSI= 0.10630528637625636
# SNR= 24.73270331967005
# Client: client41
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.155786516882774
# CSI= 0.3031471346525201
# SNR= 31.26355930142449
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.349299
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.317699
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.220945
# Model client42 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.158089
#
# Power Allocated= 7.197121290365513
# CSI= 0.7952960336082722
# SNR= 25.5667087020647
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.286745
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.238758
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.197780
# Model client46 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.034652
#
#
# Test set: Average loss for Cluster4 model: 2.2832, Accuracy: 1481/10000 (15%)
# ROUND 0
# 0.11778000000001572
# Power Allocated= 5.342621967858911
# CSI= 0.3176838182589903
# SNR= 24.776274703436403
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301718
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.228674
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.059249
# Model client11 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.695395
#
# Power Allocated= 7.207846961426169
# CSI= 0.7796912996476977
# SNR= 26.96472013684797
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.318604
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.260519
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.153449
# Model client14 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.869705
#
# Power Allocated= 6.485227856829772
# CSI= 0.4987088466439976
# SNR= 30.323138255413753
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.308823
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.283425
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.260502
# Model client15 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.209235
#
# Power Allocated= 2.314982604390001
# CSI= 0.16193222093786197
# SNR= 32.169404484190316
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305698
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.285255
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.252234
# Model client16 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.183508
#
# Power Allocated= 7.31176857263765
# CSI= 0.8484374510333382
# SNR= 32.28020007484866
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.284811
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.250987
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.188910
# Model client17 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.121843
#
# Power Allocated= 7.223786738447949
# CSI= 0.7895033302994222
# SNR= 41.0786055003276
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307285
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.285133
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.263694
# Model client22 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.216490
#
# Power Allocated= 3.666875445958765
# CSI= 0.20731703089204256
# SNR= 45.94326377605648
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.314536
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.255580
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.115100
# Model client30 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.846749
#
# Power Allocated= 2.4814940597690427
# CSI= 0.16641948431615938
# SNR= 39.458734935449264
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.290091
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.277135
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.253486
# Model client37 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.227334
#
# Power Allocated= 3.932648552317734
# CSI= 0.21940615451284295
# SNR= 19.8992279562447
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.291890
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.240801
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.151313
# Model client44 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.918244
#
# Power Allocated= 6.970639649444516
# CSI= 0.6579959504919366
# SNR= 21.744198828660373
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.310451
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.272027
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.198729
# Model client45 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.028757
#
# Power Allocated= 7.062397937126022
# CSI= 0.7002762358726271
# SNR= 23.532700318907576
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.315435
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.275031
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.175752
# Model client50 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.986889
#
#
# Test set: Average loss for Cluster1 model: 2.3063, Accuracy: 1501/10000 (15%)
#
# 0.12890000000001642
# Power Allocated= 6.404034440879716
# CSI= 0.7385974623111705
# SNR= 30.044046166152498
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297202
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.240109
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.119012
# Model client2 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.820690
#
# Power Allocated= 6.4330257416135055
# CSI= 0.7547590430938197
# SNR= 27.652557291922168
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304049
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.274027
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.243753
# Model client12 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.193301
#
# Power Allocated= 5.658421378762288
# CSI= 0.4762969576066912
# SNR= 28.176975960156817
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.322621
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.262125
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.121604
# Model client18 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.853218
#
# Power Allocated= 2.8085144825636963
# CSI= 0.20204316481227624
# SNR= 31.184404325748485
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.308605
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.220630
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.977177
# Model client21 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.577916
#
# Power Allocated= 3.149200357101745
# CSI= 0.21697850069389024
# SNR= 31.96566355530362
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.310418
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.278013
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.216980
# Model client23 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.078558
#
# Power Allocated= 6.736539638679467
# CSI= 0.979036611548543
# SNR= 30.324781871853
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.310162
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.284817
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.258518
# Model client24 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.208753
#
# Power Allocated= 5.4492165380039435
# CSI= 0.4331375592711664
# SNR= 24.549228851143056
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.289143
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.236822
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.154494
# Model client25 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.027002
#
# Power Allocated= 6.104512405404552
# CSI= 0.6047998749558054
# SNR= 25.36606534665926
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.282774
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.143522
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.636100
# Model client26 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.926505
#
# Power Allocated= 4.400126257211217
# CSI= 0.29781177052475694
# SNR= 19.713455219599112
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.314389
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.187604
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.924234
# Model client36 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.591703
#
# Power Allocated= 6.3739720302044915
# CSI= 0.7225538617436481
# SNR= 26.680710504545665
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297876
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.256991
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.192330
# Model client40 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.084724
#
# Power Allocated= 6.481896187779557
# CSI= 0.7836648430604369
# SNR= 24.804687812485835
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.308407
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.266551
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.219263
# Model client49 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.098410
#
#
# Test set: Average loss for Cluster2 model: 2.3652, Accuracy: 974/10000 (10%)
#
# 0.11716000000001553
# Power Allocated= 6.584227467544903
# CSI= 0.5125290744106856
# SNR= 29.957880861231335
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.282707
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.249469
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.194059
# Model client3 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.148346
#
# Power Allocated= 7.30435827228831
# CSI= 0.8123621898887446
# SNR= 27.54982444872212
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.313398
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.281563
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.253101
# Model client5 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.197020
#
# Power Allocated= 7.294576557140373
# CSI= 0.8059578109315635
# SNR= 34.74673767210371
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.308572
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.264999
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.173870
# Model client6 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.012318
#
# Power Allocated= 7.187931779259251
# CSI= 0.742167619567539
# SNR= 27.444065912994617
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.317866
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.270546
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.194602
# Model client9 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.011367
#
# Power Allocated= 6.682629964691962
# CSI= 0.5397509498003974
# SNR= 34.6744222985515
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.294826
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.250221
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.142799
# Model client28 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.974591
#
# Power Allocated= 0
# CSI= 0.03474053729871218
# SNR= 27.375415893233534
# Client: client29
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.841732177650893
# CSI= 0.27073827323502064
# SNR= 25.899415537480245
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.287290
# /home/test/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: RuntimeWarning: invalid value encountered in true_divide
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.266614
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.243724
# Model client31 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.211517
#
# Power Allocated= 0
# CSI= 0.10225011198741485
# SNR= 30.63500327753379
# Client: client33
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.126678708826221
# CSI= 0.7098957275126709
# SNR= 27.529005806652897
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299610
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.256855
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.169956
# Model client34 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.024778
#
# Power Allocated= 5.927652261275342
# CSI= 0.38348204311651324
# SNR= 23.977475843169202
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295067
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.272745
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.239629
# Model client39 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.189378
#
# Power Allocated= 0
# CSI= 0.015495244143939768
# SNR= 23.511083363796878
# Client: client43
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.052522006700542
# CSI= 0.6743932869720568
# SNR= 41.57311731589153
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.316770
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.282932
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.222337
# Model client48 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.125051
#
#
# Test set: Average loss for Cluster3 model: 2.3027, Accuracy: 1232/10000 (12%)
#
# 0.11828000000001587
# Power Allocated= 7.169108571167056
# CSI= 0.7779642317899512
# SNR= 28.645052716069564
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303272
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.270691
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.223470
# Model client4 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.147684
#
# Power Allocated= 7.121984823620183
# CSI= 0.750452210926046
# SNR= 24.920586236955778
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.289562
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.252803
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.190398
# Model client7 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.061520
#
# Power Allocated= 0
# CSI= 0.11447499504437864
# SNR= 28.761380224862293
# Client: client8
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.856034760839213
# CSI= 0.27789511512930953
# SNR= 29.057064155241278
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305829
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.287722
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.222848
# Model client10 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.107755
#
# Power Allocated= 6.82728008147674
# CSI= 0.6145395273344287
# SNR= 23.795893641190798
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.285295
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.226652
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.144173
# Model client20 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.046743
#
# Power Allocated= 6.193605529354793
# CSI= 0.442299942068746
# SNR= 52.911470801015646
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.294466
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.282493
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.252757
# Model client27 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.223111
#
# Power Allocated= 7.206196601207019
# CSI= 0.8010778600996379
# SNR= 23.38763871547513
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.316968
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.204894
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.925729
# Model client32 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.335874
#
# Power Allocated= 2.0688116811655792
# CSI= 0.15659982860943045
# SNR= 26.42859931038003
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.275344
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.212130
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.141087
# Model client35 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.004792
#
# Power Allocated= 6.20442612256438
# CSI= 0.44442694621189704
# SNR= 28.605062366613755
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298487
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.285356
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.253522
# Model client38 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.215332
#
# Power Allocated= 0
# CSI= 0.10630528637625636
# SNR= 24.73270331967005
# Client: client41
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.155786516882774
# CSI= 0.3031471346525201
# SNR= 31.26355930142449
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.285763
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.249834
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.205045
# Model client42 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.148518
#
# Power Allocated= 7.197121290365513
# CSI= 0.7952960336082722
# SNR= 25.5667087020647
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298649
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.243136
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.154971
# Model client46 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.013219
#
#
# Test set: Average loss for Cluster4 model: 2.3005, Accuracy: 958/10000 (10%)
# ROUND 1
# 0.11778000000001572
# Power Allocated= 5.342621967858911
# CSI= 0.3176838182589903
# SNR= 24.776274703436403
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302625
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.125085
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.563162
# Model client11 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.076512
#
# Power Allocated= 7.207846961426169
# CSI= 0.7796912996476977
# SNR= 26.96472013684797
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307839
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.187255
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.819240
# Model client14 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.322062
#
# Power Allocated= 6.485227856829772
# CSI= 0.4987088466439976
# SNR= 30.323138255413753
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304103
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.275193
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.232176
# Model client15 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.177839
#
# Power Allocated= 2.314982604390001
# CSI= 0.16193222093786197
# SNR= 32.169404484190316
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307060
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.272618
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.219215
# Model client16 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.114611
#
# Power Allocated= 7.31176857263765
# CSI= 0.8484374510333382
# SNR= 32.28020007484866
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.292624
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.248499
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.146175
# Model client17 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.957225
#
# Power Allocated= 7.223786738447949
# CSI= 0.7895033302994222
# SNR= 41.0786055003276
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301963
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.276050
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.233579
# Model client22 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.188637
#
# Power Allocated= 3.666875445958765
# CSI= 0.20731703089204256
# SNR= 45.94326377605648
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305264
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.197522
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.830188
# Model client30 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.248370
#
# Power Allocated= 2.4814940597690427
# CSI= 0.16641948431615938
# SNR= 39.458734935449264
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.294871
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.266889
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.230503
# Model client37 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.197781
#
# Power Allocated= 3.932648552317734
# CSI= 0.21940615451284295
# SNR= 19.8992279562447
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.286621
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.105298
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.752349
# Model client44 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.651398
#
# Power Allocated= 6.970639649444516
# CSI= 0.6579959504919366
# SNR= 21.744198828660373
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.311782
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.199936
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.893661
# Model client45 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.568766
#
# Power Allocated= 7.062397937126022
# CSI= 0.7002762358726271
# SNR= 23.532700318907576
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.309682
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.245897
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.046199
# Model client50 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.647564
#
#
# Test set: Average loss for Cluster1 model: 2.4366, Accuracy: 1488/10000 (15%)
#
# 0.12890000000001642
# Power Allocated= 6.404034440879716
# CSI= 0.7385974623111705
# SNR= 30.044046166152498
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305267
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.240210
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.023582
# Model client2 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.484009
#
# Power Allocated= 6.4330257416135055
# CSI= 0.7547590430938197
# SNR= 27.652557291922168
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298933
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.267689
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.221047
# Model client12 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.143925
#
# Power Allocated= 5.658421378762288
# CSI= 0.4762969576066912
# SNR= 28.176975960156817
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.313218
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.226607
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.906791
# Model client18 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.516488
#
# Power Allocated= 2.8085144825636963
# CSI= 0.20204316481227624
# SNR= 31.184404325748485
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.309559
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.176776
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.846262
# Model client21 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.289052
#
# Power Allocated= 3.149200357101745
# CSI= 0.21697850069389024
# SNR= 31.96566355530362
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307813
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.232271
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.102674
# Model client23 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.767569
#
# Power Allocated= 6.736539638679467
# CSI= 0.979036611548543
# SNR= 30.324781871853
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301398
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.268143
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.230330
# Model client24 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.163927
#
# Power Allocated= 5.4492165380039435
# CSI= 0.4331375592711664
# SNR= 24.549228851143056
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.292940
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.237066
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.135492
# Model client25 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.975517
#
# Power Allocated= 6.104512405404552
# CSI= 0.6047998749558054
# SNR= 25.36606534665926
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297714
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.051057
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.429754
# Model client26 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.963487
#
# Power Allocated= 4.400126257211217
# CSI= 0.29781177052475694
# SNR= 19.713455219599112
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305125
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.241656
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.064578
# Model client36 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.017586
#
# Power Allocated= 6.3739720302044915
# CSI= 0.7225538617436481
# SNR= 26.680710504545665
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301425
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.239471
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.151050
# Model client40 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.004953
#
# Power Allocated= 6.481896187779557
# CSI= 0.7836648430604369
# SNR= 24.804687812485835
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.308362
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.270450
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.183135
# Model client49 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.011806
#
#
# Test set: Average loss for Cluster2 model: 2.5285, Accuracy: 974/10000 (10%)
#
# 0.11716000000001553
# Power Allocated= 6.584227467544903
# CSI= 0.5125290744106856
# SNR= 29.957880861231335
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.287027
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.225420
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.166660
# Model client3 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.072979
#
# Power Allocated= 7.30435827228831
# CSI= 0.8123621898887446
# SNR= 27.54982444872212
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.308800
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.271702
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.232257
# Model client5 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.181146
#
# Power Allocated= 7.294576557140373
# CSI= 0.8059578109315635
# SNR= 34.74673767210371
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305496
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.238056
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.059142
# Model client6 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.632313
#
# Power Allocated= 7.187931779259251
# CSI= 0.742167619567539
# SNR= 27.444065912994617
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304593
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.243444
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.111016
# Model client9 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.682708
#
# Power Allocated= 6.682629964691962
# CSI= 0.5397509498003974
# SNR= 34.6744222985515
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305607
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.236239
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.013252
# Model client28 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.604606
#
# Power Allocated= 0
# CSI= 0.03474053729871218
# SNR= 27.375415893233534
# Client: client29
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.841732177650893
# CSI= 0.27073827323502064
# SNR= 25.899415537480245
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295269
# /home/test/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: RuntimeWarning: invalid value encountered in true_divide
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.267777
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.224356
# Model client31 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.168479
#
# Power Allocated= 0
# CSI= 0.10225011198741485
# SNR= 30.63500327753379
# Client: client33
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.126678708826221
# CSI= 0.7098957275126709
# SNR= 27.529005806652897
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299960
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.201374
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.010259
# Model client34 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.638687
#
# Power Allocated= 5.927652261275342
# CSI= 0.38348204311651324
# SNR= 23.977475843169202
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302075
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.265640
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.213716
# Model client39 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.155724
#
# Power Allocated= 0
# CSI= 0.015495244143939768
# SNR= 23.511083363796878
# Client: client43
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.052522006700542
# CSI= 0.6743932869720568
# SNR= 41.57311731589153
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307372
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.241846
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.140633
# Model client48 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.965729
#
#
# Test set: Average loss for Cluster3 model: 2.3168, Accuracy: 893/10000 (9%)
#
# 0.11828000000001587
# Power Allocated= 7.169108571167056
# CSI= 0.7779642317899512
# SNR= 28.645052716069564
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304131
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.242486
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.133368
# Model client4 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.016160
#
# Power Allocated= 7.121984823620183
# CSI= 0.750452210926046
# SNR= 24.920586236955778
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295977
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.223427
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.088093
# Model client7 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.857697
#
# Power Allocated= 0
# CSI= 0.11447499504437864
# SNR= 28.761380224862293
# Client: client8
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.856034760839213
# CSI= 0.27789511512930953
# SNR= 29.057064155241278
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307190
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.270112
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.156477
# Model client10 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.906152
#
# Power Allocated= 6.82728008147674
# CSI= 0.6145395273344287
# SNR= 23.795893641190798
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.285887
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.216964
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.122167
# Model client20 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.844647
#
# Power Allocated= 6.193605529354793
# CSI= 0.442299942068746
# SNR= 52.911470801015646
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302945
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.272218
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.232195
# Model client27 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.188159
#
# Power Allocated= 7.206196601207019
# CSI= 0.8010778600996379
# SNR= 23.38763871547513
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305015
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.148284
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.548994
# Model client32 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.243518
#
# Power Allocated= 2.0688116811655792
# CSI= 0.15659982860943045
# SNR= 26.42859931038003
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.285053
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.225384
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.077404
# Model client35 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.823881
#
# Power Allocated= 6.20442612256438
# CSI= 0.44442694621189704
# SNR= 28.605062366613755
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300918
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.265230
# ...
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.312829
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.210011
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.092629
# Model client18 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.139331
#
# Power Allocated= 2.8085144825636963
# CSI= 0.20204316481227624
# SNR= 31.184404325748485
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.312869
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.065753
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.581343
# Model client21 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.229107
#
# Power Allocated= 3.149200357101745
# CSI= 0.21697850069389024
# SNR= 31.96566355530362
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305181
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.218317
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.978195
# Model client23 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.601111
#
# Power Allocated= 6.736539638679467
# CSI= 0.979036611548543
# SNR= 30.324781871853
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296038
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.240339
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.159919
# Model client24 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.034162
#
# Power Allocated= 5.4492165380039435
# CSI= 0.4331375592711664
# SNR= 24.549228851143056
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.293551
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.163889
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.914320
# Model client25 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.688763
#
# Power Allocated= 6.104512405404552
# CSI= 0.6047998749558054
# SNR= 25.36606534665926
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302891
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.161249
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.975004
# Model client26 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.687707
#
# Power Allocated= 4.400126257211217
# CSI= 0.29781177052475694
# SNR= 19.713455219599112
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303075
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.055319
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.628368
# Model client36 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.440986
#
# Power Allocated= 6.3739720302044915
# CSI= 0.7225538617436481
# SNR= 26.680710504545665
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298309
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.195674
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.976967
# Model client40 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.584314
#
# Power Allocated= 6.481896187779557
# CSI= 0.7836648430604369
# SNR= 24.804687812485835
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307458
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.244853
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.026705
# Model client49 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.708046
#
#
# Test set: Average loss for Cluster2 model: 2.8274, Accuracy: 974/10000 (10%)
#
# 0.11716000000001553
# Power Allocated= 6.584227467544903
# CSI= 0.5125290744106856
# SNR= 29.957880861231335
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.283872
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.191036
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.066484
# Model client3 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.846437
#
# Power Allocated= 7.30435827228831
# CSI= 0.8123621898887446
# SNR= 27.54982444872212
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.306318
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.258621
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.187621
# Model client5 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.082832
#
# Power Allocated= 7.294576557140373
# CSI= 0.8059578109315635
# SNR= 34.74673767210371
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301333
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.195798
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.929671
# Model client6 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.560530
#
# Power Allocated= 7.187931779259251
# CSI= 0.742167619567539
# SNR= 27.444065912994617
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304650
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.194301
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.897744
# Model client9 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.503715
#
# Power Allocated= 6.682629964691962
# CSI= 0.5397509498003974
# SNR= 34.6744222985515
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.311686
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.225285
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.043079
# Model client28 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.245915
#
# Power Allocated= 0
# CSI= 0.03474053729871218
# SNR= 27.375415893233534
# Client: client29
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.841732177650893
# CSI= 0.27073827323502064
# SNR= 25.899415537480245
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302137
# /home/test/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: RuntimeWarning: invalid value encountered in true_divide
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.250773
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.183549
# Model client31 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.090817
#
# Power Allocated= 0
# CSI= 0.10225011198741485
# SNR= 30.63500327753379
# Client: client33
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.126678708826221
# CSI= 0.7098957275126709
# SNR= 27.529005806652897
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301313
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.143288
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.675922
# Model client34 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.617631
#
# Power Allocated= 5.927652261275342
# CSI= 0.38348204311651324
# SNR= 23.977475843169202
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301298
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.250544
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.185083
# Model client39 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.088394
#
# Power Allocated= 0
# CSI= 0.015495244143939768
# SNR= 23.511083363796878
# Client: client43
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.052522006700542
# CSI= 0.6743932869720568
# SNR= 41.57311731589153
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305095
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.205205
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.940477
# Model client48 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.593944
#
#
# Test set: Average loss for Cluster3 model: 2.3887, Accuracy: 892/10000 (9%)
#
# 0.11828000000001587
# Power Allocated= 7.169108571167056
# CSI= 0.7779642317899512
# SNR= 28.645052716069564
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304915
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.202421
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.949852
# Model client4 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.754929
#
# Power Allocated= 7.121984823620183
# CSI= 0.750452210926046
# SNR= 24.920586236955778
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.291651
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.109375
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.745297
# Model client7 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.854264
#
# Power Allocated= 0
# CSI= 0.11447499504437864
# SNR= 28.761380224862293
# Client: client8
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.856034760839213
# CSI= 0.27789511512930953
# SNR= 29.057064155241278
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.308460
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.235034
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.956642
# Model client10 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.661467
#
# Power Allocated= 6.82728008147674
# CSI= 0.6145395273344287
# SNR= 23.795893641190798
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.281297
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.148837
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.839162
# Model client20 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.543118
#
# Power Allocated= 6.193605529354793
# CSI= 0.442299942068746
# SNR= 52.911470801015646
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299673
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.257471
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.202227
# Model client27 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.131165
#
# Power Allocated= 7.206196601207019
# CSI= 0.8010778600996379
# SNR= 23.38763871547513
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305428
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.084494
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.280627
# Model client32 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.493164
#
# Power Allocated= 2.0688116811655792
# CSI= 0.15659982860943045
# SNR= 26.42859931038003
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.286094
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.158538
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.775935
# Model client35 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.359325
#
# Power Allocated= 6.20442612256438
# CSI= 0.44442694621189704
# SNR= 28.605062366613755
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302036
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.245928
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.141055
# Model client38 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.934392
#
# Power Allocated= 0
# CSI= 0.10630528637625636
# SNR= 24.73270331967005
# Client: client41
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.155786516882774
# CSI= 0.3031471346525201
# SNR= 31.26355930142449
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.289054
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.193562
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.049988
# Model client42 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.787604
#
# Power Allocated= 7.197121290365513
# CSI= 0.7952960336082722
# SNR= 25.5667087020647
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297880
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.158407
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.784386
# Model client46 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.566688
#
#
# Test set: Average loss for Cluster4 model: 2.4542, Accuracy: 958/10000 (10%)
# ROUND 3
# 0.11778000000001572
# Power Allocated= 5.342621967858911
# CSI= 0.3176838182589903
# SNR= 24.776274703436403
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302029
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.174042
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.054801
# Model client11 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.884351
#
# Power Allocated= 7.207846961426169
# CSI= 0.7796912996476977
# SNR= 26.96472013684797
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.310908
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.231850
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.138102
# Model client14 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.062174
#
# Power Allocated= 6.485227856829772
# CSI= 0.4987088466439976
# SNR= 30.323138255413753
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.308934
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.229254
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.056141
# Model client15 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.741918
#
# Power Allocated= 2.314982604390001
# CSI= 0.16193222093786197
# SNR= 32.169404484190316
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307686
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.202276
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.920418
# Model client16 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.723821
#
# Power Allocated= 7.31176857263765
# CSI= 0.8484374510333382
# SNR= 32.28020007484866
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298252
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.175729
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.980221
# Model client17 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.747358
#
# Power Allocated= 7.223786738447949
# CSI= 0.7895033302994222
# SNR= 41.0786055003276
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303446
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.236336
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.146365
# Model client22 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.007047
#
# Power Allocated= 3.666875445958765
# CSI= 0.20731703089204256
# SNR= 45.94326377605648
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296959
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.070139
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.333076
# Model client30 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.978214
#
# Power Allocated= 2.4814940597690427
# CSI= 0.16641948431615938
# SNR= 39.458734935449264
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.293541
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.234870
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.172623
# Model client37 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.096086
#
# Power Allocated= 3.932648552317734
# CSI= 0.21940615451284295
# SNR= 19.8992279562447
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.283614
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.208635
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.100576
# Model client44 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.974676
#
# Power Allocated= 6.970639649444516
# CSI= 0.6579959504919366
# SNR= 21.744198828660373
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.318474
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.179447
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.014761
# Model client45 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.794591
#
# Power Allocated= 7.062397937126022
# CSI= 0.7002762358726271
# SNR= 23.532700318907576
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.317201
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.091276
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.808763
# Model client50 Train Epoch: 4 [0/1216 (0%)]	Loss: 3.041550
#
#
# Test set: Average loss for Cluster1 model: 2.3265, Accuracy: 1009/10000 (10%)
#
# 0.12890000000001642
# Power Allocated= 6.404034440879716
# CSI= 0.7385974623111705
# SNR= 30.044046166152498
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.309869
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.113502
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.197132
# Model client2 Train Epoch: 4 [0/1216 (0%)]	Loss: 2.938915
#
# Power Allocated= 6.4330257416135055
# CSI= 0.7547590430938197
# SNR= 27.652557291922168
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300331
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.207648

# %%
print(final_acc)
