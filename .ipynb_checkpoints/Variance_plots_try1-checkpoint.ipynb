# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import numpy as np
from Dataset import load_dataset, getImage
from utils import averageModels
from utils import averageModelscluster
import random
import math
import matplotlib.pyplot as plt
from ipynb.fs.full.K_clusters import cluster_former
from copy import deepcopy
# from torch import linalg as LA

# %%
P=2 #signal power threshold
#stream = BitStream()
#random.seed(10)
key=[]
for i in range (10000): #generating a random password to activate training (Pilot signal)
    temp=random.randint(0,1)
    key.append(temp)

key1=[0]*len(key)
for i in range (len(key)):   #bpsk modulation
    if(key[i]==1):
        #print("yay")
        key1[i]=-math.sqrt(P)
    else:
        key1[i]=math.sqrt(P)

#print(key)
        
key_np=np.array(key1)

# %%
class Arguments():
    def __init__(self):
        self.images = 10000
        self.clients = 50
        self.rounds = 200
        self.epochs = 3
        self.local_batches = 64
        self.lr = 0.001
        self.C = 1 #fraction of clients used in the round
        self.drop_rate = 0 #fraction of devices in the selected set to be dropped for various reasons
        self.torch_seed = 0 #same weights and parameters whenever the program is run
        self.log_interval = 64
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = True
        self.numclusters=3

args = Arguments()

# %%
#checking if gpu is available
#use_cuda = args.use_cuda and torch.cuda.is_available()
use_cuda=False
device = torch.device("cuda:0" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

hook = sy.TorchHook(torch)
me = hook.local_worker
clients = []

#generating virtual clients
for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})
#print(clients)

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid) #load data

for inx, client in enumerate(clients):  #return actual image set for each client
    trainset_ind_list = list(train_group[inx]) 
    client['trainset'] = getImage(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getImage(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images #useful while taking weighted average

# %%
#load dataset for global model (to compare accuracies)
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.MNIST('./', train=False, download=True, transform=transform)
# global_test_dataset = torch.utils.data.random_split(global_test_dataset, [10000, len(global_test_dataset)-10000])[0]
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
"""class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        #self.quant = torch.quantization.QuantStub()
        self.conv1 = nn.Conv2d(1, 5, 5, 1)
        self.conv2 = nn.Conv2d(5, 10, 5, 1)
        self.fc1 = nn.Linear(4*4*10, 50) #10 iid #50 non iid
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        #x=self.quant(x)
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*10
                   )
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1) """

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x)

# %%
def fedprox(params,global_params):
    global_param=[]
    diff=[]
    ind=0
    for gp in global_params:
        global_param.append(gp)
    for p in params:
    #                 print(p.grad)
        lr=0.001
        mu=0.1
        if(p.grad is None):
            continue
        grad=p.grad.data #batch gradients
        diff.append(p.data.clone()-global_param[ind].data.clone())
        p.data.sub_(lr,(grad+mu*(p.data.clone()-global_param[ind].data.clone())))
        ind+=1
    return(p,diff)

# %%
def ClientUpdate(args, device, client,key_np,key,snr,csi,mu,head):
    gc=False
    diff_=0
    client['model'].train()
    #simulating a wireless channel
    poptim=max((1/mu-1/csi),0)
    #print(mu,csi)
    print("Power Allocated=",poptim)
    print("CSI=",csi)
    
    snr__=10**(snr/10)
    
    absh=csi*poptim/snr__
    x=random.uniform(0,absh)
    #print(x)
    y=math.sqrt(absh*absh-x*x)
    #x=x*100
    #y=y*100
    #x=random.random()
    #y=random.random()
    #snr=10*math.log(poptim/(std*std),10)
    std=math.sqrt(poptim/snr__*absh*absh) #channel noise
    
    #print(x,y)
    h=complex(x,y)
    #std=math.sqrt(abs(h)/csi)
    #snr=poptim/(std*std)
    #print(std)
    print("SNR=",snr)
    #print("csi",abs(h)/(std*std))
    
    
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data

    
    #print(client['model'].conv1.weight.size)
    client['model'].send(client['hook'])
    head['model'].send(client['hook'])
    print("Client:",client['hook'].id)
    
    key_np_received=h*key_np+(np.random.randn(len(key_np))*std*2)
    #print(key_np_received)
    key_np_received=(key_np_received/(h)).real
    
    for o in range (len(key_np_received)):  #demodulation bpsk
        if(key_np_received[o]>=0):
            key_np_received[o]=0
        else:
            key_np_received[o]=1
    
    key_np_received=key_np_received.tolist()
    key_np_received = [int(item) for item in key_np_received]
    #key_np=key_np.tolist()
    
    
    if(sum(np.bitwise_xor(key,key_np_received))/len(key)==0 and poptim>0): #...............................................checking if channel is good enough for transmission by checking BER..................................#
        gc=True #considering the client model for training
        
        for epoch in range(1, args.epochs + 1):
            for batch_idx, (data, target) in enumerate(client['trainset']): 
                data = data.send(client['hook'])
                target = target.send(client['hook'])
                #client['optim'].zero_grad()
                #train model on client
                data, target = data.to(device), target.to(device) #send data to cpu/gpu (data is stored locally)
                output = client['model'](data)
                loss = F.nll_loss(output, target)
                loss.backward()
                #client['optim'].step()
                params=client['model'].parameters()
                gp=head['model'].parameters()
                params,diff=fedprox(params,gp) 
                for k in range(len(diff)):
#                     print(diff[k].get())
                    npa=diff[k].get().cpu().detach().numpy()
#                     print(npa.shape)
#                     diff_=diff_+torch.norm(diff[k].get())
                    diff_=diff_+np.linalg.norm(npa)
                    
                
                
                if batch_idx % args.log_interval == 0:
                    loss = loss.get() 
                    print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                        client['hook'].id,
                        epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                        100. * batch_idx / len(client['trainset']), loss))
#         print(diff_)
    else:
        print("Poor Channel, client not taken for averaging in this round")
            
                    
    client['model'].get()
    head['model'].get()
    # print()
         #CHANGE
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
    #CHANGE ENDS
    print()
    return (gc,diff_)

# %%
def test(args, model, device, test_loader, name,fed_round):
    model.eval()    #no need to train the model while testing
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            if(use_cuda and fed_round==0):
                data,target=data.cuda(),target.cuda()
                #model.cuda()
            else:
                data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    return([100. * correct / len(test_loader.dataset),test_loss])

# %%
torch.manual_seed(args.torch_seed)

# %%
def distort(neighbours,snrs):
    ind=0
    poptim=2
    csi=random.random()
    distorted_models=[]
    for client in neighbours:
        snr=snrs[ind]
        ind+=1
        snr__=10**(snr/10)
        absh=csi*poptim/snr__
        x=random.uniform(0,absh)
        y=math.sqrt(absh*absh-x*x)
        std=math.sqrt(poptim/snr__*absh*absh) #channel noise
        h=complex(x,y)
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
        
        distorted_models.append(client)
    return(distorted_models)

# %%
def decentralized(clients,snrs,weights):
    big_daddy_of_distorted_models=[]
    for client in clients:
        distorted_models=[]
        snr_list=[]
        for snr in snrs:
            if(client['hook'].id in snr):
                snr_list.append(snr[2])
        neighbours_c = [x for x in clients if x != client]
        neighbours={}
        jjj=[jkl for jkl in range(len(neighbours_c))]
        
        dictionary = dict(zip(jjj, neighbours_c))
        #for jjj in range(len(neighbours_c)):
        #   neighbours[jjj].append(neighbours_c[jjj])
        distorted_models=distort(neighbours,snr_list)
        distorted_models.append(client)
        big_daddy_of_distorted_models.append(distorted_models)
    
    
    weight_final1=[]
    for oho in big_daddy_of_distorted_models:
        weight_final=[]
        for comeon in oho:
            for w in weights:
                if(comeon['hook'].id==w[0]):
                    weight_final.append(w[1])
        weight_final1.append(weight_final)
    
    final_heads=[]
    nets=[]
    ind=0
    for client in clients:
        for oof in big_daddy_of_distorted_models:
            if(client==oof[0]):
#                 print(client)
#                 print("shut up")
#                 print(distorted_models)
#                 print("shut up")
#                 print(weight_final1)
                
                overall=Net()
                overall=averageModelscluster(overall,distorted_models,weight_final1[ind])
                client['model'].load_state_dict(overall.state_dict())
                ind+=1
                final_heads.append(client)
                nets.append(overall)
    
    return(final_heads,nets)

# %%
discrepancy_=[]
for client in clients: #give the model and optimizer to every client
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    #client['model'] = torch.quantization.quantize_dynamic(
    #client['model'],  # the original model
    #{torch.nn.Linear},  # a set of layers to dynamically quantize
    #dtype=torch.fp)  # the target dtype for quantized weights
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)

final_acc=[]
final_loss=[]
clor = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(args.numclusters)] 
dis1=[]
dis2=[]
dis3=[]
for fed_round in range(args.rounds):
    overall=Net()
    if(fed_round==0): #fed_round==0
        arranged_clusters,head_snr_list=cluster_former(args.numclusters,args.clients)
        temp=deepcopy(arranged_clusters)
        temp2=deepcopy(head_snr_list)
    else:
        #print(temp)
        arranged_clusters=deepcopy(temp)
        head_snr_list=deepcopy(temp2)
#     print(arranged_clusters)
    
    no=1
    heads_list=[]
    weights=[]
    weight_head_list=[]
    head_acc=[]
    head_loss=[]
    for cluster in arranged_clusters:
        
        head=cluster['Cluster Head']
        members=cluster['Members']
        snrs=cluster['SNR']
        csis=cluster['CSI']
        weights.append(sum(snrs))
        weight_head_list.append([head,sum(snrs)])
        new_members=[]
        
        for ij in members:
        #print(ij)
            cl_no=int(ij[6:])
            new_members.append(clients[cl_no-1])
#         print(head)
        head=clients[int(head[6:])-1]
        cluster['Members']=new_members
#         print(head)

        smallmu1=0
        gsmall1=3.402823466E+38 
        
        #water filling algorithm
        mu=1e-15
        while(mu<=1):
            g1=0
            pn1=0
            for jj in csis:
                pn=max(1/mu-1/jj,0)
                g1+=math.log(1+pn*jj) #capacity of a channel (shannon's law)
                pn1+=pn
            g=g1-mu*(pn1-P*30)
            if(g<gsmall1):
                smallmu1=mu
                gsmall1=g
            mu+=0.00002
        
        print(smallmu1)
        good_mem=[]
#         print(len(snrs))
#         print(len(csis))
#         print(len(new_members))
        index=0
        discrepancy=0
        for client in new_members:
            goodchannel,diff_=ClientUpdate(args, device, client,key_np,key,snrs[index],csis[index],smallmu1,head)
            index+=1
            if(goodchannel):
                good_mem.append(client)
                discrepancy+=(diff_/len(members))
        
        discrepancy_.append(discrepancy)
        print(discrepancy_)
        head['model']=averageModels(head['model'], good_mem)
        arr=test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)
        ac=arr[0]#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[0]
        no+=1
        heads_list.append(head)
        head_acc.append(ac)
        head_loss.append(arr[1])#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[1])
    
    final_acc.append(head_acc)
    final_loss.append(head_loss)
    fig,ax=plt.subplots()
    
    #ax.plot([i for i in range(fed_round)],head_acc[0])
    for jj in range(0,args.numclusters):
        
        ax.plot([i for i in range(len(final_acc))],[final_acc[j][jj] for j in range(len(final_acc))], color = clor[jj])
        
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][0] for j in range(len(final_acc))], color ="red")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][1] for j in range(len(final_acc))],color ="blue")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][2] for j in range(len(final_acc))],color ="green")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][3] for j in range(len(final_acc))],color ="black")
    #ax.plot([i for i in range(len(final_acc))],head_acc[1], fed_round, color ="blue")
    #ax.plot([i for i in range(len(final_acc))],head_acc[2], fed_round, color ="green")
    #ax.plot([i for i in range(len(final_acc))],head_acc[3], fed_round, color ="black")
    
    
    plt.show()
    
    fig1,ax1=plt.subplots()
    sumx1=0
    sumx2=0
    sumx3=0
#     for i in range(len(discrepancy_)):
#         print(discrepancy_[i].item())
    print("ddfgg")
    print(discrepancy_)
    sumx1=sumx1+discrepancy_[-1].item()
    sumx2=sumx2+discrepancy_[-2].item()
    sumx3=sumx3+discrepancy_[-3].item()
#     sumx=sumx/(3)
    dis1.append(sumx1)
    dis2.append(sumx2)
    dis3.append(sumx3)
#     print(dis)
    plt.plot([i for i in range(len(dis1))],dis1)
    plt.show()
    plt.plot([i for i in range(len(dis2))],dis2)
    plt.show()
    plt.plot([i for i in range(len(dis2))],dis3)
    plt.show()
# #     print(discrepancy_.item())
#     plt.show()
    
    weightsum=sum(weights)
    
    weights[:] = [x / weightsum for x in weights]
    for aah in range(len(weight_head_list)):
        weight_head_list[aah][1]=weights[aah]
    final_heads,nets=decentralized(heads_list,head_snr_list,weight_head_list)
    
    for head in range(len(final_heads)):
        for cluster in arranged_clusters:
            head1=cluster['Cluster Head']
            if(head1==final_heads[head]['hook'].id):
                for mem in cluster['Members']:
                    mem['model'].load_state_dict(nets[head].state_dict())
    print("ROUND",fed_round)
# Out:
# 0.15960000000000452
# Power Allocated= 2.828213613164787
# CSI= 0.29091327606271256
# SNR= 22.9028266611235
# Client: client1
# Model client1 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.316234
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/generic/frameworks/hook/hook.py:165: UserWarning: This overload of sub_ is deprecated:
# 	sub_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	sub_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   response = method(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client1 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.269771
# Model client1 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.250352
#
# Power Allocated= 0
# CSI= 0.07998701214299608
# SNR= 20.335637986201103
# Client: client2
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.213785655375546
# CSI= 0.9506801357975921
# SNR= 23.375942852787112
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.320044
# /home/test/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: RuntimeWarning: invalid value encountered in true_divide
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.316737
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.270516
#
# Power Allocated= 1.9085541040478713
# CSI= 0.22950992448353102
# SNR= 22.521838676521156
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295193
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.303448
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.187388
#
# Power Allocated= 4.856145197911582
# CSI= 0.7094618991389634
# SNR= 19.292608980737604
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.346832
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.337495
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272650
#
# Power Allocated= 3.9754217274399144
# CSI= 0.43663499794087857
# SNR= 31.64509463595151
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.310373
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292429
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.248419
#
# Power Allocated= 4.940666221089445
# CSI= 0.7547181548974434
# SNR= 29.10110288614316
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.331951
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.321662
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.275730
#
# Power Allocated= 4.6905628021981345
# CSI= 0.6348797776043285
# SNR= 36.73901901983204
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.311508
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299922
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.281377
#
# Power Allocated= 5.264812367241354
# CSI= 0.9991489317746215
# SNR= 32.78664183004505
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.323442
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301309
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.279025
#
# Power Allocated= 4.709288208818107
# CSI= 0.642518280357053
# SNR= 27.062371772082365
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.293723
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.330013
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.258170
#
# Power Allocated= 0
# CSI= 0.06744217356567683
# SNR= 25.433692024579706
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.164805089527919
# CSI= 0.9083814872025968
# SNR= 27.281383202970318
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304681
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297258
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.253531
#
# Power Allocated= 4.380181429229497
# CSI= 0.5303681563706312
# SNR= 26.722193571241426
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.322907
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.306500
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.267078
#
# Power Allocated= 4.0819431284629815
# CSI= 0.4579339509830135
# SNR= 22.4784222476229
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.314662
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304241
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.277850
#
# Power Allocated= 3.262067062776137
# CSI= 0.33293413447190445
# SNR= 26.13373161704844
# Client: client47
# Model client47 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.326699
# Model client47 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.320467
# Model client47 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.292416
#
# Power Allocated= 4.720940106968302
# CSI= 0.6473648143031795
# SNR= 31.66781445295055
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.337700
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291450
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.259979
#
# [113.65000171843371]
#
# Test set: Average loss for Cluster1 model: 1.9509, Accuracy: 3420/10000 (34%)
#
# 0.16898000000000088
# Power Allocated= 4.714886003157334
# CSI= 0.8312730931937659
# SNR= 22.86842514561434
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.321556
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293751
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.279620
#
# Power Allocated= 3.8830110104713462
# CSI= 0.4914369346934515
# SNR= 25.610642152913385
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.278928
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.265153
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.256979
#
# Power Allocated= 3.5102488293551453
# CSI= 0.41534944259912143
# SNR= 26.988736149159845
# Client: client13
# Model client13 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298592
# Model client13 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299999
# Model client13 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.249677
#
# Power Allocated= 4.86524190207757
# CSI= 0.9500120749155678
# SNR= 27.408230131714667
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.347231
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.312167
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.267968
#
# Power Allocated= 4.604137131842531
# CSI= 0.7611954901284446
# SNR= 24.08697207104706
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.376224
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.272974
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.219888
#
# Power Allocated= 4.738812808159199
# CSI= 0.8481423988710163
# SNR= 28.903835309507855
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.322883
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.274290
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.305176
#
# Power Allocated= 4.6779567635489485
# CSI= 0.8065144831539093
# SNR= 45.55021475846493
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.339370
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294670
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.260777
#
# Power Allocated= 4.034175327349524
# CSI= 0.5308743870367285
# SNR= 32.430904356794784
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.337718
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.309195
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285959
#
# Power Allocated= 2.2297508386263254
# CSI= 0.2711416415963136
# SNR= 26.135258053556782
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.357787
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.310551
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265679
#
# Power Allocated= 4.65185488593124
# CSI= 0.7898861611908274
# SNR= 28.783023714291073
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307258
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.317486
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.278788
#
# Power Allocated= 4.757169760438412
# CSI= 0.8615562345749989
# SNR= 27.756570945423768
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.325340
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.313345
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.246871
#
# Power Allocated= 4.343324869589925
# CSI= 0.6351080493794458
# SNR= 36.38954672090302
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.309081
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.258239
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272283
#
# Power Allocated= 3.476645152714041
# CSI= 0.4096320974847705
# SNR= 24.125746030096195
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303995
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.322737
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.240869
#
# Power Allocated= 2.2665903776060214
# CSI= 0.2738773291322012
# SNR= 25.633239073421198
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.268427
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.290806
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.273131
#
# Power Allocated= 3.244483384411401
# CSI= 0.3740587675131769
# SNR= 27.980990172967864
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.333629
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.310803
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.244142
#
# [113.65000171843371, 123.37897927569321]
#
# Test set: Average loss for Cluster2 model: 1.8710, Accuracy: 2762/10000 (28%)
#
# 0.15020000000000816
# Power Allocated= 0.44703066457726326
# CSI= 0.16101091801629897
# SNR= 27.74690215351428
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303832
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.282816
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.221595
#
# Power Allocated= 3.0429712905866304
# CSI= 0.276639075763515
# SNR= 32.09597946751814
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.318885
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.317468
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.293564
#
# Power Allocated= 5.596773442770485
# CSI= 0.9424927039373964
# SNR= 24.518238402129136
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.351390
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.317063
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.261996
#
# Power Allocated= 0.22308168608685008
# CSI= 0.15540720903364424
# SNR= 23.622966282333916
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.318838
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.257200
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.241162
#
# Power Allocated= 5.637556787377949
# CSI= 0.9801684223983467
# SNR= 18.882098749463196
# Client: client19
# Model client19 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.355108
# Model client19 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.263887
# Model client19 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.237186
#
# Power Allocated= 5.385930925535348
# CSI= 0.7862508698405832
# SNR= 24.472895856194537
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.268889
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304822
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.258808
#
# Power Allocated= 0
# CSI= 0.1342530883234464
# SNR= 22.717781960147057
# Client: client22
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.910534252626482
# CSI= 0.5723261877994664
# SNR= 20.4034906861921
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.357430
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.309654
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.233912
#
# Power Allocated= 0
# CSI= 0.10254459754258549
# SNR= 33.7435487546005
# Client: client27
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.746942763369986
# CSI= 0.5233281776349189
# SNR= 28.130662492427454
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299999
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300417
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.244556
#
# Power Allocated= 4.818621946511167
# CSI= 0.5437242170791938
# SNR= 30.633693621329783
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.306238
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.271571
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.281753
#
# Power Allocated= 4.3961567579409095
# CSI= 0.44215841549533585
# SNR= 30.790478411898192
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.332650
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.277244
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.283321
#
# Power Allocated= 5.616794075079512
# CSI= 0.9606189102243098
# SNR= 27.417067134161865
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.310757
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286178
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.263959
#
# Power Allocated= 5.410351997290966
# CSI= 0.8016432940030768
# SNR= 30.97546044236309
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.312796
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302559
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.262589
#
# Power Allocated= 5.60782211399334
# CSI= 0.9524104318834392
# SNR= 26.401684752314715
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.331905
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.324783
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.280525
#
# Power Allocated= 4.156263082833197
# CSI= 0.39975590408565065
# SNR= 21.327714229539392
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.341319
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.328283
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.191131
#
# [113.65000171843371, 123.37897927569321, 118.80178671012266]
#
# Test set: Average loss for Cluster3 model: 1.9104, Accuracy: 3215/10000 (32%)
# ddfgg
# [113.65000171843371, 123.37897927569321, 118.80178671012266]
# ROUND 0
# 0.15960000000000452
# Power Allocated= 2.828213613164787
# CSI= 0.29091327606271256
# SNR= 22.9028266611235
# Client: client1
# Model client1 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.285139
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client1 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.272599
# Model client1 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.259413
#
# Power Allocated= 0
# CSI= 0.07998701214299608
# SNR= 20.335637986201103
# Client: client2
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.213785655375546
# CSI= 0.9506801357975921
# SNR= 23.375942852787112
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.290378
# /home/test/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: RuntimeWarning: invalid value encountered in true_divide
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.279605
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.236016
#
# Power Allocated= 1.9085541040478713
# CSI= 0.22950992448353102
# SNR= 22.521838676521156
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.290696
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.269655
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.199942
#
# Power Allocated= 4.856145197911582
# CSI= 0.7094618991389634
# SNR= 19.292608980737604
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295589
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289037
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.270893
#
# Power Allocated= 3.9754217274399144
# CSI= 0.43663499794087857
# SNR= 31.64509463595151
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297836
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.285846
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.233269
#
# Power Allocated= 4.940666221089445
# CSI= 0.7547181548974434
# SNR= 29.10110288614316
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302303
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.283385
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.253960
#
# Power Allocated= 4.6905628021981345
# CSI= 0.6348797776043285
# SNR= 36.73901901983204
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296735
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.287240
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.259155
#
# Power Allocated= 5.264812367241354
# CSI= 0.9991489317746215
# SNR= 32.78664183004505
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.291191
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.279285
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.252077
#
# Power Allocated= 4.709288208818107
# CSI= 0.642518280357053
# SNR= 27.062371772082365
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.294665
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289919
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.264642
#
# Power Allocated= 0
# CSI= 0.06744217356567683
# SNR= 25.433692024579706
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.164805089527919
# CSI= 0.9083814872025968
# SNR= 27.281383202970318
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307645
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286841
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.222448
#
# Power Allocated= 4.380181429229497
# CSI= 0.5303681563706312
# SNR= 26.722193571241426
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.292461
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288350
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.240516
#
# Power Allocated= 4.0819431284629815
# CSI= 0.4579339509830135
# SNR= 22.4784222476229
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300840
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286011
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.257417
#
# Power Allocated= 3.262067062776137
# CSI= 0.33293413447190445
# SNR= 26.13373161704844
# Client: client47
# Model client47 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.288919
# Model client47 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.272774
# Model client47 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.212552
#
# Power Allocated= 4.720940106968302
# CSI= 0.6473648143031795
# SNR= 31.66781445295055
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.289417
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.275316
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.227263
#
# [113.65000171843371, 123.37897927569321, 118.80178671012266, 115.03641102200345]
#
# Test set: Average loss for Cluster1 model: 1.8586, Accuracy: 3174/10000 (32%)
#
# 0.16898000000000088
# Power Allocated= 4.714886003157334
# CSI= 0.8312730931937659
# SNR= 22.86842514561434
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299180
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.280935
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.216255
#
# Power Allocated= 3.8830110104713462
# CSI= 0.4914369346934515
# SNR= 25.610642152913385
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.285905
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.282066
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.205647
#
# Power Allocated= 3.5102488293551453
# CSI= 0.41534944259912143
# SNR= 26.988736149159845
# Client: client13
# Model client13 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304940
# Model client13 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.271631
# Model client13 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.199565
#
# Power Allocated= 4.86524190207757
# CSI= 0.9500120749155678
# SNR= 27.408230131714667
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300830
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.287451
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.257190
#
# Power Allocated= 4.604137131842531
# CSI= 0.7611954901284446
# SNR= 24.08697207104706
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.289888
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.279964
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.270186
#
# Power Allocated= 4.738812808159199
# CSI= 0.8481423988710163
# SNR= 28.903835309507855
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298444
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.281627
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.227418
#
# Power Allocated= 4.6779567635489485
# CSI= 0.8065144831539093
# SNR= 45.55021475846493
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.293247
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288099
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.250829
#
# Power Allocated= 4.034175327349524
# CSI= 0.5308743870367285
# SNR= 32.430904356794784
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.292602
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.275906
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.246481
#
# Power Allocated= 2.2297508386263254
# CSI= 0.2711416415963136
# SNR= 26.135258053556782
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296845
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291700
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.224362
#
# Power Allocated= 4.65185488593124
# CSI= 0.7898861611908274
# SNR= 28.783023714291073
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296681
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.284674
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.261893
#
# Power Allocated= 4.757169760438412
# CSI= 0.8615562345749989
# SNR= 27.756570945423768
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296355
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286443
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265871
#
# Power Allocated= 4.343324869589925
# CSI= 0.6351080493794458
# SNR= 36.38954672090302
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.291996
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.276709
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.230273
#
# Power Allocated= 3.476645152714041
# CSI= 0.4096320974847705
# SNR= 24.125746030096195
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301033
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.276574
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.223777
#
# Power Allocated= 2.2665903776060214
# CSI= 0.2738773291322012
# SNR= 25.633239073421198
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299984
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.278688
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.268699
#
# Power Allocated= 3.244483384411401
# CSI= 0.3740587675131769
# SNR= 27.980990172967864
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.293961
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.283534
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.247293
#
# [113.65000171843371, 123.37897927569321, 118.80178671012266, 115.03641102200345, 117.58687796801871]
#
# Test set: Average loss for Cluster2 model: 1.9846, Accuracy: 2903/10000 (29%)
#
# 0.15020000000000816
# Power Allocated= 0.44703066457726326
# CSI= 0.16101091801629897
# SNR= 27.74690215351428
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307409
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.284813
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.236536
#
# Power Allocated= 3.0429712905866304
# CSI= 0.276639075763515
# SNR= 32.09597946751814
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304924
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.273377
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.239616
#
# Power Allocated= 5.596773442770485
# CSI= 0.9424927039373964
# SNR= 24.518238402129136
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302215
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.265168
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.238139
#
# Power Allocated= 0.22308168608685008
# CSI= 0.15540720903364424
# SNR= 23.622966282333916
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299502
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.280718
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.257339
#
# Power Allocated= 5.637556787377949
# CSI= 0.9801684223983467
# SNR= 18.882098749463196
# Client: client19
# Model client19 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296314
# Model client19 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289946
# Model client19 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.236176
#
# Power Allocated= 5.385930925535348
# CSI= 0.7862508698405832
# SNR= 24.472895856194537
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.289926
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286521
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.260176
#
# Power Allocated= 0
# CSI= 0.1342530883234464
# SNR= 22.717781960147057
# Client: client22
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.910534252626482
# CSI= 0.5723261877994664
# SNR= 20.4034906861921
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300161
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.290905
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.273167
#
# Power Allocated= 0
# CSI= 0.10254459754258549
# SNR= 33.7435487546005
# Client: client27
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.746942763369986
# CSI= 0.5233281776349189
# SNR= 28.130662492427454
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301726
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.276388
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.237051
#
# Power Allocated= 4.818621946511167
# CSI= 0.5437242170791938
# SNR= 30.633693621329783
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.290375
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.268437
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.231128
#
# Power Allocated= 4.3961567579409095
# CSI= 0.44215841549533585
# SNR= 30.790478411898192
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.290725
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.275780
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.263659
#
# Power Allocated= 5.616794075079512
# CSI= 0.9606189102243098
# SNR= 27.417067134161865
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.284577
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.284760
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.247298
#
# Power Allocated= 5.410351997290966
# CSI= 0.8016432940030768
# SNR= 30.97546044236309
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299067
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.278151
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.240180
#
# Power Allocated= 5.60782211399334
# CSI= 0.9524104318834392
# SNR= 26.401684752314715
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297117
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286260
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.262460
#
# Power Allocated= 4.156263082833197
# CSI= 0.39975590408565065
# SNR= 21.327714229539392
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296274
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.287759
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.243996
#
# [113.65000171843371, 123.37897927569321, 118.80178671012266, 115.03641102200345, 117.58687796801871, 115.58573674470244]
#
# Test set: Average loss for Cluster3 model: 1.9743, Accuracy: 2552/10000 (26%)
# ddfgg
# [113.65000171843371, 123.37897927569321, 118.80178671012266, 115.03641102200345, 117.58687796801871, 115.58573674470244]
# ROUND 1
# 0.15960000000000452
# Power Allocated= 2.828213613164787
# CSI= 0.29091327606271256
# SNR= 22.9028266611235
# Client: client1
# Model client1 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.281155
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client1 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.202352
# Model client1 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.958042
#
# Power Allocated= 0
# CSI= 0.07998701214299608
# SNR= 20.335637986201103
# Client: client2
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.213785655375546
# CSI= 0.9506801357975921
# SNR= 23.375942852787112
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.287759
# /home/test/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: RuntimeWarning: invalid value encountered in true_divide
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.221648
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.890185
#
# Power Allocated= 1.9085541040478713
# CSI= 0.22950992448353102
# SNR= 22.521838676521156
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.279090
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.201084
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.888331
#
# Power Allocated= 4.856145197911582
# CSI= 0.7094618991389634
# SNR= 19.292608980737604
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.287941
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.254778
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.146079
#
# Power Allocated= 3.9754217274399144
# CSI= 0.43663499794087857
# SNR= 31.64509463595151
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.291488
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.229769
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.001402
#
# Power Allocated= 4.940666221089445
# CSI= 0.7547181548974434
# SNR= 29.10110288614316
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.280654
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.261170
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.162229
#
# Power Allocated= 4.6905628021981345
# CSI= 0.6348797776043285
# SNR= 36.73901901983204
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295554
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.242694
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.080233
#
# Power Allocated= 5.264812367241354
# CSI= 0.9991489317746215
# SNR= 32.78664183004505
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.279454
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.228113
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.075204
#
# Power Allocated= 4.709288208818107
# CSI= 0.642518280357053
# SNR= 27.062371772082365
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.285845
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.250864
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.160733
#
# Power Allocated= 0
# CSI= 0.06744217356567683
# SNR= 25.433692024579706
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.164805089527919
# CSI= 0.9083814872025968
# SNR= 27.281383202970318
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.275993
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.212976
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.852683
#
# Power Allocated= 4.380181429229497
# CSI= 0.5303681563706312
# SNR= 26.722193571241426
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.289549
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.230226
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.139854
#
# Power Allocated= 4.0819431284629815
# CSI= 0.4579339509830135
# SNR= 22.4784222476229
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.286414
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.219887
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.053388
#
# Power Allocated= 3.262067062776137
# CSI= 0.33293413447190445
# SNR= 26.13373161704844
# Client: client47
# Model client47 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.284782
# Model client47 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.242022
# Model client47 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.087651
#
# Power Allocated= 4.720940106968302
# CSI= 0.6473648143031795
# SNR= 31.66781445295055
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.291177
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.209879
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.025813
#
# [113.65000171843371, 123.37897927569321, 118.80178671012266, 115.03641102200345, 117.58687796801871, 115.58573674470244, 158.77422386450598]
#
# Test set: Average loss for Cluster1 model: 1.1562, Accuracy: 6665/10000 (67%)
#
# 0.16898000000000088
# Power Allocated= 4.714886003157334
# CSI= 0.8312730931937659
# SNR= 22.86842514561434
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.282255
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.230132
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.992179
#
# Power Allocated= 3.8830110104713462
# CSI= 0.4914369346934515
# SNR= 25.610642152913385
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.281706
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.180410
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.966938
#
# Power Allocated= 3.5102488293551453
# CSI= 0.41534944259912143
# SNR= 26.988736149159845
# Client: client13
# Model client13 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.287435
# Model client13 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.183343
# Model client13 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.975149
#
# Power Allocated= 4.86524190207757
# CSI= 0.9500120749155678
# SNR= 27.408230131714667
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.291885
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.250195
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.245137
#
# Power Allocated= 4.604137131842531
# CSI= 0.7611954901284446
# SNR= 24.08697207104706
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.286323
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.242535
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.972779
#
# Power Allocated= 4.738812808159199
# CSI= 0.8481423988710163
# SNR= 28.903835309507855
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.293265
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.218311
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.200393
#
# Power Allocated= 4.6779567635489485
# CSI= 0.8065144831539093
# SNR= 45.55021475846493
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.290314
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.227545
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.078864
#
# Power Allocated= 4.034175327349524
# CSI= 0.5308743870367285
# SNR= 32.430904356794784
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.289456
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.254307
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.948695
#
# Power Allocated= 2.2297508386263254
# CSI= 0.2711416415963136
# SNR= 26.135258053556782
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.289531
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.241473
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.047314
#
# Power Allocated= 4.65185488593124
# CSI= 0.7898861611908274
# SNR= 28.783023714291073
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.290651
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.227222
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.058333
#
# Power Allocated= 4.757169760438412
# CSI= 0.8615562345749989
# SNR= 27.756570945423768
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.286375
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.262452
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.091381
#
# Power Allocated= 4.343324869589925
# CSI= 0.6351080493794458
# SNR= 36.38954672090302
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.291085
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.210696
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.012276
#
# Power Allocated= 3.476645152714041
# CSI= 0.4096320974847705
# SNR= 24.125746030096195
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.291002
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.201449
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.003309
#
# Power Allocated= 2.2665903776060214
# CSI= 0.2738773291322012
# SNR= 25.633239073421198
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.285964
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.225552
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.059637
#
# Power Allocated= 3.244483384411401
# CSI= 0.3740587675131769
# SNR= 27.980990172967864
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.289018
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.254711
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.958154
#
# [113.65000171843371, 123.37897927569321, 118.80178671012266, 115.03641102200345, 117.58687796801871, 115.58573674470244, 158.77422386450598, 166.9991005227901]
#
# Test set: Average loss for Cluster2 model: 1.5342, Accuracy: 6618/10000 (66%)
#
# 0.15020000000000816
# Power Allocated= 0.44703066457726326
# CSI= 0.16101091801629897
# SNR= 27.74690215351428
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.291374
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.204587
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.159422
#
# Power Allocated= 3.0429712905866304
# CSI= 0.276639075763515
# SNR= 32.09597946751814
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.286931
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.244552
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.071947
#
# Power Allocated= 5.596773442770485
# CSI= 0.9424927039373964
# SNR= 24.518238402129136
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.282768
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.210039
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.068364
#
# Power Allocated= 0.22308168608685008
# CSI= 0.15540720903364424
# SNR= 23.622966282333916
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300793
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.240763
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.056361
#
# Power Allocated= 5.637556787377949
# CSI= 0.9801684223983467
# SNR= 18.882098749463196
# Client: client19
# Model client19 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.277466
# Model client19 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.252220
# Model client19 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.155443
#
# Power Allocated= 5.385930925535348
# CSI= 0.7862508698405832
# SNR= 24.472895856194537
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.291242
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.217000
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.014169
#
# Power Allocated= 0
# CSI= 0.1342530883234464
# SNR= 22.717781960147057
# Client: client22
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.910534252626482
# CSI= 0.5723261877994664
# SNR= 20.4034906861921
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.283164
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.250608
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.089896
#
# Power Allocated= 0
# CSI= 0.10254459754258549
# SNR= 33.7435487546005
# Client: client27
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.746942763369986
# CSI= 0.5233281776349189
# SNR= 28.130662492427454
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.291577
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.223812
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.032490
#
# Power Allocated= 4.818621946511167
# CSI= 0.5437242170791938
# SNR= 30.633693621329783
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.284559
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.183176
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.851978
#
# Power Allocated= 4.3961567579409095
# CSI= 0.44215841549533585
# SNR= 30.790478411898192
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295390
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.225369
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.916211
#
# Power Allocated= 5.616794075079512
# CSI= 0.9606189102243098
# SNR= 27.417067134161865
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.286053
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.202244
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.144746
#
# Power Allocated= 5.410351997290966
# CSI= 0.8016432940030768
# SNR= 30.97546044236309
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.289408
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.228710
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.140765
#
# Power Allocated= 5.60782211399334
# CSI= 0.9524104318834392
# SNR= 26.401684752314715
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.280935
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.225381
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.153710
#
# Power Allocated= 4.156263082833197
# CSI= 0.39975590408565065
# SNR= 21.327714229539392
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.288736
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.156661
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.951254
#
# [113.65000171843371, 123.37897927569321, 118.80178671012266, 115.03641102200345, 117.58687796801871, 115.58573674470244, 158.77422386450598, 166.9991005227901, 170.70894162876357]
#
# Test set: Average loss for Cluster3 model: 1.2286, Accuracy: 6735/10000 (67%)
# ddfgg
# [113.65000171843371, 123.37897927569321, 118.80178671012266, 115.03641102200345, 117.58687796801871, 115.58573674470244, 158.77422386450598, 166.9991005227901, 170.70894162876357]
# ROUND 2
# 0.15960000000000452
# Power Allocated= 2.828213613164787
# CSI= 0.29091327606271256
# SNR= 22.9028266611235
# Client: client1
# Model client1 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.182862
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client1 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.895605
# Model client1 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.372024
#
# Power Allocated= 0
# CSI= 0.07998701214299608
# SNR= 20.335637986201103
# Client: client2
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.213785655375546
# CSI= 0.9506801357975921
# SNR= 23.375942852787112
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.181273
# /home/test/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: RuntimeWarning: invalid value encountered in true_divide
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.702786
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.249476
#
# Power Allocated= 1.9085541040478713
# CSI= 0.22950992448353102
# SNR= 22.521838676521156
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.193452
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.803335
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.287538
#
# Power Allocated= 4.856145197911582
# CSI= 0.7094618991389634
# SNR= 19.292608980737604
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.178007
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.724134
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.576514
#
# Power Allocated= 3.9754217274399144
# CSI= 0.43663499794087857
# SNR= 31.64509463595151
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.163540
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.797108
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.390468
#
# Power Allocated= 4.940666221089445
# CSI= 0.7547181548974434
# SNR= 29.10110288614316
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.205216
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.922934
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.423900
#
# Power Allocated= 4.6905628021981345
# CSI= 0.6348797776043285
# SNR= 36.73901901983204
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.185776
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.892667
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.453961
#
# Power Allocated= 5.264812367241354
# CSI= 0.9991489317746215
# SNR= 32.78664183004505
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.181704
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.556177
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.922269
#
# Power Allocated= 4.709288208818107
# CSI= 0.642518280357053
# SNR= 27.062371772082365
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.185378
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.784463
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.426074
#
# ...
#
# Power Allocated= 5.213785655375546
# CSI= 0.9506801357975921
# SNR= 23.375942852787112
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.383079
# /home/test/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: RuntimeWarning: invalid value encountered in true_divide
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.175108
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.184057
#
# Power Allocated= 1.9085541040478713
# CSI= 0.22950992448353102
# SNR= 22.521838676521156
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.597136
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.178293
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.273257
#
# Power Allocated= 4.856145197911582
# CSI= 0.7094618991389634
# SNR= 19.292608980737604
# Client: client10
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.9754217274399144
# CSI= 0.43663499794087857
# SNR= 31.64509463595151
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.348097
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.127016
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.133318
#
# Power Allocated= 4.940666221089445
# CSI= 0.7547181548974434
# SNR= 29.10110288614316
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.250727
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.141066
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.245419
#
# Power Allocated= 4.6905628021981345
# CSI= 0.6348797776043285
# SNR= 36.73901901983204
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.215228
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.089534
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.077025
#
# Power Allocated= 5.264812367241354
# CSI= 0.9991489317746215
# SNR= 32.78664183004505
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.291289
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.150472
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.145848
#
# Power Allocated= 4.709288208818107
# CSI= 0.642518280357053
# SNR= 27.062371772082365
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.224550
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.267973
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.102252
#
# Power Allocated= 0
# CSI= 0.06744217356567683
# SNR= 25.433692024579706
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.164805089527919
# CSI= 0.9083814872025968
# SNR= 27.281383202970318
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.306614
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.224969
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.158311
#
# Power Allocated= 4.380181429229497
# CSI= 0.5303681563706312
# SNR= 26.722193571241426
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.279140
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.156953
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.041956
#
# Power Allocated= 4.0819431284629815
# CSI= 0.4579339509830135
# SNR= 22.4784222476229
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.283486
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.102861
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.220066
#
# Power Allocated= 3.262067062776137
# CSI= 0.33293413447190445
# SNR= 26.13373161704844
# Client: client47
# Model client47 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.207624
# Model client47 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.041697
# Model client47 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.220877
#
# Power Allocated= 4.720940106968302
# CSI= 0.6473648143031795
# SNR= 31.66781445295055
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.296044
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.119335
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.290687
#
# [113.65000171843371, 123.37897927569321, 118.80178671012266, 115.03641102200345, 117.58687796801871, 115.58573674470244, 158.77422386450598, 166.9991005227901, 170.70894162876357, 220.69021040343432, 242.4551730766271, 206.1283209827161, 261.8345304489776, 310.12046828217564, 240.03064523494686, 294.27080161045524, 336.37946984700005, 315.12538523734474, 358.0154283319098, 392.7219988600467, 352.4189399325842, 379.1596099866292, 380.47132854231944, 346.84142243061797, 364.033431422984, 399.4381555254416, 364.33937767853786, 356.16314892083756, 420.8253983727501, 354.50948348235397, 381.5374680296736, 417.34539007395506, 401.96189109169063, 403.3559761659999, 442.55837124217453, 371.70295045815874, 374.40434380434453, 421.9639815633186, 421.873841859182, 396.1943381149031, 456.5914446223139, 372.2752261673886, 424.28483127102663, 466.5148918880151, 419.6080081020773, 395.40859630482737, 462.1922946889574, 447.1432263906463, 426.23772556848417, 471.1339800032786, 421.341544849216, 459.5485625555011, 500.8485436723568, 445.4001524255873, 447.29043791649747, 489.8511492455845, 465.1167715368938, 443.2199033142533, 489.43052589643435, 437.7893252025533, 455.2293084253324, 503.45702832030764, 433.26828667464724, 447.66376288988977, 525.3663648660994, 432.7438950277865, 439.14826162294776, 529.1932603312035, 417.7067441172112, 451.32633112053736, 534.2393503702866, 459.7013257946819, 478.17608783976175, 536.6352326040932, 484.97213879773335, 470.1269737849361, 523.7370953728444, 447.02623705890437, 502.1456298323901, 550.5746348700952, 500.8621117212024, 494.22106409999833, 562.025847728566, 458.78610467108956, 526.5804420951172, 569.6332235567272, 476.47887090442237, 497.31294703022286, 569.5206026118093, 469.0810250550858, 520.2358682648628, 578.6391827044077, 503.71762650855817, 535.7385623323789, 581.580892574306, 501.13631708471803, 523.9139190551505, 591.5078742167758, 512.2648846723314, 482.20086874926346, 579.799930115013, 479.58531803425285, 525.2038388155343, 584.3279653828282, 531.647697485314, 534.6028325708467, 600.3697571448981, 546.0955808921426, 554.4882670687948, 597.2510657893648, 539.3086855870497, 536.6755225046072, 587.5055857313176, 480.170502230234, 503.75392331005423, 612.7005977706363, 491.17036918678787, 548.8994290375849, 644.0217949064138, 549.1140397925628, 538.4116536131769, 620.3403821290702, 556.8548736775701, 551.9202531179471, 604.7776498380117, 569.8867007271037, 521.1724852398911]
#
# Test set: Average loss for Cluster1 model: 1.6606, Accuracy: 9703/10000 (97%)
#
# 0.16898000000000088
# Power Allocated= 4.714886003157334
# CSI= 0.8312730931937659
# SNR= 22.86842514561434
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.287676
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.277929
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.283631
#
# Power Allocated= 3.8830110104713462
# CSI= 0.4914369346934515
# SNR= 25.610642152913385
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.342736
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.168978
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.132938
#
# Power Allocated= 3.5102488293551453
# CSI= 0.41534944259912143
# SNR= 26.988736149159845
# Client: client13
# Model client13 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.276812
# Model client13 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.185439
# Model client13 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.074479
#
# Power Allocated= 4.86524190207757
# CSI= 0.9500120749155678
# SNR= 27.408230131714667
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.338570
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.061278
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.130027
#
# Power Allocated= 4.604137131842531
# CSI= 0.7611954901284446
# SNR= 24.08697207104706
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.236440
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.366407
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.110215
#
# Power Allocated= 4.738812808159199
# CSI= 0.8481423988710163
# SNR= 28.903835309507855
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.273664
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.275448
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.285566
#
# Power Allocated= 4.6779567635489485
# CSI= 0.8065144831539093
# SNR= 45.55021475846493
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.186538
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.109466
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.078516
#
# Power Allocated= 4.034175327349524
# CSI= 0.5308743870367285
# SNR= 32.430904356794784
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.193474
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.200661
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.075161
#
# Power Allocated= 2.2297508386263254
# CSI= 0.2711416415963136
# SNR= 26.135258053556782
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.270409
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.485678
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.393968
#
# Power Allocated= 4.65185488593124
# CSI= 0.7898861611908274
# SNR= 28.783023714291073
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.195133
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.194122
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.094568
#
# Power Allocated= 4.757169760438412
# CSI= 0.8615562345749989
# SNR= 27.756570945423768
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.187593
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.147678
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.128895
#
# Power Allocated= 4.343324869589925
# CSI= 0.6351080493794458
# SNR= 36.38954672090302
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.230621
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.092167
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.209616
#
# Power Allocated= 3.476645152714041
# CSI= 0.4096320974847705
# SNR= 24.125746030096195
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.128347
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.209355
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.031940
#
# Power Allocated= 2.2665903776060214
# CSI= 0.2738773291322012
# SNR= 25.633239073421198
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.162328
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.083778
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.235655
#
# Power Allocated= 3.244483384411401
# CSI= 0.3740587675131769
# SNR= 27.980990172967864
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.219139
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.084905
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.359647
#
# [113.65000171843371, 123.37897927569321, 118.80178671012266, 115.03641102200345, 117.58687796801871, 115.58573674470244, 158.77422386450598, 166.9991005227901, 170.70894162876357, 220.69021040343432, 242.4551730766271, 206.1283209827161, 261.8345304489776, 310.12046828217564, 240.03064523494686, 294.27080161045524, 336.37946984700005, 315.12538523734474, 358.0154283319098, 392.7219988600467, 352.4189399325842, 379.1596099866292, 380.47132854231944, 346.84142243061797, 364.033431422984, 399.4381555254416, 364.33937767853786, 356.16314892083756, 420.8253983727501, 354.50948348235397, 381.5374680296736, 417.34539007395506, 401.96189109169063, 403.3559761659999, 442.55837124217453, 371.70295045815874, 374.40434380434453, 421.9639815633186, 421.873841859182, 396.1943381149031, 456.5914446223139, 372.2752261673886, 424.28483127102663, 466.5148918880151, 419.6080081020773, 395.40859630482737, 462.1922946889574, 447.1432263906463, 426.23772556848417, 471.1339800032786, 421.341544849216, 459.5485625555011, 500.8485436723568, 445.4001524255873, 447.29043791649747, 489.8511492455845, 465.1167715368938, 443.2199033142533, 489.43052589643435, 437.7893252025533, 455.2293084253324, 503.45702832030764, 433.26828667464724, 447.66376288988977, 525.3663648660994, 432.7438950277865, 439.14826162294776, 529.1932603312035, 417.7067441172112, 451.32633112053736, 534.2393503702866, 459.7013257946819, 478.17608783976175, 536.6352326040932, 484.97213879773335, 470.1269737849361, 523.7370953728444, 447.02623705890437, 502.1456298323901, 550.5746348700952, 500.8621117212024, 494.22106409999833, 562.025847728566, 458.78610467108956, 526.5804420951172, 569.6332235567272, 476.47887090442237, 497.31294703022286, 569.5206026118093, 469.0810250550858, 520.2358682648628, 578.6391827044077, 503.71762650855817, 535.7385623323789, 581.580892574306, 501.13631708471803, 523.9139190551505, 591.5078742167758, 512.2648846723314, 482.20086874926346, 579.799930115013, 479.58531803425285, 525.2038388155343, 584.3279653828282, 531.647697485314, 534.6028325708467, 600.3697571448981, 546.0955808921426, 554.4882670687948, 597.2510657893648, 539.3086855870497, 536.6755225046072, 587.5055857313176, 480.170502230234, 503.75392331005423, 612.7005977706363, 491.17036918678787, 548.8994290375849, 644.0217949064138, 549.1140397925628, 538.4116536131769, 620.3403821290702, 556.8548736775701, 551.9202531179471, 604.7776498380117, 569.8867007271037, 521.1724852398911, 631.9074442422948]
#
# Test set: Average loss for Cluster2 model: 2.8830, Accuracy: 9703/10000 (97%)
#
# 0.15020000000000816
# Power Allocated= 0.44703066457726326
# CSI= 0.16101091801629897
# SNR= 27.74690215351428
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.253279
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.193863
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.240220
#
# Power Allocated= 3.0429712905866304
# CSI= 0.276639075763515
# SNR= 32.09597946751814
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.271403
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.161277
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.206410
#
# Power Allocated= 5.596773442770485
# CSI= 0.9424927039373964
# SNR= 24.518238402129136
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.291540
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.225340
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.058286
#
# Power Allocated= 0.22308168608685008
# CSI= 0.15540720903364424
# SNR= 23.622966282333916
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.226575
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.084236
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.117483
#
# Power Allocated= 5.637556787377949
# CSI= 0.9801684223983467
# SNR= 18.882098749463196
# Client: client19
# Model client19 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.335257
# Model client19 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.115671
# Model client19 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.041782
#
# Power Allocated= 5.385930925535348
# CSI= 0.7862508698405832
# SNR= 24.472895856194537
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.316487
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.106161
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.179262
#
# Power Allocated= 0
# CSI= 0.1342530883234464
# SNR= 22.717781960147057
# Client: client22
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.910534252626482
# CSI= 0.5723261877994664
# SNR= 20.4034906861921
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.244797
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.275240
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.199977
#
# Power Allocated= 0
# CSI= 0.10254459754258549
# SNR= 33.7435487546005
# Client: client27
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.746942763369986
# CSI= 0.5233281776349189
# SNR= 28.130662492427454
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.316192
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.115865
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.125478
#
# Power Allocated= 4.818621946511167
# CSI= 0.5437242170791938
# SNR= 30.633693621329783
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.349456
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.140514
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.353745
#
# Power Allocated= 4.3961567579409095
# CSI= 0.44215841549533585
# SNR= 30.790478411898192
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.408989

# %%
print(final_acc)
