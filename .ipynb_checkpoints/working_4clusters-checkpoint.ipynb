# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import numpy as np
from Dataset import load_dataset, getImage
from utils import averageModels
from utils import averageModelscluster
import random
import math
import matplotlib.pyplot as plt
from ipynb.fs.full.K_clusters import cluster_former
from copy import deepcopy
# Out:
# 0.7703313827514648
# {'Cluster Head': 'client79', 'Members': ['client17', 'client29', 'client31', 'client38', 'client41', 'client42', 'client46', 'client51', 'client54', 'client59', 'client74', 'client81', 'client86', 'client100'], 'SNR': [22.751147505522926, 52.99238043522077, 20.92399800777953, 26.635166262473135, 28.15598034134795, 36.13549991688954, 39.40815224319007, 28.151686339191, 20.76801419791916, 30.183275471049413, 22.73704503933692, 29.123232047097133, 23.501427559741764, 29.179661523253166], 'CSI': [0.038825633588572495, 0.29149992403282843, 0.481873816825075, 0.5413887839813818, 0.36180275832050923, 0.6750952291664314, 0.565811324146884, 0.40585278868296526, 0.4487257505674407, 0.5534858760920778, 0.18978118851187564, 0.4189215834922715, 0.0724044655895163, 0.48078874163351726]}

# %%
P=2 #signal power threshold
#stream = BitStream()
#random.seed(10)
key=[]
for i in range (10000): #generating a random password to activate training (Pilot signal)
    temp=random.randint(0,1)
    key.append(temp)

key1=[0]*len(key)
for i in range (len(key)):   #bpsk modulation
    if(key[i]==1):
        #print("yay")
        key1[i]=-math.sqrt(P)
    else:
        key1[i]=math.sqrt(P)

#print(key)
        
key_np=np.array(key1)

# %%
class Arguments():
    def __init__(self):
        self.images = 10000
        self.clients = 50
        self.rounds = 200
        self.epochs = 3
        self.local_batches = 64
        self.lr = 0.01
        self.C = 1 #fraction of clients used in the round
        self.drop_rate = 0 #fraction of devices in the selected set to be dropped for various reasons
        self.torch_seed = 0 #same weights and parameters whenever the program is run
        self.log_interval = 64
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = True
        self.numclusters=4

args = Arguments()

# %%
#checking if gpu is available
#use_cuda = args.use_cuda and torch.cuda.is_available()
use_cuda=False
device = torch.device("cuda:0" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

hook = sy.TorchHook(torch)
me = hook.local_worker
clients = []

#generating virtual clients
for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})
#print(clients)

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid) #load data

for inx, client in enumerate(clients):  #return actual image set for each client
    trainset_ind_list = list(train_group[inx]) 
    client['trainset'] = getImage(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getImage(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images #useful while taking weighted average

# %%
#load dataset for global model (to compare accuracies)
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.MNIST('./', train=False, download=True, transform=transform)
# global_test_dataset = torch.utils.data.random_split(global_test_dataset, [10000, len(global_test_dataset)-10000])[0]
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
"""class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        #self.quant = torch.quantization.QuantStub()
        self.conv1 = nn.Conv2d(1, 5, 5, 1)
        self.conv2 = nn.Conv2d(5, 10, 5, 1)
        self.fc1 = nn.Linear(4*4*10, 50) #10 iid #50 non iid
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        #x=self.quant(x)
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*10
                   )
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1) """

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x)

# %%
def fedprox(params,global_params):
    global_param=[]
    ind=0
    for gp in global_params:
        global_param.append(gp)
    for p in params:
    #                 print(p.grad)
        lr=0.001
        mu=0.1
        if(p.grad is None):
            continue
        grad=p.grad.data #batch gradients
        p.data.sub_(lr,(grad+mu*(p.data.clone()-global_param[ind].data.clone())))
        ind+=1
    return(p)

# %%
def ClientUpdate(args, device, client,key_np,key,snr,csi,mu,head):
    gc=False
    client['model'].train()
    #simulating a wireless channel
    poptim=max((1/mu-1/csi),0)
    #print(mu,csi)
    print("Power Allocated=",poptim)
    print("CSI=",csi)
    
    snr__=10**(snr/10)
    
    absh=csi*poptim/snr__
    x=random.uniform(0,absh)
    #print(x)
    y=math.sqrt(absh*absh-x*x)
    #x=x*100
    #y=y*100
    #x=random.random()
    #y=random.random()
    #snr=10*math.log(poptim/(std*std),10)
    std=math.sqrt(poptim/snr__*absh*absh) #channel noise
    
    #print(x,y)
    h=complex(x,y)
    #std=math.sqrt(abs(h)/csi)
    #snr=poptim/(std*std)
    #print(std)
    print("SNR=",snr)
    #print("csi",abs(h)/(std*std))
    
    
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data

    
    #print(client['model'].conv1.weight.size)
    client['model'].send(client['hook'])
    head['model'].send(client['hook'])
    print("Client:",client['hook'].id)
    
    key_np_received=h*key_np+(np.random.randn(len(key_np))*std*2)
    #print(key_np_received)
    key_np_received=(key_np_received/(h)).real
    
    for o in range (len(key_np_received)):  #demodulation bpsk
        if(key_np_received[o]>=0):
            key_np_received[o]=0
        else:
            key_np_received[o]=1
    
    key_np_received=key_np_received.tolist()
    key_np_received = [int(item) for item in key_np_received]
    #key_np=key_np.tolist()
    
    
    if(sum(np.bitwise_xor(key,key_np_received))/len(key)==0 and poptim>0): #...............................................checking if channel is good enough for transmission by checking BER..................................#
        gc=True #considering the client model for training
        for epoch in range(1, args.epochs + 1):
            for batch_idx, (data, target) in enumerate(client['trainset']): 
                data = data.send(client['hook'])
                target = target.send(client['hook'])
                #client['optim'].zero_grad()
                #train model on client
                data, target = data.to(device), target.to(device) #send data to cpu/gpu (data is stored locally)
                output = client['model'](data)
                loss = F.nll_loss(output, target)
                loss.backward()
                #client['optim'].step()
                params=client['model'].parameters()
                gp=head['model'].parameters()
                params=fedprox(params,gp) 
                
                if batch_idx % args.log_interval == 0:
                    loss = loss.get() 
                    print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                        client['hook'].id,
                        epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                        100. * batch_idx / len(client['trainset']), loss))
    else:
        print("Poor Channel, client not taken for averaging in this round")
            
                    
    client['model'].get()
    head['model'].get()
    # print()
         #CHANGE
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
    #CHANGE ENDS
    print()
    return gc

# %%
def test(args, model, device, test_loader, name,fed_round):
    model.eval()    #no need to train the model while testing
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            if(use_cuda and fed_round==0):
                data,target=data.cuda(),target.cuda()
                #model.cuda()
            else:
                data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    return([100. * correct / len(test_loader.dataset),test_loss])

# %%
torch.manual_seed(args.torch_seed)

# %%
def distort(neighbours,snrs):
    ind=0
    poptim=2
    csi=random.random()
    distorted_models=[]
    for client in neighbours:
        snr=snrs[ind]
        ind+=1
        snr__=10**(snr/10)
        absh=csi*poptim/snr__
        x=random.uniform(0,absh)
        y=math.sqrt(absh*absh-x*x)
        std=math.sqrt(poptim/snr__*absh*absh) #channel noise
        h=complex(x,y)
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
        
        distorted_models.append(client)
    return(distorted_models)

# %%
def decentralized(clients,snrs,weights):
    big_daddy_of_distorted_models=[]
    for client in clients:
        distorted_models=[]
        snr_list=[]
        for snr in snrs:
            if(client['hook'].id in snr):
                snr_list.append(snr[2])
        neighbours_c = [x for x in clients if x != client]
        neighbours={}
        jjj=[jkl for jkl in range(len(neighbours_c))]
        
        dictionary = dict(zip(jjj, neighbours_c))
        #for jjj in range(len(neighbours_c)):
        #   neighbours[jjj].append(neighbours_c[jjj])
        distorted_models=distort(neighbours,snr_list)
        distorted_models.append(client)
        big_daddy_of_distorted_models.append(distorted_models)
    
    
    weight_final1=[]
    for oho in big_daddy_of_distorted_models:
        weight_final=[]
        for comeon in oho:
            for w in weights:
                if(comeon['hook'].id==w[0]):
                    weight_final.append(w[1])
        weight_final1.append(weight_final)
    
    final_heads=[]
    nets=[]
    ind=0
    for client in clients:
        for oof in big_daddy_of_distorted_models:
            if(client==oof[0]):
#                 print(client)
#                 print("shut up")
#                 print(distorted_models)
#                 print("shut up")
#                 print(weight_final1)
                
                overall=Net()
                overall=averageModelscluster(overall,distorted_models,weight_final1[ind])
                client['model'].load_state_dict(overall.state_dict())
                ind+=1
                final_heads.append(client)
                nets.append(overall)
    
    return(final_heads,nets)

# %%
for client in clients: #give the model and optimizer to every client
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    #client['model'] = torch.quantization.quantize_dynamic(
    #client['model'],  # the original model
    #{torch.nn.Linear},  # a set of layers to dynamically quantize
    #dtype=torch.fp)  # the target dtype for quantized weights
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)

final_acc=[]
final_loss=[]
    
for fed_round in range(args.rounds):
    overall=Net()
    if(fed_round==0): #fed_round==0
        arranged_clusters,head_snr_list=cluster_former(args.numclusters,args.clients)
        temp=deepcopy(arranged_clusters)
        temp2=deepcopy(head_snr_list)
    else:
        #print(temp)
        arranged_clusters=deepcopy(temp)
        head_snr_list=deepcopy(temp2)
#     print(arranged_clusters)
    
    no=1
    heads_list=[]
    weights=[]
    weight_head_list=[]
    head_acc=[]
    head_loss=[]
    for cluster in arranged_clusters:
        
        head=cluster['Cluster Head']
        members=cluster['Members']
        snrs=cluster['SNR']
        csis=cluster['CSI']
        weights.append(sum(snrs))
        weight_head_list.append([head,sum(snrs)])
        new_members=[]
        
        for ij in members:
        #print(ij)
            cl_no=int(ij[6:])
            new_members.append(clients[cl_no-1])
#         print(head)
        head=clients[int(head[6:])-1]
        cluster['Members']=new_members
#         print(head)

        smallmu1=0
        gsmall1=3.402823466E+38 
        
        #water filling algorithm
        mu=1e-15
        while(mu<=1):
            g1=0
            pn1=0
            for jj in csis:
                pn=max(1/mu-1/jj,0)
                g1+=math.log(1+pn*jj) #capacity of a channel (shannon's law)
                pn1+=pn
            g=g1-mu*(pn1-P*30)
            if(g<gsmall1):
                smallmu1=mu
                gsmall1=g
            mu+=0.00002
        
        print(smallmu1)
        good_mem=[]
#         print(len(snrs))
#         print(len(csis))
#         print(len(new_members))
        index=0
        for client in new_members:
            goodchannel=ClientUpdate(args, device, client,key_np,key,snrs[index],csis[index],smallmu1,head)
            index+=1
            if(goodchannel):
                good_mem.append(client)
        
        head['model']=averageModels(head['model'], good_mem)
        arr=test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)
        ac=arr[0]#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[0]
        no+=1
        heads_list.append(head)
        head_acc.append(ac)
        head_loss.append(arr[1])#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[1])
    
    final_acc.append(head_acc)
    final_loss.append(head_loss)
    fig,ax=plt.subplots()
    clor = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(args.numclusters)]
    #ax.plot([i for i in range(fed_round)],head_acc[0])
    for jj in range(0,args.numclusters):
        
        ax.plot([i for i in range(len(final_acc))],[final_acc[j][jj] for j in range(len(final_acc))], color = clor[jj])
        
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][0] for j in range(len(final_acc))], color ="red")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][1] for j in range(len(final_acc))],color ="blue")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][2] for j in range(len(final_acc))],color ="green")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][3] for j in range(len(final_acc))],color ="black")
    #ax.plot([i for i in range(len(final_acc))],head_acc[1], fed_round, color ="blue")
    #ax.plot([i for i in range(len(final_acc))],head_acc[2], fed_round, color ="green")
    #ax.plot([i for i in range(len(final_acc))],head_acc[3], fed_round, color ="black")
    
    
    plt.show()
    weightsum=sum(weights)
    
    weights[:] = [x / weightsum for x in weights]
    for aah in range(len(weight_head_list)):
        weight_head_list[aah][1]=weights[aah]
    final_heads,nets=decentralized(heads_list,head_snr_list,weight_head_list)
    
    for head in range(len(final_heads)):
        for cluster in arranged_clusters:
            head1=cluster['Cluster Head']
            if(head1==final_heads[head]['hook'].id):
                for mem in cluster['Members']:
                    mem['model'].load_state_dict(nets[head].state_dict())
    print("ROUND",fed_round)
# Out:
# 0.11776000000001571
# Power Allocated= 3.266140521850355
# CSI= 0.1913616553283598
# SNR= 25.87590887415036
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300406
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook.py:165: UserWarning: This overload of sub_ is deprecated:
# 	sub_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	sub_(Tensor other, *, Number alpha) (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629411241/work/torch/csrc/utils/python_arg_parser.cpp:766.)
#   response = method(*args, **kwargs)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.305655
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272196
#
# Power Allocated= 0
# CSI= 0.07821933675496628
# SNR= 26.906891303371403
# Client: client14
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.463846462650929
# CSI= 0.49309631543159615
# SNR= 27.944612009929514
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.347690
# /tmp/ipykernel_663174/1497942811.py:66: RuntimeWarning: invalid value encountered in true_divide
#   key_np_received=(key_np_received/(h)).real
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.314888
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.271505
#
# Power Allocated= 7.020242665518935
# CSI= 0.6795300986949392
# SNR= 29.807642281125027
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.254750
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292272
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.300516
#
# Power Allocated= 0
# CSI= 0.0573822072727016
# SNR= 28.21586983209352
# Client: client17
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.987198296162842
# CSI= 0.6646065945012369
# SNR= 40.878017219320235
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.323489
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.268279
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.281919
#
# Power Allocated= 7.434414052096864
# CSI= 0.9456857011741718
# SNR= 47.25830962136973
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.329199
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.313462
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272765
#
# Power Allocated= 7.364241848739735
# CSI= 0.8868346036561288
# SNR= 40.65308272828209
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.292114
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.326128
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.259565
#
# Power Allocated= 7.115951414003299
# CSI= 0.7267989008608746
# SNR= 22.367293680619564
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.395624
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.345428
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.249186
#
# Power Allocated= 7.334056659218291
# CSI= 0.8637136200525303
# SNR= 20.39888339220043
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.315535
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.252527
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.248904
#
# Power Allocated= 7.00789647355461
# CSI= 0.6738765379972024
# SNR= 26.066492231320613
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.318126
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.328945
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.310179
#
#
# Test set: Average loss for Cluster1 model: 2.2273, Accuracy: 3256/10000 (33%)
#
# 0.11404000000001457
# Power Allocated= 7.017379255074322
# CSI= 0.5709477424211306
# SNR= 28.37825963670521
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300916
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301127
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.277326
#
# Power Allocated= 2.257761302687574
# CSI= 0.1535840748775703
# SNR= 27.467903280044528
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.323787
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.318119
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265897
#
# Power Allocated= 6.029796168156427
# CSI= 0.36508917082449033
# SNR= 29.135258862067044
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.380271
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.239095
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.236667
#
# Power Allocated= 5.724009379800108
# CSI= 0.3284240879210397
# SNR= 31.154933584310992
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304291
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.332050
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.259978
#
# Power Allocated= 2.2281688321551156
# CSI= 0.15288920381059967
# SNR= 30.31454226925601
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.306731
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294961
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.282620
#
# Power Allocated= 5.954139415044825
# CSI= 0.35527593047401196
# SNR= 34.12418386506635
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.323711
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.318928
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.269786
#
# Power Allocated= 7.153893985336131
# CSI= 0.6192107476741937
# SNR= 22.539643657340317
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.357228
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.330961
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.242906
#
# Power Allocated= 7.425994334447984
# CSI= 0.7446799877881417
# SNR= 25.01358407223157
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.322900
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300497
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.279171
#
# Power Allocated= 6.127212518821668
# CSI= 0.37855264342209427
# SNR= 20.175697877989833
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.288810
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.307985
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.239071
#
# Power Allocated= 3.150351377978092
# CSI= 0.17798339507905625
# SNR= 24.569257487334024
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.313403
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.281992
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.286235
#
# Power Allocated= 6.935159401514921
# CSI= 0.5453473700689876
# SNR= 21.424159648833253
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305512
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.305224
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.264973
#
#
# Test set: Average loss for Cluster2 model: 2.1275, Accuracy: 4557/10000 (46%)
#
# 0.14270000000001107
# Power Allocated= 4.315347379313261
# CSI= 0.3714212034912413
# SNR= 33.08659623553197
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.310315
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.269563
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265142
#
# Power Allocated= 5.473420520609678
# CSI= 0.6517681340836393
# SNR= 29.63866278002983
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296505
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.315760
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.276817
#
# Power Allocated= 5.667490090727935
# CSI= 0.7461470522319245
# SNR= 31.869576689634215
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296057
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298335
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.235853
#
# Power Allocated= 5.468690760703579
# CSI= 0.6497650988025253
# SNR= 28.15719910386783
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.318666
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.214043
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.240837
#
# Power Allocated= 5.93377077724639
# CSI= 0.931152708451243
# SNR= 32.93561949613788
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.348550
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.305328
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.267327
#
# Power Allocated= 5.468953629776615
# CSI= 0.6498760996869503
# SNR= 27.701963003935607
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.321887
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301156
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.261568
#
# Power Allocated= 5.254781432829523
# CSI= 0.5704743970938561
# SNR= 23.4785979638781
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.350692
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.259663
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.268893
#
# Power Allocated= 5.596757314066923
# CSI= 0.7087417513956791
# SNR= 28.801862778728324
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.324419
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.279797
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285652
#
# Power Allocated= 5.239541771391789
# CSI= 0.5655575322803793
# SNR= 30.87682480968015
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.313180
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.262002
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.293472
#
# Power Allocated= 4.833772420091907
# CSI= 0.45999512991747515
# SNR= 22.669723086896926
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.381491
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.370042
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.218395
#
# Power Allocated= 0.860668803014951
# CSI= 0.16267993256227065
# SNR= 27.242960480764992
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.327993
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.315574
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.256893
#
# Power Allocated= 5.892663786584867
# CSI= 0.8968250389507183
# SNR= 39.326403762427944
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.328867
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288559
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287079
#
#
# Test set: Average loss for Cluster3 model: 2.0557, Accuracy: 3284/10000 (33%)
#
# 0.12732000000001703
# Power Allocated= 5.4401466259953875
# CSI= 0.41423665994550196
# SNR= 31.850183021569055
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.319697
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289760
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.263211
#
# Power Allocated= 3.9689019245582347
# CSI= 0.25737881587009237
# SNR= 25.5733477121122
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301565
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.267695
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.275553
#
# Power Allocated= 6.198431826229561
# CSI= 0.603939954317742
# SNR= 26.642824095690507
# Client: client8
# Model client8 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.309663
# Model client8 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.307713
# Model client8 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287825
#
# Power Allocated= 6.10837403320419
# CSI= 0.5727863893353922
# SNR= 29.393295469924357
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.365248
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297822
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.301702
#
# Power Allocated= 2.651307369262116
# CSI= 0.1921998310895766
# SNR= 24.114473131869538
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.336489
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.283556
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.259345
#
# Power Allocated= 1.890096593177038
# CSI= 0.16766907679614873
# SNR= 54.77606649051003
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.319777
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.312681
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.256609
#
# Power Allocated= 6.5595375224703485
# CSI= 0.7723868304143542
# SNR= 21.60006154573508
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.391335
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298796
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265664
#
# Power Allocated= 6.652306945741579
# CSI= 0.8320030799286562
# SNR= 24.321204709347292
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.365046
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.263620
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.271308
#
# Power Allocated= 5.3482345037047185
# CSI= 0.3990437205103802
# SNR= 28.41685886784671
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.340645
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.329428
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265245
#
# Power Allocated= 6.1115521703950915
# CSI= 0.5738309876653457
# SNR= 25.703759201265733
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.265759
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.270814
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.261487
#
# Power Allocated= 5.007411166991506
# CSI= 0.35126982558604725
# SNR= 31.203880699820065
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300862
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299651
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.253240
#
# Power Allocated= 4.064968378844316
# CSI= 0.2639039655181007
# SNR= 25.29191295119692
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295917
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.303331
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265695
#
#
# Test set: Average loss for Cluster4 model: 2.0785, Accuracy: 3843/10000 (38%)
# ROUND 0
# 0.11776000000001571
# Power Allocated= 3.266140521850355
# CSI= 0.1913616553283598
# SNR= 25.87590887415036
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301370
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301157
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288087
#
# Power Allocated= 0
# CSI= 0.07821933675496628
# SNR= 26.906891303371403
# Client: client14
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.463846462650929
# CSI= 0.49309631543159615
# SNR= 27.944612009929514
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301013
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293501
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.282849
#
# Power Allocated= 7.020242665518935
# CSI= 0.6795300986949392
# SNR= 29.807642281125027
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305754
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301383
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287678
#
# Power Allocated= 0
# CSI= 0.0573822072727016
# SNR= 28.21586983209352
# Client: client17
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.987198296162842
# CSI= 0.6646065945012369
# SNR= 40.878017219320235
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300210
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293406
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.290065
#
# Power Allocated= 7.434414052096864
# CSI= 0.9456857011741718
# SNR= 47.25830962136973
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302670
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295808
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.290117
#
# Power Allocated= 7.364241848739735
# CSI= 0.8868346036561288
# SNR= 40.65308272828209
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299472
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304966
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289243
#
# Power Allocated= 7.115951414003299
# CSI= 0.7267989008608746
# SNR= 22.367293680619564
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301718
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302200
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288446
#
# Power Allocated= 7.334056659218291
# CSI= 0.8637136200525303
# SNR= 20.39888339220043
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.306244
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.290010
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.269754
#
# Power Allocated= 7.00789647355461
# CSI= 0.6738765379972024
# SNR= 26.066492231320613
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299515
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295417
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.276903
#
#
# Test set: Average loss for Cluster1 model: 2.2730, Accuracy: 2956/10000 (30%)
#
# 0.11404000000001457
# Power Allocated= 7.017379255074322
# CSI= 0.5709477424211306
# SNR= 28.37825963670521
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302362
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302788
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.296682
#
# Power Allocated= 2.257761302687574
# CSI= 0.1535840748775703
# SNR= 27.467903280044528
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303133
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300544
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.298218
#
# Power Allocated= 6.029796168156427
# CSI= 0.36508917082449033
# SNR= 29.135258862067044
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301070
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288777
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288126
#
# Power Allocated= 5.724009379800108
# CSI= 0.3284240879210397
# SNR= 31.154933584310992
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301898
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.303409
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.296052
#
# Power Allocated= 2.2281688321551156
# CSI= 0.15288920381059967
# SNR= 30.31454226925601
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299203
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297372
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.292150
#
# Power Allocated= 5.954139415044825
# CSI= 0.35527593047401196
# SNR= 34.12418386506635
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300993
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.303424
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.292534
#
# Power Allocated= 7.153893985336131
# CSI= 0.6192107476741937
# SNR= 22.539643657340317
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301772
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291931
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272004
#
# Power Allocated= 7.425994334447984
# CSI= 0.7446799877881417
# SNR= 25.01358407223157
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303598
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294122
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.275512
#
# Power Allocated= 6.127212518821668
# CSI= 0.37855264342209427
# SNR= 20.175697877989833
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299803
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296896
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.301331
#
# Power Allocated= 3.150351377978092
# CSI= 0.17798339507905625
# SNR= 24.569257487334024
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304986
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294582
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284116
#
# Power Allocated= 6.935159401514921
# CSI= 0.5453473700689876
# SNR= 21.424159648833253
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304925
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304222
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.303062
#
#
# Test set: Average loss for Cluster2 model: 2.2512, Accuracy: 3191/10000 (32%)
#
# 0.14270000000001107
# Power Allocated= 4.315347379313261
# CSI= 0.3714212034912413
# SNR= 33.08659623553197
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299774
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293630
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.294055
#
# Power Allocated= 5.473420520609678
# CSI= 0.6517681340836393
# SNR= 29.63866278002983
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303583
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296914
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.277719
#
# Power Allocated= 5.667490090727935
# CSI= 0.7461470522319245
# SNR= 31.869576689634215
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300326
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297364
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.293081
#
# Power Allocated= 5.468690760703579
# CSI= 0.6497650988025253
# SNR= 28.15719910386783
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303584
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.282219
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.242705
#
# Power Allocated= 5.93377077724639
# CSI= 0.931152708451243
# SNR= 32.93561949613788
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307782
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288217
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285158
#
# Power Allocated= 5.468953629776615
# CSI= 0.6498760996869503
# SNR= 27.701963003935607
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300257
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297100
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.295632
#
# Power Allocated= 5.254781432829523
# CSI= 0.5704743970938561
# SNR= 23.4785979638781
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297900
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288026
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.273549
#
# Power Allocated= 5.596757314066923
# CSI= 0.7087417513956791
# SNR= 28.801862778728324
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302834
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301787
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285661
#
# Power Allocated= 5.239541771391789
# CSI= 0.5655575322803793
# SNR= 30.87682480968015
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301332
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296504
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287793
#
# Power Allocated= 4.833772420091907
# CSI= 0.45999512991747515
# SNR= 22.669723086896926
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295826
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299094
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.275435
#
# Power Allocated= 0.860668803014951
# CSI= 0.16267993256227065
# SNR= 27.242960480764992
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.306623
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294996
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.264262
#
# Power Allocated= 5.892663786584867
# CSI= 0.8968250389507183
# SNR= 39.326403762427944
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302295
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293782
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289461
#
#
# Test set: Average loss for Cluster3 model: 2.1378, Accuracy: 2757/10000 (28%)
#
# 0.12732000000001703
# Power Allocated= 5.4401466259953875
# CSI= 0.41423665994550196
# SNR= 31.850183021569055
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307506
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304140
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.293712
#
# Power Allocated= 3.9689019245582347
# CSI= 0.25737881587009237
# SNR= 25.5733477121122
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301010
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292232
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289697
#
# Power Allocated= 6.198431826229561
# CSI= 0.603939954317742
# SNR= 26.642824095690507
# Client: client8
# Model client8 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304077
# Model client8 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293125
# Model client8 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.293961
#
# Power Allocated= 6.10837403320419
# CSI= 0.5727863893353922
# SNR= 29.393295469924357
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299005
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292599
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.291590
#
# Power Allocated= 2.651307369262116
# CSI= 0.1921998310895766
# SNR= 24.114473131869538
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301570
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289866
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284755
#
# Power Allocated= 1.890096593177038
# CSI= 0.16766907679614873
# SNR= 54.77606649051003
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304920
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296352
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284480
#
# Power Allocated= 6.5595375224703485
# CSI= 0.7723868304143542
# SNR= 21.60006154573508
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301532
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.303772
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.290256
#
# Power Allocated= 6.652306945741579
# CSI= 0.8320030799286562
# SNR= 24.321204709347292
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300357
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297719
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.295412
#
# Power Allocated= 5.3482345037047185
# CSI= 0.3990437205103802
# SNR= 28.41685886784671
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300842
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294750
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.299692
#
# Power Allocated= 6.1115521703950915
# CSI= 0.5738309876653457
# SNR= 25.703759201265733
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299062
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295393
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272199
#
# Power Allocated= 5.007411166991506
# CSI= 0.35126982558604725
# SNR= 31.203880699820065
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299069
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297109
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.294720
#
# Power Allocated= 4.064968378844316
# CSI= 0.2639039655181007
# SNR= 25.29191295119692
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305038
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297273
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.294784
#
#
# Test set: Average loss for Cluster4 model: 2.1997, Accuracy: 3513/10000 (35%)
# ROUND 1
# 0.11776000000001571
# Power Allocated= 3.266140521850355
# CSI= 0.1913616553283598
# SNR= 25.87590887415036
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303331
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298738
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.283037
#
# Power Allocated= 0
# CSI= 0.07821933675496628
# SNR= 26.906891303371403
# Client: client14
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.463846462650929
# CSI= 0.49309631543159615
# SNR= 27.944612009929514
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300468
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297004
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.258431
#
# Power Allocated= 7.020242665518935
# CSI= 0.6795300986949392
# SNR= 29.807642281125027
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305013
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298101
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.290653
#
# Power Allocated= 0
# CSI= 0.0573822072727016
# SNR= 28.21586983209352
# Client: client17
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.987198296162842
# CSI= 0.6646065945012369
# SNR= 40.878017219320235
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303382
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297321
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284833
#
# Power Allocated= 7.434414052096864
# CSI= 0.9456857011741718
# SNR= 47.25830962136973
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299982
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297661
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285709
#
# Power Allocated= 7.364241848739735
# CSI= 0.8868346036561288
# SNR= 40.65308272828209
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302783
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299600
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288916
#
# Power Allocated= 7.115951414003299
# CSI= 0.7267989008608746
# SNR= 22.367293680619564
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299284
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296426
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288696
#
# Power Allocated= 7.334056659218291
# CSI= 0.8637136200525303
# SNR= 20.39888339220043
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301261
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296814
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.259817
#
# Power Allocated= 7.00789647355461
# CSI= 0.6738765379972024
# SNR= 26.066492231320613
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302374
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296868
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265857
#
#
# Test set: Average loss for Cluster1 model: 2.2468, Accuracy: 1980/10000 (20%)
#
# 0.11404000000001457
# Power Allocated= 7.017379255074322
# CSI= 0.5709477424211306
# SNR= 28.37825963670521
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299996
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296634
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.290127
#
# Power Allocated= 2.257761302687574
# CSI= 0.1535840748775703
# SNR= 27.467903280044528
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301459
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296252
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.296505
#
# Power Allocated= 6.029796168156427
# CSI= 0.36508917082449033
# SNR= 29.135258862067044
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303271
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295282
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.298171
#
# Power Allocated= 5.724009379800108
# CSI= 0.3284240879210397
# SNR= 31.154933584310992
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302855
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297646
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.283987
#
# Power Allocated= 2.2281688321551156
# CSI= 0.15288920381059967
# SNR= 30.31454226925601
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300601
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301788
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.296138
#
# Power Allocated= 5.954139415044825
# CSI= 0.35527593047401196
# SNR= 34.12418386506635
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302142
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296703
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.294906
#
# Power Allocated= 7.153893985336131
# CSI= 0.6192107476741937
# SNR= 22.539643657340317
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299085
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293170
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.260617
#
# Power Allocated= 7.425994334447984
# CSI= 0.7446799877881417
# SNR= 25.01358407223157
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300008
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304883
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.286547
#
# Power Allocated= 6.127212518821668
# CSI= 0.37855264342209427
# SNR= 20.175697877989833
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302942
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301601
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.303934
#
# Power Allocated= 3.150351377978092
# CSI= 0.17798339507905625
# SNR= 24.569257487334024
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302019
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294930
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.297058
#
# Power Allocated= 6.935159401514921
# CSI= 0.5453473700689876
# SNR= 21.424159648833253
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300142
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300391
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.307559
#
#
# Test set: Average loss for Cluster2 model: 2.2311, Accuracy: 2888/10000 (29%)
#
# 0.14270000000001107
# Power Allocated= 4.315347379313261
# CSI= 0.3714212034912413
# SNR= 33.08659623553197
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296442
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296556
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.294952
#
# Power Allocated= 5.473420520609678
# CSI= 0.6517681340836393
# SNR= 29.63866278002983
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302459
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291398
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.225750
#
# Power Allocated= 5.667490090727935
# CSI= 0.7461470522319245
# SNR= 31.869576689634215
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301121
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294936
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.271480
#
# Power Allocated= 5.468690760703579
# CSI= 0.6497650988025253
# SNR= 28.15719910386783
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300986
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.270225
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.138695
#
# Power Allocated= 5.93377077724639
# CSI= 0.931152708451243
# SNR= 32.93561949613788
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297571
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297755
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.260875
#
# Power Allocated= 5.468953629776615
# CSI= 0.6498760996869503
# SNR= 27.701963003935607
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298271
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297003
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.286034
#
# Power Allocated= 5.254781432829523
# CSI= 0.5704743970938561
# SNR= 23.4785979638781
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302065
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.285746
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.228170
#
# Power Allocated= 5.596757314066923
# CSI= 0.7087417513956791
# SNR= 28.801862778728324
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300902
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295179
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.275133
#
# Power Allocated= 5.239541771391789
# CSI= 0.5655575322803793
# SNR= 30.87682480968015
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304904
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298884
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289717
#
# Power Allocated= 4.833772420091907
# CSI= 0.45999512991747515
# SNR= 22.669723086896926
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302579
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288857
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.278932
#
# Power Allocated= 0.860668803014951
# CSI= 0.16267993256227065
# SNR= 27.242960480764992
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304371
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293718
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.259976
#
# Power Allocated= 5.892663786584867
# CSI= 0.8968250389507183
# SNR= 39.326403762427944
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300299
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289462
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.279137
#
#
# Test set: Average loss for Cluster3 model: 2.0565, Accuracy: 2081/10000 (21%)
#
# 0.12732000000001703
# Power Allocated= 5.4401466259953875
# CSI= 0.41423665994550196
# SNR= 31.850183021569055
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300859
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292670
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.276708
#
# Power Allocated= 3.9689019245582347
# CSI= 0.25737881587009237
# SNR= 25.5733477121122
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298283
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297883
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272329
#
# Power Allocated= 6.198431826229561
# CSI= 0.603939954317742
# SNR= 26.642824095690507
# Client: client8
# Model client8 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300397
# Model client8 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297654
# Model client8 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272441
#
# Power Allocated= 6.10837403320419
# CSI= 0.5727863893353922
# SNR= 29.393295469924357
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299856
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296873
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.281814
#
# Power Allocated= 2.651307369262116
# CSI= 0.1921998310895766
# SNR= 24.114473131869538
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303085
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288345
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289008
#
# Power Allocated= 1.890096593177038
# CSI= 0.16766907679614873
# SNR= 54.77606649051003
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298614
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293655
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.257006
#
# Power Allocated= 6.5595375224703485
# CSI= 0.7723868304143542
# SNR= 21.60006154573508
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298152
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295349
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.277659
#
# Power Allocated= 6.652306945741579
# CSI= 0.8320030799286562
# SNR= 24.321204709347292
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301234
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286883
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.291168
#
# Power Allocated= 5.3482345037047185
# CSI= 0.3990437205103802
# SNR= 28.41685886784671
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303273
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297654
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287414
#
# Power Allocated= 6.1115521703950915
# CSI= 0.5738309876653457
# SNR= 25.703759201265733
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302634
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.283110
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.205210
#
# Power Allocated= 5.007411166991506
# CSI= 0.35126982558604725
# SNR= 31.203880699820065
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301386
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295249
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.275098
#
# Power Allocated= 4.064968378844316
# CSI= 0.2639039655181007
# SNR= 25.29191295119692
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302438
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296420
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.274473
#
#
# Test set: Average loss for Cluster4 model: 2.1391, Accuracy: 2027/10000 (20%)
# ROUND 2
# 0.11776000000001571
# Power Allocated= 3.266140521850355
# CSI= 0.1913616553283598
# SNR= 25.87590887415036
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299813
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.278229
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.230492
#
# Power Allocated= 0
# CSI= 0.07821933675496628
# SNR= 26.906891303371403
# Client: client14
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.463846462650929
# CSI= 0.49309631543159615
# SNR= 27.944612009929514
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301108
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300085
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.196923
#
# Power Allocated= 7.020242665518935
# CSI= 0.6795300986949392
# SNR= 29.807642281125027
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302315
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299598
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.274642
#
# Power Allocated= 0
# CSI= 0.0573822072727016
# SNR= 28.21586983209352
# Client: client17
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.987198296162842
# CSI= 0.6646065945012369
# SNR= 40.878017219320235
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301224
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.287434
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.244110
#
# Power Allocated= 7.434414052096864
# CSI= 0.9456857011741718
# SNR= 47.25830962136973
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297668
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293166
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.260746
#
# Power Allocated= 7.364241848739735
# CSI= 0.8868346036561288
# SNR= 40.65308272828209
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304597
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.273978
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.174736
#
# Power Allocated= 7.115951414003299
# CSI= 0.7267989008608746
# SNR= 22.367293680619564
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297520
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294712
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265864
#
# Power Allocated= 7.334056659218291
# CSI= 0.8637136200525303
# SNR= 20.39888339220043
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300412
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.273520
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.943668
#
# Power Allocated= 7.00789647355461
# CSI= 0.6738765379972024
# SNR= 26.066492231320613
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302302
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286648
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.224453
#
#
# Test set: Average loss for Cluster1 model: 2.0615, Accuracy: 2948/10000 (29%)
#
# 0.11404000000001457
# Power Allocated= 7.017379255074322
# CSI= 0.5709477424211306
# SNR= 28.37825963670521
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301128
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299441
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.312438
#
# Power Allocated= 2.257761302687574
# CSI= 0.1535840748775703
# SNR= 27.467903280044528
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303313
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.290014
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.296540
#
# Power Allocated= 6.029796168156427
# CSI= 0.36508917082449033
# SNR= 29.135258862067044
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302524
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296157
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.263639
#
# Power Allocated= 5.724009379800108
# CSI= 0.3284240879210397
# SNR= 31.154933584310992
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298447
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291834
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265833
#
# Power Allocated= 2.2281688321551156
# CSI= 0.15288920381059967
# SNR= 30.31454226925601
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301730
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298036
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.295284
#
# Power Allocated= 5.954139415044825
# CSI= 0.35527593047401196
# SNR= 34.12418386506635
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298571
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292944
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.271635
#
# Power Allocated= 7.153893985336131
# CSI= 0.6192107476741937
# SNR= 22.539643657340317
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301587
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298810
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.155188
#
# Power Allocated= 7.425994334447984
# CSI= 0.7446799877881417
# SNR= 25.01358407223157
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302991
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296804
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.250364
#
# Power Allocated= 6.127212518821668
# CSI= 0.37855264342209427
# SNR= 20.175697877989833
# Client: client36
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.150351377978092
# CSI= 0.17798339507905625
# SNR= 24.569257487334024
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299476
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298238
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.251710
#
# Power Allocated= 6.935159401514921
# CSI= 0.5453473700689876
# SNR= 21.424159648833253
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304733
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291259
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.271437
#
#
# Test set: Average loss for Cluster2 model: 2.1256, Accuracy: 2838/10000 (28%)
#
# 0.14270000000001107
# Power Allocated= 4.315347379313261
# CSI= 0.3714212034912413
# SNR= 33.08659623553197
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303461
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296318
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.217067
#
# Power Allocated= 5.473420520609678
# CSI= 0.6517681340836393
# SNR= 29.63866278002983
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301544
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.280831
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.134823
#
# Power Allocated= 5.667490090727935
# CSI= 0.7461470522319245
# SNR= 31.869576689634215
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303171
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286054
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.184873
#
# Power Allocated= 5.468690760703579
# CSI= 0.6497650988025253
# SNR= 28.15719910386783
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303753
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.211094
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.745947
#
# Power Allocated= 5.93377077724639
# CSI= 0.931152708451243
# SNR= 32.93561949613788
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297097
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.280432
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.165696
#
# Power Allocated= 5.468953629776615
# CSI= 0.6498760996869503
# SNR= 27.701963003935607
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301392
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288886
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.290941
#
# ...
#
# Power Allocated= 6.463846462650929
# CSI= 0.49309631543159615
# SNR= 27.944612009929514
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.530649
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.165144
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.315845
#
# Power Allocated= 7.020242665518935
# CSI= 0.6795300986949392
# SNR= 29.807642281125027
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.391313
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.112997
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.818153
#
# Power Allocated= 0
# CSI= 0.0573822072727016
# SNR= 28.21586983209352
# Client: client17
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.987198296162842
# CSI= 0.6646065945012369
# SNR= 40.878017219320235
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.352047
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.030602
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.036644
#
# Power Allocated= 7.434414052096864
# CSI= 0.9456857011741718
# SNR= 47.25830962136973
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.521767
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.184040
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.393725
#
# Power Allocated= 7.364241848739735
# CSI= 0.8868346036561288
# SNR= 40.65308272828209
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.476456
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.051892
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.327371
#
# Power Allocated= 7.115951414003299
# CSI= 0.7267989008608746
# SNR= 22.367293680619564
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.405121
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.176073
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.126695
#
# Power Allocated= 7.334056659218291
# CSI= 0.8637136200525303
# SNR= 20.39888339220043
# Client: client45
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.00789647355461
# CSI= 0.6738765379972024
# SNR= 26.066492231320613
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.438106
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.147241
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.251488
#
#
# Test set: Average loss for Cluster1 model: 0.9028, Accuracy: 9704/10000 (97%)
#
# 0.11404000000001457
# Power Allocated= 7.017379255074322
# CSI= 0.5709477424211306
# SNR= 28.37825963670521
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.520701
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.297900
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.067744
#
# Power Allocated= 2.257761302687574
# CSI= 0.1535840748775703
# SNR= 27.467903280044528
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.753063
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.113956
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.163248
#
# Power Allocated= 6.029796168156427
# CSI= 0.36508917082449033
# SNR= 29.135258862067044
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.572054
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.263928
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.494999
#
# Power Allocated= 5.724009379800108
# CSI= 0.3284240879210397
# SNR= 31.154933584310992
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.718149
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.177691
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.293030
#
# Power Allocated= 2.2281688321551156
# CSI= 0.15288920381059967
# SNR= 30.31454226925601
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.619858
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.182085
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.490019
#
# Power Allocated= 5.954139415044825
# CSI= 0.35527593047401196
# SNR= 34.12418386506635
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.676026
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.208422
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.224680
#
# Power Allocated= 7.153893985336131
# CSI= 0.6192107476741937
# SNR= 22.539643657340317
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.843871
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.307697
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.658400
#
# Power Allocated= 7.425994334447984
# CSI= 0.7446799877881417
# SNR= 25.01358407223157
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.787068
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.039260
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.621306
#
# Power Allocated= 6.127212518821668
# CSI= 0.37855264342209427
# SNR= 20.175697877989833
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.685797
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.373281
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.546995
#
# Power Allocated= 3.150351377978092
# CSI= 0.17798339507905625
# SNR= 24.569257487334024
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.672783
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.316390
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.610210
#
# Power Allocated= 6.935159401514921
# CSI= 0.5453473700689876
# SNR= 21.424159648833253
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.801772
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.146655
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.251086
#
#
# Test set: Average loss for Cluster2 model: 5.1943, Accuracy: 9661/10000 (97%)
#
# 0.14270000000001107
# Power Allocated= 4.315347379313261
# CSI= 0.3714212034912413
# SNR= 33.08659623553197
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.325341
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.046824
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.026850
#
# Power Allocated= 5.473420520609678
# CSI= 0.6517681340836393
# SNR= 29.63866278002983
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.270229
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.039412
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.017610
#
# Power Allocated= 5.667490090727935
# CSI= 0.7461470522319245
# SNR= 31.869576689634215
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.335121
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.149129
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.478246
#
# Power Allocated= 5.468690760703579
# CSI= 0.6497650988025253
# SNR= 28.15719910386783
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.336455
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.112141
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.315427
#
# Power Allocated= 5.93377077724639
# CSI= 0.931152708451243
# SNR= 32.93561949613788
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.413634
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.047819
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.374461
#
# Power Allocated= 5.468953629776615
# CSI= 0.6498760996869503
# SNR= 27.701963003935607
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.415165
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.086707
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.132595
#
# Power Allocated= 5.254781432829523
# CSI= 0.5704743970938561
# SNR= 23.4785979638781
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.399747
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.219368
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.369766
#
# Power Allocated= 5.596757314066923
# CSI= 0.7087417513956791
# SNR= 28.801862778728324
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.335699
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.134029
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.167151
#
# Power Allocated= 5.239541771391789
# CSI= 0.5655575322803793
# SNR= 30.87682480968015
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.289133
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.124829
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.133132
#
# Power Allocated= 4.833772420091907
# CSI= 0.45999512991747515
# SNR= 22.669723086896926
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.345152
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.265912
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.052406
#
# Power Allocated= 0.860668803014951
# CSI= 0.16267993256227065
# SNR= 27.242960480764992
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.419690
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.051269
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.146693
#
# Power Allocated= 5.892663786584867
# CSI= 0.8968250389507183
# SNR= 39.326403762427944
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.316579
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.204165
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.092887
#
#
# Test set: Average loss for Cluster3 model: 3.5628, Accuracy: 9703/10000 (97%)
#
# 0.12732000000001703
# Power Allocated= 5.4401466259953875
# CSI= 0.41423665994550196
# SNR= 31.850183021569055
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.322882
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.109895
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.320166
#
# Power Allocated= 3.9689019245582347
# CSI= 0.25737881587009237
# SNR= 25.5733477121122
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.457500
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.248453
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.152978
#
# Power Allocated= 6.198431826229561
# CSI= 0.603939954317742
# SNR= 26.642824095690507
# Client: client8
# Model client8 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.401475
# Model client8 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.114898
# Model client8 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.437166
#
# Power Allocated= 6.10837403320419
# CSI= 0.5727863893353922
# SNR= 29.393295469924357
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.348529
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.172739
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.411253
#
# Power Allocated= 2.651307369262116
# CSI= 0.1921998310895766
# SNR= 24.114473131869538
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.427667
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.257491
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.194565
#
# Power Allocated= 1.890096593177038
# CSI= 0.16766907679614873
# SNR= 54.77606649051003
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.273954
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.107824
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.520027
#
# Power Allocated= 6.5595375224703485
# CSI= 0.7723868304143542
# SNR= 21.60006154573508
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.418660
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.259432
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.018122
#
# Power Allocated= 6.652306945741579
# CSI= 0.8320030799286562
# SNR= 24.321204709347292
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.464050
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.273111
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.416797
#
# Power Allocated= 5.3482345037047185
# CSI= 0.3990437205103802
# SNR= 28.41685886784671
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.356852
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.173301
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.246189
#
# Power Allocated= 6.1115521703950915
# CSI= 0.5738309876653457
# SNR= 25.703759201265733
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.358354
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.379158
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.401326
#
# Power Allocated= 5.007411166991506
# CSI= 0.35126982558604725
# SNR= 31.203880699820065
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.345992
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.166931
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.311669
#
# Power Allocated= 4.064968378844316
# CSI= 0.2639039655181007
# SNR= 25.29191295119692
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.567691
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.193774
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.288918
#
#
# Test set: Average loss for Cluster4 model: 3.9870, Accuracy: 9709/10000 (97%)
# ROUND 86
# 0.11776000000001571
# Power Allocated= 3.266140521850355
# CSI= 0.1913616553283598
# SNR= 25.87590887415036
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.332885
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.141928
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.243630
#
# Power Allocated= 0
# CSI= 0.07821933675496628
# SNR= 26.906891303371403
# Client: client14
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.463846462650929
# CSI= 0.49309631543159615
# SNR= 27.944612009929514
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.405691
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.048458
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_663174/982425597.py in <module>
#      73         index=0
#      74         for client in new_members:
# ---> 75             goodchannel=ClientUpdate(args, device, client,key_np,key,snrs[index],csis[index],smallmu1,head)
#      76             index+=1
#      77             if(goodchannel):
#
# /tmp/ipykernel_663174/1497942811.py in ClientUpdate(args, device, client, key_np, key, snr, csi, mu, head)
#      80         gc=True #considering the client model for training
#      81         for epoch in range(1, args.epochs + 1):
# ---> 82             for batch_idx, (data, target) in enumerate(client['trainset']):
#      83                 data = data.send(client['hook'])
#      84                 target = target.send(client['hook'])
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     361
#     362     def __next__(self):
# --> 363         data = self._next_data()
#     364         self._num_yielded += 1
#     365         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     401     def _next_data(self):
#     402         index = self._next_index()  # may raise StopIteration
# --> 403         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     404         if self._pin_memory:
#     405             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/Federated-Learning-In-Wireless-Sensor-Networks/K_clusters_notebooks/Dataset.py in __getitem__(self, item)
#     142
#     143     def __getitem__(self,item):
# --> 144         images,labels=self.dataset[self.indx[item]]
#     145         return (torch.tensor(images),torch.tensor(labels))
#     146
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#      92         # doing this so that it is consistent with all other datasets
#      93         # to return a PIL Image
# ---> 94         img = Image.fromarray(img.numpy(), mode='L')
#      95
#      96         if self.transform is not None:
#
# KeyboardInterrupt:
