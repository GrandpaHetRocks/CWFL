# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import numpy as np
from Dataset import load_dataset, getImage
from utils import averageModels
from utils import averageModelscluster
import random
import math
import matplotlib.pyplot as plt
from ipynb.fs.full.K_clusters import cluster_former
from copy import deepcopy
# Out:
# 0.7622261047363281
# {'Cluster Head': 'client79', 'Members': ['client7', 'client17', 'client29', 'client31', 'client38', 'client41', 'client42', 'client46', 'client51', 'client54', 'client59', 'client74', 'client81', 'client86', 'client100'], 'SNR': [19.927834857409128, 21.008901947794318, 54.813961993528736, 23.258422862079836, 23.390769260789536, 25.770361713891297, 39.26263353039717, 35.414374219421234, 24.899427702021715, 24.593965961506612, 26.45744222463239, 21.68842936756043, 28.049434779460658, 20.982681660747637, 26.21783863016665], 'CSI': [0.08129725746439342, 0.22646913686243797, 0.7205701468614406, 0.30905071315495114, 0.8098415553939374, 0.8570404296953152, 0.4348537987139187, 0.5735233895311365, 0.37917742659821907, 0.9466006102758378, 0.44182010796009175, 0.6724567931881174, 0.9128929426278298, 0.35186526589537437, 0.8666216030763775]}

# %%
P=2 #signal power threshold
#stream = BitStream()
#random.seed(10)
key=[]
for i in range (10000): #generating a random password to activate training (Pilot signal)
    temp=random.randint(0,1)
    key.append(temp)

key1=[0]*len(key)
for i in range (len(key)):   #bpsk modulation
    if(key[i]==1):
        #print("yay")
        key1[i]=-math.sqrt(P)
    else:
        key1[i]=math.sqrt(P)

#print(key)
        
key_np=np.array(key1)

# %%
class Arguments():
    def __init__(self):
        self.images = 10000
        self.clients = 50
        self.rounds = 200
        self.epochs = 3
        self.local_batches = 64
        self.lr = 0.01
        self.C = 1 #fraction of clients used in the round
        self.drop_rate = 0 #fraction of devices in the selected set to be dropped for various reasons
        self.torch_seed = 0 #same weights and parameters whenever the program is run
        self.log_interval = 64
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = True
        self.numclusters=4

args = Arguments()

# %%
#checking if gpu is available
#use_cuda = args.use_cuda and torch.cuda.is_available()
use_cuda=False
device = torch.device("cuda:0" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

hook = sy.TorchHook(torch)
me = hook.local_worker
clients = []

#generating virtual clients
for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})
#print(clients)

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid) #load data

for inx, client in enumerate(clients):  #return actual image set for each client
    trainset_ind_list = list(train_group[inx]) 
    client['trainset'] = getImage(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getImage(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images #useful while taking weighted average

# %%
#load dataset for global model (to compare accuracies)
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.MNIST('./', train=False, download=True, transform=transform)
# global_test_dataset = torch.utils.data.random_split(global_test_dataset, [10000, len(global_test_dataset)-10000])[0]
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
"""class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        #self.quant = torch.quantization.QuantStub()
        self.conv1 = nn.Conv2d(1, 5, 5, 1)
        self.conv2 = nn.Conv2d(5, 10, 5, 1)
        self.fc1 = nn.Linear(4*4*10, 50) #10 iid #50 non iid
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        #x=self.quant(x)
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*10
                   )
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1) """

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x)

# %%
def fedprox(params,global_params):
    global_param=[]
    ind=0
    for gp in global_params:
        global_param.append(gp)
    for p in params:
    #                 print(p.grad)
        lr=0.001
        mu=0.1
        if(p.grad is None):
            continue
        grad=p.grad.data #batch gradients
        p.data.sub_(lr,(grad+mu*(p.data.clone()-global_param[ind].data.clone())))
        ind+=1
    return(p)

# %%
def ClientUpdate(args, device, client,key_np,key,snr,csi,mu,head):
    gc=False
    client['model'].train()
    #simulating a wireless channel
    poptim=max((1/mu-1/csi),0)
    #print(mu,csi)
    print("Power Allocated=",poptim)
    print("CSI=",csi)
    
    snr__=10**(snr/10)
    
    absh=csi*poptim/snr__
    x=random.uniform(0,absh)
    #print(x)
    y=math.sqrt(absh*absh-x*x)
    #x=x*100
    #y=y*100
    #x=random.random()
    #y=random.random()
    #snr=10*math.log(poptim/(std*std),10)
    std=math.sqrt(poptim/snr__*absh*absh) #channel noise
    
    #print(x,y)
    h=complex(x,y)
    #std=math.sqrt(abs(h)/csi)
    #snr=poptim/(std*std)
    #print(std)
    print("SNR=",snr)
    #print("csi",abs(h)/(std*std))
    
    
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data

    
    #print(client['model'].conv1.weight.size)
    client['model'].send(client['hook'])
    head['model'].send(client['hook'])
    print("Client:",client['hook'].id)
    
    key_np_received=h*key_np+(np.random.randn(len(key_np))*std*2)
    #print(key_np_received)
    key_np_received=(key_np_received/(h)).real
    
    for o in range (len(key_np_received)):  #demodulation bpsk
        if(key_np_received[o]>=0):
            key_np_received[o]=0
        else:
            key_np_received[o]=1
    
    key_np_received=key_np_received.tolist()
    key_np_received = [int(item) for item in key_np_received]
    #key_np=key_np.tolist()
    
    
    if(sum(np.bitwise_xor(key,key_np_received))/len(key)==0 and poptim>0): #...............................................checking if channel is good enough for transmission by checking BER..................................#
        gc=True #considering the client model for training
        for epoch in range(1, args.epochs + 1):
            for batch_idx, (data, target) in enumerate(client['trainset']): 
                data = data.send(client['hook'])
                target = target.send(client['hook'])
                #client['optim'].zero_grad()
                #train model on client
                data, target = data.to(device), target.to(device) #send data to cpu/gpu (data is stored locally)
                output = client['model'](data)
                loss = F.nll_loss(output, target)
                loss.backward()
                #client['optim'].step()
                params=client['model'].parameters()
                gp=head['model'].parameters()
                params=fedprox(params,gp) 
                
                if batch_idx % args.log_interval == 0:
                    loss = loss.get() 
                    print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                        client['hook'].id,
                        epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                        100. * batch_idx / len(client['trainset']), loss))
    else:
        print("Poor Channel, client not taken for averaging in this round")
            
                    
    client['model'].get()
    head['model'].get()
    # print()
         #CHANGE
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
    #CHANGE ENDS
    print()
    return gc

# %%
def test(args, model, device, test_loader, name,fed_round):
    model.eval()    #no need to train the model while testing
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            if(use_cuda and fed_round==0):
                data,target=data.cuda(),target.cuda()
                #model.cuda()
            else:
                data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    return([100. * correct / len(test_loader.dataset),test_loss])

# %%
torch.manual_seed(args.torch_seed)

# %%
def distort(neighbours,snrs):
    ind=0
    poptim=2
    csi=random.random()
    distorted_models=[]
    for client in neighbours:
        snr=snrs[ind]
        ind+=1
        snr__=10**(snr/10)
        absh=csi*poptim/snr__
        x=random.uniform(0,absh)
        y=math.sqrt(absh*absh-x*x)
        std=math.sqrt(poptim/snr__*absh*absh) #channel noise
        h=complex(x,y)
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
        
        distorted_models.append(client)
    return(distorted_models)

# %%
def decentralized(clients,snrs,weights):
    big_daddy_of_distorted_models=[]
    for client in clients:
        distorted_models=[]
        snr_list=[]
        for snr in snrs:
            if(client['hook'].id in snr):
                snr_list.append(snr[2])
        neighbours_c = [x for x in clients if x != client]
        neighbours={}
        jjj=[jkl for jkl in range(len(neighbours_c))]
        
        dictionary = dict(zip(jjj, neighbours_c))
        #for jjj in range(len(neighbours_c)):
        #   neighbours[jjj].append(neighbours_c[jjj])
        distorted_models=distort(neighbours,snr_list)
        distorted_models.append(client)
        big_daddy_of_distorted_models.append(distorted_models)
    
    
    weight_final1=[]
    for oho in big_daddy_of_distorted_models:
        weight_final=[]
        for comeon in oho:
            for w in weights:
                if(comeon['hook'].id==w[0]):
                    weight_final.append(w[1])
        weight_final1.append(weight_final)
    
    final_heads=[]
    nets=[]
    ind=0
    for client in clients:
        for oof in big_daddy_of_distorted_models:
            if(client==oof[0]):
#                 print(client)
#                 print("shut up")
#                 print(distorted_models)
#                 print("shut up")
#                 print(weight_final1)
                
                overall=Net()
                overall=averageModelscluster(overall,distorted_models,weight_final1[ind])
                client['model'].load_state_dict(overall.state_dict())
                ind+=1
                final_heads.append(client)
                nets.append(overall)
    
    return(final_heads,nets)

# %%
for client in clients: #give the model and optimizer to every client
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    #client['model'] = torch.quantization.quantize_dynamic(
    #client['model'],  # the original model
    #{torch.nn.Linear},  # a set of layers to dynamically quantize
    #dtype=torch.fp)  # the target dtype for quantized weights
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)

final_acc=[]
final_loss=[]
    
for fed_round in range(args.rounds):
    overall=Net()
    if(fed_round==0): #fed_round==0
        arranged_clusters,head_snr_list=cluster_former(args.numclusters,args.clients)
        temp=deepcopy(arranged_clusters)
        temp2=deepcopy(head_snr_list)
    else:
        #print(temp)
        arranged_clusters=deepcopy(temp)
        head_snr_list=deepcopy(temp2)
#     print(arranged_clusters)
    
    no=1
    heads_list=[]
    weights=[]
    weight_head_list=[]
    head_acc=[]
    head_loss=[]
    for cluster in arranged_clusters:
        
        head=cluster['Cluster Head']
        members=cluster['Members']
        snrs=cluster['SNR']
        csis=cluster['CSI']
        weights.append(sum(snrs))
        weight_head_list.append([head,sum(snrs)])
        new_members=[]
        
        for ij in members:
        #print(ij)
            cl_no=int(ij[6:])
            new_members.append(clients[cl_no-1])
#         print(head)
        head=clients[int(head[6:])-1]
        cluster['Members']=new_members
#         print(head)

        smallmu1=0
        gsmall1=3.402823466E+38 
        
        #water filling algorithm
        mu=1e-15
        while(mu<=1):
            g1=0
            pn1=0
            for jj in csis:
                pn=max(1/mu-1/jj,0)
                g1+=math.log(1+pn*jj) #capacity of a channel (shannon's law)
                pn1+=pn
            g=g1-mu*(pn1-P*30)
            if(g<gsmall1):
                smallmu1=mu
                gsmall1=g
            mu+=0.00002
        
        print(smallmu1)
        good_mem=[]
#         print(len(snrs))
#         print(len(csis))
#         print(len(new_members))
        index=0
        for client in new_members:
            goodchannel=ClientUpdate(args, device, client,key_np,key,snrs[index],csis[index],smallmu1,head)
            index+=1
            if(goodchannel):
                good_mem.append(client)
        
        head['model']=averageModels(head['model'], good_mem)
        arr=test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)
        ac=arr[0]#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[0]
        no+=1
        heads_list.append(head)
        head_acc.append(ac)
        head_loss.append(arr[1])#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[1])
    
    final_acc.append(head_acc)
    final_loss.append(head_loss)
    fig,ax=plt.subplots()
    clor = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(args.numclusters)]
    #ax.plot([i for i in range(fed_round)],head_acc[0])
    for jj in range(0,args.numclusters):
        
        ax.plot([i for i in range(len(final_acc))],[final_acc[j][jj] for j in range(len(final_acc))], color = clor[jj])
        
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][0] for j in range(len(final_acc))], color ="red")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][1] for j in range(len(final_acc))],color ="blue")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][2] for j in range(len(final_acc))],color ="green")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][3] for j in range(len(final_acc))],color ="black")
    #ax.plot([i for i in range(len(final_acc))],head_acc[1], fed_round, color ="blue")
    #ax.plot([i for i in range(len(final_acc))],head_acc[2], fed_round, color ="green")
    #ax.plot([i for i in range(len(final_acc))],head_acc[3], fed_round, color ="black")
    
    
    plt.show()
    weightsum=sum(weights)
    
    weights[:] = [x / weightsum for x in weights]
    for aah in range(len(weight_head_list)):
        weight_head_list[aah][1]=weights[aah]
    final_heads,nets=decentralized(heads_list,head_snr_list,weight_head_list)
    
    for head in range(len(final_heads)):
        for cluster in arranged_clusters:
            head1=cluster['Cluster Head']
            if(head1==final_heads[head]['hook'].id):
                for mem in cluster['Members']:
                    mem['model'].load_state_dict(nets[head].state_dict())
    print("ROUND",fed_round)
# Out:
# 0.1108400000000136
# Power Allocated= 7.7267944207572565
# CSI= 0.7720700314102752
# SNR= 27.372803967967307
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300563
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook.py:165: UserWarning: This overload of sub_ is deprecated:
# 	sub_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	sub_(Tensor other, *, Number alpha) (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629411241/work/torch/csrc/utils/python_arg_parser.cpp:766.)
#   response = method(*args, **kwargs)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304367
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272805
#
# Power Allocated= 6.304697730566481
# CSI= 0.36801020061540723
# SNR= 26.54305170991507
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.283958
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.322433
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.280830
#
# Power Allocated= 7.835625540306173
# CSI= 0.842894444355322
# SNR= 30.38539365677691
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.347556
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.303932
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.235312
#
# Power Allocated= 6.970499240429884
# CSI= 0.48744476977689244
# SNR= 32.70520648265001
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.329684
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293273
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.277414
#
# Power Allocated= 0
# CSI= 0.037233490417702186
# SNR= 31.023827003242513
# Client: client17
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.09287875868562667
# SNR= 39.956554296916586
# Client: client22
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.749314739774576
# CSI= 0.7857317564297636
# SNR= 48.76365583007644
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.329733
# /tmp/ipykernel_668792/1497942811.py:66: RuntimeWarning: invalid value encountered in true_divide
#   key_np_received=(key_np_received/(h)).real
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.313967
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.273844
#
# Power Allocated= 6.146701242476175
# CSI= 0.3477882873919189
# SNR= 40.71043647249153
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.292767
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.333472
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.263073
#
# Power Allocated= 5.2637060187576585
# CSI= 0.26607720315440264
# SNR= 20.24379990130509
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.345087
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.322297
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.270777
#
# Power Allocated= 4.940851877562826
# CSI= 0.245028264060553
# SNR= 20.5690506707594
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.313605
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288679
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.257710
#
# Power Allocated= 7.059545269257699
# CSI= 0.5095623335776032
# SNR= 26.874398941090973
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.310693
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.329513
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.313376
#
#
# Test set: Average loss for Cluster1 model: 2.2164, Accuracy: 3844/10000 (38%)
#
# 0.13480000000001413
# Power Allocated= 5.480740477288595
# CSI= 0.5160871729073614
# SNR= 28.630615905602994
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302896
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.307228
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272739
#
# Power Allocated= 5.77683541532793
# CSI= 0.6091758164452228
# SNR= 23.755187578029414
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.328006
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.333692
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.235808
#
# Power Allocated= 5.4427453606938405
# CSI= 0.5061619483873862
# SNR= 29.015717887694294
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.359601
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.254431
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.250138
#
# Power Allocated= 4.970686174517494
# CSI= 0.408544887653559
# SNR= 33.54801759182378
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304262
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.331954
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.259900
#
# Power Allocated= 5.586654268596948
# CSI= 0.5459280067250317
# SNR= 27.866466263405908
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.308686
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295260
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.283384
#
# Power Allocated= 5.097762271868685
# CSI= 0.4309164721512553
# SNR= 31.700405826678917
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.322855
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.319804
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.270524
#
# Power Allocated= 6.322794524490216
# CSI= 0.9127392926505502
# SNR= 25.489526374166697
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.327292
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.323158
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.274994
#
# Power Allocated= 4.471128382467864
# CSI= 0.3392971314570369
# SNR= 24.208641932022466
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.324862
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.273339
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.273674
#
# Power Allocated= 6.360966624693519
# CSI= 0.9456881807499267
# SNR= 18.759231526494126
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300049
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301510
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.256223
#
# Power Allocated= 6.269435716811126
# CSI= 0.8703508723004577
# SNR= 23.2476074881916
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.311465
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.280956
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.282012
#
# Power Allocated= 4.224613724969171
# CSI= 0.31310822239481395
# SNR= 22.83952802968699
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.313122
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.320261
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.250400
#
#
# Test set: Average loss for Cluster2 model: 2.1520, Accuracy: 4469/10000 (45%)
#
# 0.12480000000001787
# Power Allocated= 4.553706421428434
# CSI= 0.2890913608454857
# SNR= 32.2889702362765
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305634
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.274669
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.269303
#
# Power Allocated= 3.8826247732733687
# CSI= 0.24211927546802492
# SNR= 26.780627877616233
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295627
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.315829
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.274095
#
# Power Allocated= 4.978835445333782
# CSI= 0.3295995127717457
# SNR= 36.253038415473036
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299375
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301825
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.246922
#
# Power Allocated= 6.902265963399368
# CSI= 0.9004510408986792
# SNR= 30.070085721817602
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.327363
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.254437
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272924
#
# Power Allocated= 7.007866900814742
# CSI= 0.9950708053133495
# SNR= 35.48823490007299
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.346537
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.290880
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.271944
#
# Power Allocated= 3.7250558845656006
# CSI= 0.2332217569524706
# SNR= 28.24177210918613
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.313697
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293123
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.267551
#
# Power Allocated= 6.849650293552463
# CSI= 0.859719397415675
# SNR= 26.97803560390833
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.342578
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.271484
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.275033
#
# Power Allocated= 0
# CSI= 0.12283264301251517
# SNR= 30.73315824588984
# Client: client33
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.716106130836049
# CSI= 0.771179848002076
# SNR= 26.795868157558704
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.336184
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294717
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.268596
#
# Power Allocated= 6.293775092461766
# CSI= 0.581718195550632
# SNR= 25.796500572145245
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.314855
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296960
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.280300
#
# Power Allocated= 6.219604564979497
# CSI= 0.55765732019315
# SNR= 26.402396663210556
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.313343
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.317152
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.267989
#
# Power Allocated= 2.8692694957061704
# CSI= 0.19441821354019495
# SNR= 40.07877319158733
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.332200
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.277433
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.283296
#
#
# Test set: Average loss for Cluster3 model: 2.1053, Accuracy: 3472/10000 (35%)
#
# 0.12214000000001705
# Power Allocated= 4.664896784407732
# CSI= 0.28389498647362843
# SNR= 29.318660749751952
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.277389
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300192
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.270205
#
# Power Allocated= 4.4302844784496855
# CSI= 0.2661668733553847
# SNR= 23.779682419315783
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301981
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.311697
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.319019
#
# Power Allocated= 5.932663797960879
# CSI= 0.44352541614715857
# SNR= 26.462557647197517
# Client: client8
# Model client8 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.340637
# Model client8 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.284421
# Model client8 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265301
#
# Power Allocated= 6.074860334161992
# CSI= 0.4733804705209943
# SNR= 26.176793329212586
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.321299
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288525
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.260785
#
# Power Allocated= 6.992593686410622
# CSI= 0.8370075643337088
# SNR= 23.531144323247318
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.359365
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.332807
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.233445
#
# Power Allocated= 6.767981221553068
# CSI= 0.704550438746556
# SNR= 51.064265362315226
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299729
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.326492
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.253782
#
# Power Allocated= 0
# CSI= 0.014912810277535327
# SNR= 21.931991015976102
# Client: client32
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.7744798523088186
# CSI= 0.4144483032825582
# SNR= 27.351305490731402
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.374212
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.315529
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272082
#
# Power Allocated= 6.579682482623115
# CSI= 0.6220284392484441
# SNR= 28.193179114023543
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.285453
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294686
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.269680
#
# Power Allocated= 2.4832942932965683
# CSI= 0.17531459291110651
# SNR= 22.7643707075083
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.346691
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.305079
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.255087
#
# Power Allocated= 4.978863353445699
# CSI= 0.3116757475896036
# SNR= 33.9296461620172
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307908
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.283208
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.274307
#
# Power Allocated= 5.320769455738145
# CSI= 0.3488506079747954
# SNR= 26.228555407001522
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.347480
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288421
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.233557
#
#
# Test set: Average loss for Cluster4 model: 2.1173, Accuracy: 3933/10000 (39%)
# ROUND 0
# 0.1108400000000136
# Power Allocated= 7.7267944207572565
# CSI= 0.7720700314102752
# SNR= 27.372803967967307
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296669
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304991
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285380
#
# Power Allocated= 6.304697730566481
# CSI= 0.36801020061540723
# SNR= 26.54305170991507
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300419
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302027
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.298076
#
# Power Allocated= 7.835625540306173
# CSI= 0.842894444355322
# SNR= 30.38539365677691
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298018
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296924
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.286212
#
# Power Allocated= 6.970499240429884
# CSI= 0.48744476977689244
# SNR= 32.70520648265001
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303267
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293959
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.293257
#
# Power Allocated= 0
# CSI= 0.037233490417702186
# SNR= 31.023827003242513
# Client: client17
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.09287875868562667
# SNR= 39.956554296916586
# Client: client22
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.749314739774576
# CSI= 0.7857317564297636
# SNR= 48.76365583007644
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300852
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300875
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.291984
#
# Power Allocated= 6.146701242476175
# CSI= 0.3477882873919189
# SNR= 40.71043647249153
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301835
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298264
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288099
#
# Power Allocated= 5.2637060187576585
# CSI= 0.26607720315440264
# SNR= 20.24379990130509
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300499
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297470
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284800
#
# Power Allocated= 4.940851877562826
# CSI= 0.245028264060553
# SNR= 20.5690506707594
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302328
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296679
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.282444
#
# Power Allocated= 7.059545269257699
# CSI= 0.5095623335776032
# SNR= 26.874398941090973
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303053
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296755
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.280535
#
#
# Test set: Average loss for Cluster1 model: 2.2714, Accuracy: 3071/10000 (31%)
#
# 0.13480000000001413
# Power Allocated= 5.480740477288595
# CSI= 0.5160871729073614
# SNR= 28.630615905602994
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304223
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298866
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.300767
#
# Power Allocated= 5.77683541532793
# CSI= 0.6091758164452228
# SNR= 23.755187578029414
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297575
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297443
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.282883
#
# Power Allocated= 5.4427453606938405
# CSI= 0.5061619483873862
# SNR= 29.015717887694294
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301805
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304420
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.301844
#
# Power Allocated= 4.970686174517494
# CSI= 0.408544887653559
# SNR= 33.54801759182378
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300471
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299135
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288417
#
# Power Allocated= 5.586654268596948
# CSI= 0.5459280067250317
# SNR= 27.866466263405908
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.306527
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296872
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.297282
#
# Power Allocated= 5.097762271868685
# CSI= 0.4309164721512553
# SNR= 31.700405826678917
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302010
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302570
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.300189
#
# Power Allocated= 6.322794524490216
# CSI= 0.9127392926505502
# SNR= 25.489526374166697
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301779
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.290322
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.286771
#
# Power Allocated= 4.471128382467864
# CSI= 0.3392971314570369
# SNR= 24.208641932022466
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302278
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302942
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.292938
#
# Power Allocated= 6.360966624693519
# CSI= 0.9456881807499267
# SNR= 18.759231526494126
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301271
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300799
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289548
#
# Power Allocated= 6.269435716811126
# CSI= 0.8703508723004577
# SNR= 23.2476074881916
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305908
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.290713
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.295090
#
# Power Allocated= 4.224613724969171
# CSI= 0.31310822239481395
# SNR= 22.83952802968699
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303990
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293550
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.307338
#
#
# Test set: Average loss for Cluster2 model: 2.2699, Accuracy: 2650/10000 (26%)
#
# 0.12480000000001787
# Power Allocated= 4.553706421428434
# CSI= 0.2890913608454857
# SNR= 32.2889702362765
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.294542
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291179
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289984
#
# Power Allocated= 3.8826247732733687
# CSI= 0.24211927546802492
# SNR= 26.780627877616233
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298043
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294901
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.273274
#
# Power Allocated= 4.978835445333782
# CSI= 0.3295995127717457
# SNR= 36.253038415473036
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.306619
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296674
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.283705
#
# Power Allocated= 6.902265963399368
# CSI= 0.9004510408986792
# SNR= 30.070085721817602
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301137
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294672
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.283737
#
# Power Allocated= 7.007866900814742
# CSI= 0.9950708053133495
# SNR= 35.48823490007299
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298027
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295958
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285230
#
# Power Allocated= 3.7250558845656006
# CSI= 0.2332217569524706
# SNR= 28.24177210918613
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301871
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300481
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289052
#
# Power Allocated= 6.849650293552463
# CSI= 0.859719397415675
# SNR= 26.97803560390833
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295794
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291810
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.271190
#
# Power Allocated= 0
# CSI= 0.12283264301251517
# SNR= 30.73315824588984
# Client: client33
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.716106130836049
# CSI= 0.771179848002076
# SNR= 26.795868157558704
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.293335
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299585
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284993
#
# Power Allocated= 6.293775092461766
# CSI= 0.581718195550632
# SNR= 25.796500572145245
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302982
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.303395
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.293315
#
# Power Allocated= 6.219604564979497
# CSI= 0.55765732019315
# SNR= 26.402396663210556
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.310396
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298237
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285721
#
# Power Allocated= 2.8692694957061704
# CSI= 0.19441821354019495
# SNR= 40.07877319158733
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.308381
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296277
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289683
#
#
# Test set: Average loss for Cluster3 model: 2.2038, Accuracy: 2758/10000 (28%)
#
# 0.12214000000001705
# Power Allocated= 4.664896784407732
# CSI= 0.28389498647362843
# SNR= 29.318660749751952
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302662
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294102
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.278545
#
# Power Allocated= 4.4302844784496855
# CSI= 0.2661668733553847
# SNR= 23.779682419315783
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298102
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299499
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284626
#
# Power Allocated= 5.932663797960879
# CSI= 0.44352541614715857
# SNR= 26.462557647197517
# Client: client8
# Model client8 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298723
# Model client8 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299647
# Model client8 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285618
#
# Power Allocated= 6.074860334161992
# CSI= 0.4733804705209943
# SNR= 26.176793329212586
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298606
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295572
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.294943
#
# Power Allocated= 6.992593686410622
# CSI= 0.8370075643337088
# SNR= 23.531144323247318
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301569
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.290996
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288345
#
# Power Allocated= 6.767981221553068
# CSI= 0.704550438746556
# SNR= 51.064265362315226
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.306714
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297543
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.294179
#
# Power Allocated= 0
# CSI= 0.014912810277535327
# SNR= 21.931991015976102
# Client: client32
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.7744798523088186
# CSI= 0.4144483032825582
# SNR= 27.351305490731402
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304611
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295556
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288141
#
# Power Allocated= 6.579682482623115
# CSI= 0.6220284392484441
# SNR= 28.193179114023543
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305861
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298752
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.298338
#
# Power Allocated= 2.4832942932965683
# CSI= 0.17531459291110651
# SNR= 22.7643707075083
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301386
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297057
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.300617
#
# Power Allocated= 4.978863353445699
# CSI= 0.3116757475896036
# SNR= 33.9296461620172
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297207
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293561
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284761
#
# Power Allocated= 5.320769455738145
# CSI= 0.3488506079747954
# SNR= 26.228555407001522
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303332
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302359
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284693
#
#
# Test set: Average loss for Cluster4 model: 2.2390, Accuracy: 3820/10000 (38%)
# ROUND 1
# 0.1108400000000136
# Power Allocated= 7.7267944207572565
# CSI= 0.7720700314102752
# SNR= 27.372803967967307
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300102
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292866
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284055
#
# Power Allocated= 6.304697730566481
# CSI= 0.36801020061540723
# SNR= 26.54305170991507
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302427
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294486
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.291851
#
# Power Allocated= 7.835625540306173
# CSI= 0.842894444355322
# SNR= 30.38539365677691
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300919
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300222
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.295089
#
# Power Allocated= 6.970499240429884
# CSI= 0.48744476977689244
# SNR= 32.70520648265001
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302603
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299196
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.279778
#
# Power Allocated= 0
# CSI= 0.037233490417702186
# SNR= 31.023827003242513
# Client: client17
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.09287875868562667
# SNR= 39.956554296916586
# Client: client22
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.749314739774576
# CSI= 0.7857317564297636
# SNR= 48.76365583007644
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301767
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302505
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.303077
#
# Power Allocated= 6.146701242476175
# CSI= 0.3477882873919189
# SNR= 40.71043647249153
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301226
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292911
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.254373
#
# Power Allocated= 5.2637060187576585
# CSI= 0.26607720315440264
# SNR= 20.24379990130509
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301929
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296644
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.301547
#
# Power Allocated= 4.940851877562826
# CSI= 0.245028264060553
# SNR= 20.5690506707594
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300798
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293858
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.244856
#
# Power Allocated= 7.059545269257699
# CSI= 0.5095623335776032
# SNR= 26.874398941090973
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300789
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301742
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.274757
#
#
# Test set: Average loss for Cluster1 model: 2.2619, Accuracy: 1993/10000 (20%)
#
# 0.13480000000001413
# Power Allocated= 5.480740477288595
# CSI= 0.5160871729073614
# SNR= 28.630615905602994
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300402
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295518
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.298307
#
# Power Allocated= 5.77683541532793
# CSI= 0.6091758164452228
# SNR= 23.755187578029414
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300191
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300002
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.311378
#
# Power Allocated= 5.4427453606938405
# CSI= 0.5061619483873862
# SNR= 29.015717887694294
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303544
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302866
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.295624
#
# Power Allocated= 4.970686174517494
# CSI= 0.408544887653559
# SNR= 33.54801759182378
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301708
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300576
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.300589
#
# Power Allocated= 5.586654268596948
# CSI= 0.5459280067250317
# SNR= 27.866466263405908
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301256
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302678
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285581
#
# Power Allocated= 5.097762271868685
# CSI= 0.4309164721512553
# SNR= 31.700405826678917
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302356
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297156
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287933
#
# Power Allocated= 6.322794524490216
# CSI= 0.9127392926505502
# SNR= 25.489526374166697
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298467
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298869
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.293608
#
# Power Allocated= 4.471128382467864
# CSI= 0.3392971314570369
# SNR= 24.208641932022466
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302514
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300858
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.291423
#
# Power Allocated= 6.360966624693519
# CSI= 0.9456881807499267
# SNR= 18.759231526494126
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302627
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300718
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265996
#
# Power Allocated= 6.269435716811126
# CSI= 0.8703508723004577
# SNR= 23.2476074881916
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303316
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300016
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.299743
#
# Power Allocated= 4.224613724969171
# CSI= 0.31310822239481395
# SNR= 22.83952802968699
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300210
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295709
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.302698
#
#
# Test set: Average loss for Cluster2 model: 2.2666, Accuracy: 3002/10000 (30%)
#
# 0.12480000000001787
# Power Allocated= 4.553706421428434
# CSI= 0.2890913608454857
# SNR= 32.2889702362765
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300717
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300206
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.281202
#
# Power Allocated= 3.8826247732733687
# CSI= 0.24211927546802492
# SNR= 26.780627877616233
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302131
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294762
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.260764
#
# Power Allocated= 4.978835445333782
# CSI= 0.3295995127717457
# SNR= 36.253038415473036
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303600
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297323
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288575
#
# Power Allocated= 6.902265963399368
# CSI= 0.9004510408986792
# SNR= 30.070085721817602
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300756
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295160
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.263373
#
# Power Allocated= 7.007866900814742
# CSI= 0.9950708053133495
# SNR= 35.48823490007299
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302852
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299275
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287109
#
# Power Allocated= 3.7250558845656006
# CSI= 0.2332217569524706
# SNR= 28.24177210918613
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302299
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293921
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288630
#
# Power Allocated= 6.849650293552463
# CSI= 0.859719397415675
# SNR= 26.97803560390833
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300537
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289386
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287426
#
# Power Allocated= 0
# CSI= 0.12283264301251517
# SNR= 30.73315824588984
# Client: client33
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.716106130836049
# CSI= 0.771179848002076
# SNR= 26.795868157558704
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303331
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295406
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.276974
#
# Power Allocated= 6.293775092461766
# CSI= 0.581718195550632
# SNR= 25.796500572145245
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304332
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.303549
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.286319
#
# Power Allocated= 6.219604564979497
# CSI= 0.55765732019315
# SNR= 26.402396663210556
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303760
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301441
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.274817
#
# Power Allocated= 2.8692694957061704
# CSI= 0.19441821354019495
# SNR= 40.07877319158733
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301184
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299478
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.292315
#
#
# Test set: Average loss for Cluster3 model: 2.1642, Accuracy: 1973/10000 (20%)
#
# 0.12214000000001705
# Power Allocated= 4.664896784407732
# CSI= 0.28389498647362843
# SNR= 29.318660749751952
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301947
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296307
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.283108
#
# Power Allocated= 4.4302844784496855
# CSI= 0.2661668733553847
# SNR= 23.779682419315783
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300177
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292666
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.292539
#
# Power Allocated= 5.932663797960879
# CSI= 0.44352541614715857
# SNR= 26.462557647197517
# Client: client8
# Model client8 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301011
# Model client8 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296607
# Model client8 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.293126
#
# Power Allocated= 6.074860334161992
# CSI= 0.4733804705209943
# SNR= 26.176793329212586
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301337
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301431
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284374
#
# Power Allocated= 6.992593686410622
# CSI= 0.8370075643337088
# SNR= 23.531144323247318
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302182
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304666
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285864
#
# Power Allocated= 6.767981221553068
# CSI= 0.704550438746556
# SNR= 51.064265362315226
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302475
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294621
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.300997
#
# Power Allocated= 0
# CSI= 0.014912810277535327
# SNR= 21.931991015976102
# Client: client32
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.7744798523088186
# CSI= 0.4144483032825582
# SNR= 27.351305490731402
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302359
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299824
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.298815
#
# Power Allocated= 6.579682482623115
# CSI= 0.6220284392484441
# SNR= 28.193179114023543
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302676
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295871
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.297482
#
# Power Allocated= 2.4832942932965683
# CSI= 0.17531459291110651
# SNR= 22.7643707075083
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302815
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302060
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.275268
#
# Power Allocated= 4.978863353445699
# CSI= 0.3116757475896036
# SNR= 33.9296461620172
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301700
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297299
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.278377
#
# Power Allocated= 5.320769455738145
# CSI= 0.3488506079747954
# SNR= 26.228555407001522
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301122
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293410
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287446
#
#
# Test set: Average loss for Cluster4 model: 2.2227, Accuracy: 2129/10000 (21%)
# ROUND 2
# 0.1108400000000136
# Power Allocated= 7.7267944207572565
# CSI= 0.7720700314102752
# SNR= 27.372803967967307
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300166
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.287754
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.251780
#
# Power Allocated= 6.304697730566481
# CSI= 0.36801020061540723
# SNR= 26.54305170991507
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303040
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292477
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.266158
#
# Power Allocated= 7.835625540306173
# CSI= 0.842894444355322
# SNR= 30.38539365677691
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298082
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294680
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.281846
#
# Power Allocated= 6.970499240429884
# CSI= 0.48744476977689244
# SNR= 32.70520648265001
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299651
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294243
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.253840
#
# Power Allocated= 0
# CSI= 0.037233490417702186
# SNR= 31.023827003242513
# Client: client17
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.09287875868562667
# SNR= 39.956554296916586
# Client: client22
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.749314739774576
# CSI= 0.7857317564297636
# SNR= 48.76365583007644
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304853
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293100
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.269851
#
# Power Allocated= 6.146701242476175
# CSI= 0.3477882873919189
# SNR= 40.71043647249153
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301310
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292932
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288262
#
# Power Allocated= 5.2637060187576585
# CSI= 0.26607720315440264
# SNR= 20.24379990130509
# Client: client44
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.940851877562826
# CSI= 0.245028264060553
# SNR= 20.5690506707594
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304092
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292117
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.250299
#
# Power Allocated= 7.059545269257699
# CSI= 0.5095623335776032
# SNR= 26.874398941090973
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300974
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288461
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.270734
#
#
# Test set: Average loss for Cluster1 model: 2.2004, Accuracy: 2800/10000 (28%)
#
# 0.13480000000001413
# Power Allocated= 5.480740477288595
# CSI= 0.5160871729073614
# SNR= 28.630615905602994
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302915
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293601
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.315110
#
# Power Allocated= 5.77683541532793
# CSI= 0.6091758164452228
# SNR= 23.755187578029414
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300443
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291700
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.278596
#
# Power Allocated= 5.4427453606938405
# CSI= 0.5061619483873862
# SNR= 29.015717887694294
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304317
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299132
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.294118
#
# Power Allocated= 4.970686174517494
# CSI= 0.408544887653559
# SNR= 33.54801759182378
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304741
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299392
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272010
#
# Power Allocated= 5.586654268596948
# CSI= 0.5459280067250317
# SNR= 27.866466263405908
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301317
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301132
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.279385
#
# Power Allocated= 5.097762271868685
# CSI= 0.4309164721512553
# SNR= 31.700405826678917
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302115
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295950
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.288061
#
# Power Allocated= 6.322794524490216
# CSI= 0.9127392926505502
# SNR= 25.489526374166697
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301096
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296538
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.262047
#
# Power Allocated= 4.471128382467864
# CSI= 0.3392971314570369
# SNR= 24.208641932022466
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302970
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.290772
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.294531
#
# Power Allocated= 6.360966624693519
# CSI= 0.9456881807499267
# SNR= 18.759231526494126
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302793
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293150
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.235013
#
# Power Allocated= 6.269435716811126
# CSI= 0.8703508723004577
# SNR= 23.2476074881916
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299734
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296326
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.283789
#
# Power Allocated= 4.224613724969171
# CSI= 0.31310822239481395
# SNR= 22.83952802968699
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301153
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299755
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.276873
#
#
# Test set: Average loss for Cluster2 model: 2.1812, Accuracy: 2933/10000 (29%)
#
# 0.12480000000001787
# Power Allocated= 4.553706421428434
# CSI= 0.2890913608454857
# SNR= 32.2889702362765
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300865
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292710
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.194334
#
# Power Allocated= 3.8826247732733687
# CSI= 0.24211927546802492
# SNR= 26.780627877616233
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300569
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.281920
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.144206
#
# Power Allocated= 4.978835445333782
# CSI= 0.3295995127717457
# SNR= 36.253038415473036
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301733
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297065
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.256766
#
# Power Allocated= 6.902265963399368
# CSI= 0.9004510408986792
# SNR= 30.070085721817602
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297045
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289245
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.209294
#
# Power Allocated= 7.007866900814742
# CSI= 0.9950708053133495
# SNR= 35.48823490007299
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298439
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.280775
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.219493
#
# Power Allocated= 3.7250558845656006
# CSI= 0.2332217569524706
# SNR= 28.24177210918613
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302332
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296506
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272604
#
# Power Allocated= 6.849650293552463
# CSI= 0.859719397415675
# SNR= 26.97803560390833
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298512
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.283233
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.167158
#
# Power Allocated= 0
# CSI= 0.12283264301251517
# SNR= 30.73315824588984
# Client: client33
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.716106130836049
# CSI= 0.771179848002076
# SNR= 26.795868157558704
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301554
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296638
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.181462
#
# Power Allocated= 6.293775092461766
# CSI= 0.581718195550632
# SNR= 25.796500572145245
# Client: client39
# ...
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.484376
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.556216
#
# Power Allocated= 4.978835445333782
# CSI= 0.3295995127717457
# SNR= 36.253038415473036
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.161524
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.486396
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.894884
#
# Power Allocated= 6.902265963399368
# CSI= 0.9004510408986792
# SNR= 30.070085721817602
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.124550
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.409694
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.842245
#
# Power Allocated= 7.007866900814742
# CSI= 0.9950708053133495
# SNR= 35.48823490007299
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.280192
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.491571
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.663900
#
# Power Allocated= 3.7250558845656006
# CSI= 0.2332217569524706
# SNR= 28.24177210918613
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.114345
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.419933
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.842162
#
# Power Allocated= 6.849650293552463
# CSI= 0.859719397415675
# SNR= 26.97803560390833
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.243284
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.406207
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.753139
#
# Power Allocated= 0
# CSI= 0.12283264301251517
# SNR= 30.73315824588984
# Client: client33
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.716106130836049
# CSI= 0.771179848002076
# SNR= 26.795868157558704
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.170392
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.553916
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.600552
#
# Power Allocated= 6.293775092461766
# CSI= 0.581718195550632
# SNR= 25.796500572145245
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.094240
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.349547
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.669640
#
# Power Allocated= 6.219604564979497
# CSI= 0.55765732019315
# SNR= 26.402396663210556
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.335132
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.438482
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.553947
#
# Power Allocated= 2.8692694957061704
# CSI= 0.19441821354019495
# SNR= 40.07877319158733
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.115176
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.452306
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.650214
#
#
# Test set: Average loss for Cluster3 model: 2.5842, Accuracy: 9377/10000 (94%)
#
# 0.12214000000001705
# Power Allocated= 4.664896784407732
# CSI= 0.28389498647362843
# SNR= 29.318660749751952
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.409489
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.483323
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.667776
#
# Power Allocated= 4.4302844784496855
# CSI= 0.2661668733553847
# SNR= 23.779682419315783
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.276146
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.574984
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.526325
#
# Power Allocated= 5.932663797960879
# CSI= 0.44352541614715857
# SNR= 26.462557647197517
# Client: client8
# Model client8 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.429830
# Model client8 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.614907
# Model client8 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.816204
#
# Power Allocated= 6.074860334161992
# CSI= 0.4733804705209943
# SNR= 26.176793329212586
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.404822
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.348252
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.717611
#
# Power Allocated= 6.992593686410622
# CSI= 0.8370075643337088
# SNR= 23.531144323247318
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.424785
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.466973
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.512865
#
# Power Allocated= 6.767981221553068
# CSI= 0.704550438746556
# SNR= 51.064265362315226
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.327419
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.653704
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.656756
#
# Power Allocated= 0
# CSI= 0.014912810277535327
# SNR= 21.931991015976102
# Client: client32
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.7744798523088186
# CSI= 0.4144483032825582
# SNR= 27.351305490731402
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.358787
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.483908
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.433037
#
# Power Allocated= 6.579682482623115
# CSI= 0.6220284392484441
# SNR= 28.193179114023543
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.374259
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.818922
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.780429
#
# Power Allocated= 2.4832942932965683
# CSI= 0.17531459291110651
# SNR= 22.7643707075083
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.606000
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.470909
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.447214
#
# Power Allocated= 4.978863353445699
# CSI= 0.3116757475896036
# SNR= 33.9296461620172
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.328728
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.362528
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.419253
#
# Power Allocated= 5.320769455738145
# CSI= 0.3488506079747954
# SNR= 26.228555407001522
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.330476
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.327450
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.617351
#
#
# Test set: Average loss for Cluster4 model: 2.5460, Accuracy: 9382/10000 (94%)
# ROUND 30
# 0.1108400000000136
# Power Allocated= 7.7267944207572565
# CSI= 0.7720700314102752
# SNR= 27.372803967967307
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.272262
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.430974
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.404392
#
# Power Allocated= 6.304697730566481
# CSI= 0.36801020061540723
# SNR= 26.54305170991507
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.344570
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.417110
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.350863
#
# Power Allocated= 7.835625540306173
# CSI= 0.842894444355322
# SNR= 30.38539365677691
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.287832
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.288359
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.425405
#
# Power Allocated= 6.970499240429884
# CSI= 0.48744476977689244
# SNR= 32.70520648265001
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.210648
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.247911
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.352509
#
# Power Allocated= 0
# CSI= 0.037233490417702186
# SNR= 31.023827003242513
# Client: client17
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.09287875868562667
# SNR= 39.956554296916586
# Client: client22
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.749314739774576
# CSI= 0.7857317564297636
# SNR= 48.76365583007644
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.178632
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.348898
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.883133
#
# Power Allocated= 6.146701242476175
# CSI= 0.3477882873919189
# SNR= 40.71043647249153
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.239627
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.340398
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.536164
#
# Power Allocated= 5.2637060187576585
# CSI= 0.26607720315440264
# SNR= 20.24379990130509
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.362506
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.595359
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.576232
#
# Power Allocated= 4.940851877562826
# CSI= 0.245028264060553
# SNR= 20.5690506707594
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.315701
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.444964
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.714044
#
# Power Allocated= 7.059545269257699
# CSI= 0.5095623335776032
# SNR= 26.874398941090973
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.153651
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.505180
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.398261
#
#
# Test set: Average loss for Cluster1 model: 1.1810, Accuracy: 9366/10000 (94%)
#
# 0.13480000000001413
# Power Allocated= 5.480740477288595
# CSI= 0.5160871729073614
# SNR= 28.630615905602994
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.572933
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.429491
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.812683
#
# Power Allocated= 5.77683541532793
# CSI= 0.6091758164452228
# SNR= 23.755187578029414
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.696353
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.654283
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.319251
#
# Power Allocated= 5.4427453606938405
# CSI= 0.5061619483873862
# SNR= 29.015717887694294
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.592326
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.439152
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.165388
#
# Power Allocated= 4.970686174517494
# CSI= 0.408544887653559
# SNR= 33.54801759182378
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.566859
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.720859
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.550714
#
# Power Allocated= 5.586654268596948
# CSI= 0.5459280067250317
# SNR= 27.866466263405908
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.716723
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.676586
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.030192
#
# Power Allocated= 5.097762271868685
# CSI= 0.4309164721512553
# SNR= 31.700405826678917
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.613449
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.495824
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.656136
#
# Power Allocated= 6.322794524490216
# CSI= 0.9127392926505502
# SNR= 25.489526374166697
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.688883
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.775449
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.960242
#
# Power Allocated= 4.471128382467864
# CSI= 0.3392971314570369
# SNR= 24.208641932022466
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.776056
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.505621
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.928519
#
# Power Allocated= 6.360966624693519
# CSI= 0.9456881807499267
# SNR= 18.759231526494126
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.632894
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.721632
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.673885
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_668792/982425597.py in <module>
#      73         index=0
#      74         for client in new_members:
# ---> 75             goodchannel=ClientUpdate(args, device, client,key_np,key,snrs[index],csis[index],smallmu1,head)
#      76             index+=1
#      77             if(goodchannel):
#
# /tmp/ipykernel_668792/1497942811.py in ClientUpdate(args, device, client, key_np, key, snr, csi, mu, head)
#      92                 params=client['model'].parameters()
#      93                 gp=head['model'].parameters()
# ---> 94                 params=fedprox(params,gp)
#      95
#      96                 if batch_idx % args.log_interval == 0:
#
# /tmp/ipykernel_668792/4292594119.py in fedprox(params, global_params)
#      11             continue
#      12         grad=p.grad.data #batch gradients
# ---> 13         p.data.sub_(lr,(grad+mu*(p.data.clone()-global_param[ind].data.clone())))
#      14         ind+=1
#      15     return(p)
#
# ~/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook.py in overloaded_native_method(self, *args, **kwargs)
#     207                 # Send the new command to the appropriate class and get the response
#     208                 method = getattr(new_self, method_name)
# --> 209                 response = method(*new_args, **new_kwargs)
#     210
#     211                 # For inplace methods, just directly return self
#
# ~/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/pointers.py in overloaded_pointer_method(self, *args, **kwargs)
#      82
#      83             # Send the command
# ---> 84             response = owner.send_command(location, attr, self, args, kwargs)
#      85
#      86             # For inplace methods, just directly return self
#
# ~/.local/lib/python3.8/site-packages/syft/workers/base.py in send_command(self, recipient, cmd_name, target, args_, kwargs_, return_ids, return_value)
#     523                 cmd_name, target, args_, kwargs_, return_ids, return_value
#     524             )
# --> 525             ret_val = self.send_msg(message, location=recipient)
#     526         except ResponseSignatureError as e:
#     527             ret_val = None
#
# ~/.local/lib/python3.8/site-packages/syft/workers/base.py in send_msg(self, message, location)
#     311
#     312         # Step 1: serialize the message to a binary
# --> 313         bin_message = sy.serde.serialize(message, worker=self)
#     314
#     315         # Step 2: send the message and wait for a response
#
# ~/.local/lib/python3.8/site-packages/syft/serde/serde.py in serialize(obj, worker, simplified, force_full_simplification, strategy)
#      45         strategy = msgpack_serialize
#      46
# ---> 47     return strategy(obj, worker, simplified, force_full_simplification)
#      48
#      49
#
# ~/.local/lib/python3.8/site-packages/syft/serde/msgpack/serde.py in serialize(obj, worker, simplified, force_full_simplification)
#     340         worker = syft.framework.hook.local_worker
#     341
# --> 342     simple_objects = _serialize_msgpack_simple(obj, worker, simplified, force_full_simplification)
#     343     return _serialize_msgpack_binary(simple_objects)
#     344
#
# ~/.local/lib/python3.8/site-packages/syft/serde/msgpack/serde.py in _serialize_msgpack_simple(obj, worker, simplified, force_full_simplification)
#     280             simple_objects = _force_full_simplify(worker, obj)
#     281         else:
# --> 282             simple_objects = _simplify(worker, obj)
#     283     else:
#     284         simple_objects = obj
#
# ~/.local/lib/python3.8/site-packages/syft/serde/msgpack/serde.py in _simplify(worker, obj, **kwargs)
#     423     current_type, obj = _simplify_field(obj)
#     424
# --> 425     if current_type in msgpack_global_state.simplifiers:
#     426         result = (
#     427             msgpack_global_state.simplifiers[current_type][0],
#
# ~/.local/lib/python3.8/site-packages/syft/serde/msgpack/serde.py in wrapper(self)
#      70         def wrapper(self):
#      71             self = self.update()
# ---> 72             return wrapped_func.__get__(self, type(self))
#      73
#      74         return wrapper
#
# ~/.local/lib/python3.8/site-packages/syft/serde/msgpack/serde.py in simplifiers(self)
#     118     @property
#     119     def simplifiers(self):
# --> 120         return self._simplifiers
#     121
#     122     @property
#
# KeyboardInterrupt:

# %%
print(final_acc)
