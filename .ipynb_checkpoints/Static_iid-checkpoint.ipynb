# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import numpy as np
from Dataset import load_dataset, getImage
from utils import averageModels
from utils import averageModelscluster
import random
import math
import matplotlib.pyplot as plt
from ipynb.fs.full.K_clusters import cluster_former
import copy
# Out:
# 0.8753788471221924
# {'Cluster Head': 'client79', 'Members': ['client17', 'client29', 'client31', 'client38', 'client41', 'client42', 'client46', 'client51', 'client54', 'client59', 'client66', 'client74', 'client81', 'client86', 'client100'], 'SNR': [23.139629354719258, 53.767817176325345, 23.148707263449754, 26.95687441126924, 26.774972944138963, 35.68215361754276, 38.834186910117644, 26.50420159514345, 20.952969856701664, 25.76209744122651, 22.585916368883947, 21.611297196603616, 25.40516420215239, 20.402193204587533, 29.799311142183985], 'CSI': [0.910093255667172, 0.36353794585159127, 0.8496128459196806, 0.058556572294388376, 0.04234412759544004, 0.7058381376212366, 0.6179495915529449, 0.15420968560711756, 0.04694221722218894, 0.544623622687464, 0.8645395211714668, 0.7064538725963647, 0.5960952710056385, 0.6350599833744774, 0.045629849473581396]}

# %%
P=2 #signal power threshold
#stream = BitStream()
#random.seed(10)
key=[]
for i in range (10000): #generating a random password to activate training (Pilot signal)
    temp=random.randint(0,1)
    key.append(temp)

key1=[0]*len(key)
for i in range (len(key)):   #bpsk modulation
    if(key[i]==1):
        #print("yay")
        key1[i]=-math.sqrt(P)
    else:
        key1[i]=math.sqrt(P)

#print(key)
        
key_np=np.array(key1)

# %%
class Arguments():
    def __init__(self):
        self.images = 10000
        self.clients = 100
        self.rounds = 200
        self.epochs = 2
        self.local_batches = 64
        self.lr = 0.01
        self.C = 1 #fraction of clients used in the round
        self.drop_rate = 0 #fraction of devices in the selected set to be dropped for various reasons
        self.torch_seed = 0 #same weights and parameters whenever the program is run
        self.log_interval = 64
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = True
        self.numclusters=4

args = Arguments()

# %%
#checking if gpu is available
#use_cuda = args.use_cuda and torch.cuda.is_available()
use_cuda=False
device = torch.device("cuda:0" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

hook = sy.TorchHook(torch)
me = hook.local_worker
clients = []

#generating virtual clients
for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})
#print(clients)

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid) #load data

for inx, client in enumerate(clients):  #return actual image set for each client
    trainset_ind_list = list(train_group[inx]) 
    client['trainset'] = getImage(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getImage(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images #useful while taking weighted average

# %%
#load dataset for global model (to compare accuracies)
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.MNIST('./', train=False, download=True, transform=transform)
# global_test_dataset = torch.utils.data.random_split(global_test_dataset, [10000, len(global_test_dataset)-10000])[0]
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        #self.quant = torch.quantization.QuantStub()
        self.conv1 = nn.Conv2d(1, 5, 5, 1)
        self.conv2 = nn.Conv2d(5, 10, 5, 1)
        self.fc1 = nn.Linear(4*4*10, 10) #10 iid #50 non iid
        self.fc2 = nn.Linear(10, 10)

    def forward(self, x):
        #x=self.quant(x)
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*10
                   )
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def ClientUpdate(args, device, client,key_np,key,snr,csi,mu):
    gc=False
    client['model'].train()
    #simulating a wireless channel
    poptim=max((1/mu-1/csi),0)
    #print(mu,csi)
    print("Power Allocated=",poptim)
    print("CSI=",csi)
    
    snr__=10**(snr/10)
    
    absh=csi*poptim/snr__
    x=random.uniform(0,absh)
    #print(x)
    y=math.sqrt(absh*absh-x*x)
    #x=x*100
    #y=y*100
    #x=random.random()
    #y=random.random()
    #snr=10*math.log(poptim/(std*std),10)
    std=math.sqrt(poptim/snr__*absh*absh) #channel noise
    
    #print(x,y)
    h=complex(x,y)
    #std=math.sqrt(abs(h)/csi)
    #snr=poptim/(std*std)
    #print(std)
    print("SNR=",snr)
    #print("csi",abs(h)/(std*std))
    
    
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data

    
    #print(client['model'].conv1.weight.size)
    client['model'].send(client['hook'])
    print("Client:",client['hook'].id)
    
    key_np_received=h*key_np+(np.random.randn(len(key_np))*std*2)
    #print(key_np_received)
    key_np_received=(key_np_received/(h)).real
    
    for o in range (len(key_np_received)):  #demodulation bpsk
        if(key_np_received[o]>=0):
            key_np_received[o]=0
        else:
            key_np_received[o]=1
    
    key_np_received=key_np_received.tolist()
    key_np_received = [int(item) for item in key_np_received]
    #key_np=key_np.tolist()
    
    
    if(sum(np.bitwise_xor(key,key_np_received))/len(key)==0 and poptim>0): #...............................................checking if channel is good enough for transmission by checking BER..................................#
        gc=True #considering the client model for training
        for epoch in range(1, args.epochs + 1):
            for batch_idx, (data, target) in enumerate(client['trainset']): 
                data = data.send(client['hook'])
                target = target.send(client['hook'])
                
                #train model on client
                data, target = data.to(device), target.to(device) #send data to cpu/gpu (data is stored locally)
                output = client['model'](data)
                loss = F.nll_loss(output, target)
                loss.backward()
                client['optim'].step()
                
                if batch_idx % args.log_interval == 0:
                    loss = loss.get() 
                    print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                        client['hook'].id,
                        epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                        100. * batch_idx / len(client['trainset']), loss))
    else:
        print("Poor Channel, client not taken for averaging in this round")
            
                    
    client['model'].get()
    # print()
         #CHANGE
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
    #CHANGE ENDS
    print()
    return gc

# %%
def test(args, model, device, test_loader, name,fed_round):
    model.eval()    #no need to train the model while testing
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            if(use_cuda and fed_round==0):
                data,target=data.cuda(),target.cuda()
                #model.cuda()
            else:
                data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    return(100. * correct / len(test_loader.dataset))

# %%
torch.manual_seed(args.torch_seed)

# %%
def distort(neighbours,snrs):
    ind=0
    poptim=2
    csi=random.random()
    distorted_models=[]
    for client in neighbours:
        snr=snrs[ind]
        ind+=1
        snr__=10**(snr/10)
        absh=csi*poptim/snr__
        x=random.uniform(0,absh)
        y=math.sqrt(absh*absh-x*x)
        std=math.sqrt(poptim/snr__*absh*absh) #channel noise
        h=complex(x,y)
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
        
        distorted_models.append(client)
    return(distorted_models)

# %%
def decentralized(clients,snrs,weights):
    big_daddy_of_distorted_models=[]
    for client in clients:
        distorted_models=[]
        snr_list=[]
        for snr in snrs:
            if(client['hook'].id in snr):
                snr_list.append(snr[2])
        neighbours = [x for x in clients if x != client]
        distorted_models=distort(neighbours,snr_list)
        distorted_models.append(client)
        big_daddy_of_distorted_models.append(distorted_models)
    
    
    weight_final1=[]
    for oho in big_daddy_of_distorted_models:
        weight_final=[]
        for comeon in oho:
            for w in weights:
                if(comeon['hook'].id==w[0]):
                    weight_final.append(w[1])
        weight_final1.append(weight_final)
    
    final_heads=[]
    nets=[]
    ind=0
    for client in clients:
        for oof in big_daddy_of_distorted_models:
            if(client==oof[0]):
#                 print(client)
#                 print("shut up")
#                 print(distorted_models)
#                 print("shut up")
#                 print(weight_final1)
                
                overall=Net()
                overall=averageModelscluster(overall,distorted_models,weight_final1[ind])
                client['model'].load_state_dict(overall.state_dict())
                ind+=1
                final_heads.append(client)
                nets.append(overall)
    
    return(final_heads,nets)

# %%
for client in clients: #give the model and optimizer to every client
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    #client['model'] = torch.quantization.quantize_dynamic(
    #client['model'],  # the original model
    #{torch.nn.Linear},  # a set of layers to dynamically quantize
    #dtype=torch.fp)  # the target dtype for quantized weights
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)
    
for fed_round in range(args.rounds):
    overall=Net()
    if(fed_round==0): #fed_round==0
        arranged_clusters,head_snr_list=cluster_former(args.numclusters,args.clients)
        temp=copy.deepcopy(arranged_clusters)
        temp2=copy.deepcopy(head_snr_list)
    else:
        #print(temp)
        arranged_clusters=copy.deepcopy(temp)
        head_snr_list=copy.deepcopy(temp2)
#     print(arranged_clusters)
    
    no=1
    heads_list=[]
    weights=[]
    weight_head_list=[]
    for cluster in arranged_clusters:
        
        head=cluster['Cluster Head']
        members=cluster['Members']
        snrs=cluster['SNR']
        csis=cluster['CSI']
        weights.append(sum(snrs))
        weight_head_list.append([head,sum(snrs)])
        new_members=[]
        
        for ij in members:
        #print(ij)
            cl_no=int(ij[6:])
            new_members.append(clients[cl_no-1])
#         print(head)
        head=clients[int(head[6:])-1]
        cluster['Members']=new_members
#         print(head)

        smallmu1=0
        gsmall1=3.402823466E+38 
        
        #water filling algorithm
        mu=1e-15
        while(mu<=1):
            g1=0
            pn1=0
            for jj in csis:
                pn=max(1/mu-1/jj,0)
                g1+=math.log(1+pn*jj) #capacity of a channel (shannon's law)
                pn1+=pn
            g=g1-mu*(pn1-P*30)
            if(g<gsmall1):
                smallmu1=mu
                gsmall1=g
            mu+=0.00002
        
        print(smallmu1)
        good_mem=[]
#         print(len(snrs))
#         print(len(csis))
#         print(len(new_members))
        index=0
        for client in new_members:
            goodchannel=ClientUpdate(args, device, client,key_np,key,snrs[index],csis[index],smallmu1)
            index+=1
            if(goodchannel):
                good_mem.append(client)
        
        head['model']=averageModels(head['model'], good_mem)
        ac=test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)
        no+=1
        heads_list.append(head)
    
    weightsum=sum(weights)
    weights[:] = [x / weightsum for x in weights]
    for aah in range(len(weight_head_list)):
        weight_head_list[aah][1]=weights[aah]
    final_heads,nets=decentralized(heads_list,head_snr_list,weight_head_list)
    
    for head in range(len(final_heads)):
        for cluster in arranged_clusters:
            head1=cluster['Cluster Head']
            if(head1==final_heads[head]['hook'].id):
                for mem in cluster['Members']:
                    mem['model'].load_state_dict(nets[head].state_dict())
    print("ROUND",fed_round)
# Out:
# 0.20023999999998876
# Power Allocated= 1.4677777282006987
# CSI= 0.2835890319800801
# SNR= 28.55584955523917
# Client: client1
# Model client1 Train Epoch: 1 [0/640 (0%)]	Loss: 2.329648
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client1 Train Epoch: 2 [0/640 (0%)]	Loss: 2.304055
#
# Power Allocated= 3.2514783584230225
# CSI= 0.5738785959187992
# SNR= 14.936269167463102
# Client: client5
# Model client5 Train Epoch: 1 [0/640 (0%)]	Loss: 2.323226
# Model client5 Train Epoch: 2 [0/640 (0%)]	Loss: 2.242707
#
# Power Allocated= 2.3096611458887275
# CSI= 0.3725302114766931
# SNR= 27.54727786413042
# Client: client8
# Model client8 Train Epoch: 1 [0/640 (0%)]	Loss: 2.348493
# Model client8 Train Epoch: 2 [0/640 (0%)]	Loss: 2.295366
#
# Power Allocated= 3.8923100401829527
# CSI= 0.9076904654985734
# SNR= 15.03404375072379
# Client: client10
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.102192739744211
# CSI= 0.34580365259519896
# SNR= 22.128242523037674
# Client: client15
# Model client15 Train Epoch: 1 [0/640 (0%)]	Loss: 2.277967
# Model client15 Train Epoch: 2 [0/640 (0%)]	Loss: 2.203846
#
# Power Allocated= 3.7292489127957418
# CSI= 0.7906649175103889
# SNR= 27.003704173285712
# Client: client18
# Model client18 Train Epoch: 1 [0/640 (0%)]	Loss: 2.331451
# Model client18 Train Epoch: 2 [0/640 (0%)]	Loss: 2.303531
#
# Power Allocated= 3.661569093906309
# CSI= 0.7505039085140486
# SNR= 19.46960530214449
# Client: client21
# Model client21 Train Epoch: 1 [0/640 (0%)]	Loss: 2.324397
# Model client21 Train Epoch: 2 [0/640 (0%)]	Loss: 2.268038
#
# Power Allocated= 0
# CSI= 0.0922002951972355
# SNR= 18.693950823212045
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.02462886522268204
# SNR= 24.98489734299053
# Client: client50
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.6556436033438215
# CSI= 0.7471811165113414
# SNR= 15.25417121289029
# /tmp/ipykernel_632865/3032248498.py:65: RuntimeWarning: invalid value encountered in true_divide
#   key_np_received=(key_np_received/(h)).real
# Client: client53
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.601877140659603
# CSI= 0.7183236936012183
# SNR= 17.003323215428427
# Client: client55
# Model client55 Train Epoch: 1 [0/640 (0%)]	Loss: 2.383195
# Model client55 Train Epoch: 2 [0/640 (0%)]	Loss: 2.230811
#
# Power Allocated= 0
# CSI= 0.001654457576196866
# SNR= 28.809291630180827
# Client: client57
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.8917135176241686
# CSI= 0.9071992553501715
# SNR= 17.94787448869871
# Client: client60
# Model client60 Train Epoch: 1 [0/640 (0%)]	Loss: 2.327700
# Model client60 Train Epoch: 2 [0/640 (0%)]	Loss: 2.275098
#
# Power Allocated= 3.905428292319895
# CSI= 0.9186288663798434
# SNR= 28.604090599402475
# Client: client65
# Model client65 Train Epoch: 1 [0/640 (0%)]	Loss: 2.321862
# Model client65 Train Epoch: 2 [0/640 (0%)]	Loss: 2.280979
#
# Power Allocated= 1.1748153336020466
# CSI= 0.26183549746680246
# SNR= 38.06199825288803
# Client: client76
# Model client76 Train Epoch: 1 [0/640 (0%)]	Loss: 2.308608
# Model client76 Train Epoch: 2 [0/640 (0%)]	Loss: 2.289741
#
# Power Allocated= 3.629248387230932
# CSI= 0.7327302062215785
# SNR= 22.284863450085574
# Client: client77
# Model client77 Train Epoch: 1 [0/640 (0%)]	Loss: 2.340762
# Model client77 Train Epoch: 2 [0/640 (0%)]	Loss: 2.280138
#
# Power Allocated= 0.26267816988242476
# CSI= 0.2113571039888188
# SNR= 27.896956065886574
# Client: client85
# Model client85 Train Epoch: 1 [0/640 (0%)]	Loss: 2.337368
# Model client85 Train Epoch: 2 [0/640 (0%)]	Loss: 2.272650
#
# Power Allocated= 3.9521656132516934
# CSI= 0.9598388286686659
# SNR= 30.53566111191541
# Client: client88
# Model client88 Train Epoch: 1 [0/640 (0%)]	Loss: 2.335040
# Model client88 Train Epoch: 2 [0/640 (0%)]	Loss: 2.265692
#
# Power Allocated= 3.957562083327348
# CSI= 0.9648364319919531
# SNR= 23.440932548653386
# Client: client90
# Model client90 Train Epoch: 1 [0/640 (0%)]	Loss: 2.349721
# Model client90 Train Epoch: 2 [0/640 (0%)]	Loss: 2.287131
#
# Power Allocated= 3.8133483248082434
# CSI= 0.8469847034745956
# SNR= 13.19956793345282
# Client: client93
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.757969270097669
# CSI= 0.8090366669091537
# SNR= 19.961038760761646
# Client: client95
# Model client95 Train Epoch: 1 [0/640 (0%)]	Loss: 2.318821
# Model client95 Train Epoch: 2 [0/640 (0%)]	Loss: 2.254571
#
# Power Allocated= 3.9798672148183654
# CSI= 0.9860571746709551
# SNR= 21.58984179673025
# Client: client97
# Model client97 Train Epoch: 1 [0/640 (0%)]	Loss: 2.319185
# Model client97 Train Epoch: 2 [0/640 (0%)]	Loss: 2.270759
#
#
# Test set: Average loss for Cluster1 model: 2.2428, Accuracy: 3569/10000 (36%)
#
# 0.17753999999999756
# Power Allocated= 4.419482829756638
# CSI= 0.8243678630580308
# SNR= 45.300680213335205
# Client: client2
# Model client2 Train Epoch: 1 [0/640 (0%)]	Loss: 2.335299
# Model client2 Train Epoch: 2 [0/640 (0%)]	Loss: 2.280413
#
# Power Allocated= 3.9870024911987185
# CSI= 0.6077065618345088
# SNR= 22.36316904653916
# Client: client6
# Model client6 Train Epoch: 1 [0/640 (0%)]	Loss: 2.291889
# Model client6 Train Epoch: 2 [0/640 (0%)]	Loss: 2.233215
#
# Power Allocated= 3.012503478096714
# CSI= 0.3816750138200792
# SNR= 21.458753783461653
# Client: client20
# Model client20 Train Epoch: 1 [0/640 (0%)]	Loss: 2.330876
# Model client20 Train Epoch: 2 [0/640 (0%)]	Loss: 2.288587
#
# Power Allocated= 4.091697819879581
# CSI= 0.6489984649836442
# SNR= 25.647880399636477
# Client: client24
# Model client24 Train Epoch: 1 [0/640 (0%)]	Loss: 2.277320
# Model client24 Train Epoch: 2 [0/640 (0%)]	Loss: 2.284579
#
# Power Allocated= 4.217213696241107
# CSI= 0.7065540860468654
# SNR= 43.302564401689125
# Client: client26
# Model client26 Train Epoch: 1 [0/640 (0%)]	Loss: 2.320529
# Model client26 Train Epoch: 2 [0/640 (0%)]	Loss: 2.262798
#
# Power Allocated= 4.623745099280175
# CSI= 0.9912881490610137
# SNR= 31.979170611725568
# Client: client28
# Model client28 Train Epoch: 1 [0/640 (0%)]	Loss: 2.296357
# Model client28 Train Epoch: 2 [0/640 (0%)]	Loss: 2.296350
#
# Power Allocated= 2.792458194214951
# CSI= 0.3521033379584845
# SNR= 25.70163663354505
# Client: client36
# Model client36 Train Epoch: 1 [0/640 (0%)]	Loss: 2.330036
# Model client36 Train Epoch: 2 [0/640 (0%)]	Loss: 2.292297
#
# Power Allocated= 3.683524122850553
# CSI= 0.5130811604907481
# SNR= 30.3266429030801
# Client: client52
# Model client52 Train Epoch: 1 [0/640 (0%)]	Loss: 2.331350
# Model client52 Train Epoch: 2 [0/640 (0%)]	Loss: 2.280735
#
# Power Allocated= 3.514854394334999
# CSI= 0.47221507305560395
# SNR= 33.8325474458185
# Client: client68
# Model client68 Train Epoch: 1 [0/640 (0%)]	Loss: 2.343119
# Model client68 Train Epoch: 2 [0/640 (0%)]	Loss: 2.278924
#
# Power Allocated= 1.2551609594180393
# CSI= 0.2284475419051254
# SNR= 39.44694682475724
# Client: client70
# Model client70 Train Epoch: 1 [0/640 (0%)]	Loss: 2.312066
# Model client70 Train Epoch: 2 [0/640 (0%)]	Loss: 2.282500
#
# Power Allocated= 4.438200615420016
# CSI= 0.8372874945881859
# SNR= 28.9260967311767
# Client: client72
# Model client72 Train Epoch: 1 [0/640 (0%)]	Loss: 2.331882
# Model client72 Train Epoch: 2 [0/640 (0%)]	Loss: 2.286016
#
# Power Allocated= 2.4606741932635305
# CSI= 0.3152724944629528
# SNR= 25.804389850172065
# Client: client75
# Model client75 Train Epoch: 1 [0/640 (0%)]	Loss: 2.341691
# Model client75 Train Epoch: 2 [0/640 (0%)]	Loss: 2.281407
#
# Power Allocated= 2.4783499853583293
# CSI= 0.3170392562938623
# SNR= 22.764276429901784
# Client: client80
# Model client80 Train Epoch: 1 [0/640 (0%)]	Loss: 2.277730
# Model client80 Train Epoch: 2 [0/640 (0%)]	Loss: 2.281528
#
# Power Allocated= 3.623270517753249
# CSI= 0.49769492698554174
# SNR= 14.569050666077178
# Client: client86
# Model client86 Train Epoch: 1 [0/640 (0%)]	Loss: 2.295606
# Model client86 Train Epoch: 2 [0/640 (0%)]	Loss: 2.261528
#
# Power Allocated= 3.7864922078858743
# CSI= 0.5416996883647632
# SNR= 30.262454960714393
# Client: client89
# Model client89 Train Epoch: 1 [0/640 (0%)]	Loss: 2.323861
# Model client89 Train Epoch: 2 [0/640 (0%)]	Loss: 2.307241
#
# Power Allocated= 3.036212561872845
# CSI= 0.3851603937273612
# SNR= 21.453025024048664
# Client: client96
# Model client96 Train Epoch: 1 [0/640 (0%)]	Loss: 2.294899
# Model client96 Train Epoch: 2 [0/640 (0%)]	Loss: 2.269797
#
# Power Allocated= 4.580915416992294
# CSI= 0.9509155493330226
# SNR= 23.08235455310809
# Client: client98
# Model client98 Train Epoch: 1 [0/640 (0%)]	Loss: 2.329680
# Model client98 Train Epoch: 2 [0/640 (0%)]	Loss: 2.305763
#
#
# Test set: Average loss for Cluster2 model: 2.2212, Accuracy: 4034/10000 (40%)
#
# 0.1565600000000057
# Power Allocated= 1.6092888527047142
# CSI= 0.20929089632692233
# SNR= 40.81420949455737
# Client: client3
# Model client3 Train Epoch: 1 [0/640 (0%)]	Loss: 2.293902
# Model client3 Train Epoch: 2 [0/640 (0%)]	Loss: 2.305058
#
# Power Allocated= 2.9151399828821565
# CSI= 0.2880028751122816
# SNR= 27.62274005757876
# Client: client9
# Model client9 Train Epoch: 1 [0/640 (0%)]	Loss: 2.332434
# Model client9 Train Epoch: 2 [0/640 (0%)]	Loss: 2.298918
#
# Power Allocated= 5.1111106071478325
# CSI= 0.7835658441513302
# SNR= 32.18476021813094
# Client: client13
# Model client13 Train Epoch: 1 [0/640 (0%)]	Loss: 2.330501
# Model client13 Train Epoch: 2 [0/640 (0%)]	Loss: 2.283107
#
# Power Allocated= 4.530766236750285
# CSI= 0.5386302068712995
# SNR= 37.07330286594608
# Client: client19
# Model client19 Train Epoch: 1 [0/640 (0%)]	Loss: 2.330376
# Model client19 Train Epoch: 2 [0/640 (0%)]	Loss: 2.284124
#
# Power Allocated= 4.892296300119289
# CSI= 0.6688823429787281
# SNR= 32.824007507228465
# Client: client22
# Model client22 Train Epoch: 1 [0/640 (0%)]	Loss: 2.288188
# Model client22 Train Epoch: 2 [0/640 (0%)]	Loss: 2.291927
#
# Power Allocated= 5.357733333062052
# CSI= 0.9712564340079993
# SNR= 28.517912174328025
# Client: client39
# Model client39 Train Epoch: 1 [0/640 (0%)]	Loss: 2.310343
# Model client39 Train Epoch: 2 [0/640 (0%)]	Loss: 2.270262
#
# Power Allocated= 5.073866817928819
# CSI= 0.7613474705064249
# SNR= 27.958995219345038
# Client: client43
# Model client43 Train Epoch: 1 [0/640 (0%)]	Loss: 2.293329
# Model client43 Train Epoch: 2 [0/640 (0%)]	Loss: 2.294135
#
# Power Allocated= 4.556432634708542
# CSI= 0.5461809937491601
# SNR= 29.002450846464914
# Client: client49
# Model client49 Train Epoch: 1 [0/640 (0%)]	Loss: 2.315990
# Model client49 Train Epoch: 2 [0/640 (0%)]	Loss: 2.286598
#
# Power Allocated= 4.181544639839679
# CSI= 0.45335377246320485
# SNR= 28.000079300164632
# Client: client58
# Model client58 Train Epoch: 1 [0/640 (0%)]	Loss: 2.325147
# Model client58 Train Epoch: 2 [0/640 (0%)]	Loss: 2.288507
#
# Power Allocated= 3.4568774053967357
# CSI= 0.34124450283458463
# SNR= 25.263092758072787
# Client: client62
# Model client62 Train Epoch: 1 [0/640 (0%)]	Loss: 2.310543
# Model client62 Train Epoch: 2 [0/640 (0%)]	Loss: 2.269948
#
# Power Allocated= 4.40910414311071
# CSI= 0.5055040803190096
# SNR= 33.822239423267185
# Client: client63
# Model client63 Train Epoch: 1 [0/640 (0%)]	Loss: 2.293999
# Model client63 Train Epoch: 2 [0/640 (0%)]	Loss: 2.291674
#
# Power Allocated= 5.356896911075815
# CSI= 0.9704680449489247
# SNR= 32.77394130003627
# Client: client69
# Model client69 Train Epoch: 1 [0/640 (0%)]	Loss: 2.304831
# Model client69 Train Epoch: 2 [0/640 (0%)]	Loss: 2.268184
#
# Power Allocated= 3.4778695360197505
# CSI= 0.34370662779489713
# SNR= 26.169261272402004
# Client: client71
# Model client71 Train Epoch: 1 [0/640 (0%)]	Loss: 2.336932
# Model client71 Train Epoch: 2 [0/640 (0%)]	Loss: 2.277855
#
# Power Allocated= 4.307708427706048
# CSI= 0.4808572844188501
# SNR= 23.271102140767464
# Client: client82
# Model client82 Train Epoch: 1 [0/640 (0%)]	Loss: 2.320952
# Model client82 Train Epoch: 2 [0/640 (0%)]	Loss: 2.276921
#
# Power Allocated= 0.7594244463601214
# CSI= 0.17768607294375605
# SNR= 29.38269010699483
# Client: client84
# Model client84 Train Epoch: 1 [0/640 (0%)]	Loss: 2.307383
# Model client84 Train Epoch: 2 [0/640 (0%)]	Loss: 2.295584
#
# Power Allocated= 0
# CSI= 0.07023295347562553
# SNR= 26.226758477138695
# Client: client91
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.00947693696857943
# SNR= 20.48818639443506
# Client: client99
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster3 model: 2.2566, Accuracy: 2976/10000 (30%)
#
# 0.2437399999999719
# Power Allocated= 0
# CSI= 0.09220416303981105
# SNR= 13.13811971551739
# Client: client4
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.10363201075111
# CSI= 0.5002249989432715
# SNR= 18.317254880635964
# Client: client7
# Model client7 Train Epoch: 1 [0/640 (0%)]	Loss: 2.297934
# Model client7 Train Epoch: 2 [0/640 (0%)]	Loss: 2.264044
#
# Power Allocated= 0
# CSI= 0.04031260016796223
# SNR= 18.77334421662698
# Client: client11
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.0250624600128323
# SNR= 20.411424286700615
# Client: client12
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.999742816063665
# CSI= 0.9066268590562796
# SNR= 29.579609777564695
# Client: client14
# Model client14 Train Epoch: 1 [0/640 (0%)]	Loss: 2.336648
# Model client14 Train Epoch: 2 [0/640 (0%)]	Loss: 2.270843
#
# Power Allocated= 0
# CSI= 0.05712132334434494
# SNR= 25.320660687512397
# Client: client16
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.4789482878891733
# CSI= 0.6158454072513442
# SNR= 15.714110861018828
# Client: client17
# Model client17 Train Epoch: 1 [0/640 (0%)]	Loss: 2.417259
# Model client17 Train Epoch: 2 [0/640 (0%)]	Loss: 2.051361
#
# Power Allocated= 0
# CSI= 0.12108978281913718
# SNR= 38.76566791625069
# Client: client23
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.22325262800259604
# SNR= 16.78232036531985
# Client: client25
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.772885183088003
# CSI= 0.7519660697859115
# SNR= 26.50824642881274
# Client: client27
# Model client27 Train Epoch: 1 [0/640 (0%)]	Loss: 2.335408
# Model client27 Train Epoch: 2 [0/640 (0%)]	Loss: 2.291041
#
# Power Allocated= 0.9930141550646079
# CSI= 0.32157253965501786
# SNR= 17.863160917577176
# Client: client29
# Model client29 Train Epoch: 1 [0/640 (0%)]	Loss: 2.336707
# Model client29 Train Epoch: 2 [0/640 (0%)]	Loss: 2.243855
#
# Power Allocated= 2.6130336071228895
# CSI= 0.6712766308836968
# SNR= 16.93998403973758
# Client: client31
# Model client31 Train Epoch: 1 [0/640 (0%)]	Loss: 2.372865
# Model client31 Train Epoch: 2 [0/640 (0%)]	Loss: 2.268883
#
# Power Allocated= 0
# CSI= 0.08049894482487807
# SNR= 14.461603320425422
# Client: client32
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.8545346584297415
# CSI= 0.8011550981381159
# SNR= 25.754833201549104
# Client: client33
# Model client33 Train Epoch: 1 [0/640 (0%)]	Loss: 2.292335
# Model client33 Train Epoch: 2 [0/640 (0%)]	Loss: 2.282357
#
# Power Allocated= 2.913679257895167
# CSI= 0.8410052906336904
# SNR= 17.773748205796288
# Client: client34
# Model client34 Train Epoch: 1 [0/640 (0%)]	Loss: 2.329411
# Model client34 Train Epoch: 2 [0/640 (0%)]	Loss: 2.288126
#
# Power Allocated= 1.5833503874526844
# CSI= 0.3969227323064819
# SNR= 21.733883262172327
# Client: client35
# Model client35 Train Epoch: 1 [0/640 (0%)]	Loss: 2.321527
# Model client35 Train Epoch: 2 [0/640 (0%)]	Loss: 2.270492
#
# Power Allocated= 0
# CSI= 0.08127883959572446
# SNR= 26.853020724477712
# Client: client37
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0.6586803012256426
# CSI= 0.2903556524621499
# SNR= 19.140296051772687
# Client: client38
# Model client38 Train Epoch: 1 [0/640 (0%)]	Loss: 2.370815
# Model client38 Train Epoch: 2 [0/640 (0%)]	Loss: 2.241573
#
# Power Allocated= 0
# CSI= 0.04019756525726126
# SNR= 17.07459634886405
# Client: client40
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.24067156644491983
# SNR= 14.867853824364175
# Client: client41
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.834071046656863
# CSI= 0.788232400840534
# SNR= 14.9961348039262
# Client: client42
# Model client42 Train Epoch: 1 [0/640 (0%)]	Loss: 2.300720
# Model client42 Train Epoch: 2 [0/640 (0%)]	Loss: 2.272724
#
# Power Allocated= 0
# CSI= 0.06886659825994113
# SNR= 32.274509574784126
# Client: client44
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.900691038743286
# CSI= 0.8319181151047488
# SNR= 28.37758838255435
# Client: client45
# Model client45 Train Epoch: 1 [0/640 (0%)]	Loss: 2.310483
# Model client45 Train Epoch: 2 [0/640 (0%)]	Loss: 2.306247
#
# Power Allocated= 2.86345945087632
# CSI= 0.8069247252886675
# SNR= 15.683755699874014
# Client: client46
# Model client46 Train Epoch: 1 [0/640 (0%)]	Loss: 2.341090
# Model client46 Train Epoch: 2 [0/640 (0%)]	Loss: 2.266860
#
# Power Allocated= 2.8525309114972552
# CSI= 0.7998710554780415
# SNR= 22.787489422488818
# Client: client47
# Model client47 Train Epoch: 1 [0/640 (0%)]	Loss: 2.292742
# Model client47 Train Epoch: 2 [0/640 (0%)]	Loss: 2.266800
#
# Power Allocated= 2.3964160014789164
# CSI= 0.5860577729121301
# SNR= 21.50693556351531
# Client: client48
# Model client48 Train Epoch: 1 [0/640 (0%)]	Loss: 2.322132
# Model client48 Train Epoch: 2 [0/640 (0%)]	Loss: 2.212424
#
# Power Allocated= 2.5753418301841338
# CSI= 0.6547113795278123
# SNR= 13.599564639465026
# Client: client51
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.668011486786045
# CSI= 0.6969996582574512
# SNR= 16.703245180082014
# Client: client54
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 1.9051154219916486
# CSI= 0.4550383442614886
# SNR= 12.689863867054212
# Client: client56
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.0889947357432107
# SNR= 14.58052732268292
# Client: client59
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.04733592215768656
# SNR= 29.268784986541664
# Client: client61
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0.591158407807332
# CSI= 0.2847725824906665
# SNR= 26.41617705444456
# Client: client64
# Model client64 Train Epoch: 1 [0/640 (0%)]	Loss: 2.301571
# Model client64 Train Epoch: 2 [0/640 (0%)]	Loss: 2.257339
#
# Power Allocated= 2.692588741120234
# CSI= 0.7091475961810327
# SNR= 23.419434182136612
# Client: client66
# Model client66 Train Epoch: 1 [0/640 (0%)]	Loss: 2.335552
# Model client66 Train Epoch: 2 [0/640 (0%)]	Loss: 2.288352
#
# Power Allocated= 0
# CSI= 0.1857435110842136
# SNR= 32.63376853658289
# Client: client73
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.693927372289232
# CSI= 0.7098214204815283
# SNR= 20.84989538711031
# Client: client74
# Model client74 Train Epoch: 1 [0/640 (0%)]	Loss: 2.298599
# Model client74 Train Epoch: 2 [0/640 (0%)]	Loss: 2.273580
#
# Power Allocated= 2.9047891066273372
# CSI= 0.8347640401766662
# SNR= 17.239990069636264
# Client: client79
# Model client79 Train Epoch: 1 [0/640 (0%)]	Loss: 2.305437
# Model client79 Train Epoch: 2 [0/640 (0%)]	Loss: 2.267309
#
# Power Allocated= 2.671208581489892
# CSI= 0.6985563029016932
# SNR= 12.757972134937758
# Client: client81
# Model client81 Train Epoch: 1 [0/640 (0%)]	Loss: 2.426097
# Model client81 Train Epoch: 2 [0/640 (0%)]	Loss: 2.118326
#
# Power Allocated= 2.4791205557300886
# CSI= 0.6159107494436459
# SNR= 23.36971493851529
# Client: client92
# Model client92 Train Epoch: 1 [0/640 (0%)]	Loss: 2.329961
# Model client92 Train Epoch: 2 [0/640 (0%)]	Loss: 2.270574
#
# Power Allocated= 2.9993785493651535
# CSI= 0.9063275407853404
# SNR= 15.79367225871178
# Client: client94
# Model client94 Train Epoch: 1 [0/640 (0%)]	Loss: 2.309357
# Model client94 Train Epoch: 2 [0/640 (0%)]	Loss: 2.261783
#
# Power Allocated= 0
# CSI= 0.140906257197001
# SNR= 19.122930026199324
# Client: client100
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster4 model: 2.1079, Accuracy: 3390/10000 (34%)
#
# ROUND 0
# 0.20023999999998876
# Power Allocated= 1.4677777282006987
# CSI= 0.2835890319800801
# SNR= 28.55584955523917
# Client: client1
# Model client1 Train Epoch: 1 [0/640 (0%)]	Loss: 2.418482
# Model client1 Train Epoch: 2 [0/640 (0%)]	Loss: 1.444569
#
# Power Allocated= 3.2514783584230225
# CSI= 0.5738785959187992
# SNR= 14.936269167463102
# Client: client5
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.3096611458887275
# CSI= 0.3725302114766931
# SNR= 27.54727786413042
# Client: client8
# Model client8 Train Epoch: 1 [0/640 (0%)]	Loss: 2.329986
# Model client8 Train Epoch: 2 [0/640 (0%)]	Loss: 1.590359
#
# Power Allocated= 3.8923100401829527
# CSI= 0.9076904654985734
# SNR= 15.03404375072379
# Client: client10
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.102192739744211
# CSI= 0.34580365259519896
# SNR= 22.128242523037674
# Client: client15
# Model client15 Train Epoch: 1 [0/640 (0%)]	Loss: 2.441409
# Model client15 Train Epoch: 2 [0/640 (0%)]	Loss: 1.195966
#
# Power Allocated= 3.7292489127957418
# CSI= 0.7906649175103889
# SNR= 27.003704173285712
# Client: client18
# Model client18 Train Epoch: 1 [0/640 (0%)]	Loss: 2.432134
# Model client18 Train Epoch: 2 [0/640 (0%)]	Loss: 1.560725
#
# Power Allocated= 3.661569093906309
# CSI= 0.7505039085140486
# SNR= 19.46960530214449
# Client: client21
# Model client21 Train Epoch: 1 [0/640 (0%)]	Loss: 2.568915
# Model client21 Train Epoch: 2 [0/640 (0%)]	Loss: 1.436091
#
# Power Allocated= 0
# CSI= 0.0922002951972355
# SNR= 18.693950823212045
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.02462886522268204
# SNR= 24.98489734299053
# Client: client50
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.6556436033438215
# CSI= 0.7471811165113414
# SNR= 15.25417121289029
# Client: client53
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.601877140659603
# CSI= 0.7183236936012183
# SNR= 17.003323215428427
# Client: client55
# Model client55 Train Epoch: 1 [0/640 (0%)]	Loss: 2.475132
# Model client55 Train Epoch: 2 [0/640 (0%)]	Loss: 1.528409
#
# Power Allocated= 0
# CSI= 0.001654457576196866
# SNR= 28.809291630180827
# Client: client57
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.8917135176241686
# CSI= 0.9071992553501715
# SNR= 17.94787448869871
# Client: client60
# Model client60 Train Epoch: 1 [0/640 (0%)]	Loss: 2.501156
# Model client60 Train Epoch: 2 [0/640 (0%)]	Loss: 1.290604
#
# Power Allocated= 3.905428292319895
# CSI= 0.9186288663798434
# SNR= 28.604090599402475
# Client: client65
# Model client65 Train Epoch: 1 [0/640 (0%)]	Loss: 2.460031
# Model client65 Train Epoch: 2 [0/640 (0%)]	Loss: 1.557970
#
# Power Allocated= 1.1748153336020466
# CSI= 0.26183549746680246
# SNR= 38.06199825288803
# Client: client76
# Model client76 Train Epoch: 1 [0/640 (0%)]	Loss: 2.449893
# Model client76 Train Epoch: 2 [0/640 (0%)]	Loss: 1.601265
#
# Power Allocated= 3.629248387230932
# CSI= 0.7327302062215785
# SNR= 22.284863450085574
# Client: client77
# Model client77 Train Epoch: 1 [0/640 (0%)]	Loss: 2.459353
# Model client77 Train Epoch: 2 [0/640 (0%)]	Loss: 1.510738
#
# Power Allocated= 0.26267816988242476
# CSI= 0.2113571039888188
# SNR= 27.896956065886574
# Client: client85
# Model client85 Train Epoch: 1 [0/640 (0%)]	Loss: 2.355345
# Model client85 Train Epoch: 2 [0/640 (0%)]	Loss: 1.528917
#
# Power Allocated= 3.9521656132516934
# CSI= 0.9598388286686659
# SNR= 30.53566111191541
# Client: client88
# Model client88 Train Epoch: 1 [0/640 (0%)]	Loss: 2.422954
# Model client88 Train Epoch: 2 [0/640 (0%)]	Loss: 1.343218
#
# Power Allocated= 3.957562083327348
# CSI= 0.9648364319919531
# SNR= 23.440932548653386
# Client: client90
# Model client90 Train Epoch: 1 [0/640 (0%)]	Loss: 2.370195
# Model client90 Train Epoch: 2 [0/640 (0%)]	Loss: 1.632790
#
# Power Allocated= 3.8133483248082434
# CSI= 0.8469847034745956
# SNR= 13.19956793345282
# Client: client93
# Model client93 Train Epoch: 1 [0/640 (0%)]	Loss: 2.561358
# Model client93 Train Epoch: 2 [0/640 (0%)]	Loss: 1.649771
#
# Power Allocated= 3.757969270097669
# CSI= 0.8090366669091537
# SNR= 19.961038760761646
# Client: client95
# Model client95 Train Epoch: 1 [0/640 (0%)]	Loss: 2.521989
# Model client95 Train Epoch: 2 [0/640 (0%)]	Loss: 1.268132
#
# Power Allocated= 3.9798672148183654
# CSI= 0.9860571746709551
# SNR= 21.58984179673025
# Client: client97
# Model client97 Train Epoch: 1 [0/640 (0%)]	Loss: 2.317157
# Model client97 Train Epoch: 2 [0/640 (0%)]	Loss: 1.371018
#
#
# Test set: Average loss for Cluster1 model: 0.6988, Accuracy: 7741/10000 (77%)
#
# 0.17753999999999756
# Power Allocated= 4.419482829756638
# CSI= 0.8243678630580308
# SNR= 45.300680213335205
# Client: client2
# Model client2 Train Epoch: 1 [0/640 (0%)]	Loss: 2.426423
# Model client2 Train Epoch: 2 [0/640 (0%)]	Loss: 1.591532
#
# Power Allocated= 3.9870024911987185
# CSI= 0.6077065618345088
# SNR= 22.36316904653916
# Client: client6
# Model client6 Train Epoch: 1 [0/640 (0%)]	Loss: 2.379889
# Model client6 Train Epoch: 2 [0/640 (0%)]	Loss: 1.260554
#
# Power Allocated= 3.012503478096714
# CSI= 0.3816750138200792
# SNR= 21.458753783461653
# Client: client20
# Model client20 Train Epoch: 1 [0/640 (0%)]	Loss: 2.560473
# Model client20 Train Epoch: 2 [0/640 (0%)]	Loss: 1.655817
#
# Power Allocated= 4.091697819879581
# CSI= 0.6489984649836442
# SNR= 25.647880399636477
# Client: client24
# Model client24 Train Epoch: 1 [0/640 (0%)]	Loss: 2.325375
# Model client24 Train Epoch: 2 [0/640 (0%)]	Loss: 1.541398
#
# Power Allocated= 4.217213696241107
# CSI= 0.7065540860468654
# SNR= 43.302564401689125
# Client: client26
# Model client26 Train Epoch: 1 [0/640 (0%)]	Loss: 2.538213
# Model client26 Train Epoch: 2 [0/640 (0%)]	Loss: 1.690412
#
# Power Allocated= 4.623745099280175
# CSI= 0.9912881490610137
# SNR= 31.979170611725568
# Client: client28
# Model client28 Train Epoch: 1 [0/640 (0%)]	Loss: 2.410507
# Model client28 Train Epoch: 2 [0/640 (0%)]	Loss: 1.694758
#
# Power Allocated= 2.792458194214951
# CSI= 0.3521033379584845
# SNR= 25.70163663354505
# Client: client36
# Model client36 Train Epoch: 1 [0/640 (0%)]	Loss: 2.374334
# Model client36 Train Epoch: 2 [0/640 (0%)]	Loss: 1.640823
#
# Power Allocated= 3.683524122850553
# CSI= 0.5130811604907481
# SNR= 30.3266429030801
# Client: client52
# Model client52 Train Epoch: 1 [0/640 (0%)]	Loss: 2.384724
# Model client52 Train Epoch: 2 [0/640 (0%)]	Loss: 1.579551
#
# Power Allocated= 3.514854394334999
# CSI= 0.47221507305560395
# SNR= 33.8325474458185
# Client: client68
# Model client68 Train Epoch: 1 [0/640 (0%)]	Loss: 2.353768
# Model client68 Train Epoch: 2 [0/640 (0%)]	Loss: 1.675959
#
# Power Allocated= 1.2551609594180393
# CSI= 0.2284475419051254
# SNR= 39.44694682475724
# Client: client70
# Model client70 Train Epoch: 1 [0/640 (0%)]	Loss: 2.379541
# Model client70 Train Epoch: 2 [0/640 (0%)]	Loss: 1.605067
#
# Power Allocated= 4.438200615420016
# CSI= 0.8372874945881859
# SNR= 28.9260967311767
# Client: client72
# Model client72 Train Epoch: 1 [0/640 (0%)]	Loss: 2.306576
# Model client72 Train Epoch: 2 [0/640 (0%)]	Loss: 1.759660
#
# Power Allocated= 2.4606741932635305
# CSI= 0.3152724944629528
# SNR= 25.804389850172065
# Client: client75
# Model client75 Train Epoch: 1 [0/640 (0%)]	Loss: 2.426975
# Model client75 Train Epoch: 2 [0/640 (0%)]	Loss: 1.706764
#
# Power Allocated= 2.4783499853583293
# CSI= 0.3170392562938623
# SNR= 22.764276429901784
# Client: client80
# Model client80 Train Epoch: 1 [0/640 (0%)]	Loss: 2.327506
# Model client80 Train Epoch: 2 [0/640 (0%)]	Loss: 1.617327
#
# Power Allocated= 3.623270517753249
# CSI= 0.49769492698554174
# SNR= 14.569050666077178
# Client: client86
# Model client86 Train Epoch: 1 [0/640 (0%)]	Loss: 2.414938
# Model client86 Train Epoch: 2 [0/640 (0%)]	Loss: 1.666686
#
# Power Allocated= 3.7864922078858743
# CSI= 0.5416996883647632
# SNR= 30.262454960714393
# Client: client89
# Model client89 Train Epoch: 1 [0/640 (0%)]	Loss: 2.277053
# Model client89 Train Epoch: 2 [0/640 (0%)]	Loss: 1.822030
#
# Power Allocated= 3.036212561872845
# CSI= 0.3851603937273612
# SNR= 21.453025024048664
# Client: client96
# Model client96 Train Epoch: 1 [0/640 (0%)]	Loss: 2.454551
# Model client96 Train Epoch: 2 [0/640 (0%)]	Loss: 1.469098
#
# Power Allocated= 4.580915416992294
# CSI= 0.9509155493330226
# SNR= 23.08235455310809
# Client: client98
# Model client98 Train Epoch: 1 [0/640 (0%)]	Loss: 2.432211
# Model client98 Train Epoch: 2 [0/640 (0%)]	Loss: 1.594094
#
#
# Test set: Average loss for Cluster2 model: 0.7629, Accuracy: 7497/10000 (75%)
#
# 0.1565600000000057
# Power Allocated= 1.6092888527047142
# CSI= 0.20929089632692233
# SNR= 40.81420949455737
# Client: client3
# Model client3 Train Epoch: 1 [0/640 (0%)]	Loss: 2.228585
# Model client3 Train Epoch: 2 [0/640 (0%)]	Loss: 1.809747
#
# Power Allocated= 2.9151399828821565
# CSI= 0.2880028751122816
# SNR= 27.62274005757876
# Client: client9
# Model client9 Train Epoch: 1 [0/640 (0%)]	Loss: 2.225515
# Model client9 Train Epoch: 2 [0/640 (0%)]	Loss: 1.877743
#
# Power Allocated= 5.1111106071478325
# CSI= 0.7835658441513302
# SNR= 32.18476021813094
# Client: client13
# Model client13 Train Epoch: 1 [0/640 (0%)]	Loss: 2.232588
# Model client13 Train Epoch: 2 [0/640 (0%)]	Loss: 1.869658
#
# Power Allocated= 4.530766236750285
# CSI= 0.5386302068712995
# SNR= 37.07330286594608
# Client: client19
# Model client19 Train Epoch: 1 [0/640 (0%)]	Loss: 2.220603
# Model client19 Train Epoch: 2 [0/640 (0%)]	Loss: 1.869755
#
# Power Allocated= 4.892296300119289
# CSI= 0.6688823429787281
# SNR= 32.824007507228465
# Client: client22
# Model client22 Train Epoch: 1 [0/640 (0%)]	Loss: 2.216121
# Model client22 Train Epoch: 2 [0/640 (0%)]	Loss: 1.916356
#
# Power Allocated= 5.357733333062052
# CSI= 0.9712564340079993
# SNR= 28.517912174328025
# Client: client39
# Model client39 Train Epoch: 1 [0/640 (0%)]	Loss: 2.195568
# Model client39 Train Epoch: 2 [0/640 (0%)]	Loss: 1.834136
#
# Power Allocated= 5.073866817928819
# CSI= 0.7613474705064249
# SNR= 27.958995219345038
# Client: client43
# Model client43 Train Epoch: 1 [0/640 (0%)]	Loss: 2.219903
# Model client43 Train Epoch: 2 [0/640 (0%)]	Loss: 1.905661
#
# Power Allocated= 4.556432634708542
# CSI= 0.5461809937491601
# SNR= 29.002450846464914
# Client: client49
# Model client49 Train Epoch: 1 [0/640 (0%)]	Loss: 2.182105
# Model client49 Train Epoch: 2 [0/640 (0%)]	Loss: 1.683409
#
# Power Allocated= 4.181544639839679
# CSI= 0.45335377246320485
# SNR= 28.000079300164632
# Client: client58
# Model client58 Train Epoch: 1 [0/640 (0%)]	Loss: 2.258206
# Model client58 Train Epoch: 2 [0/640 (0%)]	Loss: 1.906659
#
# Power Allocated= 3.4568774053967357
# CSI= 0.34124450283458463
# SNR= 25.263092758072787
# Client: client62
# Model client62 Train Epoch: 1 [0/640 (0%)]	Loss: 2.229496
# Model client62 Train Epoch: 2 [0/640 (0%)]	Loss: 1.960020
#
# Power Allocated= 4.40910414311071
# CSI= 0.5055040803190096
# SNR= 33.822239423267185
# Client: client63
# Model client63 Train Epoch: 1 [0/640 (0%)]	Loss: 2.202087
# Model client63 Train Epoch: 2 [0/640 (0%)]	Loss: 1.754423
#
# Power Allocated= 5.356896911075815
# CSI= 0.9704680449489247
# SNR= 32.77394130003627
# Client: client69
# Model client69 Train Epoch: 1 [0/640 (0%)]	Loss: 2.155728
# Model client69 Train Epoch: 2 [0/640 (0%)]	Loss: 1.520556
#
# Power Allocated= 3.4778695360197505
# CSI= 0.34370662779489713
# SNR= 26.169261272402004
# Client: client71
# Model client71 Train Epoch: 1 [0/640 (0%)]	Loss: 2.185197
# Model client71 Train Epoch: 2 [0/640 (0%)]	Loss: 1.594528
#
# Power Allocated= 4.307708427706048
# CSI= 0.4808572844188501
# SNR= 23.271102140767464
# Client: client82
# Model client82 Train Epoch: 1 [0/640 (0%)]	Loss: 2.221191
# Model client82 Train Epoch: 2 [0/640 (0%)]	Loss: 1.724790
#
# Power Allocated= 0.7594244463601214
# CSI= 0.17768607294375605
# SNR= 29.38269010699483
# Client: client84
# Model client84 Train Epoch: 1 [0/640 (0%)]	Loss: 2.266261
# Model client84 Train Epoch: 2 [0/640 (0%)]	Loss: 2.054814
#
# Power Allocated= 0
# CSI= 0.07023295347562553
# SNR= 26.226758477138695
# Client: client91
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.00947693696857943
# SNR= 20.48818639443506
# Client: client99
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster3 model: 0.9844, Accuracy: 7116/10000 (71%)
#
# 0.2437399999999719
# Power Allocated= 0
# CSI= 0.09220416303981105
# SNR= 13.13811971551739
# Client: client4
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.10363201075111
# CSI= 0.5002249989432715
# SNR= 18.317254880635964
# Client: client7
# Model client7 Train Epoch: 1 [0/640 (0%)]	Loss: 2.209878
# Model client7 Train Epoch: 2 [0/640 (0%)]	Loss: 1.600376
#
# Power Allocated= 0
# CSI= 0.04031260016796223
# SNR= 18.77334421662698
# Client: client11
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.0250624600128323
# SNR= 20.411424286700615
# Client: client12
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.999742816063665
# CSI= 0.9066268590562796
# SNR= 29.579609777564695
# Client: client14
# Model client14 Train Epoch: 1 [0/640 (0%)]	Loss: 2.224915
# Model client14 Train Epoch: 2 [0/640 (0%)]	Loss: 2.031138
#
# Power Allocated= 0
# CSI= 0.05712132334434494
# SNR= 25.320660687512397
# Client: client16
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.4789482878891733
# CSI= 0.6158454072513442
# SNR= 15.714110861018828
# Client: client17
# Model client17 Train Epoch: 1 [0/640 (0%)]	Loss: 1.575542
# Model client17 Train Epoch: 2 [0/640 (0%)]	Loss: 0.971954
#
# Power Allocated= 0
# CSI= 0.12108978281913718
# SNR= 38.76566791625069
# Client: client23
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.22325262800259604
# SNR= 16.78232036531985
# Client: client25
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.772885183088003
# CSI= 0.7519660697859115
# SNR= 26.50824642881274
# Client: client27
# Model client27 Train Epoch: 1 [0/640 (0%)]	Loss: 2.226114
# Model client27 Train Epoch: 2 [0/640 (0%)]	Loss: 1.982301
#
# Power Allocated= 0.9930141550646079
# CSI= 0.32157253965501786
# SNR= 17.863160917577176
# Client: client29
# Model client29 Train Epoch: 1 [0/640 (0%)]	Loss: 2.216017
# Model client29 Train Epoch: 2 [0/640 (0%)]	Loss: 1.421418
#
# Power Allocated= 2.6130336071228895
# CSI= 0.6712766308836968
# SNR= 16.93998403973758
# Client: client31
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.08049894482487807
# SNR= 14.461603320425422
# Client: client32
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.8545346584297415
# CSI= 0.8011550981381159
# SNR= 25.754833201549104
# Client: client33
# Model client33 Train Epoch: 1 [0/640 (0%)]	Loss: 2.224661
# Model client33 Train Epoch: 2 [0/640 (0%)]	Loss: 1.719956
#
# Power Allocated= 2.913679257895167
# CSI= 0.8410052906336904
# SNR= 17.773748205796288
# Client: client34
# Model client34 Train Epoch: 1 [0/640 (0%)]	Loss: 2.349077
# Model client34 Train Epoch: 2 [0/640 (0%)]	Loss: 1.231807
#
# Power Allocated= 1.5833503874526844
# CSI= 0.3969227323064819
# SNR= 21.733883262172327
# Client: client35
# Model client35 Train Epoch: 1 [0/640 (0%)]	Loss: 2.195646
# Model client35 Train Epoch: 2 [0/640 (0%)]	Loss: 1.504547
#
# Power Allocated= 0
# CSI= 0.08127883959572446
# SNR= 26.853020724477712
# Client: client37
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0.6586803012256426
# CSI= 0.2903556524621499
# SNR= 19.140296051772687
# Client: client38
# Model client38 Train Epoch: 1 [0/640 (0%)]	Loss: 1.991175
# Model client38 Train Epoch: 2 [0/640 (0%)]	Loss: 0.913025
#
# Power Allocated= 0
# CSI= 0.04019756525726126
# SNR= 17.07459634886405
# Client: client40
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.24067156644491983
# SNR= 14.867853824364175
# Client: client41
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.834071046656863
# CSI= 0.788232400840534
# SNR= 14.9961348039262
# Client: client42
# Model client42 Train Epoch: 1 [0/640 (0%)]	Loss: 2.281060
# Model client42 Train Epoch: 2 [0/640 (0%)]	Loss: 1.409936
#
# Power Allocated= 0
# CSI= 0.06886659825994113
# SNR= 32.274509574784126
# Client: client44
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.900691038743286
# CSI= 0.8319181151047488
# SNR= 28.37758838255435
# Client: client45
# Model client45 Train Epoch: 1 [0/640 (0%)]	Loss: 2.208674
# Model client45 Train Epoch: 2 [0/640 (0%)]	Loss: 1.848550
#
# Power Allocated= 2.86345945087632
# CSI= 0.8069247252886675
# SNR= 15.683755699874014
# Client: client46
# Model client46 Train Epoch: 1 [0/640 (0%)]	Loss: 2.169473
# Model client46 Train Epoch: 2 [0/640 (0%)]	Loss: 1.301414
#
# Power Allocated= 2.8525309114972552
# CSI= 0.7998710554780415
# SNR= 22.787489422488818
# Client: client47
# Model client47 Train Epoch: 1 [0/640 (0%)]	Loss: 2.231586
# Model client47 Train Epoch: 2 [0/640 (0%)]	Loss: 1.589844
#
# Power Allocated= 2.3964160014789164
# CSI= 0.5860577729121301
# SNR= 21.50693556351531
# Client: client48
# Model client48 Train Epoch: 1 [0/640 (0%)]	Loss: 2.104276
# Model client48 Train Epoch: 2 [0/640 (0%)]	Loss: 1.196245
#
# Power Allocated= 2.5753418301841338
# CSI= 0.6547113795278123
# SNR= 13.599564639465026
# Client: client51
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.668011486786045
# CSI= 0.6969996582574512
# SNR= 16.703245180082014
# Client: client54
# Model client54 Train Epoch: 1 [0/640 (0%)]	Loss: 2.608945
# Model client54 Train Epoch: 2 [0/640 (0%)]	Loss: 2.044364
#
# Power Allocated= 1.9051154219916486
# CSI= 0.4550383442614886
# SNR= 12.689863867054212
# Client: client56
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.0889947357432107
# SNR= 14.58052732268292
# Client: client59
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.04733592215768656
# SNR= 29.268784986541664
# Client: client61
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0.591158407807332
# CSI= 0.2847725824906665
# SNR= 26.41617705444456
# Client: client64
# Model client64 Train Epoch: 1 [0/640 (0%)]	Loss: 2.151725
# Model client64 Train Epoch: 2 [0/640 (0%)]	Loss: 1.628922
#
# Power Allocated= 2.692588741120234
# CSI= 0.7091475961810327
# SNR= 23.419434182136612
# Client: client66
# Model client66 Train Epoch: 1 [0/640 (0%)]	Loss: 2.193509
# Model client66 Train Epoch: 2 [0/640 (0%)]	Loss: 1.741913
#
# Power Allocated= 0
# CSI= 0.1857435110842136
# SNR= 32.63376853658289
# Client: client73
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.693927372289232
# CSI= 0.7098214204815283
# SNR= 20.84989538711031
# Client: client74
# Model client74 Train Epoch: 1 [0/640 (0%)]	Loss: 2.233829
# Model client74 Train Epoch: 2 [0/640 (0%)]	Loss: 1.970372
#
# Power Allocated= 2.9047891066273372
# CSI= 0.8347640401766662
# SNR= 17.239990069636264
# Client: client79
# Model client79 Train Epoch: 1 [0/640 (0%)]	Loss: 2.200630
# Model client79 Train Epoch: 2 [0/640 (0%)]	Loss: 1.831236
#
# Power Allocated= 2.671208581489892
# CSI= 0.6985563029016932
# SNR= 12.757972134937758
# Client: client81
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.4791205557300886
# CSI= 0.6159107494436459
# SNR= 23.36971493851529
# Client: client92
# Model client92 Train Epoch: 1 [0/640 (0%)]	Loss: 2.229484
# Model client92 Train Epoch: 2 [0/640 (0%)]	Loss: 1.867304
#
# Power Allocated= 2.9993785493651535
# CSI= 0.9063275407853404
# SNR= 15.79367225871178
# Client: client94
# Model client94 Train Epoch: 1 [0/640 (0%)]	Loss: 2.128994
# Model client94 Train Epoch: 2 [0/640 (0%)]	Loss: 1.265607
#
# Power Allocated= 0
# CSI= 0.140906257197001
# SNR= 19.122930026199324
# Client: client100
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster4 model: 1.0041, Accuracy: 6808/10000 (68%)
#
# ROUND 1
# 0.20023999999998876
# Power Allocated= 1.4677777282006987
# CSI= 0.2835890319800801
# SNR= 28.55584955523917
# Client: client1
# Model client1 Train Epoch: 1 [0/640 (0%)]	Loss: 1.522338
# Model client1 Train Epoch: 2 [0/640 (0%)]	Loss: 0.607441
#
# Power Allocated= 3.2514783584230225
# CSI= 0.5738785959187992
# SNR= 14.936269167463102
# Client: client5
# Model client5 Train Epoch: 1 [0/640 (0%)]	Loss: 1.768140
# Model client5 Train Epoch: 2 [0/640 (0%)]	Loss: 1.053814
#
# Power Allocated= 2.3096611458887275
# CSI= 0.3725302114766931
# SNR= 27.54727786413042
# Client: client8
# Model client8 Train Epoch: 1 [0/640 (0%)]	Loss: 1.926448
# Model client8 Train Epoch: 2 [0/640 (0%)]	Loss: 1.721496
#
# Power Allocated= 3.8923100401829527
# CSI= 0.9076904654985734
# SNR= 15.03404375072379
# Client: client10
# Model client10 Train Epoch: 1 [0/640 (0%)]	Loss: 1.663579
# Model client10 Train Epoch: 2 [0/640 (0%)]	Loss: 1.003739
#
# Power Allocated= 2.102192739744211
# CSI= 0.34580365259519896
# SNR= 22.128242523037674
# Client: client15
# Model client15 Train Epoch: 1 [0/640 (0%)]	Loss: 1.601399
# Model client15 Train Epoch: 2 [0/640 (0%)]	Loss: 0.880046
#
# Power Allocated= 3.7292489127957418
# CSI= 0.7906649175103889
# SNR= 27.003704173285712
# Client: client18
# Model client18 Train Epoch: 1 [0/640 (0%)]	Loss: 1.901903
# Model client18 Train Epoch: 2 [0/640 (0%)]	Loss: 0.777130
#
# Power Allocated= 3.661569093906309
# CSI= 0.7505039085140486
# SNR= 19.46960530214449
# Client: client21
# Model client21 Train Epoch: 1 [0/640 (0%)]	Loss: 1.990145
# Model client21 Train Epoch: 2 [0/640 (0%)]	Loss: 0.844366
#
# Power Allocated= 0
# CSI= 0.0922002951972355
# SNR= 18.693950823212045
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.02462886522268204
# SNR= 24.98489734299053
# Client: client50
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.6556436033438215
# CSI= 0.7471811165113414
# SNR= 15.25417121289029
# Client: client53
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.601877140659603
# CSI= 0.7183236936012183
# SNR= 17.003323215428427
# Client: client55
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.001654457576196866
# SNR= 28.809291630180827
# Client: client57
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.8917135176241686
# CSI= 0.9071992553501715
# SNR= 17.94787448869871
# Client: client60
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.905428292319895
# CSI= 0.9186288663798434
# SNR= 28.604090599402475
# Client: client65
# Model client65 Train Epoch: 1 [0/640 (0%)]	Loss: 1.742238
# Model client65 Train Epoch: 2 [0/640 (0%)]	Loss: 1.058170
#
# Power Allocated= 1.1748153336020466
# CSI= 0.26183549746680246
# SNR= 38.06199825288803
# Client: client76
# Model client76 Train Epoch: 1 [0/640 (0%)]	Loss: 1.797360
# Model client76 Train Epoch: 2 [0/640 (0%)]	Loss: 0.902899
#
# Power Allocated= 3.629248387230932
# CSI= 0.7327302062215785
# SNR= 22.284863450085574
# Client: client77
# Model client77 Train Epoch: 1 [0/640 (0%)]	Loss: 1.632841
# Model client77 Train Epoch: 2 [0/640 (0%)]	Loss: 1.121890
#
# Power Allocated= 0.26267816988242476
# CSI= 0.2113571039888188
# SNR= 27.896956065886574
# Client: client85
# Model client85 Train Epoch: 1 [0/640 (0%)]	Loss: 1.587926
# Model client85 Train Epoch: 2 [0/640 (0%)]	Loss: 0.897624
#
# Power Allocated= 3.9521656132516934
# CSI= 0.9598388286686659
# SNR= 30.53566111191541
# Client: client88
# Model client88 Train Epoch: 1 [0/640 (0%)]	Loss: 1.724954
# Model client88 Train Epoch: 2 [0/640 (0%)]	Loss: 0.802029
#
# Power Allocated= 3.957562083327348
# CSI= 0.9648364319919531
# SNR= 23.440932548653386
# Client: client90
# Model client90 Train Epoch: 1 [0/640 (0%)]	Loss: 1.632965
# Model client90 Train Epoch: 2 [0/640 (0%)]	Loss: 2.118852
#
# Power Allocated= 3.8133483248082434
# CSI= 0.8469847034745956
# SNR= 13.19956793345282
# Client: client93
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.757969270097669
# CSI= 0.8090366669091537
# SNR= 19.961038760761646
# Client: client95
# Model client95 Train Epoch: 1 [0/640 (0%)]	Loss: 1.585880
# Model client95 Train Epoch: 2 [0/640 (0%)]	Loss: 1.392238
#
# Power Allocated= 3.9798672148183654
# CSI= 0.9860571746709551
# SNR= 21.58984179673025
# Client: client97
# Model client97 Train Epoch: 1 [0/640 (0%)]	Loss: 1.850482
# Model client97 Train Epoch: 2 [0/640 (0%)]	Loss: 1.046398
#
#
# Test set: Average loss for Cluster1 model: 0.7541, Accuracy: 7857/10000 (79%)
#
# 0.17753999999999756
# Power Allocated= 4.419482829756638
# CSI= 0.8243678630580308
# SNR= 45.300680213335205
# Client: client2
# Model client2 Train Epoch: 1 [0/640 (0%)]	Loss: 1.421742
# Model client2 Train Epoch: 2 [0/640 (0%)]	Loss: 0.973950
#
# Power Allocated= 3.9870024911987185
# CSI= 0.6077065618345088
# SNR= 22.36316904653916
# Client: client6
# Model client6 Train Epoch: 1 [0/640 (0%)]	Loss: 1.327745
# Model client6 Train Epoch: 2 [0/640 (0%)]	Loss: 1.349586
#
# Power Allocated= 3.012503478096714
# CSI= 0.3816750138200792
# SNR= 21.458753783461653
# Client: client20
# Model client20 Train Epoch: 1 [0/640 (0%)]	Loss: 1.408494
# Model client20 Train Epoch: 2 [0/640 (0%)]	Loss: 1.278058
#
# Power Allocated= 4.091697819879581
# CSI= 0.6489984649836442
# SNR= 25.647880399636477
# Client: client24
# Model client24 Train Epoch: 1 [0/640 (0%)]	Loss: 1.510228
# Model client24 Train Epoch: 2 [0/640 (0%)]	Loss: 1.136396
#
# Power Allocated= 4.217213696241107
# CSI= 0.7065540860468654
# SNR= 43.302564401689125
# Client: client26
# Model client26 Train Epoch: 1 [0/640 (0%)]	Loss: 1.169147
# Model client26 Train Epoch: 2 [0/640 (0%)]	Loss: 0.944600
#
# Power Allocated= 4.623745099280175
# CSI= 0.9912881490610137
# SNR= 31.979170611725568
# Client: client28
# Model client28 Train Epoch: 1 [0/640 (0%)]	Loss: 1.321970
# Model client28 Train Epoch: 2 [0/640 (0%)]	Loss: 1.324293
#
# Power Allocated= 2.792458194214951
# CSI= 0.3521033379584845
# SNR= 25.70163663354505
# Client: client36
# Model client36 Train Epoch: 1 [0/640 (0%)]	Loss: 1.263447
# Model client36 Train Epoch: 2 [0/640 (0%)]	Loss: 0.744549
#
# Power Allocated= 3.683524122850553
# CSI= 0.5130811604907481
# SNR= 30.3266429030801
# Client: client52
# Model client52 Train Epoch: 1 [0/640 (0%)]	Loss: 1.188344
# Model client52 Train Epoch: 2 [0/640 (0%)]	Loss: 0.965888
#
# Power Allocated= 3.514854394334999
# CSI= 0.47221507305560395
# SNR= 33.8325474458185
# Client: client68
# Model client68 Train Epoch: 1 [0/640 (0%)]	Loss: 1.403315
# Model client68 Train Epoch: 2 [0/640 (0%)]	Loss: 0.673520
#
# Power Allocated= 1.2551609594180393
# CSI= 0.2284475419051254
# SNR= 39.44694682475724
# Client: client70
# Model client70 Train Epoch: 1 [0/640 (0%)]	Loss: 1.186535
# Model client70 Train Epoch: 2 [0/640 (0%)]	Loss: 0.574171
#
# Power Allocated= 4.438200615420016
# CSI= 0.8372874945881859
# SNR= 28.9260967311767
# Client: client72
# Model client72 Train Epoch: 1 [0/640 (0%)]	Loss: 1.096254
# Model client72 Train Epoch: 2 [0/640 (0%)]	Loss: 1.021404
#
# Power Allocated= 2.4606741932635305
# CSI= 0.3152724944629528
# SNR= 25.804389850172065
# Client: client75
# Model client75 Train Epoch: 1 [0/640 (0%)]	Loss: 1.281200
# Model client75 Train Epoch: 2 [0/640 (0%)]	Loss: 0.342016
#
# Power Allocated= 2.4783499853583293
# CSI= 0.3170392562938623
# SNR= 22.764276429901784
# Client: client80
# Model client80 Train Epoch: 1 [0/640 (0%)]	Loss: 1.681482
# Model client80 Train Epoch: 2 [0/640 (0%)]	Loss: 0.726786
#
# Power Allocated= 3.623270517753249
# CSI= 0.49769492698554174
# SNR= 14.569050666077178
# Client: client86
# Model client86 Train Epoch: 1 [0/640 (0%)]	Loss: 1.446824
# Model client86 Train Epoch: 2 [0/640 (0%)]	Loss: 1.689248
#
# Power Allocated= 3.7864922078858743
# CSI= 0.5416996883647632
# SNR= 30.262454960714393
# Client: client89
# Model client89 Train Epoch: 1 [0/640 (0%)]	Loss: 1.581156
# Model client89 Train Epoch: 2 [0/640 (0%)]	Loss: 2.175570
#
# Power Allocated= 3.036212561872845
# CSI= 0.3851603937273612
# SNR= 21.453025024048664
# Client: client96
# Model client96 Train Epoch: 1 [0/640 (0%)]	Loss: 1.467224
# Model client96 Train Epoch: 2 [0/640 (0%)]	Loss: 1.089261
#
# Power Allocated= 4.580915416992294
# CSI= 0.9509155493330226
# SNR= 23.08235455310809
# Client: client98
# Model client98 Train Epoch: 1 [0/640 (0%)]	Loss: 1.367446
# Model client98 Train Epoch: 2 [0/640 (0%)]	Loss: 0.884898
#
#
# ...
# CSI= 0.7906649175103889
# SNR= 27.003704173285712
# Client: client18
# Model client18 Train Epoch: 1 [0/640 (0%)]	Loss: 2.289305
# Model client18 Train Epoch: 2 [0/640 (0%)]	Loss: 2.330749
#
# Power Allocated= 3.661569093906309
# CSI= 0.7505039085140486
# SNR= 19.46960530214449
# Client: client21
# Model client21 Train Epoch: 1 [0/640 (0%)]	Loss: 2.317103
# Model client21 Train Epoch: 2 [0/640 (0%)]	Loss: 2.291533
#
# Power Allocated= 0
# CSI= 0.0922002951972355
# SNR= 18.693950823212045
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.02462886522268204
# SNR= 24.98489734299053
# Client: client50
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.6556436033438215
# CSI= 0.7471811165113414
# SNR= 15.25417121289029
# Client: client53
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.601877140659603
# CSI= 0.7183236936012183
# SNR= 17.003323215428427
# Client: client55
# Model client55 Train Epoch: 1 [0/640 (0%)]	Loss: 2.297949
# Model client55 Train Epoch: 2 [0/640 (0%)]	Loss: 2.294242
#
# Power Allocated= 0
# CSI= 0.001654457576196866
# SNR= 28.809291630180827
# Client: client57
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.8917135176241686
# CSI= 0.9071992553501715
# SNR= 17.94787448869871
# Client: client60
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.905428292319895
# CSI= 0.9186288663798434
# SNR= 28.604090599402475
# Client: client65
# Model client65 Train Epoch: 1 [0/640 (0%)]	Loss: 2.317508
# Model client65 Train Epoch: 2 [0/640 (0%)]	Loss: 2.296544
#
# Power Allocated= 1.1748153336020466
# CSI= 0.26183549746680246
# SNR= 38.06199825288803
# Client: client76
# Model client76 Train Epoch: 1 [0/640 (0%)]	Loss: 2.306736
# Model client76 Train Epoch: 2 [0/640 (0%)]	Loss: 2.312937
#
# Power Allocated= 3.629248387230932
# CSI= 0.7327302062215785
# SNR= 22.284863450085574
# Client: client77
# Model client77 Train Epoch: 1 [0/640 (0%)]	Loss: 2.313330
# Model client77 Train Epoch: 2 [0/640 (0%)]	Loss: 2.264938
#
# Power Allocated= 0.26267816988242476
# CSI= 0.2113571039888188
# SNR= 27.896956065886574
# Client: client85
# Model client85 Train Epoch: 1 [0/640 (0%)]	Loss: 2.296936
# Model client85 Train Epoch: 2 [0/640 (0%)]	Loss: 2.279997
#
# Power Allocated= 3.9521656132516934
# CSI= 0.9598388286686659
# SNR= 30.53566111191541
# Client: client88
# Model client88 Train Epoch: 1 [0/640 (0%)]	Loss: 2.292556
# Model client88 Train Epoch: 2 [0/640 (0%)]	Loss: 2.278709
#
# Power Allocated= 3.957562083327348
# CSI= 0.9648364319919531
# SNR= 23.440932548653386
# Client: client90
# Model client90 Train Epoch: 1 [0/640 (0%)]	Loss: 2.309239
# Model client90 Train Epoch: 2 [0/640 (0%)]	Loss: 2.279146
#
# Power Allocated= 3.8133483248082434
# CSI= 0.8469847034745956
# SNR= 13.19956793345282
# Client: client93
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.757969270097669
# CSI= 0.8090366669091537
# SNR= 19.961038760761646
# Client: client95
# Model client95 Train Epoch: 1 [0/640 (0%)]	Loss: 2.311169
# Model client95 Train Epoch: 2 [0/640 (0%)]	Loss: 2.297475
#
# Power Allocated= 3.9798672148183654
# CSI= 0.9860571746709551
# SNR= 21.58984179673025
# Client: client97
# Model client97 Train Epoch: 1 [0/640 (0%)]	Loss: 2.308172
# Model client97 Train Epoch: 2 [0/640 (0%)]	Loss: 2.320691
#
#
# Test set: Average loss for Cluster1 model: 2.3064, Accuracy: 1135/10000 (11%)
#
# 0.17753999999999756
# Power Allocated= 4.419482829756638
# CSI= 0.8243678630580308
# SNR= 45.300680213335205
# Client: client2
# Model client2 Train Epoch: 1 [0/640 (0%)]	Loss: 2.298626
# Model client2 Train Epoch: 2 [0/640 (0%)]	Loss: 2.294139
#
# Power Allocated= 3.9870024911987185
# CSI= 0.6077065618345088
# SNR= 22.36316904653916
# Client: client6
# Model client6 Train Epoch: 1 [0/640 (0%)]	Loss: 2.314873
# Model client6 Train Epoch: 2 [0/640 (0%)]	Loss: 2.265907
#
# Power Allocated= 3.012503478096714
# CSI= 0.3816750138200792
# SNR= 21.458753783461653
# Client: client20
# Model client20 Train Epoch: 1 [0/640 (0%)]	Loss: 2.298978
# Model client20 Train Epoch: 2 [0/640 (0%)]	Loss: 2.287804
#
# Power Allocated= 4.091697819879581
# CSI= 0.6489984649836442
# SNR= 25.647880399636477
# Client: client24
# Model client24 Train Epoch: 1 [0/640 (0%)]	Loss: 2.313681
# Model client24 Train Epoch: 2 [0/640 (0%)]	Loss: 2.295125
#
# Power Allocated= 4.217213696241107
# CSI= 0.7065540860468654
# SNR= 43.302564401689125
# Client: client26
# Model client26 Train Epoch: 1 [0/640 (0%)]	Loss: 2.293544
# Model client26 Train Epoch: 2 [0/640 (0%)]	Loss: 2.280807
#
# Power Allocated= 4.623745099280175
# CSI= 0.9912881490610137
# SNR= 31.979170611725568
# Client: client28
# Model client28 Train Epoch: 1 [0/640 (0%)]	Loss: 2.300048
# Model client28 Train Epoch: 2 [0/640 (0%)]	Loss: 2.281046
#
# Power Allocated= 2.792458194214951
# CSI= 0.3521033379584845
# SNR= 25.70163663354505
# Client: client36
# Model client36 Train Epoch: 1 [0/640 (0%)]	Loss: 2.305140
# Model client36 Train Epoch: 2 [0/640 (0%)]	Loss: 2.333908
#
# Power Allocated= 3.683524122850553
# CSI= 0.5130811604907481
# SNR= 30.3266429030801
# Client: client52
# Model client52 Train Epoch: 1 [0/640 (0%)]	Loss: 2.309414
# Model client52 Train Epoch: 2 [0/640 (0%)]	Loss: 2.271227
#
# Power Allocated= 3.514854394334999
# CSI= 0.47221507305560395
# SNR= 33.8325474458185
# Client: client68
# Model client68 Train Epoch: 1 [0/640 (0%)]	Loss: 2.308196
# Model client68 Train Epoch: 2 [0/640 (0%)]	Loss: 2.299971
#
# Power Allocated= 1.2551609594180393
# CSI= 0.2284475419051254
# SNR= 39.44694682475724
# Client: client70
# Model client70 Train Epoch: 1 [0/640 (0%)]	Loss: 2.293457
# Model client70 Train Epoch: 2 [0/640 (0%)]	Loss: 2.307323
#
# Power Allocated= 4.438200615420016
# CSI= 0.8372874945881859
# SNR= 28.9260967311767
# Client: client72
# Model client72 Train Epoch: 1 [0/640 (0%)]	Loss: 2.293413
# Model client72 Train Epoch: 2 [0/640 (0%)]	Loss: 2.291224
#
# Power Allocated= 2.4606741932635305
# CSI= 0.3152724944629528
# SNR= 25.804389850172065
# Client: client75
# Model client75 Train Epoch: 1 [0/640 (0%)]	Loss: 2.300018
# Model client75 Train Epoch: 2 [0/640 (0%)]	Loss: 2.291091
#
# Power Allocated= 2.4783499853583293
# CSI= 0.3170392562938623
# SNR= 22.764276429901784
# Client: client80
# Model client80 Train Epoch: 1 [0/640 (0%)]	Loss: 2.290738
# Model client80 Train Epoch: 2 [0/640 (0%)]	Loss: 2.295782
#
# Power Allocated= 3.623270517753249
# CSI= 0.49769492698554174
# SNR= 14.569050666077178
# Client: client86
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.7864922078858743
# CSI= 0.5416996883647632
# SNR= 30.262454960714393
# Client: client89
# Model client89 Train Epoch: 1 [0/640 (0%)]	Loss: 2.298933
# Model client89 Train Epoch: 2 [0/640 (0%)]	Loss: 2.314079
#
# Power Allocated= 3.036212561872845
# CSI= 0.3851603937273612
# SNR= 21.453025024048664
# Client: client96
# Model client96 Train Epoch: 1 [0/640 (0%)]	Loss: 2.294461
# Model client96 Train Epoch: 2 [0/640 (0%)]	Loss: 2.323624
#
# Power Allocated= 4.580915416992294
# CSI= 0.9509155493330226
# SNR= 23.08235455310809
# Client: client98
# Model client98 Train Epoch: 1 [0/640 (0%)]	Loss: 2.302303
# Model client98 Train Epoch: 2 [0/640 (0%)]	Loss: 2.265674
#
#
# Test set: Average loss for Cluster2 model: 2.3058, Accuracy: 1032/10000 (10%)
#
# 0.1565600000000057
# Power Allocated= 1.6092888527047142
# CSI= 0.20929089632692233
# SNR= 40.81420949455737
# Client: client3
# Model client3 Train Epoch: 1 [0/640 (0%)]	Loss: 2.344243
# Model client3 Train Epoch: 2 [0/640 (0%)]	Loss: 2.339674
#
# Power Allocated= 2.9151399828821565
# CSI= 0.2880028751122816
# SNR= 27.62274005757876
# Client: client9
# Model client9 Train Epoch: 1 [0/640 (0%)]	Loss: 2.361117
# Model client9 Train Epoch: 2 [0/640 (0%)]	Loss: 2.366522
#
# Power Allocated= 5.1111106071478325
# CSI= 0.7835658441513302
# SNR= 32.18476021813094
# Client: client13
# Model client13 Train Epoch: 1 [0/640 (0%)]	Loss: 2.475380
# Model client13 Train Epoch: 2 [0/640 (0%)]	Loss: 2.376905
#
# Power Allocated= 4.530766236750285
# CSI= 0.5386302068712995
# SNR= 37.07330286594608
# Client: client19
# Model client19 Train Epoch: 1 [0/640 (0%)]	Loss: 2.347741
# Model client19 Train Epoch: 2 [0/640 (0%)]	Loss: 2.285466
#
# Power Allocated= 4.892296300119289
# CSI= 0.6688823429787281
# SNR= 32.824007507228465
# Client: client22
# Model client22 Train Epoch: 1 [0/640 (0%)]	Loss: 2.375369
# Model client22 Train Epoch: 2 [0/640 (0%)]	Loss: 2.377603
#
# Power Allocated= 5.357733333062052
# CSI= 0.9712564340079993
# SNR= 28.517912174328025
# Client: client39
# Model client39 Train Epoch: 1 [0/640 (0%)]	Loss: 2.332494
# Model client39 Train Epoch: 2 [0/640 (0%)]	Loss: 2.311038
#
# Power Allocated= 5.073866817928819
# CSI= 0.7613474705064249
# SNR= 27.958995219345038
# Client: client43
# Model client43 Train Epoch: 1 [0/640 (0%)]	Loss: 2.595863
# Model client43 Train Epoch: 2 [0/640 (0%)]	Loss: 2.595117
#
# Power Allocated= 4.556432634708542
# CSI= 0.5461809937491601
# SNR= 29.002450846464914
# Client: client49
# Model client49 Train Epoch: 1 [0/640 (0%)]	Loss: 2.395473
# Model client49 Train Epoch: 2 [0/640 (0%)]	Loss: 2.351639
#
# Power Allocated= 4.181544639839679
# CSI= 0.45335377246320485
# SNR= 28.000079300164632
# Client: client58
# Model client58 Train Epoch: 1 [0/640 (0%)]	Loss: 2.260919
# Model client58 Train Epoch: 2 [0/640 (0%)]	Loss: 2.297464
#
# Power Allocated= 3.4568774053967357
# CSI= 0.34124450283458463
# SNR= 25.263092758072787
# Client: client62
# Model client62 Train Epoch: 1 [0/640 (0%)]	Loss: 2.283850
# Model client62 Train Epoch: 2 [0/640 (0%)]	Loss: 2.277695
#
# Power Allocated= 4.40910414311071
# CSI= 0.5055040803190096
# SNR= 33.822239423267185
# Client: client63
# Model client63 Train Epoch: 1 [0/640 (0%)]	Loss: 2.366206
# Model client63 Train Epoch: 2 [0/640 (0%)]	Loss: 2.357872
#
# Power Allocated= 5.356896911075815
# CSI= 0.9704680449489247
# SNR= 32.77394130003627
# Client: client69
# Model client69 Train Epoch: 1 [0/640 (0%)]	Loss: 2.366453
# Model client69 Train Epoch: 2 [0/640 (0%)]	Loss: 2.335374
#
# Power Allocated= 3.4778695360197505
# CSI= 0.34370662779489713
# SNR= 26.169261272402004
# Client: client71
# Model client71 Train Epoch: 1 [0/640 (0%)]	Loss: 2.324644
# Model client71 Train Epoch: 2 [0/640 (0%)]	Loss: 2.338873
#
# Power Allocated= 4.307708427706048
# CSI= 0.4808572844188501
# SNR= 23.271102140767464
# Client: client82
# Model client82 Train Epoch: 1 [0/640 (0%)]	Loss: 2.377230
# Model client82 Train Epoch: 2 [0/640 (0%)]	Loss: 2.360077
#
# Power Allocated= 0.7594244463601214
# CSI= 0.17768607294375605
# SNR= 29.38269010699483
# Client: client84
# Model client84 Train Epoch: 1 [0/640 (0%)]	Loss: 2.335126
# Model client84 Train Epoch: 2 [0/640 (0%)]	Loss: 2.504757
#
# Power Allocated= 0
# CSI= 0.07023295347562553
# SNR= 26.226758477138695
# Client: client91
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.00947693696857943
# SNR= 20.48818639443506
# Client: client99
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster3 model: 2.3066, Accuracy: 1032/10000 (10%)
#
# 0.2437399999999719
# Power Allocated= 0
# CSI= 0.09220416303981105
# SNR= 13.13811971551739
# Client: client4
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.10363201075111
# CSI= 0.5002249989432715
# SNR= 18.317254880635964
# Client: client7
# Model client7 Train Epoch: 1 [0/640 (0%)]	Loss: 2.397130
# Model client7 Train Epoch: 2 [0/640 (0%)]	Loss: 2.368423
#
# Power Allocated= 0
# CSI= 0.04031260016796223
# SNR= 18.77334421662698
# Client: client11
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.0250624600128323
# SNR= 20.411424286700615
# Client: client12
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.999742816063665
# CSI= 0.9066268590562796
# SNR= 29.579609777564695
# Client: client14
# Model client14 Train Epoch: 1 [0/640 (0%)]	Loss: 2.330602
# Model client14 Train Epoch: 2 [0/640 (0%)]	Loss: 2.323026
#
# Power Allocated= 0
# CSI= 0.05712132334434494
# SNR= 25.320660687512397
# Client: client16
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.4789482878891733
# CSI= 0.6158454072513442
# SNR= 15.714110861018828
# Client: client17
# Model client17 Train Epoch: 1 [0/640 (0%)]	Loss: 2.256185
# Model client17 Train Epoch: 2 [0/640 (0%)]	Loss: 2.421605
#
# Power Allocated= 0
# CSI= 0.12108978281913718
# SNR= 38.76566791625069
# Client: client23
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.22325262800259604
# SNR= 16.78232036531985
# Client: client25
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.772885183088003
# CSI= 0.7519660697859115
# SNR= 26.50824642881274
# Client: client27
# Model client27 Train Epoch: 1 [0/640 (0%)]	Loss: 2.308985
# Model client27 Train Epoch: 2 [0/640 (0%)]	Loss: 2.321168
#
# Power Allocated= 0.9930141550646079
# CSI= 0.32157253965501786
# SNR= 17.863160917577176
# Client: client29
# Model client29 Train Epoch: 1 [0/640 (0%)]	Loss: 2.379934
# Model client29 Train Epoch: 2 [0/640 (0%)]	Loss: 2.509798
#
# Power Allocated= 2.6130336071228895
# CSI= 0.6712766308836968
# SNR= 16.93998403973758
# Client: client31
# Model client31 Train Epoch: 1 [0/640 (0%)]	Loss: 2.373537
# Model client31 Train Epoch: 2 [0/640 (0%)]	Loss: 2.400872
#
# Power Allocated= 0
# CSI= 0.08049894482487807
# SNR= 14.461603320425422
# Client: client32
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.8545346584297415
# CSI= 0.8011550981381159
# SNR= 25.754833201549104
# Client: client33
# Model client33 Train Epoch: 1 [0/640 (0%)]	Loss: 2.342551
# Model client33 Train Epoch: 2 [0/640 (0%)]	Loss: 2.416025
#
# Power Allocated= 2.913679257895167
# CSI= 0.8410052906336904
# SNR= 17.773748205796288
# Client: client34
# Model client34 Train Epoch: 1 [0/640 (0%)]	Loss: 2.440649
# Model client34 Train Epoch: 2 [0/640 (0%)]	Loss: 2.386631
#
# Power Allocated= 1.5833503874526844
# CSI= 0.3969227323064819
# SNR= 21.733883262172327
# Client: client35
# Model client35 Train Epoch: 1 [0/640 (0%)]	Loss: 2.366551
# Model client35 Train Epoch: 2 [0/640 (0%)]	Loss: 2.300050
#
# Power Allocated= 0
# CSI= 0.08127883959572446
# SNR= 26.853020724477712
# Client: client37
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0.6586803012256426
# CSI= 0.2903556524621499
# SNR= 19.140296051772687
# Client: client38
# Model client38 Train Epoch: 1 [0/640 (0%)]	Loss: 2.443107
# Model client38 Train Epoch: 2 [0/640 (0%)]	Loss: 2.370893
#
# Power Allocated= 0
# CSI= 0.04019756525726126
# SNR= 17.07459634886405
# Client: client40
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.24067156644491983
# SNR= 14.867853824364175
# Client: client41
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.834071046656863
# CSI= 0.788232400840534
# SNR= 14.9961348039262
# Client: client42
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.06886659825994113
# SNR= 32.274509574784126
# Client: client44
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.900691038743286
# CSI= 0.8319181151047488
# SNR= 28.37758838255435
# Client: client45
# Model client45 Train Epoch: 1 [0/640 (0%)]	Loss: 2.401096
# Model client45 Train Epoch: 2 [0/640 (0%)]	Loss: 2.437256
#
# Power Allocated= 2.86345945087632
# CSI= 0.8069247252886675
# SNR= 15.683755699874014
# Client: client46
# Model client46 Train Epoch: 1 [0/640 (0%)]	Loss: 2.332771
# Model client46 Train Epoch: 2 [0/640 (0%)]	Loss: 2.374480
#
# Power Allocated= 2.8525309114972552
# CSI= 0.7998710554780415
# SNR= 22.787489422488818
# Client: client47
# Model client47 Train Epoch: 1 [0/640 (0%)]	Loss: 2.397420
# Model client47 Train Epoch: 2 [0/640 (0%)]	Loss: 2.335889
#
# Power Allocated= 2.3964160014789164
# CSI= 0.5860577729121301
# SNR= 21.50693556351531
# Client: client48
# Model client48 Train Epoch: 1 [0/640 (0%)]	Loss: 2.375653
# Model client48 Train Epoch: 2 [0/640 (0%)]	Loss: 2.363808
#
# Power Allocated= 2.5753418301841338
# CSI= 0.6547113795278123
# SNR= 13.599564639465026
# Client: client51
# Model client51 Train Epoch: 1 [0/640 (0%)]	Loss: 2.427766
# Model client51 Train Epoch: 2 [0/640 (0%)]	Loss: 2.463448
#
# Power Allocated= 2.668011486786045
# CSI= 0.6969996582574512
# SNR= 16.703245180082014
# Client: client54
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 1.9051154219916486
# CSI= 0.4550383442614886
# SNR= 12.689863867054212
# Client: client56
