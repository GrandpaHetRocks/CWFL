# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import numpy as np
from Dataset import load_dataset, getImage
from utils import averageModels
from utils import averageModelscluster
import random
import math
import matplotlib.pyplot as plt
from ipynb.fs.full.K_clusters import cluster_former
from copy import deepcopy
# Out:
# 0.6943721771240234
# {'Cluster Head': 'client62', 'Members': ['client6', 'client8', 'client12', 'client13', 'client21', 'client28', 'client29', 'client32', 'client36', 'client38', 'client39', 'client44', 'client47', 'client55', 'client56', 'client58', 'client71', 'client74', 'client75', 'client78', 'client84', 'client95', 'client97', 'client98'], 'SNR': [25.90696932810043, 29.36292660382678, 35.20945654785733, 34.87425460319868, 28.071838843258163, 26.310664201551262, 24.777387150862808, 32.32854596232554, 22.188728999444173, 36.70504515185978, 25.73398049192723, 35.90654249994659, 30.59285362735017, 39.734832082455675, 25.62637679329836, 30.466465757693378, 28.36630838619258, 31.77402144697104, 27.181852789176812, 23.298768949619838, 25.02704884667905, 23.5724269373426, 28.162195014257822, 26.4380438470808], 'CSI': [0.5242261763944217, 0.13312708137465068, 0.029238459324412602, 0.7892327444499571, 0.7035950875171926, 0.2746356339335364, 0.07370194931214524, 0.1848442903345825, 0.9035673270639761, 0.6446682879224099, 0.4316711127692905, 0.4721597921217747, 0.8658276702780888, 0.08846592918256169, 0.1088776992559447, 0.9155340139908411, 0.3897870860900595, 0.041379368014214934, 0.4744208339984849, 0.04077555892526796, 0.33329263437715106, 0.9745209109512103, 0.21459157140153495, 0.31567488367331686]}

# %%
P=2 #signal power threshold
#stream = BitStream()
#random.seed(10)
key=[]
for i in range (10000): #generating a random password to activate training (Pilot signal)
    temp=random.randint(0,1)
    key.append(temp)

key1=[0]*len(key)
for i in range (len(key)):   #bpsk modulation
    if(key[i]==1):
        #print("yay")
        key1[i]=-math.sqrt(P)
    else:
        key1[i]=math.sqrt(P)

#print(key)
        
key_np=np.array(key1)

# %%
class Arguments():
    def __init__(self):
        self.images = 10000
        self.clients = 50
        self.rounds = 200
        self.epochs = 3
        self.local_batches = 64
        self.lr = 0.001
        self.C = 1 #fraction of clients used in the round
        self.drop_rate = 0 #fraction of devices in the selected set to be dropped for various reasons
        self.torch_seed = 0 #same weights and parameters whenever the program is run
        self.log_interval = 64
        self.iid = 'noniid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = True
        self.numclusters=3

args = Arguments()

# %%
#checking if gpu is available
#use_cuda = args.use_cuda and torch.cuda.is_available()
use_cuda=False
device = torch.device("cuda:0" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

hook = sy.TorchHook(torch)
me = hook.local_worker
clients = []

#generating virtual clients
for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})
#print(clients)

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid) #load data

for inx, client in enumerate(clients):  #return actual image set for each client
    trainset_ind_list = list(train_group[inx]) 
    client['trainset'] = getImage(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getImage(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images #useful while taking weighted average
# Out:
# /home/test/anaconda3/lib/python3.7/site-packages/torchvision/datasets/mnist.py:45: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")

# %%
#load dataset for global model (to compare accuracies)
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.MNIST('./', train=False, download=True, transform=transform)
# global_test_dataset = torch.utils.data.random_split(global_test_dataset, [10000, len(global_test_dataset)-10000])[0]
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
"""class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        #self.quant = torch.quantization.QuantStub()
        self.conv1 = nn.Conv2d(1, 5, 5, 1)
        self.conv2 = nn.Conv2d(5, 10, 5, 1)
        self.fc1 = nn.Linear(4*4*10, 50) #10 iid #50 non iid
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        #x=self.quant(x)
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*10
                   )
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1) """

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x)

# %%
def fedprox(params,global_params):
    global_param=[]
    ind=0
    for gp in global_params:
        global_param.append(gp)
    for p in params:
    #                 print(p.grad)
        lr=0.001
        mu=0.1
        if(p.grad is None):
            continue
        grad=p.grad.data #batch gradients
        p.data.sub_(lr,(grad+mu*(p.data.clone()-global_param[ind].data.clone())))
        ind+=1
    return(p)

# %%
def ClientUpdate(args, device, client,key_np,key,snr,csi,mu,head):
    gc=False
    client['model'].train()
    #simulating a wireless channel
    poptim=max((1/mu-1/csi),0)
    #print(mu,csi)
    print("Power Allocated=",poptim)
    print("CSI=",csi)
    
    snr__=10**(snr/10)
    
    absh=csi*poptim/snr__
    x=random.uniform(0,absh)
    #print(x)
    y=math.sqrt(absh*absh-x*x)
    #x=x*100
    #y=y*100
    #x=random.random()
    #y=random.random()
    #snr=10*math.log(poptim/(std*std),10)
    std=math.sqrt(poptim/snr__*absh*absh) #channel noise
    
    #print(x,y)
    h=complex(x,y)
    #std=math.sqrt(abs(h)/csi)
    #snr=poptim/(std*std)
    #print(std)
    print("SNR=",snr)
    #print("csi",abs(h)/(std*std))
    
    
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data

    
    #print(client['model'].conv1.weight.size)
    client['model'].send(client['hook'])
    head['model'].send(client['hook'])
    print("Client:",client['hook'].id)
    
    key_np_received=h*key_np+(np.random.randn(len(key_np))*std*2)
    #print(key_np_received)
    key_np_received=(key_np_received/(h)).real
    
    for o in range (len(key_np_received)):  #demodulation bpsk
        if(key_np_received[o]>=0):
            key_np_received[o]=0
        else:
            key_np_received[o]=1
    
    key_np_received=key_np_received.tolist()
    key_np_received = [int(item) for item in key_np_received]
    #key_np=key_np.tolist()
    
    
    if(sum(np.bitwise_xor(key,key_np_received))/len(key)==0 and poptim>0): #...............................................checking if channel is good enough for transmission by checking BER..................................#
        gc=True #considering the client model for training
        for epoch in range(1, args.epochs + 1):
            for batch_idx, (data, target) in enumerate(client['trainset']): 
                data = data.send(client['hook'])
                target = target.send(client['hook'])
                #client['optim'].zero_grad()
                #train model on client
                data, target = data.to(device), target.to(device) #send data to cpu/gpu (data is stored locally)
                output = client['model'](data)
                loss = F.nll_loss(output, target)
                loss.backward()
                #client['optim'].step()
                params=client['model'].parameters()
                gp=head['model'].parameters()
                params=fedprox(params,gp) 
                
                if batch_idx % args.log_interval == 0:
                    loss = loss.get() 
                    print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                        client['hook'].id,
                        epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                        100. * batch_idx / len(client['trainset']), loss))
    else:
        print("Poor Channel, client not taken for averaging in this round")
            
                    
    client['model'].get()
    head['model'].get()
    # print()
         #CHANGE
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
    #CHANGE ENDS
    print()
    return gc

# %%
def test(args, model, device, test_loader, name,fed_round):
    model.eval()    #no need to train the model while testing
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            if(use_cuda and fed_round==0):
                data,target=data.cuda(),target.cuda()
                #model.cuda()
            else:
                data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    return([100. * correct / len(test_loader.dataset),test_loss])

# %%
torch.manual_seed(args.torch_seed)

# %%
def distort(neighbours,snrs):
    ind=0
    poptim=2
    csi=random.random()
    distorted_models=[]
    for client in neighbours:
        snr=snrs[ind]
        ind+=1
        snr__=10**(snr/10)
        absh=csi*poptim/snr__
        x=random.uniform(0,absh)
        y=math.sqrt(absh*absh-x*x)
        std=math.sqrt(poptim/snr__*absh*absh) #channel noise
        h=complex(x,y)
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
        
        distorted_models.append(client)
    return(distorted_models)

# %%
def decentralized(clients,snrs,weights):
    big_daddy_of_distorted_models=[]
    for client in clients:
        distorted_models=[]
        snr_list=[]
        for snr in snrs:
            if(client['hook'].id in snr):
                snr_list.append(snr[2])
        neighbours_c = [x for x in clients if x != client]
        neighbours={}
        jjj=[jkl for jkl in range(len(neighbours_c))]
        
        dictionary = dict(zip(jjj, neighbours_c))
        #for jjj in range(len(neighbours_c)):
        #   neighbours[jjj].append(neighbours_c[jjj])
        distorted_models=distort(neighbours,snr_list)
        distorted_models.append(client)
        big_daddy_of_distorted_models.append(distorted_models)
    
    
    weight_final1=[]
    for oho in big_daddy_of_distorted_models:
        weight_final=[]
        for comeon in oho:
            for w in weights:
                if(comeon['hook'].id==w[0]):
                    weight_final.append(w[1])
        weight_final1.append(weight_final)
    
    final_heads=[]
    nets=[]
    ind=0
    for client in clients:
        for oof in big_daddy_of_distorted_models:
            if(client==oof[0]):
#                 print(client)
#                 print("shut up")
#                 print(distorted_models)
#                 print("shut up")
#                 print(weight_final1)
                
                overall=Net()
                overall=averageModelscluster(overall,distorted_models,weight_final1[ind])
                client['model'].load_state_dict(overall.state_dict())
                ind+=1
                final_heads.append(client)
                nets.append(overall)
    
    return(final_heads,nets)

# %%
for client in clients: #give the model and optimizer to every client
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    #client['model'] = torch.quantization.quantize_dynamic(
    #client['model'],  # the original model
    #{torch.nn.Linear},  # a set of layers to dynamically quantize
    #dtype=torch.fp)  # the target dtype for quantized weights
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)

final_acc=[]
final_loss=[]
clor = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(args.numclusters)]   
for fed_round in range(args.rounds):
    overall=Net()
    if(fed_round==0): #fed_round==0
        arranged_clusters,head_snr_list=cluster_former(args.numclusters,args.clients)
        temp=deepcopy(arranged_clusters)
        temp2=deepcopy(head_snr_list)
    else:
        #print(temp)
        arranged_clusters=deepcopy(temp)
        head_snr_list=deepcopy(temp2)
#     print(arranged_clusters)
    
    no=1
    heads_list=[]
    weights=[]
    weight_head_list=[]
    head_acc=[]
    head_loss=[]
    for cluster in arranged_clusters:
        
        head=cluster['Cluster Head']
        members=cluster['Members']
        snrs=cluster['SNR']
        csis=cluster['CSI']
        weights.append(sum(snrs))
        weight_head_list.append([head,sum(snrs)])
        new_members=[]
        
        for ij in members:
        #print(ij)
            cl_no=int(ij[6:])
            new_members.append(clients[cl_no-1])
#         print(head)
        head=clients[int(head[6:])-1]
        cluster['Members']=new_members
#         print(head)

        smallmu1=0
        gsmall1=3.402823466E+38 
        
        #water filling algorithm
        mu=1e-15
        while(mu<=1):
            g1=0
            pn1=0
            for jj in csis:
                pn=max(1/mu-1/jj,0)
                g1+=math.log(1+pn*jj) #capacity of a channel (shannon's law)
                pn1+=pn
            g=g1-mu*(pn1-P*30)
            if(g<gsmall1):
                smallmu1=mu
                gsmall1=g
            mu+=0.00002
        
        print(smallmu1)
        good_mem=[]
#         print(len(snrs))
#         print(len(csis))
#         print(len(new_members))
        index=0
        for client in new_members:
            goodchannel=ClientUpdate(args, device, client,key_np,key,snrs[index],csis[index],smallmu1,head)
            index+=1
            if(goodchannel):
                good_mem.append(client)
        
        head['model']=averageModels(head['model'], good_mem)
        arr=test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)
        ac=arr[0]#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[0]
        no+=1
        heads_list.append(head)
        head_acc.append(ac)
        head_loss.append(arr[1])#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[1])
    
    final_acc.append(head_acc)
    final_loss.append(head_loss)
    fig,ax=plt.subplots()
    
    #ax.plot([i for i in range(fed_round)],head_acc[0])
    for jj in range(0,args.numclusters):
        
        ax.plot([i for i in range(len(final_acc))],[final_acc[j][jj] for j in range(len(final_acc))], color = clor[jj])
        
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][0] for j in range(len(final_acc))], color ="red")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][1] for j in range(len(final_acc))],color ="blue")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][2] for j in range(len(final_acc))],color ="green")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][3] for j in range(len(final_acc))],color ="black")
    #ax.plot([i for i in range(len(final_acc))],head_acc[1], fed_round, color ="blue")
    #ax.plot([i for i in range(len(final_acc))],head_acc[2], fed_round, color ="green")
    #ax.plot([i for i in range(len(final_acc))],head_acc[3], fed_round, color ="black")
    
    
    plt.show()
    weightsum=sum(weights)
    
    weights[:] = [x / weightsum for x in weights]
    for aah in range(len(weight_head_list)):
        weight_head_list[aah][1]=weights[aah]
    final_heads,nets=decentralized(heads_list,head_snr_list,weight_head_list)
    
    for head in range(len(final_heads)):
        for cluster in arranged_clusters:
            head1=cluster['Cluster Head']
            if(head1==final_heads[head]['hook'].id):
                for mem in cluster['Members']:
                    mem['model'].load_state_dict(nets[head].state_dict())
    print("ROUND",fed_round)
# Out:
# 0.12778000000001685
# Power Allocated= 6.453645918130475
# CSI= 0.7287010157658268
# SNR= 24.458826730275607
# Client: client1
# Model client1 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.378901
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/generic/frameworks/hook/hook.py:165: UserWarning: This overload of sub_ is deprecated:
# 	sub_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	sub_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   response = method(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client1 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.053110
# Model client1 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.527737
# Model client1 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.134568
# Model client1 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.928939
# Model client1 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.984990
# Model client1 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.860006
# Model client1 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.415999
# Model client1 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.337096
# Model client1 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.470529
#
# Power Allocated= 0
# CSI= 0.0025242906965751155
# SNR= 25.911531996827847
# Client: client5
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.88095486565874
# CSI= 0.33955903651109
# SNR= 21.521942148609327
# Client: client13
# Model client13 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.323891
# /home/test/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: RuntimeWarning: invalid value encountered in true_divide
# Model client13 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.489583
# Model client13 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.045046
# Model client13 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.741535
# Model client13 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.631228
# Model client13 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.387605
# Model client13 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.589531
# Model client13 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.389962
# Model client13 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.532942
# Model client13 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.315123
#
# Power Allocated= 6.509850004683837
# CSI= 0.759820192547124
# SNR= 24.938392240107817
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.214202
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.750824
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.406825
# Model client15 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.117267
# Model client15 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.037469
# Model client15 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.059314
# Model client15 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.790398
# Model client15 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.449973
# Model client15 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.418304
# Model client15 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.272859
#
# Power Allocated= 6.776541027964391
# CSI= 0.9529165594954825
# SNR= 28.95397095791166
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.312587
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.042852
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.648347
# Model client17 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.613306
# Model client17 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.304597
# Model client17 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.202682
# Model client17 Train Epoch: 7 [0/1216 (0%)]	Loss: 1.042944
# Model client17 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.753098
# Model client17 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.659145
# Model client17 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.710392
#
# Power Allocated= 6.501203901665296
# CSI= 0.7548611445919097
# SNR= 25.28150550313914
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301339
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.532383
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.996225
# Model client18 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.779573
# Model client18 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.699147
# Model client18 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.668540
# Model client18 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.456448
# Model client18 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.607983
# Model client18 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.352666
# Model client18 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.305408
#
# Power Allocated= 6.345773691570149
# CSI= 0.6755948044863402
# SNR= 30.443249776253925
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.357411
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.987555
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.706021
# Model client20 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.516639
# Model client20 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.270142
# Model client20 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.062338
# Model client20 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.927789
# Model client20 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.765795
# Model client20 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.888414
# Model client20 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.521909
#
# Power Allocated= 6.527532194580699
# CSI= 0.770167613885138
# SNR= 30.981146048771446
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.223078
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.777456
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.062278
# Model client26 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.503086
# Model client26 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.057378
# Model client26 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.977985
# Model client26 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.795841
# Model client26 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.571242
# Model client26 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.247824
# Model client26 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.316692
#
# Power Allocated= 5.108245444959841
# CSI= 0.36795746773414206
# SNR= 27.72570314665594
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.310617
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.532294
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.305287
# Model client33 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.166245
# Model client33 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.088048
# Model client33 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.781242
# Model client33 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.399821
# Model client33 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.299246
# Model client33 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.109559
# Model client33 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.103717
#
# Power Allocated= 6.383871926686089
# CSI= 0.6934433211203958
# SNR= 40.12178078919072
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.387475
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.040111
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.455514
# Model client48 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.000541
# Model client48 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.950721
# Model client48 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.016963
# Model client48 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.707356
# Model client48 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.567236
# Model client48 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.220349
# Model client48 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.192802
#
# Power Allocated= 4.51480660535806
# CSI= 0.30201040039370675
# SNR= 21.345877799035385
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.293588
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.034696
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.252062
# Model client49 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.307405
# Model client49 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.144814
# Model client49 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.982416
# Model client49 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.895860
# Model client49 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.001451
# Model client49 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.583630
# Model client49 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.325357
#
#
# Test set: Average loss for Cluster1 model: 2.3094, Accuracy: 1695/10000 (17%)
#
# 0.1405200000000119
# Power Allocated= 5.819797220198247
# CSI= 0.7712315288958368
# SNR= 27.5138858891458
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.349378
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.989727
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.612087
# Model client2 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.682943
# Model client2 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.224885
# Model client2 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.102900
# Model client2 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.970960
# Model client2 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.797139
# Model client2 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.583724
# Model client2 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.458621
#
# Power Allocated= 4.845712884488385
# CSI= 0.44039053725188115
# SNR= 24.170568499463066
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.286461
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.114834
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.719308
# Model client4 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.416641
# Model client4 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.956386
# Model client4 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.688002
# Model client4 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.391625
# Model client4 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.651139
# Model client4 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.258307
# Model client4 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.240784
#
# Power Allocated= 5.8735686882329095
# CSI= 0.8045984280669715
# SNR= 26.9763595104297
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.330397
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.070703
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.607767
# Model client9 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.281305
# Model client9 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.621420
# Model client9 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.934682
# Model client9 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.846568
# Model client9 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.896741
# Model client9 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.574910
# Model client9 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.587251
#
# Power Allocated= 5.346055843717853
# CSI= 0.5648540369454782
# SNR= 32.20737948234665
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.350627
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.136559
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.719919
# Model client21 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.505874
# Model client21 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.521716
# Model client21 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.303560
# Model client21 Train Epoch: 7 [0/1216 (0%)]	Loss: 1.343498
# Model client21 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.099381
# Model client21 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.939662
# Model client21 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.615202
#
# Power Allocated= 5.1007573833597135
# CSI= 0.49611361342395366
# SNR= 25.348315012639304
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.279418
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.034478
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.457996
# Model client22 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.304202
# Model client22 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.204416
# Model client22 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.762123
# Model client22 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.593434
# Model client22 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.359734
# Model client22 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.391136
# Model client22 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.320889
#
# Power Allocated= 5.0937401193772605
# CSI= 0.4943924552118045
# SNR= 29.927534231368828
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.311068
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.050475
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.817135
# Model client27 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.198865
# Model client27 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.083283
# Model client27 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.869079
# Model client27 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.723694
# Model client27 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.593188
# Model client27 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.680768
# Model client27 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.274125
#
# Power Allocated= 1.5903547233755786
# CSI= 0.18096042987900574
# SNR= 35.911882712882
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.320366
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.007068
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.963449
# Model client36 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.297557
# Model client36 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.155707
# Model client36 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.153748
# Model client36 Train Epoch: 7 [0/1216 (0%)]	Loss: 1.130701
# Model client36 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.748797
# Model client36 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.620543
# Model client36 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.535328
#
# Power Allocated= 4.661877628546991
# CSI= 0.4074071376666284
# SNR= 28.056875109023427
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307991
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.016037
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.208102
# Model client39 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.216453
# Model client39 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.838663
# Model client39 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.644570
# Model client39 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.362655
# Model client39 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.389361
# Model client39 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.202647
# Model client39 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.480064
#
# Power Allocated= 4.409259466396108
# CSI= 0.3693900854474852
# SNR= 26.09191933418457
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300685
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.157573
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.791638
# Model client41 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.870062
# Model client41 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.697524
# Model client41 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.739233
# Model client41 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.761061
# Model client41 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.650052
# Model client41 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.550617
# Model client41 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.394027
#
# Power Allocated= 6.016102315414532
# CSI= 0.9088245468174867
# SNR= 30.457507251827206
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.290796
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.096696
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.801229
# Model client42 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.461977
# Model client42 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.357671
# Model client42 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.425936
# Model client42 Train Epoch: 7 [0/1216 (0%)]	Loss: 1.338828
# Model client42 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.276529
# Model client42 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.960653
# Model client42 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.554914
#
# Power Allocated= 5.9496228703068565
# CSI= 0.8570435591560245
# SNR= 29.267019522513436
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.335876
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.083089
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.703706
# Model client46 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.304752
# Model client46 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.499013
# Model client46 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.128397
# Model client46 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.638488
# Model client46 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.549851
# Model client46 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.369255
# Model client46 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.556573
#
# Power Allocated= 5.297559229190764
# CSI= 0.5497932703249883
# SNR= 22.078542515671053
# Client: client47
# Model client47 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.235258
# Model client47 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.019039
# Model client47 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.518722
# Model client47 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.349445
# Model client47 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.190181
# Model client47 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.860860
# Model client47 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.621468
# Model client47 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.291957
# Model client47 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.332119
# Model client47 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.396230
#
#
# Test set: Average loss for Cluster2 model: 2.1006, Accuracy: 1989/10000 (20%)
#
# 0.20341999999998753
# Power Allocated= 1.7157700739555417
# CSI= 0.3124836536558607
# SNR= 18.018047333411268
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.489981
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.494140
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.884604
# Model client3 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.760649
# Model client3 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.323366
# Model client3 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.323761
# Model client3 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.286835
# Model client3 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.226611
# Model client3 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.253240
# Model client3 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.156968
#
# Power Allocated= 1.6379873293713691
# CSI= 0.3050687037079789
# SNR= 27.510045116603038
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.284495
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.964623
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.201826
# Model client6 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.157643
# Model client6 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.808165
# Model client6 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.689303
# Model client6 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.369198
# Model client6 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.384539
# Model client6 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.179280
# Model client6 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.358496
#
# Power Allocated= 3.7621231611299093
# CSI= 0.8666905869862477
# SNR= 12.283880453780549
# Client: client7
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.16913826473550042
# SNR= 31.459931507418535
# Client: client10
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 1.8367465235939497
# CSI= 0.3247606327897268
# SNR= 22.83092160055677
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.346183
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.646105
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.487827
# Model client12 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.066384
# Model client12 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.052602
# Model client12 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.959378
# Model client12 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.558092
# Model client12 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.447979
# Model client12 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.283605
# Model client12 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.335909
#
# Power Allocated= 3.6793453728754217
# CSI= 0.8086740994957092
# SNR= 23.207261422086304
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.433182
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.271603
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.634091
# Model client14 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.567930
# Model client14 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.755274
# Model client14 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.264546
# Model client14 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.282836
# Model client14 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.270132
# Model client14 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.069791
# Model client14 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.068935
#
# Power Allocated= 3.674632677819548
# CSI= 0.8056039152373883
# SNR= 23.99723819450564
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.363959
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.634885
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.185229
# Model client16 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.205437
# Model client16 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.673283
# Model client16 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.568347
# Model client16 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.528110
# Model client16 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.244454
# Model client16 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.143575
# Model client16 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.212284
#
# Power Allocated= 1.0753979358231076
# CSI= 0.26038008235291243
# SNR= 12.480114134337592
# Client: client19
# Model client19 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.334984
# Model client19 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.900406
# Model client19 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.500493
# Model client19 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.420254
# Model client19 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.137246
# Model client19 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.980736
# Model client19 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.894565
# Model client19 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.901950
# Model client19 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.622075
# Model client19 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.612979
#
# Power Allocated= 0
# CSI= 0.009516919332134277
# SNR= 13.440699681376348
# Client: client23
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.15355314278942578
# SNR= 14.370221198766274
# Client: client25
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.7851268583399404
# CSI= 0.8843213800164951
# SNR= 22.413179600091933
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.273775
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.805534
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.631354
# Model client28 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.350469
# Model client28 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.294136
# Model client28 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.084637
# Model client28 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.749746
# Model client28 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.600700
# Model client28 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.525003
# Model client28 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.549320
#
# Power Allocated= 3.552387247066444
# CSI= 0.7333796612051313
# SNR= 13.330668618372101
# Client: client29
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 1.862374754488406
# CSI= 0.3274863146439947
# SNR= 20.890076783857246
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.371853
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.611889
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.902208
# Model client30 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.507013
# Model client30 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.323023
# Model client30 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.156119
# Model client30 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.484584
# Model client30 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.252152
# Model client30 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.217823
# Model client30 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.284408
#
# Power Allocated= 3.2333406176814066
# CSI= 0.5943194289544076
# SNR= 21.73650347169476
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.337283
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.837807
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.272431
# Model client31 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.116226
# Model client31 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.969373
# Model client31 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.714083
# Model client31 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.471933
# Model client31 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.429916
# Model client31 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.535445
# Model client31 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.622711
#
# Power Allocated= 3.7573735463012725
# CSI= 0.863137527563146
# SNR= 14.10457848317453
# Client: client32
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.1676576351732946
# CSI= 0.5719908109066647
# SNR= 9.660701632610708
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.333365
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.996864
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.606158
# Model client34 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.681673
# Model client34 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.522608
# Model client34 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.213728
# Model client34 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.066547
# Model client34 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.059650
# Model client34 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.202228
# Model client34 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.066875
#
# Power Allocated= 3.8494381975418737
# CSI= 0.9376471475449671
# SNR= 22.60671724362816
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.271796
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.635914
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.324543
# Model client35 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.204515
# Model client35 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.037316
# Model client35 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.867700
# Model client35 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.748496
# Model client35 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.618932
# Model client35 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.374335
# Model client35 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.285083
#
# Power Allocated= 3.3648687472459162
# CSI= 0.6447167593524605
# SNR= 28.68624453830259
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.333669
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.349787
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.779478
# Model client37 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.911662
# Model client37 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.607763
# Model client37 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.541102
# Model client37 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.501634
# Model client37 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.216940
# Model client37 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.296842
# Model client37 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.032256
#
# Power Allocated= 3.1197177356466015
# CSI= 0.5567247599376915
# SNR= 37.271142786493414
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.361785
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.025867
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.454523
# Model client38 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.077884
# Model client38 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.751234
# Model client38 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.702940
# Model client38 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.230883
# Model client38 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.218973
# Model client38 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.181504
# Model client38 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.075937
#
# Power Allocated= 0
# CSI= 0.05382830264547356
# SNR= 11.312661421891974
# Client: client40
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 1.8274582386070026
# CSI= 0.32378394844620306
# SNR= 10.612898016707952
# Client: client43
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.81915990034482
# CSI= 0.9117618998853063
# SNR= 16.039221790968895
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.308438
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.104460
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.546580
# Model client44 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.037634
# Model client44 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.951096
# Model client44 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.744969
# Model client44 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.503166
# Model client44 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.419076
# Model client44 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.238832
# Model client44 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.122504
#
# Power Allocated= 3.4347758988994195
# CSI= 0.6751457909794141
# SNR= 13.299159486095721
# Client: client45
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.8435781235774398
# CSI= 0.9325232292808185
# SNR= 10.96157170769083
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.321369
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.943029
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.399060
# Model client50 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.142200
# Model client50 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.552890
# Model client50 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.458962
# Model client50 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.440701
# Model client50 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.238180
# Model client50 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.425092
# Model client50 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.376587
#
#
# Test set: Average loss for Cluster3 model: 2.6638, Accuracy: 1798/10000 (18%)
# ROUND 0
# 0.12778000000001685
# Power Allocated= 6.453645918130475
# CSI= 0.7287010157658268
# SNR= 24.458826730275607
# Client: client1
# Model client1 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.397796
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/test/anaconda3/lib/python3.7/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client1 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.193770
# Model client1 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.525427
# Model client1 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.917227
# Model client1 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.663435
# Model client1 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.428075
# Model client1 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.376206
# Model client1 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.910548
# Model client1 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.318830
# Model client1 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.404670
#
# Power Allocated= 0
# CSI= 0.0025242906965751155
# SNR= 25.911531996827847
# Client: client5
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.88095486565874
# CSI= 0.33955903651109
# SNR= 21.521942148609327
# Client: client13
# Model client13 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.462061
# /home/test/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: RuntimeWarning: invalid value encountered in true_divide
# Model client13 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.245291
# Model client13 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.899589
# Model client13 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.502875
# Model client13 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.683330
# Model client13 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.620465
# Model client13 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.929716
# Model client13 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.351243
# Model client13 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.394050
# Model client13 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.274635
#
# Power Allocated= 6.509850004683837
# CSI= 0.759820192547124
# SNR= 24.938392240107817
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.213950
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.082671
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.811401
# Model client15 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.155943
# Model client15 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.199645
# Model client15 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.261926
# Model client15 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.452520
# Model client15 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.204542
# Model client15 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.267236
# Model client15 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.330137
#
# Power Allocated= 6.776541027964391
# CSI= 0.9529165594954825
# SNR= 28.95397095791166
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.366255
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.178390
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.706305
# Model client17 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.894986
# Model client17 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.877659
# Model client17 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.398844
# Model client17 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.472553
# Model client17 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.637729
# Model client17 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.534769
# Model client17 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.265369
#
# Power Allocated= 6.501203901665296
# CSI= 0.7548611445919097
# SNR= 25.28150550313914
# Client: client18
# Model client18 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.335281
# Model client18 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.948521
# Model client18 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.177149
# Model client18 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.930794
# Model client18 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.533491
# Model client18 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.221623
# Model client18 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.297320
# Model client18 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.048519
# Model client18 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.113604
# Model client18 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.104138
#
# Power Allocated= 6.345773691570149
# CSI= 0.6755948044863402
# SNR= 30.443249776253925
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.379097
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.233969
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.951816
# Model client20 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.392520
# Model client20 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.654944
# Model client20 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.323409
# Model client20 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.289393
# Model client20 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.598983
# Model client20 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.386265
# Model client20 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.523338
#
# Power Allocated= 6.527532194580699
# CSI= 0.770167613885138
# SNR= 30.981146048771446
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.342423
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.127276
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.837192
# Model client26 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.427870
# Model client26 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.129449
# Model client26 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.805188
# Model client26 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.520509
# Model client26 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.639789
# Model client26 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.655349
# Model client26 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.433505
#
# Power Allocated= 5.108245444959841
# CSI= 0.36795746773414206
# SNR= 27.72570314665594
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.314731
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.140196
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.507899
# Model client33 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.455789
# Model client33 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.066424
# Model client33 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.553647
# Model client33 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.064209
# Model client33 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.403372
# Model client33 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.000275
# Model client33 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.204889
#
# Power Allocated= 6.383871926686089
# CSI= 0.6934433211203958
# SNR= 40.12178078919072
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.145059
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.932564
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.588907
# Model client48 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.025540
# Model client48 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.358825
# Model client48 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.877371
# Model client48 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.238318
# Model client48 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.137274
# Model client48 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.438011
# Model client48 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.882075
#
# Power Allocated= 4.51480660535806
# CSI= 0.30201040039370675
# SNR= 21.345877799035385
# Client: client49
# Model client49 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.362911
# Model client49 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.097548
# Model client49 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.429995
# Model client49 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.047620
# Model client49 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.193585
# Model client49 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.264696
# Model client49 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.134897
# Model client49 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.140477
# Model client49 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.279394
# Model client49 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.467996
#
#
# Test set: Average loss for Cluster1 model: 2.9485, Accuracy: 1043/10000 (10%)
#
# 0.1405200000000119
# Power Allocated= 5.819797220198247
# CSI= 0.7712315288958368
# SNR= 27.5138858891458
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.327091
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.036678
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.030308
# Model client2 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.514858
# Model client2 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.728420
# Model client2 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.326193
# Model client2 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.482993
# Model client2 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.128934
# Model client2 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.189116
# Model client2 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.284895
#
# Power Allocated= 4.845712884488385
# CSI= 0.44039053725188115
# SNR= 24.170568499463066
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.203877
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.078942
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.825225
# Model client4 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.389537
# Model client4 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.133660
# Model client4 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.327126
# Model client4 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.627292
# Model client4 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.444141
# Model client4 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.468153
# Model client4 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.528660
#
# Power Allocated= 5.8735686882329095
# CSI= 0.8045984280669715
# SNR= 26.9763595104297
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.194641
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.134484
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.895355
# Model client9 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.083822
# Model client9 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.653366
# Model client9 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.309177
# Model client9 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.184059
# Model client9 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.406920
# Model client9 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.384824
# Model client9 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.535725
#
# Power Allocated= 5.346055843717853
# CSI= 0.5648540369454782
# SNR= 32.20737948234665
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.452957
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.266567
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.024931
# Model client21 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.595176
# Model client21 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.071605
# Model client21 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.614874
# Model client21 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.628386
# Model client21 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.595537
# Model client21 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.661878
# Model client21 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.340861
#
# Power Allocated= 5.1007573833597135
# CSI= 0.49611361342395366
# SNR= 25.348315012639304
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.344166
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.134386
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.560310
# Model client22 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.785170
# Model client22 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.477720
# Model client22 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.124247
# Model client22 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.724136
# Model client22 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.281602
# Model client22 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.269280
# Model client22 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.425127
#
# Power Allocated= 5.0937401193772605
# CSI= 0.4943924552118045
# SNR= 29.927534231368828
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.400699
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.274262
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.022078
# Model client27 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.548789
# Model client27 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.471649
# Model client27 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.158144
# Model client27 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.760730
# Model client27 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.617588
# Model client27 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.577964
# Model client27 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.406078
#
# Power Allocated= 1.5903547233755786
# CSI= 0.18096042987900574
# SNR= 35.911882712882
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.326491
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.042099
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.236037
# Model client36 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.631692
# Model client36 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.686425
# Model client36 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.491181
# Model client36 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.712019
# Model client36 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.402208
# Model client36 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.678281
# Model client36 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.502837
#
# Power Allocated= 4.661877628546991
# CSI= 0.4074071376666284
# SNR= 28.056875109023427
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.448140
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.199118
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.838174
# Model client39 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.303800
# Model client39 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.438624
# Model client39 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.279328
# Model client39 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.555064
# Model client39 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.178248
# Model client39 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.029041
# Model client39 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.118722
#
# Power Allocated= 4.409259466396108
# CSI= 0.3693900854474852
# SNR= 26.09191933418457
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.481658
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.070715
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.489712
# Model client41 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.644591
# Model client41 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.841522
# Model client41 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.757175
# Model client41 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.516927
# Model client41 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.585816
# Model client41 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.561872
# Model client41 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.242422
#
# Power Allocated= 6.016102315414532
# CSI= 0.9088245468174867
# SNR= 30.457507251827206
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.440354
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.278748
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.033755
# Model client42 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.559499
# Model client42 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.889144
# Model client42 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.881627
# Model client42 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.520418
# Model client42 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.659076
# Model client42 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.411831
# Model client42 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.488578
#
# Power Allocated= 5.9496228703068565
# CSI= 0.8570435591560245
# SNR= 29.267019522513436
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.405196
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.237761
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.888361
# Model client46 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.958265
# Model client46 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.715019
# Model client46 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.785066
# Model client46 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.664448
# Model client46 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.772152
# Model client46 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.349806
# Model client46 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.302145
#
# Power Allocated= 5.297559229190764
# CSI= 0.5497932703249883
# SNR= 22.078542515671053
# Client: client47
# Model client47 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.269001
# Model client47 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.002747
# Model client47 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.778827
# Model client47 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.314107
# Model client47 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.891133
# Model client47 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.873792
# Model client47 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.774652
# Model client47 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.683298
# Model client47 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.793355
# Model client47 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.564200
#
#
# Test set: Average loss for Cluster2 model: 2.4857, Accuracy: 2070/10000 (21%)
#
# 0.20341999999998753
# Power Allocated= 1.7157700739555417
# CSI= 0.3124836536558607
# SNR= 18.018047333411268
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.896203
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.237246
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.763609
# Model client3 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.114959
# Model client3 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.267084
# Model client3 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.384712
# Model client3 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.198968
# Model client3 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.483112
# Model client3 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.268991
# Model client3 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.924664
#
# Power Allocated= 1.6379873293713691
# CSI= 0.3050687037079789
# SNR= 27.510045116603038
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.002827
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.521190
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.522096
# Model client6 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.176939
# Model client6 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.454387
# Model client6 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.210875
# Model client6 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.205906
# Model client6 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.112694
# Model client6 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.110553
# Model client6 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.605158
#
# Power Allocated= 3.7621231611299093
# CSI= 0.8666905869862477
# SNR= 12.283880453780549
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.450208
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.313310
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.026436
# Model client7 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.516951
# Model client7 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.031835
# Model client7 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.862571
# Model client7 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.755774
# Model client7 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.597715
# Model client7 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.406818
# Model client7 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.363313
#
# Power Allocated= 0
# ...
# CSI= 0.18096042987900574
# SNR= 35.911882712882
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.837842
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.159024
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.137817
# Model client36 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.086876
# Model client36 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.220812
# Model client36 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.039561
# Model client36 Train Epoch: 7 [0/1216 (0%)]	Loss: 1.245676
# Model client36 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.215971
# Model client36 Train Epoch: 9 [0/1216 (0%)]	Loss: 1.142455
# Model client36 Train Epoch: 10 [0/1216 (0%)]	Loss: 1.143685
#
# Power Allocated= 4.661877628546991
# CSI= 0.4074071376666284
# SNR= 28.056875109023427
# Client: client39
# Model client39 Train Epoch: 1 [0/1216 (0%)]	Loss: 3.103899
# Model client39 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.625810
# Model client39 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.652340
# Model client39 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.774854
# Model client39 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.635126
# Model client39 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.530447
# Model client39 Train Epoch: 7 [0/1216 (0%)]	Loss: 1.335096
# Model client39 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.095961
# Model client39 Train Epoch: 9 [0/1216 (0%)]	Loss: 1.381246
# Model client39 Train Epoch: 10 [0/1216 (0%)]	Loss: 1.210413
#
# Power Allocated= 4.409259466396108
# CSI= 0.3693900854474852
# SNR= 26.09191933418457
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.550843
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.478551
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.670864
# Model client41 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.235804
# Model client41 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.063665
# Model client41 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.852342
# Model client41 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.354759
# Model client41 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.426067
# Model client41 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.392769
# Model client41 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.239301
#
# Power Allocated= 6.016102315414532
# CSI= 0.9088245468174867
# SNR= 30.457507251827206
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.453662
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.459749
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.325582
# Model client42 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.166972
# Model client42 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.963233
# Model client42 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.915502
# Model client42 Train Epoch: 7 [0/1216 (0%)]	Loss: 1.041744
# Model client42 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.129102
# Model client42 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.973086
# Model client42 Train Epoch: 10 [0/1216 (0%)]	Loss: 1.160633
#
# Power Allocated= 5.9496228703068565
# CSI= 0.8570435591560245
# SNR= 29.267019522513436
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.191827
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.447185
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.064942
# Model client46 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.898669
# Model client46 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.875411
# Model client46 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.027409
# Model client46 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.990359
# Model client46 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.101509
# Model client46 Train Epoch: 9 [0/1216 (0%)]	Loss: 1.375867
# Model client46 Train Epoch: 10 [0/1216 (0%)]	Loss: 1.390141
#
# Power Allocated= 5.297559229190764
# CSI= 0.5497932703249883
# SNR= 22.078542515671053
# Client: client47
# Model client47 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.441510
# Model client47 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.760884
# Model client47 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.068582
# Model client47 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.880211
# Model client47 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.734759
# Model client47 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.883391
# Model client47 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.704830
# Model client47 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.803383
# Model client47 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.934381
# Model client47 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.711341
#
#
# Test set: Average loss for Cluster2 model: 9.9794, Accuracy: 1009/10000 (10%)
#
# 0.20341999999998753
# Power Allocated= 1.7157700739555417
# CSI= 0.3124836536558607
# SNR= 18.018047333411268
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.713870
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.661162
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.365344
# Model client3 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.365745
# Model client3 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.565823
# Model client3 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.274355
# Model client3 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.845566
# Model client3 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.317175
# Model client3 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.679733
# Model client3 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.372583
#
# Power Allocated= 1.6379873293713691
# CSI= 0.3050687037079789
# SNR= 27.510045116603038
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.787941
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.920843
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.546770
# Model client6 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.449990
# Model client6 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.421439
# Model client6 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.528485
# Model client6 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.425775
# Model client6 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.538130
# Model client6 Train Epoch: 9 [0/1216 (0%)]	Loss: 1.472852
# Model client6 Train Epoch: 10 [0/1216 (0%)]	Loss: 7.509158
#
# Power Allocated= 3.7621231611299093
# CSI= 0.8666905869862477
# SNR= 12.283880453780549
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 3.426292
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.725180
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.596130
# Model client7 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.388213
# Model client7 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.207049
# Model client7 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.199750
# Model client7 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.935319
# Model client7 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.778723
# Model client7 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.990049
# Model client7 Train Epoch: 10 [0/1216 (0%)]	Loss: 1.036865
#
# Power Allocated= 0
# CSI= 0.16913826473550042
# SNR= 31.459931507418535
# Client: client10
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 1.8367465235939497
# CSI= 0.3247606327897268
# SNR= 22.83092160055677
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.079452
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.385409
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.080481
# Model client12 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.028177
# Model client12 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.018367
# Model client12 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.214641
# Model client12 Train Epoch: 7 [0/1216 (0%)]	Loss: 1.327407
# Model client12 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.262378
# Model client12 Train Epoch: 9 [0/1216 (0%)]	Loss: 1.428334
# Model client12 Train Epoch: 10 [0/1216 (0%)]	Loss: 1.501938
#
# Power Allocated= 3.6793453728754217
# CSI= 0.8086740994957092
# SNR= 23.207261422086304
# Client: client14
# Model client14 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.793843
# Model client14 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.497542
# Model client14 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.327703
# Model client14 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.394485
# Model client14 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.375561
# Model client14 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.406932
# Model client14 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.429419
# Model client14 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.370656
# Model client14 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.465847
# Model client14 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.492441
#
# Power Allocated= 3.674632677819548
# CSI= 0.8056039152373883
# SNR= 23.99723819450564
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.585324
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.474201
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.265050
# Model client16 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.232985
# Model client16 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.437549
# Model client16 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.431983
# Model client16 Train Epoch: 7 [0/1216 (0%)]	Loss: 1.359691
# Model client16 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.385387
# Model client16 Train Epoch: 9 [0/1216 (0%)]	Loss: 1.443000
# Model client16 Train Epoch: 10 [0/1216 (0%)]	Loss: 1.125974
#
# Power Allocated= 1.0753979358231076
# CSI= 0.26038008235291243
# SNR= 12.480114134337592
# Client: client19
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.009516919332134277
# SNR= 13.440699681376348
# Client: client23
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.15355314278942578
# SNR= 14.370221198766274
# Client: client25
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.7851268583399404
# CSI= 0.8843213800164951
# SNR= 22.413179600091933
# Client: client28
# Model client28 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.906475
# Model client28 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.673466
# Model client28 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.321410
# Model client28 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.264038
# Model client28 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.327563
# Model client28 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.395467
# Model client28 Train Epoch: 7 [0/1216 (0%)]	Loss: 1.385801
# Model client28 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.472371
# Model client28 Train Epoch: 9 [0/1216 (0%)]	Loss: 1.623182
# Model client28 Train Epoch: 10 [0/1216 (0%)]	Loss: 1.450164
#
# Power Allocated= 3.552387247066444
# CSI= 0.7333796612051313
# SNR= 13.330668618372101
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.905344
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.634975
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.107303
# Model client29 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.619003
# Model client29 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.580703
# Model client29 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.488208
# Model client29 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.477975
# Model client29 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.618068
# Model client29 Train Epoch: 9 [0/1216 (0%)]	Loss: 1.099732
# Model client29 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.736561
#
# Power Allocated= 1.862374754488406
# CSI= 0.3274863146439947
# SNR= 20.890076783857246
# Client: client30
# Model client30 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.804349
# Model client30 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.977455
# Model client30 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.995220
# Model client30 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.793730
# Model client30 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.722462
# Model client30 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.000553
# Model client30 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.903055
# Model client30 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.248307
# Model client30 Train Epoch: 9 [0/1216 (0%)]	Loss: 1.105277
# Model client30 Train Epoch: 10 [0/1216 (0%)]	Loss: 1.970969
#
# Power Allocated= 3.2333406176814066
# CSI= 0.5943194289544076
# SNR= 21.73650347169476
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.995441
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.305971
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.004653
# Model client31 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.777739
# Model client31 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.651244
# Model client31 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.129830
# Model client31 Train Epoch: 7 [0/1216 (0%)]	Loss: 1.255283
# Model client31 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.779435
# Model client31 Train Epoch: 9 [0/1216 (0%)]	Loss: 1.034908
# Model client31 Train Epoch: 10 [0/1216 (0%)]	Loss: 6.150457
#
# Power Allocated= 3.7573735463012725
# CSI= 0.863137527563146
# SNR= 14.10457848317453
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.248345
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.446507
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.974895
# Model client32 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.881000
# Model client32 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.641476
# Model client32 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.686089
# Model client32 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.894940
# Model client32 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.713211
# Model client32 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.426058
# Model client32 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.459853
#
# Power Allocated= 3.1676576351732946
# CSI= 0.5719908109066647
# SNR= 9.660701632610708
# Client: client34
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 3.8494381975418737
# CSI= 0.9376471475449671
# SNR= 22.60671724362816
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.103723
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.116896
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.719394
# Model client35 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.536635
# Model client35 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.574156
# Model client35 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.919614
# Model client35 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.842229
# Model client35 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.741777
# Model client35 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.590931
# Model client35 Train Epoch: 10 [0/1216 (0%)]	Loss: 1.105922
#
# Power Allocated= 3.3648687472459162
# CSI= 0.6447167593524605
# SNR= 28.68624453830259
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 0.950266
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.346438
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.159139
# Model client37 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.062381
# Model client37 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.126276
# Model client37 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.039059
# Model client37 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.576692
# Model client37 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.207120
# Model client37 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.335499
# Model client37 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.266585
#
# Power Allocated= 3.1197177356466015
# CSI= 0.5567247599376915
# SNR= 37.271142786493414
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 1.345501
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 0.481956
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.402204
# Model client38 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.519498
# Model client38 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.320954
# Model client38 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.141926
# Model client38 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.412794
# Model client38 Train Epoch: 8 [0/1216 (0%)]	Loss: 0.232692
# Model client38 Train Epoch: 9 [0/1216 (0%)]	Loss: 0.308917
# Model client38 Train Epoch: 10 [0/1216 (0%)]	Loss: 0.958138
#
# Power Allocated= 0
# CSI= 0.05382830264547356
# SNR= 11.312661421891974
# Client: client40
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 1.8274582386070026
# CSI= 0.32378394844620306
# SNR= 10.612898016707952
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 3.200528
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.387732
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.953624
# Model client43 Train Epoch: 4 [0/1216 (0%)]	Loss: 1.846636
# Model client43 Train Epoch: 5 [0/1216 (0%)]	Loss: 1.461609
# Model client43 Train Epoch: 6 [0/1216 (0%)]	Loss: 1.315557
# Model client43 Train Epoch: 7 [0/1216 (0%)]	Loss: 1.313015
# Model client43 Train Epoch: 8 [0/1216 (0%)]	Loss: 1.035386
# Model client43 Train Epoch: 9 [0/1216 (0%)]	Loss: 1.270513
# Model client43 Train Epoch: 10 [0/1216 (0%)]	Loss: 1.251604
#
# Power Allocated= 3.81915990034482
# CSI= 0.9117618998853063
# SNR= 16.039221790968895
# Client: client44
# Model client44 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.695282
# Model client44 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.050171
# Model client44 Train Epoch: 3 [0/1216 (0%)]	Loss: 0.684064
# Model client44 Train Epoch: 4 [0/1216 (0%)]	Loss: 0.632926
# Model client44 Train Epoch: 5 [0/1216 (0%)]	Loss: 0.353006
# Model client44 Train Epoch: 6 [0/1216 (0%)]	Loss: 0.332472
# Model client44 Train Epoch: 7 [0/1216 (0%)]	Loss: 0.669618

# %%
print(final_acc)
