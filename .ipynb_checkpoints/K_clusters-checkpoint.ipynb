# %%
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import KMeans
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
import math
import numpy as np
import random
from sklearn.datasets import make_blobs
import scipy
# from matplotlib import style
# style.use('ggplot')

# %%
def get_key(val,my_dict):
    for key, value in my_dict.items():
         if (val[0] == value[0] and val[1] == value[1]):
            return key

# %%
def calc_distance(X1, X2):
    return ((sum((X1 - X2)**2))**0.5)  #increasing spread here

# %%
class K_Means:
    def __init__(self, k, tol=0.001, max_iter=30):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter
    
    def closest_node(self,node, nodes):
        nodes = np.asarray(nodes)
        dist_2 = np.sum((nodes - node)**2, axis=1)
        return np.argmin(dist_2)

    def fit(self,data,snr_dic,clients):

        self.centroids = {}

        for i in range(self.k):
            self.centroids[i] = data[i]
#             print(self.centroids)

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                snrs=[]
                for c in self.centroids:
                    cl1=get_key(featureset,clients)
                    cl2=get_key(self.centroids[c],clients)
                    try:
                        try:
                            snr=snr_dic[tuple((tuple(featureset),tuple(self.centroids[c])))]
                        except:
                            snr=snr_dic[tuple((tuple(self.centroids[c]),tuple(featureset)))]
                    except:
                        snr=10000
                    snrs.append(snr)
                classification = snrs.index(max(snrs))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)
            
            for c in range(len(self.centroids)):
                p=self.closest_node(self.centroids[c],data)
                self.centroids[c]=data[p]

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
#                     print(np.sum((current_centroid-original_centroid)/original_centroid*100.0))
                    optimized = False
            

            if optimized:
                break

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification

# %%
def snr_list(clients):
    snr_dic={}
    csi_dic={}
    snr1_dic={}
    for i in range(len(clients)-1):
        for j in range(i+1,len(clients)):
            X1=clients['client'+str(i+1)]
            X2=clients['client'+str(j+1)]
            dis=calc_distance(X1,X2)
            path_loss=10*math.log10(1500/(dis*dis))#1000
            noise=random.uniform(0,5)
            snr_dic.update({tuple([tuple(X1),tuple(X2)]):path_loss-noise})
            csi_dic.update({tuple([tuple(X1),tuple(X2)]):random.random()})
#             snr1_dic.update({tuple(['client'+str(i+1),'client'+str(j+1)]):path_loss-noise})
    return(snr_dic,csi_dic)

# %%
def getList(dict):
    list = []
    for key in dict.keys():
        list.append(key)
          
    return list

# %%
def cluster_former(k,n):
    cluster_array, _ = make_blobs(n_samples=n,n_features=2, centers=4,random_state=40)
    # print(cluster_array)
    no=1
    clients={}
    for client in cluster_array:
        clients['client'+str(no)]=client
        no+=1
    clients_temp=clients
    snr_dic,csi_dic=snr_list(clients)
    model = K_Means(k=k)
    model.fit(cluster_array,snr_dic,clients)

    for centroid in model.centroids:
        plt.scatter(model.centroids[centroid][0], model.centroids[centroid][1],
                    marker="o", color="black",s=150)

    # no=0
    # for classification in model.classifications:
    # #     color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(k)]
    #     color=['red','blue','green','yellow']
    #     for featureset in model.classifications[classification]:
    #         plt.scatter(featureset[0], featureset[1], color=color[no])
    #     no+=1

    # plt.show()

    no=0
    cmap = plt.get_cmap('jet', 10)
    cmap=cmap.reversed()

    snrl=list(snr_dic[i] for i in snr_dic)

    intervals=np.linspace(min(snrl),max(snrl),10)
    #print(snrl)
    client_locs=getList(snr_dic)
    # print(type(client_locs))
    #print(client_locs[0][0])
    # print(len(model.classifications))
    for classification in model.classifications:
        color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(k)]
       #color=['red','blue','green','yellow']
        #cx=next(cycol)
        for featureset in model.classifications[classification]:

            plt.scatter(featureset[0], featureset[1], c=color[classification])
            #index=np.searchsorted(intervals,snr)
            #print(model.centroids[classification][0], model.centroids[classification][1])
            clients=[featureset[0], featureset[1]]
            client_t=tuple(clients)
            centroid_cl=[model.centroids[classification][0], model.centroids[classification][1]]
            centroid_t=tuple(centroid_cl)
            l=[client_t,centroid_t]
            l_rev=[centroid_t,client_t]
            #print(centroid_cl)
            xs=[clients[0],centroid_cl[0]]
            ys=[clients[1],centroid_cl[1]]
            line=tuple(l)
            line_rev=tuple(l_rev)
    #         print(line)
            if(line[0][0]==line[1][0] and line[0][1]==line[1][1]):
                continue
            else:

                if(line in snr_dic):
                    snr=snr_dic[line]
                else:
                    snr=snr_dic[line_rev]

                index=np.searchsorted(intervals,snr)
                plt.plot(xs,ys,color=cmap(index),linewidth=1.5)

        no+=1

    norm = matplotlib.colors.Normalize(vmin=min(snrl), vmax=max(snrl))
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    cbar=plt.colorbar(sm, ticks=np.linspace(min(snrl), max(snrl), 10))
    cbar.set_label("Signal-to-Noise Ratio")         
    plt.show()
    clients=clients_temp
    
    
    cluster_list=[]
    heads_list=[]
    for classification in model.classifications:
        members=[]
        snrs=[]
        csis=[]
        cluster_head=get_key(model.centroids[classification],clients)
        heads_list.append(model.centroids[classification])
        cluster_dic={}
        for m in model.classifications[classification]:
            member=get_key([m[0],m[1]],clients)
            if(m[0]!=model.centroids[classification][0] and m[1]!=model.centroids[classification][1]):
                members.append(member)
            try:
                try:
                    snr=snr_dic[tuple([tuple([m[0],m[1]]),tuple(model.centroids[classification])])]
                    snrs.append(snr)
                except:
                    snr=snr_dic[tuple([tuple(model.centroids[classification]),tuple([m[0],m[1]])])]
                    snrs.append(snr)
            except:
                None

            try:
                try:
                    csi=csi_dic[tuple([tuple([m[0],m[1]]),tuple(model.centroids[classification])])]
                    csis.append(csi)
                except:
                    csi=csi_dic[tuple([tuple(model.centroids[classification]),tuple([m[0],m[1]])])]
                    csis.append(csi)
            except:
                None

        cluster_dic.update({'Cluster Head':cluster_head})
        cluster_dic.update({'Members':members})
        cluster_dic.update({'SNR':snrs})
        cluster_dic.update({'CSI':csis})
        cluster_list.append(cluster_dic)
        
        head_snr_list=[]
#         print(heads_list)
        for h1 in range(len(heads_list)-1):
            for h2 in range(h1+1,len(heads_list)):
                try:
                    snr2=snr_dic[tuple([tuple(heads_list[h1]),tuple(heads_list[h2])])]
                except:
                    snr2=snr_dic[tuple([tuple(heads_list[h2]),tuple(heads_list[h1])])]
                head_snr_list.append([get_key(heads_list[h1],clients),get_key(heads_list[h2],clients),snr2])
    
#     print(head_snr_list)
                
    
    return(cluster_list,head_snr_list)

# %%
import time
start_time = time.time()
cluster_list,head_snr_list=cluster_former(6,100)
print(time.time() - start_time)
# Out:
# 23.755757808685303

# %%
print(cluster_list[5])
# Out:
# {'Cluster Head': 'client89', 'Members': ['client6', 'client16', 'client20', 'client21', 'client23', 'client32', 'client34', 'client42', 'client60', 'client67', 'client73', 'client90', 'client95', 'client100', 'client103', 'client112', 'client113', 'client121', 'client123', 'client130', 'client131', 'client139', 'client144', 'client146', 'client152', 'client168', 'client175', 'client178', 'client181', 'client183', 'client190', 'client199', 'client200', 'client206', 'client209', 'client217', 'client218', 'client219', 'client221', 'client222', 'client224', 'client228', 'client234', 'client236', 'client244', 'client252', 'client255', 'client256', 'client263', 'client265', 'client270', 'client272', 'client274', 'client275', 'client276', 'client291', 'client324', 'client326', 'client336', 'client340', 'client362', 'client365', 'client384', 'client388', 'client391', 'client392', 'client410', 'client425', 'client429', 'client431', 'client443', 'client459', 'client460', 'client466', 'client474', 'client480', 'client487', 'client500', 'client511', 'client512', 'client518', 'client519', 'client521', 'client528', 'client534', 'client536', 'client537', 'client543', 'client545', 'client547', 'client548', 'client550', 'client552', 'client555', 'client556', 'client557', 'client560', 'client566', 'client593', 'client599', 'client600', 'client602', 'client612', 'client614', 'client616', 'client620', 'client626', 'client647', 'client648', 'client662', 'client663', 'client664', 'client665', 'client675', 'client676', 'client684', 'client688', 'client693', 'client694', 'client701', 'client704', 'client711', 'client713', 'client715', 'client735', 'client738', 'client741', 'client742', 'client761', 'client765', 'client769', 'client774', 'client778', 'client781', 'client788', 'client804', 'client806', 'client808', 'client812', 'client820', 'client821', 'client825', 'client830', 'client844', 'client852', 'client854', 'client860', 'client873', 'client877', 'client887', 'client890', 'client902', 'client906', 'client913', 'client923', 'client931', 'client933', 'client934', 'client937', 'client942', 'client955', 'client963', 'client965', 'client978', 'client981', 'client983', 'client991'], 'SNR': [20.953830892739752, 26.36984005710787, 32.58082672655919, 27.263157985532093, 27.395622858180833, 22.814474554440615, 29.83880394684784, 24.569375031733827, 26.585365674743294, 20.954713479809108, 25.456571085328314, 27.95224115876628, 28.197794099444444, 26.634594621095275, 34.21263235295923, 34.04539280296778, 30.462328615061235, 21.96493383507543, 33.61620699365197, 29.399441962746742, 24.245818559422506, 29.658791310131722, 20.447174323704665, 36.55612274285596, 28.447742140700825, 33.91553970086635, 31.15262189040818, 27.18633946628053, 27.420857777208834, 31.424959561436523, 29.214634796814888, 29.771445815215976, 22.84430389319858, 34.00674897581833, 23.69683333747256, 31.70484945260488, 23.261604219283168, 31.38564329708336, 25.573277858422912, 26.085617613411223, 31.099937450195153, 30.509954978339245, 32.1153177693216, 29.010427444287938, 28.109055915432688, 20.158409130625834, 26.054062783452448, 23.83410918008176, 25.803992013294383, 30.427396307554687, 25.171391046410694, 27.85939527651381, 27.844863898561332, 31.429467117627638, 35.65208860241833, 37.59289132884487, 35.740241500960586, 27.647364473399502, 32.527220272898745, 23.919731603881424, 28.074174487860883, 23.800197325394976, 23.016759943532342, 35.85682683708335, 21.6784937765307, 29.78534665488764, 32.501739433691114, 23.23118227774227, 23.128992758588574, 37.216918155711596, 33.41161104792247, 21.6072786853126, 36.2447949396075, 29.953890164639677, 26.765615678649425, 25.120447620310685, 30.161651757323956, 28.618256272295447, 26.559732157984445, 32.104159425804966, 20.76671462005536, 37.23246651569713, 23.172944379463, 26.749699856738964, 29.371717661740565, 30.07769385117628, 20.953580493589232, 24.16646243018093, 23.003451754443073, 23.893735345166377, 35.94886060891358, 28.46260759330 ...
