# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import numpy as np
from Dataset import load_dataset, getImage
from utils import averageModels
from utils import averageModelscluster
import random
import math
import matplotlib.pyplot as plt
from ipynb.fs.full.K_clusters import cluster_former
from copy import deepcopy
# Out:
# 0.7921278476715088
# {'Cluster Head': 'client79', 'Members': ['client17', 'client29', 'client31', 'client38', 'client41', 'client42', 'client46', 'client51', 'client54', 'client59', 'client74', 'client81', 'client86', 'client100'], 'SNR': [20.922492740781017, 54.61179390672953, 20.681229394960962, 25.937559432992916, 23.76449829215561, 35.43090586166396, 37.62977505184642, 24.59235110331799, 22.0977172967458, 30.336464326879955, 23.610915595879106, 24.303579909337557, 24.365792178936847, 26.317311214768857], 'CSI': [0.32162461649818064, 0.8943197139976086, 0.7968500287654847, 0.8377524544602153, 0.09694237337070899, 0.401598847388665, 0.4128601281927967, 0.3579058901886325, 0.14974408970131525, 0.05032177426362605, 0.4017813818332392, 0.4767781430929876, 0.6894536073807422, 0.6913891731283246]}

# %%
P=2 #signal power threshold
#stream = BitStream()
#random.seed(10)
key=[]
for i in range (10000): #generating a random password to activate training (Pilot signal)
    temp=random.randint(0,1)
    key.append(temp)

key1=[0]*len(key)
for i in range (len(key)):   #bpsk modulation
    if(key[i]==1):
        #print("yay")
        key1[i]=-math.sqrt(P)
    else:
        key1[i]=math.sqrt(P)

#print(key)
        
key_np=np.array(key1)

# %%
class Arguments():
    def __init__(self):
        self.images = 10000
        self.clients = 50
        self.rounds = 200
        self.epochs = 3
        self.local_batches = 64
        self.lr = 0.01
        self.C = 1 #fraction of clients used in the round
        self.drop_rate = 0 #fraction of devices in the selected set to be dropped for various reasons
        self.torch_seed = 0 #same weights and parameters whenever the program is run
        self.log_interval = 64
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = True
        self.numclusters=4

args = Arguments()

# %%
#checking if gpu is available
#use_cuda = args.use_cuda and torch.cuda.is_available()
use_cuda=False
device = torch.device("cuda:0" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

hook = sy.TorchHook(torch)
me = hook.local_worker
clients = []

#generating virtual clients
for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})
#print(clients)

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid) #load data

for inx, client in enumerate(clients):  #return actual image set for each client
    trainset_ind_list = list(train_group[inx]) 
    client['trainset'] = getImage(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getImage(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images #useful while taking weighted average

# %%
#load dataset for global model (to compare accuracies)
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.MNIST('./', train=False, download=True, transform=transform)
# global_test_dataset = torch.utils.data.random_split(global_test_dataset, [10000, len(global_test_dataset)-10000])[0]
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
"""class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        #self.quant = torch.quantization.QuantStub()
        self.conv1 = nn.Conv2d(1, 5, 5, 1)
        self.conv2 = nn.Conv2d(5, 10, 5, 1)
        self.fc1 = nn.Linear(4*4*10, 50) #10 iid #50 non iid
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        #x=self.quant(x)
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*10
                   )
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1) """

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x)

# %%
def fedprox(params,global_params):
    global_param=[]
    ind=0
    for gp in global_params:
        global_param.append(gp)
    for p in params:
    #                 print(p.grad)
        lr=0.001
        mu=0.1
        if(p.grad is None):
            continue
        grad=p.grad.data #batch gradients
        p.data.sub_(lr,(grad+mu*(p.data.clone()-global_param[ind].data.clone())))
        ind+=1
    return(p)

# %%
def ClientUpdate(args, device, client,key_np,key,snr,csi,mu,head):
    gc=False
    client['model'].train()
    #simulating a wireless channel
    poptim=max((1/mu-1/csi),0)
    #print(mu,csi)
    print("Power Allocated=",poptim)
    print("CSI=",csi)
    
    snr__=10**(snr/10)
    
    absh=csi*poptim/snr__
    x=random.uniform(0,absh)
    #print(x)
    y=math.sqrt(absh*absh-x*x)
    #x=x*100
    #y=y*100
    #x=random.random()
    #y=random.random()
    #snr=10*math.log(poptim/(std*std),10)
    std=math.sqrt(poptim/snr__*absh*absh) #channel noise
    
    #print(x,y)
    h=complex(x,y)
    #std=math.sqrt(abs(h)/csi)
    #snr=poptim/(std*std)
    #print(std)
    print("SNR=",snr)
    #print("csi",abs(h)/(std*std))
    
    
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data

    
    #print(client['model'].conv1.weight.size)
    client['model'].send(client['hook'])
    head['model'].send(client['hook'])
    print("Client:",client['hook'].id)
    
    key_np_received=h*key_np+(np.random.randn(len(key_np))*std*2)
    #print(key_np_received)
    key_np_received=(key_np_received/(h)).real
    
    for o in range (len(key_np_received)):  #demodulation bpsk
        if(key_np_received[o]>=0):
            key_np_received[o]=0
        else:
            key_np_received[o]=1
    
    key_np_received=key_np_received.tolist()
    key_np_received = [int(item) for item in key_np_received]
    #key_np=key_np.tolist()
    
    
    if(sum(np.bitwise_xor(key,key_np_received))/len(key)==0 and poptim>0): #...............................................checking if channel is good enough for transmission by checking BER..................................#
        gc=True #considering the client model for training
        for epoch in range(1, args.epochs + 1):
            for batch_idx, (data, target) in enumerate(client['trainset']): 
                data = data.send(client['hook'])
                target = target.send(client['hook'])
                #client['optim'].zero_grad()
                #train model on client
                data, target = data.to(device), target.to(device) #send data to cpu/gpu (data is stored locally)
                output = client['model'](data)
                loss = F.nll_loss(output, target)
                loss.backward()
                #client['optim'].step()
                params=client['model'].parameters()
                gp=head['model'].parameters()
                params=fedprox(params,gp) 
                
                if batch_idx % args.log_interval == 0:
                    loss = loss.get() 
                    print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                        client['hook'].id,
                        epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                        100. * batch_idx / len(client['trainset']), loss))
    else:
        print("Poor Channel, client not taken for averaging in this round")
            
                    
    client['model'].get()
    head['model'].get()
    # print()
         #CHANGE
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
    #CHANGE ENDS
    print()
    return gc

# %%
def test(args, model, device, test_loader, name,fed_round):
    model.eval()    #no need to train the model while testing
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            if(use_cuda and fed_round==0):
                data,target=data.cuda(),target.cuda()
                #model.cuda()
            else:
                data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    return([100. * correct / len(test_loader.dataset),test_loss])

# %%
torch.manual_seed(args.torch_seed)

# %%
def distort(neighbours,snrs):
    ind=0
    poptim=2
    csi=random.random()
    distorted_models=[]
    for client in neighbours:
        snr=snrs[ind]
        ind+=1
        snr__=10**(snr/10)
        absh=csi*poptim/snr__
        x=random.uniform(0,absh)
        y=math.sqrt(absh*absh-x*x)
        std=math.sqrt(poptim/snr__*absh*absh) #channel noise
        h=complex(x,y)
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
        
        distorted_models.append(client)
    return(distorted_models)

# %%
def decentralized(clients,snrs,weights):
    big_daddy_of_distorted_models=[]
    for client in clients:
        distorted_models=[]
        snr_list=[]
        for snr in snrs:
            if(client['hook'].id in snr):
                snr_list.append(snr[2])
        neighbours_c = [x for x in clients if x != client]
        neighbours={}
        jjj=[jkl for jkl in range(len(neighbours_c))]
        
        dictionary = dict(zip(jjj, neighbours_c))
        #for jjj in range(len(neighbours_c)):
        #   neighbours[jjj].append(neighbours_c[jjj])
        distorted_models=distort(neighbours,snr_list)
        distorted_models.append(client)
        big_daddy_of_distorted_models.append(distorted_models)
    
    
    weight_final1=[]
    for oho in big_daddy_of_distorted_models:
        weight_final=[]
        for comeon in oho:
            for w in weights:
                if(comeon['hook'].id==w[0]):
                    weight_final.append(w[1])
        weight_final1.append(weight_final)
    
    final_heads=[]
    nets=[]
    ind=0
    for client in clients:
        for oof in big_daddy_of_distorted_models:
            if(client==oof[0]):
#                 print(client)
#                 print("shut up")
#                 print(distorted_models)
#                 print("shut up")
#                 print(weight_final1)
                
                overall=Net()
                overall=averageModelscluster(overall,distorted_models,weight_final1[ind])
                client['model'].load_state_dict(overall.state_dict())
                ind+=1
                final_heads.append(client)
                nets.append(overall)
    
    return(final_heads,nets)

# %%
for client in clients: #give the model and optimizer to every client
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    #client['model'] = torch.quantization.quantize_dynamic(
    #client['model'],  # the original model
    #{torch.nn.Linear},  # a set of layers to dynamically quantize
    #dtype=torch.fp)  # the target dtype for quantized weights
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)

final_acc=[]
final_loss=[]
    
for fed_round in range(args.rounds):
    overall=Net()
    if(fed_round==0): #fed_round==0
        arranged_clusters,head_snr_list=cluster_former(args.numclusters,args.clients)
        temp=deepcopy(arranged_clusters)
        temp2=deepcopy(head_snr_list)
    else:
        #print(temp)
        arranged_clusters=deepcopy(temp)
        head_snr_list=deepcopy(temp2)
#     print(arranged_clusters)
    
    no=1
    heads_list=[]
    weights=[]
    weight_head_list=[]
    head_acc=[]
    head_loss=[]
    for cluster in arranged_clusters:
        
        head=cluster['Cluster Head']
        members=cluster['Members']
        snrs=cluster['SNR']
        csis=cluster['CSI']
        weights.append(sum(snrs))
        weight_head_list.append([head,sum(snrs)])
        new_members=[]
        
        for ij in members:
        #print(ij)
            cl_no=int(ij[6:])
            new_members.append(clients[cl_no-1])
#         print(head)
        head=clients[int(head[6:])-1]
        cluster['Members']=new_members
#         print(head)

        smallmu1=0
        gsmall1=3.402823466E+38 
        
        #water filling algorithm
        mu=1e-15
        while(mu<=1):
            g1=0
            pn1=0
            for jj in csis:
                pn=max(1/mu-1/jj,0)
                g1+=math.log(1+pn*jj) #capacity of a channel (shannon's law)
                pn1+=pn
            g=g1-mu*(pn1-P*30)
            if(g<gsmall1):
                smallmu1=mu
                gsmall1=g
            mu+=0.00002
        
        print(smallmu1)
        good_mem=[]
#         print(len(snrs))
#         print(len(csis))
#         print(len(new_members))
        index=0
        for client in new_members:
            goodchannel=ClientUpdate(args, device, client,key_np,key,snrs[index],csis[index],smallmu1,head)
            index+=1
            if(goodchannel):
                good_mem.append(client)
        
        head['model']=averageModels(head['model'], good_mem)
        arr=test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)
        ac=arr[0]#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[0]
        no+=1
        heads_list.append(head)
        head_acc.append(ac)
        head_loss.append(arr[1])#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[1])
    
    final_acc.append(head_acc)
    final_loss.append(head_loss)
    fig,ax=plt.subplots()
    clor = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(args.numclusters)]
    #ax.plot([i for i in range(fed_round)],head_acc[0])
    for jj in range(0,args.numclusters):
        
        ax.plot([i for i in range(len(final_acc))],[final_acc[j][jj] for j in range(len(final_acc))], color = clor[jj])
        
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][0] for j in range(len(final_acc))], color ="red")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][1] for j in range(len(final_acc))],color ="blue")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][2] for j in range(len(final_acc))],color ="green")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][3] for j in range(len(final_acc))],color ="black")
    #ax.plot([i for i in range(len(final_acc))],head_acc[1], fed_round, color ="blue")
    #ax.plot([i for i in range(len(final_acc))],head_acc[2], fed_round, color ="green")
    #ax.plot([i for i in range(len(final_acc))],head_acc[3], fed_round, color ="black")
    
    
    plt.show()
    weightsum=sum(weights)
    
    weights[:] = [x / weightsum for x in weights]
    for aah in range(len(weight_head_list)):
        weight_head_list[aah][1]=weights[aah]
    final_heads,nets=decentralized(heads_list,head_snr_list,weight_head_list)
    
    for head in range(len(final_heads)):
        for cluster in arranged_clusters:
            head1=cluster['Cluster Head']
            if(head1==final_heads[head]['hook'].id):
                for mem in cluster['Members']:
                    mem['model'].load_state_dict(nets[head].state_dict())
    print("ROUND",fed_round)
# Out:
# 0.10780000000001266
# Power Allocated= 8.271656451742679
# CSI= 0.9952413568353256
# SNR= 23.883416555631968
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305272
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook.py:165: UserWarning: This overload of sub_ is deprecated:
# 	sub_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	sub_(Tensor other, *, Number alpha) (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629411241/work/torch/csrc/utils/python_arg_parser.cpp:766.)
#   response = method(*args, **kwargs)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296105
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.279088
#
# Power Allocated= 0
# CSI= 0.04581552665823985
# SNR= 25.74535530479079
# Client: client14
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.771289051874261
# CSI= 0.6643861408675862
# SNR= 29.182747553212476
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.344581
# /tmp/ipykernel_675957/1497942811.py:66: RuntimeWarning: invalid value encountered in true_divide
#   key_np_received=(key_np_received/(h)).real
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.314192
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.282852
#
# Power Allocated= 6.5868135556248175
# CSI= 0.37179914045428986
# SNR= 32.31117246514802
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.251506
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291051
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.298827
#
# Power Allocated= 8.237512991541434
# CSI= 0.9625335209885858
# SNR= 29.701418515482636
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.331241
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.284511
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.302086
#
# Power Allocated= 7.529773207564911
# CSI= 0.5725197481687179
# SNR= 40.91019863538133
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.310901
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.279216
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285815
#
# Power Allocated= 0
# CSI= 0.0005801191765809621
# SNR= 46.587536513785864
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.254602846276228
# CSI= 0.4946002019027419
# SNR= 40.335928928471944
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.292469
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.332843
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.262508
#
# Power Allocated= 0
# CSI= 0.0011841461217962923
# SNR= 20.748669774583373
# Client: client44
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.679286779876115
# CSI= 0.3850372865580851
# SNR= 22.78816607566856
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.293414
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.332596
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.255300
#
# Power Allocated= 7.672934328414853
# CSI= 0.6236344279073999
# SNR= 27.86857925418868
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.337807
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.305927
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.283221
#
#
# Test set: Average loss for Cluster1 model: 2.2470, Accuracy: 3234/10000 (32%)
#
# 0.08984000000000716
# Power Allocated= 9.25279036567989
# CSI= 0.5324504563627449
# SNR= 28.15793123446787
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.367187
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291257
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.292680
#
# Power Allocated= 9.855385135086188
# CSI= 0.7839975183336857
# SNR= 23.54658166259031
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.382373
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300138
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.243576
#
# Power Allocated= 0
# CSI= 0.04001578175612186
# SNR= 29.059985923539912
# Client: client18
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.491321302223918
# CSI= 0.2155368406252458
# SNR= 31.39951099732694
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.323246
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.303622
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.271029
#
# Power Allocated= 5.982284265022998
# CSI= 0.19422698693054008
# SNR= 27.659225719430847
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.344912
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293772
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.280039
#
# Power Allocated= 6.913340393961143
# CSI= 0.23710397509556969
# SNR= 31.81408871586568
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307159
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298973
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.255683
#
# Power Allocated= 9.926299767867976
# CSI= 0.8301513570932841
# SNR= 25.55430112496997
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.352856
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.325285
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.249653
#
# Power Allocated= 0.8199565504759683
# CSI= 0.0969843414764856
# SNR= 20.924138113861094
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.292339
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.330740
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.264168
#
# Power Allocated= 2.344608110849073
# CSI= 0.11381366377986901
# SNR= 18.290875176011767
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.331337
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.308790
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.222221
#
# Power Allocated= 8.416270720190022
# CSI= 0.36837450957183504
# SNR= 22.052242660776336
# Client: client40
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.039035129249431644
# SNR= 21.79461805490211
# Client: client49
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster2 model: 2.2568, Accuracy: 3148/10000 (31%)
#
# 0.11864000000001598
# Power Allocated= 4.492085979224714
# CSI= 0.254015061196452
# SNR= 28.999802568330807
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.331919
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293858
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.281992
#
# Power Allocated= 3.5676930557607065
# CSI= 0.20571190528294847
# SNR= 30.77019708730956
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.328398
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.278589
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.261105
#
# Power Allocated= 3.703943656673304
# CSI= 0.21164394009437015
# SNR= 34.83649958552951
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.285120
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.283742
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.273031
#
# Power Allocated= 4.954960956439688
# CSI= 0.28786095022180025
# SNR= 28.579600551176735
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295491
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.317488
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.276874
#
# Power Allocated= 0
# CSI= 0.11168810864255518
# SNR= 36.61867809292564
# Client: client28
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.230428083048699
# CSI= 0.8344234136355656
# SNR= 29.359886129876216
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.342001
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304356
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289569
#
# Power Allocated= 6.904782943449039
# CSI= 0.6561346235029665
# SNR= 26.905466211772843
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.310234
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.285966
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.240234
#
# Power Allocated= 7.424319759218129
# CSI= 0.9954798655363537
# SNR= 30.908204389292166
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.326172
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.306693
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.262311
#
# Power Allocated= 7.116933881691
# CSI= 0.7622378023999749
# SNR= 26.491410193346418
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.336174
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.309699
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.276420
#
# Power Allocated= 0
# CSI= 0.09237269575591223
# SNR= 24.95339612955847
# Client: client39
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.376175867209582
# CSI= 0.949952195253858
# SNR= 27.64597747786161
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.282541
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294235
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.258985
#
# Power Allocated= 7.227139092446857
# CSI= 0.8321396805379764
# SNR= 39.336948149463275
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.334143
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.317858
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.258061
#
#
# Test set: Average loss for Cluster3 model: 2.1721, Accuracy: 4741/10000 (47%)
#
# 0.14998000000000825
# Power Allocated= 3.358489784915901
# CSI= 0.30220008712178736
# SNR= 32.55902278045639
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.278836
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.330764
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.254678
#
# Power Allocated= 5.631535263534579
# CSI= 0.9652319489191923
# SNR= 26.241119267822985
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.354952
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292954
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.318429
#
# Power Allocated= 4.634468976033576
# CSI= 0.49186293971438233
# SNR= 28.372863863048764
# Client: client8
# Model client8 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.292531
# Model client8 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.288673
# Model client8 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.274760
#
# Power Allocated= 5.158254615593543
# CSI= 0.6625583374310409
# SNR= 24.89898521589405
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299815
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.272182
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.271078
#
# Power Allocated= 5.59285371983477
# CSI= 0.930490538368338
# SNR= 24.374862521049202
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.320910
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289259
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.273467
#
# Power Allocated= 5.5282543871321055
# CSI= 0.8777309491772612
# SNR= 52.11014430263544
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296416
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.321081
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.292578
#
# Power Allocated= 5.127988589073693
# CSI= 0.6495332419955738
# SNR= 22.167670881288657
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.315573
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.313194
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.240392
#
# Power Allocated= 4.935135651100934
# CSI= 0.5772272236122689
# SNR= 24.377237222797064
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.293782
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302966
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.248938
#
# Power Allocated= 5.286213643825949
# CSI= 0.723933666022743
# SNR= 26.711673714615863
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.317120
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.271967
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.267153
#
# Power Allocated= 5.302499049277091
# CSI= 0.7325703431074989
# SNR= 26.173499149207476
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.292120
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298891
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.245832
#
# Power Allocated= 5.623313382723198
# CSI= 0.9576321589997787
# SNR= 31.97424066033596
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.275187
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299248
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.258142
#
# Power Allocated= 3.8212294196067815
# CSI= 0.35133006921644416
# SNR= 23.16939767290096
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.315185
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.333372
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.270058
#
#
# Test set: Average loss for Cluster4 model: 2.0621, Accuracy: 3920/10000 (39%)
# ROUND 0
# 0.10780000000001266
# Power Allocated= 8.271656451742679
# CSI= 0.9952413568353256
# SNR= 23.883416555631968
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302135
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294853
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.304104
#
# Power Allocated= 0
# CSI= 0.04581552665823985
# SNR= 25.74535530479079
# Client: client14
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.771289051874261
# CSI= 0.6643861408675862
# SNR= 29.182747553212476
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296482
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292591
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289711
#
# Power Allocated= 6.5868135556248175
# CSI= 0.37179914045428986
# SNR= 32.31117246514802
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299431
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.301421
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.291071
#
# Power Allocated= 8.237512991541434
# CSI= 0.9625335209885858
# SNR= 29.701418515482636
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299320
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299330
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.289872
#
# Power Allocated= 7.529773207564911
# CSI= 0.5725197481687179
# SNR= 40.91019863538133
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299930
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297078
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284853
#
# Power Allocated= 0
# CSI= 0.0005801191765809621
# SNR= 46.587536513785864
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.254602846276228
# CSI= 0.4946002019027419
# SNR= 40.335928928471944
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303458
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294222
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.295911
#
# Power Allocated= 0
# CSI= 0.0011841461217962923
# SNR= 20.748669774583373
# Client: client44
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.679286779876115
# CSI= 0.3850372865580851
# SNR= 22.78816607566856
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297703
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291360
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.264664
#
# Power Allocated= 7.672934328414853
# CSI= 0.6236344279073999
# SNR= 27.86857925418868
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305785
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297184
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285773
#
#
# Test set: Average loss for Cluster1 model: 2.2759, Accuracy: 2807/10000 (28%)
#
# 0.08984000000000716
# Power Allocated= 9.25279036567989
# CSI= 0.5324504563627449
# SNR= 28.15793123446787
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302507
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.303575
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.304963
#
# Power Allocated= 9.855385135086188
# CSI= 0.7839975183336857
# SNR= 23.54658166259031
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304256
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300868
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.292458
#
# Power Allocated= 0
# CSI= 0.04001578175612186
# SNR= 29.059985923539912
# Client: client18
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.491321302223918
# CSI= 0.2155368406252458
# SNR= 31.39951099732694
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301571
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295079
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.290627
#
# Power Allocated= 5.982284265022998
# CSI= 0.19422698693054008
# SNR= 27.659225719430847
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299511
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296129
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.304536
#
# Power Allocated= 6.913340393961143
# CSI= 0.23710397509556969
# SNR= 31.81408871586568
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303499
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304501
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287093
#
# Power Allocated= 9.926299767867976
# CSI= 0.8301513570932841
# SNR= 25.55430112496997
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298961
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299711
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.294439
#
# Power Allocated= 0.8199565504759683
# CSI= 0.0969843414764856
# SNR= 20.924138113861094
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299130
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296727
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.276530
#
# Power Allocated= 2.344608110849073
# CSI= 0.11381366377986901
# SNR= 18.290875176011767
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307019
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304677
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.266931
#
# Power Allocated= 8.416270720190022
# CSI= 0.36837450957183504
# SNR= 22.052242660776336
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297575
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294142
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.290475
#
# Power Allocated= 0
# CSI= 0.039035129249431644
# SNR= 21.79461805490211
# Client: client49
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster2 model: 2.2858, Accuracy: 2038/10000 (20%)
#
# 0.11864000000001598
# Power Allocated= 4.492085979224714
# CSI= 0.254015061196452
# SNR= 28.999802568330807
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303535
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299630
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287523
#
# Power Allocated= 3.5676930557607065
# CSI= 0.20571190528294847
# SNR= 30.77019708730956
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298177
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.281814
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.270473
#
# Power Allocated= 3.703943656673304
# CSI= 0.21164394009437015
# SNR= 34.83649958552951
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307021
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.290149
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.278460
#
# Power Allocated= 4.954960956439688
# CSI= 0.28786095022180025
# SNR= 28.579600551176735
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.307902
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299517
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.278493
#
# Power Allocated= 0
# CSI= 0.11168810864255518
# SNR= 36.61867809292564
# Client: client28
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.230428083048699
# CSI= 0.8344234136355656
# SNR= 29.359886129876216
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298706
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299490
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.282123
#
# Power Allocated= 6.904782943449039
# CSI= 0.6561346235029665
# SNR= 26.905466211772843
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304597
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293269
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272900
#
# Power Allocated= 7.424319759218129
# CSI= 0.9954798655363537
# SNR= 30.908204389292166
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297379
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292314
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.283547
#
# Power Allocated= 7.116933881691
# CSI= 0.7622378023999749
# SNR= 26.491410193346418
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305739
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.302378
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.292835
#
# Power Allocated= 0
# CSI= 0.09237269575591223
# SNR= 24.95339612955847
# Client: client39
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.376175867209582
# CSI= 0.949952195253858
# SNR= 27.64597747786161
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.295788
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294133
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.279938
#
# Power Allocated= 7.227139092446857
# CSI= 0.8321396805379764
# SNR= 39.336948149463275
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.309022
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291046
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285259
#
#
# Test set: Average loss for Cluster3 model: 2.2331, Accuracy: 2932/10000 (29%)
#
# 0.14998000000000825
# Power Allocated= 3.358489784915901
# CSI= 0.30220008712178736
# SNR= 32.55902278045639
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.306798
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297543
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.293098
#
# Power Allocated= 5.631535263534579
# CSI= 0.9652319489191923
# SNR= 26.241119267822985
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300611
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296568
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284050
#
# Power Allocated= 4.634468976033576
# CSI= 0.49186293971438233
# SNR= 28.372863863048764
# Client: client8
# Model client8 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.305499
# Model client8 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297060
# Model client8 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.284010
#
# Power Allocated= 5.158254615593543
# CSI= 0.6625583374310409
# SNR= 24.89898521589405
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302393
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292256
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.281094
#
# Power Allocated= 5.59285371983477
# CSI= 0.930490538368338
# SNR= 24.374862521049202
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302872
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.287776
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.270771
#
# Power Allocated= 5.5282543871321055
# CSI= 0.8777309491772612
# SNR= 52.11014430263544
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303584
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296122
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.282572
#
# Power Allocated= 5.127988589073693
# CSI= 0.6495332419955738
# SNR= 22.167670881288657
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304077
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297021
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.274823
#
# Power Allocated= 4.935135651100934
# CSI= 0.5772272236122689
# SNR= 24.377237222797064
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.294530
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299614
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.278046
#
# Power Allocated= 5.286213643825949
# CSI= 0.723933666022743
# SNR= 26.711673714615863
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303507
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296626
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.291542
#
# Power Allocated= 5.302499049277091
# CSI= 0.7325703431074989
# SNR= 26.173499149207476
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304242
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296907
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.280130
#
# Power Allocated= 5.623313382723198
# CSI= 0.9576321589997787
# SNR= 31.97424066033596
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297106
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294961
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.275499
#
# Power Allocated= 3.8212294196067815
# CSI= 0.35133006921644416
# SNR= 23.16939767290096
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301848
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297849
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.282236
#
#
# Test set: Average loss for Cluster4 model: 2.1617, Accuracy: 4046/10000 (40%)
# ROUND 1
# 0.10780000000001266
# Power Allocated= 8.271656451742679
# CSI= 0.9952413568353256
# SNR= 23.883416555631968
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304708
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294115
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.283467
#
# Power Allocated= 0
# CSI= 0.04581552665823985
# SNR= 25.74535530479079
# Client: client14
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.771289051874261
# CSI= 0.6643861408675862
# SNR= 29.182747553212476
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301217
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294725
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.280648
#
# Power Allocated= 6.5868135556248175
# CSI= 0.37179914045428986
# SNR= 32.31117246514802
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301798
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292670
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287909
#
# Power Allocated= 8.237512991541434
# CSI= 0.9625335209885858
# SNR= 29.701418515482636
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299909
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296824
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.286104
#
# Power Allocated= 7.529773207564911
# CSI= 0.5725197481687179
# SNR= 40.91019863538133
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302140
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.297113
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.287779
#
# Power Allocated= 0
# CSI= 0.0005801191765809621
# SNR= 46.587536513785864
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.254602846276228
# CSI= 0.4946002019027419
# SNR= 40.335928928471944
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300139
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291470
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.269324
#
# Power Allocated= 0
# CSI= 0.0011841461217962923
# SNR= 20.748669774583373
# Client: client44
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.679286779876115
# CSI= 0.3850372865580851
# SNR= 22.78816607566856
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302586
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291700
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.279355
#
# Power Allocated= 7.672934328414853
# CSI= 0.6236344279073999
# SNR= 27.86857925418868
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302995
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291767
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.269399
#
#
# Test set: Average loss for Cluster1 model: 2.2567, Accuracy: 1765/10000 (18%)
#
# 0.08984000000000716
# Power Allocated= 9.25279036567989
# CSI= 0.5324504563627449
# SNR= 28.15793123446787
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300959
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296389
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.304618
#
# Power Allocated= 9.855385135086188
# CSI= 0.7839975183336857
# SNR= 23.54658166259031
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301005
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295877
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.282927
#
# Power Allocated= 0
# CSI= 0.04001578175612186
# SNR= 29.059985923539912
# Client: client18
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.491321302223918
# CSI= 0.2155368406252458
# SNR= 31.39951099732694
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302109
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292684
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.281898
#
# Power Allocated= 5.982284265022998
# CSI= 0.19422698693054008
# SNR= 27.659225719430847
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300374
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291901
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.285136
#
# Power Allocated= 6.913340393961143
# CSI= 0.23710397509556969
# SNR= 31.81408871586568
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302551
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294422
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.266770
#
# Power Allocated= 9.926299767867976
# CSI= 0.8301513570932841
# SNR= 25.55430112496997
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302248
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300217
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.308744
#
# Power Allocated= 0.8199565504759683
# CSI= 0.0969843414764856
# SNR= 20.924138113861094
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301218
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.303952
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.296968
#
# Power Allocated= 2.344608110849073
# CSI= 0.11381366377986901
# SNR= 18.290875176011767
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299029
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294847
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.228151
#
# Power Allocated= 8.416270720190022
# CSI= 0.36837450957183504
# SNR= 22.052242660776336
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299967
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304019
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.295424
#
# Power Allocated= 0
# CSI= 0.039035129249431644
# SNR= 21.79461805490211
# Client: client49
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster2 model: 2.2747, Accuracy: 2953/10000 (30%)
#
# 0.11864000000001598
# Power Allocated= 4.492085979224714
# CSI= 0.254015061196452
# SNR= 28.999802568330807
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302423
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293309
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.286336
#
# Power Allocated= 3.5676930557607065
# CSI= 0.20571190528294847
# SNR= 30.77019708730956
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301969
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296762
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.263739
#
# Power Allocated= 3.703943656673304
# CSI= 0.21164394009437015
# SNR= 34.83649958552951
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299894
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295004
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.274890
#
# Power Allocated= 4.954960956439688
# CSI= 0.28786095022180025
# SNR= 28.579600551176735
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300609
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296053
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.255232
#
# Power Allocated= 0
# CSI= 0.11168810864255518
# SNR= 36.61867809292564
# Client: client28
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.230428083048699
# CSI= 0.8344234136355656
# SNR= 29.359886129876216
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303379
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289341
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.265332
#
# Power Allocated= 6.904782943449039
# CSI= 0.6561346235029665
# SNR= 26.905466211772843
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300056
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292956
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.255786
#
# Power Allocated= 7.424319759218129
# CSI= 0.9954798655363537
# SNR= 30.908204389292166
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303186
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289457
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.290711
#
# Power Allocated= 7.116933881691
# CSI= 0.7622378023999749
# SNR= 26.491410193346418
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302147
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.293865
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.280174
#
# Power Allocated= 0
# CSI= 0.09237269575591223
# SNR= 24.95339612955847
# Client: client39
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.376175867209582
# CSI= 0.949952195253858
# SNR= 27.64597747786161
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.298939
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298820
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.258094
#
# Power Allocated= 7.227139092446857
# CSI= 0.8321396805379764
# SNR= 39.336948149463275
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301922
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296133
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.263811
#
#
# Test set: Average loss for Cluster3 model: 2.1627, Accuracy: 2015/10000 (20%)
#
# 0.14998000000000825
# Power Allocated= 3.358489784915901
# CSI= 0.30220008712178736
# SNR= 32.55902278045639
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301788
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295673
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.282854
#
# Power Allocated= 5.631535263534579
# CSI= 0.9652319489191923
# SNR= 26.241119267822985
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300935
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299115
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.275261
#
# Power Allocated= 4.634468976033576
# CSI= 0.49186293971438233
# SNR= 28.372863863048764
# Client: client8
# Model client8 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302153
# Model client8 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.294115
# Model client8 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.269214
#
# Power Allocated= 5.158254615593543
# CSI= 0.6625583374310409
# SNR= 24.89898521589405
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300311
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.305402
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.253368
#
# Power Allocated= 5.59285371983477
# CSI= 0.930490538368338
# SNR= 24.374862521049202
# Client: client20
# Model client20 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303227
# Model client20 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.295449
# Model client20 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.272641
#
# Power Allocated= 5.5282543871321055
# CSI= 0.8777309491772612
# SNR= 52.11014430263544
# Client: client27
# Model client27 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300091
# Model client27 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298762
# Model client27 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.275739
#
# Power Allocated= 5.127988589073693
# CSI= 0.6495332419955738
# SNR= 22.167670881288657
# Client: client32
# Model client32 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299258
# Model client32 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291756
# Model client32 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.235303
#
# Power Allocated= 4.935135651100934
# CSI= 0.5772272236122689
# SNR= 24.377237222797064
# Client: client35
# Model client35 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300541
# Model client35 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292933
# Model client35 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.260325
#
# Power Allocated= 5.286213643825949
# CSI= 0.723933666022743
# SNR= 26.711673714615863
# Client: client38
# Model client38 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304461
# Model client38 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.300250
# Model client38 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.277291
#
# Power Allocated= 5.302499049277091
# CSI= 0.7325703431074989
# SNR= 26.173499149207476
# Client: client41
# Model client41 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301824
# Model client41 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296604
# Model client41 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.264487
#
# Power Allocated= 5.623313382723198
# CSI= 0.9576321589997787
# SNR= 31.97424066033596
# Client: client42
# Model client42 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303433
# Model client42 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298888
# Model client42 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.266484
#
# Power Allocated= 3.8212294196067815
# CSI= 0.35133006921644416
# SNR= 23.16939767290096
# Client: client46
# Model client46 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300324
# Model client46 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.287250
# Model client46 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.269727
#
#
# Test set: Average loss for Cluster4 model: 2.0767, Accuracy: 2814/10000 (28%)
# ROUND 2
# 0.10780000000001266
# Power Allocated= 8.271656451742679
# CSI= 0.9952413568353256
# SNR= 23.883416555631968
# Client: client11
# Model client11 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299087
# Model client11 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.273844
# Model client11 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.250636
#
# Power Allocated= 0
# CSI= 0.04581552665823985
# SNR= 25.74535530479079
# Client: client14
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.771289051874261
# CSI= 0.6643861408675862
# SNR= 29.182747553212476
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300871
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.285020
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.233634
#
# Power Allocated= 6.5868135556248175
# CSI= 0.37179914045428986
# SNR= 32.31117246514802
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303124
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289742
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.269016
#
# Power Allocated= 8.237512991541434
# CSI= 0.9625335209885858
# SNR= 29.701418515482636
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301456
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.287117
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.259238
#
# Power Allocated= 7.529773207564911
# CSI= 0.5725197481687179
# SNR= 40.91019863538133
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299234
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286966
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.194155
#
# Power Allocated= 0
# CSI= 0.0005801191765809621
# SNR= 46.587536513785864
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.254602846276228
# CSI= 0.4946002019027419
# SNR= 40.335928928471944
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300696
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.279009
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.243320
#
# Power Allocated= 0
# CSI= 0.0011841461217962923
# SNR= 20.748669774583373
# Client: client44
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.679286779876115
# CSI= 0.3850372865580851
# SNR= 22.78816607566856
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299125
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.271663
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.147238
#
# Power Allocated= 7.672934328414853
# CSI= 0.6236344279073999
# SNR= 27.86857925418868
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299724
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.276394
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.206702
#
#
# Test set: Average loss for Cluster1 model: 2.0673, Accuracy: 3476/10000 (35%)
#
# 0.08984000000000716
# Power Allocated= 9.25279036567989
# CSI= 0.5324504563627449
# SNR= 28.15793123446787
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300797
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.304832
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.276749
#
# Power Allocated= 9.855385135086188
# CSI= 0.7839975183336857
# SNR= 23.54658166259031
# Client: client12
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.04001578175612186
# SNR= 29.059985923539912
# Client: client18
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.491321302223918
# CSI= 0.2155368406252458
# SNR= 31.39951099732694
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300160
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299468
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.257380
#
# Power Allocated= 5.982284265022998
# CSI= 0.19422698693054008
# SNR= 27.659225719430847
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300359
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.299383
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.301213
#
# Power Allocated= 6.913340393961143
# CSI= 0.23710397509556969
# SNR= 31.81408871586568
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.302066
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.290367
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.221782
#
# Power Allocated= 9.926299767867976
# CSI= 0.8301513570932841
# SNR= 25.55430112496997
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300575
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.285411
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.263158
#
# Power Allocated= 0.8199565504759683
# CSI= 0.0969843414764856
# SNR= 20.924138113861094
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297160
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.296530
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.273100
#
# Power Allocated= 2.344608110849073
# CSI= 0.11381366377986901
# SNR= 18.290875176011767
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301515
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.287979
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.251160
#
# Power Allocated= 8.416270720190022
# CSI= 0.36837450957183504
# SNR= 22.052242660776336
# Client: client40
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.039035129249431644
# SNR= 21.79461805490211
# Client: client49
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster2 model: 2.2507, Accuracy: 2676/10000 (27%)
#
# 0.11864000000001598
# Power Allocated= 4.492085979224714
# CSI= 0.254015061196452
# SNR= 28.999802568330807
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.301238
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.292027
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.209427
#
# Power Allocated= 3.5676930557607065
# CSI= 0.20571190528294847
# SNR= 30.77019708730956
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299431
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.265347
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.027858
#
# Power Allocated= 3.703943656673304
# CSI= 0.21164394009437015
# SNR= 34.83649958552951
# Client: client6
# Model client6 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299213
# Model client6 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.275444
# Model client6 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.141313
#
# Power Allocated= 4.954960956439688
# CSI= 0.28786095022180025
# SNR= 28.579600551176735
# Client: client9
# Model client9 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297715
# Model client9 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.272169
# Model client9 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.113650
#
# Power Allocated= 0
# CSI= 0.11168810864255518
# SNR= 36.61867809292564
# Client: client28
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.230428083048699
# CSI= 0.8344234136355656
# SNR= 29.359886129876216
# Client: client29
# Model client29 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299951
# Model client29 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.283107
# Model client29 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.131905
#
# Power Allocated= 6.904782943449039
# CSI= 0.6561346235029665
# SNR= 26.905466211772843
# Client: client31
# Model client31 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299849
# Model client31 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.254609
# Model client31 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.100290
#
# Power Allocated= 7.424319759218129
# CSI= 0.9954798655363537
# SNR= 30.908204389292166
# Client: client33
# Model client33 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297174
# Model client33 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289271
# Model client33 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.251978
#
# Power Allocated= 7.116933881691
# CSI= 0.7622378023999749
# SNR= 26.491410193346418
# Client: client34
# Model client34 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.303519
# Model client34 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.285120
# Model client34 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.239974
#
# Power Allocated= 0
# CSI= 0.09237269575591223
# SNR= 24.95339612955847
# Client: client39
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.376175867209582
# CSI= 0.949952195253858
# SNR= 27.64597747786161
# Client: client43
# Model client43 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.300169
# Model client43 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.286969
# Model client43 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.084120
#
# Power Allocated= 7.227139092446857
# CSI= 0.8321396805379764
# SNR= 39.336948149463275
# Client: client48
# Model client48 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.296023
# Model client48 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.262684
# Model client48 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.129565
#
#
# Test set: Average loss for Cluster3 model: 1.6071, Accuracy: 3988/10000 (40%)
#
# 0.14998000000000825
# Power Allocated= 3.358489784915901
# CSI= 0.30220008712178736
# SNR= 32.55902278045639
# Client: client4
# Model client4 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299361
# Model client4 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.289187
# Model client4 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.253504
#
# Power Allocated= 5.631535263534579
# CSI= 0.9652319489191923
# SNR= 26.241119267822985
# Client: client7
# Model client7 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.299918
# Model client7 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.298404
# Model client7 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.236399
#
# Power Allocated= 4.634468976033576
# CSI= 0.49186293971438233
# SNR= 28.372863863048764
# Client: client8
# Model client8 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.304042
# Model client8 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.291246
# Model client8 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.226602
#
# Power Allocated= 5.158254615593543
# CSI= 0.6625583374310409
# SNR= 24.89898521589405
# Client: client10
# Model client10 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.297127
# Model client10 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.274895
# Model client10 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.144487
#
# ...
#
# Power Allocated= 7.771289051874261
# CSI= 0.6643861408675862
# SNR= 29.182747553212476
# Client: client15
# Model client15 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.215140
# Model client15 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.890715
# Model client15 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.586309
#
# Power Allocated= 6.5868135556248175
# CSI= 0.37179914045428986
# SNR= 32.31117246514802
# Client: client16
# Model client16 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.235527
# Model client16 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.977769
# Model client16 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.490224
#
# Power Allocated= 8.237512991541434
# CSI= 0.9625335209885858
# SNR= 29.701418515482636
# Client: client17
# Model client17 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.220807
# Model client17 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.904765
# Model client17 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.423928
#
# Power Allocated= 7.529773207564911
# CSI= 0.5725197481687179
# SNR= 40.91019863538133
# Client: client22
# Model client22 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.232292
# Model client22 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.142964
# Model client22 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.905236
#
# Power Allocated= 0
# CSI= 0.0005801191765809621
# SNR= 46.587536513785864
# Client: client30
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 7.254602846276228
# CSI= 0.4946002019027419
# SNR= 40.335928928471944
# Client: client37
# Model client37 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.205346
# Model client37 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.013805
# Model client37 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.579293
#
# Power Allocated= 0
# CSI= 0.0011841461217962923
# SNR= 20.748669774583373
# Client: client44
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.679286779876115
# CSI= 0.3850372865580851
# SNR= 22.78816607566856
# Client: client45
# Model client45 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.245956
# Model client45 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.032578
# Model client45 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.475700
#
# Power Allocated= 7.672934328414853
# CSI= 0.6236344279073999
# SNR= 27.86857925418868
# Client: client50
# Model client50 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.232480
# Model client50 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.087365
# Model client50 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.456601
#
#
# Test set: Average loss for Cluster1 model: 0.8705, Accuracy: 7403/10000 (74%)
#
# 0.08984000000000716
# Power Allocated= 9.25279036567989
# CSI= 0.5324504563627449
# SNR= 28.15793123446787
# Client: client2
# Model client2 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.259254
# Model client2 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.006809
# Model client2 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.374555
#
# Power Allocated= 9.855385135086188
# CSI= 0.7839975183336857
# SNR= 23.54658166259031
# Client: client12
# Model client12 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.262501
# Model client12 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.154542
# Model client12 Train Epoch: 3 [0/1216 (0%)]	Loss: 2.019804
#
# Power Allocated= 0
# CSI= 0.04001578175612186
# SNR= 29.059985923539912
# Client: client18
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 6.491321302223918
# CSI= 0.2155368406252458
# SNR= 31.39951099732694
# Client: client21
# Model client21 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.273080
# Model client21 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.973528
# Model client21 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.412568
#
# Power Allocated= 5.982284265022998
# CSI= 0.19422698693054008
# SNR= 27.659225719430847
# Client: client23
# Model client23 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.255007
# Model client23 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.070108
# Model client23 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.511913
#
# Power Allocated= 6.913340393961143
# CSI= 0.23710397509556969
# SNR= 31.81408871586568
# Client: client24
# Model client24 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.281209
# Model client24 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.083199
# Model client24 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.570866
#
# Power Allocated= 9.926299767867976
# CSI= 0.8301513570932841
# SNR= 25.55430112496997
# Client: client25
# Model client25 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.264596
# Model client25 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.104548
# Model client25 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.705951
#
# Power Allocated= 0.8199565504759683
# CSI= 0.0969843414764856
# SNR= 20.924138113861094
# Client: client26
# Model client26 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.271822
# Model client26 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.166194
# Model client26 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.734677
#
# Power Allocated= 2.344608110849073
# CSI= 0.11381366377986901
# SNR= 18.290875176011767
# Client: client36
# Model client36 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.275412
# Model client36 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.983518
# Model client36 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.821675
#
# Power Allocated= 8.416270720190022
# CSI= 0.36837450957183504
# SNR= 22.052242660776336
# Client: client40
# Model client40 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.289617
# Model client40 Train Epoch: 2 [0/1216 (0%)]	Loss: 2.200158
# Model client40 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.920278
#
# Power Allocated= 0
# CSI= 0.039035129249431644
# SNR= 21.79461805490211
# Client: client49
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster2 model: 0.9178, Accuracy: 6845/10000 (68%)
#
# 0.11864000000001598
# Power Allocated= 4.492085979224714
# CSI= 0.254015061196452
# SNR= 28.999802568330807
# Client: client3
# Model client3 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.197304
# Model client3 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.990564
# Model client3 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.364471
#
# Power Allocated= 3.5676930557607065
# CSI= 0.20571190528294847
# SNR= 30.77019708730956
# Client: client5
# Model client5 Train Epoch: 1 [0/1216 (0%)]	Loss: 2.202351
# Model client5 Train Epoch: 2 [0/1216 (0%)]	Loss: 1.610870
# Model client5 Train Epoch: 3 [0/1216 (0%)]	Loss: 1.167293
# ---------------------------------------------------------------------------
# PureFrameworkTensorFoundError             Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py in handle_func_command(cls, command)
#     335             # Note that we return also args_type which helps handling case 3 in the docstring
# --> 336             new_args, new_kwargs, new_type, args_type = hook_args.unwrap_args_from_function(
#     337                 cmd, args_, kwargs_, return_args_type=True
#
# ~/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook_args.py in unwrap_args_from_function(attr, args_, kwargs_, return_args_type)
#     156         # Try running it
# --> 157         new_args = hook_args(args_)
#     158
#
# ~/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook_args.py in <lambda>(x)
#     355
# --> 356     return lambda x: f(lambdas, x)
#     357
#
# ~/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook_args.py in three_fold(lambdas, args_, **kwargs)
#     533     return (
# --> 534         lambdas[0](args_[0], **kwargs),
#     535         lambdas[1](args_[1], **kwargs),
#
# ~/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook_args.py in <lambda>(i)
#     330         # Last if not, rule is probably == 1 so use type to return the right transformation.
# --> 331         else lambda i: forward_func[type(i)](i)
#     332         for a, r in zip(args_, rules)  # And do this for all the args / rules provided
#
# ~/.local/lib/python3.8/site-packages/syft/frameworks/torch/hook/hook_args.py in <lambda>(i)
#      26     if hasattr(i, "child")
# ---> 27     else (_ for _ in ()).throw(PureFrameworkTensorFoundError),
#      28 }
#
# ~/.local/lib/python3.8/site-packages/syft/frameworks/torch/hook/hook_args.py in <genexpr>(.0)
#      26     if hasattr(i, "child")
# ---> 27     else (_ for _ in ()).throw(PureFrameworkTensorFoundError),
#      28 }
#
# PureFrameworkTensorFoundError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_675957/982425597.py in <module>
#      73         index=0
#      74         for client in new_members:
# ---> 75             goodchannel=ClientUpdate(args, device, client,key_np,key,snrs[index],csis[index],smallmu1,head)
#      76             index+=1
#      77             if(goodchannel):
#
# /tmp/ipykernel_675957/1497942811.py in ClientUpdate(args, device, client, key_np, key, snr, csi, mu, head)
#      86                 #train model on client
#      87                 data, target = data.to(device), target.to(device) #send data to cpu/gpu (data is stored locally)
# ---> 88                 output = client['model'](data)
#      89                 loss = F.nll_loss(output, target)
#      90                 loss.backward()
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /tmp/ipykernel_675957/163532216.py in forward(self, x)
#      35         x = F.relu(self.fc1(x))
#      36         x = F.dropout(x, training=self.training)
# ---> 37         x = self.fc2(x)
#      38         return F.log_softmax(x)
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      89
#      90     def forward(self, input: Tensor) -> Tensor:
# ---> 91         return F.linear(input, self.weight, self.bias)
#      92
#      93     def extra_repr(self) -> str:
#
# ~/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook.py in overloaded_func(*args, **kwargs)
#     333                 handle_func_command = syft.framework.Tensor.handle_func_command
#     334
# --> 335             response = handle_func_command(command)
#     336
#     337             return response
#
# ~/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py in handle_func_command(cls, command)
#     354             # Send it to the appropriate class and get the response
#     355             try:
# --> 356                 response = new_type.handle_func_command(new_command)
#     357             except RuntimeError:
#     358                 # Change the library path to avoid errors on layers like AvgPooling
#
# ~/.local/lib/python3.8/site-packages/syft/generic/pointers/object_pointer.py in handle_func_command(cls, command)
#     209
#     210         # Send the command
# --> 211         response = owner.send_command(location, cmd_name=cmd, args_=args_, kwargs_=kwargs_)
#     212
#     213         return response
#
# ~/.local/lib/python3.8/site-packages/syft/workers/base.py in send_command(self, recipient, cmd_name, target, args_, kwargs_, return_ids, return_value)
#     523                 cmd_name, target, args_, kwargs_, return_ids, return_value
#     524             )
# --> 525             ret_val = self.send_msg(message, location=recipient)
#     526         except ResponseSignatureError as e:
#     527             ret_val = None
#
# ~/.local/lib/python3.8/site-packages/syft/workers/base.py in send_msg(self, message, location)
#     314
#     315         # Step 2: send the message and wait for a response
# --> 316         bin_response = self._send_msg(bin_message, location)
#     317
#     318         # Step 3: deserialize the response
#
# ~/.local/lib/python3.8/site-packages/syft/workers/virtual.py in _send_msg(self, message, location)
#      10         """send message to worker location"""
#      11
# ---> 12         return location._recv_msg(message)
#      13
#      14     def _recv_msg(self, message: bin) -> bin:
#
# ~/.local/lib/python3.8/site-packages/syft/workers/virtual.py in _recv_msg(self, message)
#      20             sleep(self.message_pending_time)
#      21
# ---> 22         return self.recv_msg(message)
#      23
#      24     # For backwards compatibility with Udacity course
#
# ~/.local/lib/python3.8/site-packages/syft/workers/base.py in recv_msg(self, bin_message)
#     354         for handler in self.message_handlers:
#     355             if handler.supports(msg):
# --> 356                 response = handler.handle(msg)
#     357                 break
#     358         # TODO(karlhigley): Raise an exception if no handler is found
#
# ~/.local/lib/python3.8/site-packages/syft/generic/abstract/message_handler.py in handle(self, msg)
#      18
#      19     def handle(self, msg):
# ---> 20         return self.routing_table[type(msg)](msg)
#
# ~/.local/lib/python3.8/site-packages/syft/workers/message_handler.py in execute_tensor_command(self, cmd)
#      53     def execute_tensor_command(self, cmd: TensorCommandMessage) -> PointerTensor:
#      54         if isinstance(cmd.action, ComputationAction):
# ---> 55             return self.execute_computation_action(cmd.action)
#      56         else:
#      57             return self.execute_communication_action(cmd.action)
#
# ~/.local/lib/python3.8/site-packages/syft/workers/message_handler.py in execute_computation_action(self, action)
#     116                 command = getattr(command, path)
#     117
# --> 118             response = command(*args_, **kwargs_)
#     119
#     120         # some functions don't return anything (such as .backward())
#
# ~/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook.py in overloaded_func(*args, **kwargs)
#     333                 handle_func_command = syft.framework.Tensor.handle_func_command
#     334
# --> 335             response = handle_func_command(command)
#     336
#     337             return response
#
# ~/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py in handle_func_command(cls, command)
#     378             # in the execute_command function
#     379             try:
# --> 380                 response = cls._get_response(cmd, args_, kwargs_)
#     381             except AttributeError:
#     382                 # Change the library path to avoid errors on layers like AvgPooling
#
# ~/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py in _get_response(cmd, args_, kwargs_)
#     412
#     413         if isinstance(args_, tuple):
# --> 414             response = command_method(*args_, **kwargs_)
#     415         else:
#     416             response = command_method(args_, **kwargs_)
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1672     if input.dim() == 2 and bias is not None:
#    1673         # fused op is marginally faster
# -> 1674         ret = torch.addmm(bias, input, weight.t())
#    1675     else:
#    1676         output = input.matmul(weight.t())
#
# ~/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook.py in overloaded_func(*args, **kwargs)
#     333                 handle_func_command = syft.framework.Tensor.handle_func_command
#     334
# --> 335             response = handle_func_command(command)
#     336
#     337             return response
#
# ~/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py in handle_func_command(cls, command)
#     378             # in the execute_command function
#     379             try:
# --> 380                 response = cls._get_response(cmd, args_, kwargs_)
#     381             except AttributeError:
#     382                 # Change the library path to avoid errors on layers like AvgPooling
#
# ~/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py in _get_response(cmd, args_, kwargs_)
#     412
#     413         if isinstance(args_, tuple):
# --> 414             response = command_method(*args_, **kwargs_)
#     415         else:
#     416             response = command_method(args_, **kwargs_)
#
# KeyboardInterrupt:

# %%
print(final_acc)
