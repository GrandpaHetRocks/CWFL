# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import numpy as np
from Dataset import load_dataset, getImage
from utils import averageModels
from utils import averageModelscluster
import random
import math
import matplotlib.pyplot as plt
from ipynb.fs.full.K_clusters import cluster_former
from copy import deepcopy
# Out:
# /home/iiitd/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/iiitd/.local/lib/python3.8/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 0.7790431976318359
# {'Cluster Head': 'client79', 'Members': ['client7', 'client17', 'client29', 'client31', 'client38', 'client41', 'client42', 'client46', 'client51', 'client54', 'client59', 'client66', 'client74', 'client81', 'client86', 'client100'], 'SNR': [18.759301135775726, 23.83628107112825, 54.020729977240286, 21.094039456267318, 22.97760386946015, 26.311060144395892, 37.4667808183864, 36.88820798139711, 26.611355294837438, 24.038902390113844, 25.84086140748261, 17.94869917115447, 23.2919093443756, 28.336687942194892, 22.941332757411242, 25.67567354908413], 'CSI': [0.9126553809726784, 0.4171107847911927, 0.4661139363689504, 0.231793801163518, 0.3120433838276908, 0.15526327795904504, 0.7486059119188176, 0.833352898029216, 0.8369881433889568, 0.4499270557238786, 0.4618436286804346, 0.11362301140684683, 0.9311748829422577, 0.574623199230064, 0.6018071629603875, 0.8115676136016585]}

# %%
P=2 #signal power threshold
#stream = BitStream()
#random.seed(10)
key=[]
for i in range (10000): #generating a random password to activate training (Pilot signal)
    temp=random.randint(0,1)
    key.append(temp)

key1=[0]*len(key)
for i in range (len(key)):   #bpsk modulation
    if(key[i]==1):
        #print("yay")
        key1[i]=-math.sqrt(P)
    else:
        key1[i]=math.sqrt(P)

#print(key)
        
key_np=np.array(key1)

# %%
class Arguments():
    def __init__(self):
        self.images = 10000
        self.clients = 80
        self.numclusters=4
        self.rounds = 200
        self.epochs = 3
        self.local_batches = 64
        self.lr = 0.01
        self.C = 1 #fraction of clients used in the round
        self.drop_rate = 0 #fraction of devices in the selected set to be dropped for various reasons
        self.torch_seed = 0 #same weights and parameters whenever the program is run
        self.log_interval = 64
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = True
args = Arguments()

# %%
#checking if gpu is available
#use_cuda = args.use_cuda and torch.cuda.is_available()
use_cuda=False
device = torch.device("cuda:0" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

hook = sy.TorchHook(torch)
me = hook.local_worker
clients = []

#generating virtual clients
for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})
#print(clients)

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid) #load data

for inx, client in enumerate(clients):  #return actual image set for each client
    trainset_ind_list = list(train_group[inx]) 
    client['trainset'] = getImage(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getImage(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images #useful while taking weighted average

# %%
#load dataset for global model (to compare accuracies)
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.MNIST('./', train=False, download=True, transform=transform)
# global_test_dataset = torch.utils.data.random_split(global_test_dataset, [10000, len(global_test_dataset)-10000])[0]
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

# %%
"""class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        #self.quant = torch.quantization.QuantStub()
        self.conv1 = nn.Conv2d(1, 5, 5, 1)
        self.conv2 = nn.Conv2d(5, 10, 5, 1)
        self.fc1 = nn.Linear(4*4*10, 50) #10 iid #50 non iid
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        #x=self.quant(x)
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*10
                   )
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1) """

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x)

# %%
def fedprox(params,global_params):
    global_param=[]
    ind=0
    for gp in global_params:
        global_param.append(gp)
    for p in params:
    #                 print(p.grad)
        lr=0.001
        mu=0.1
        if(p.grad is None):
            continue
        grad=p.grad.data #batch gradients
        p.data.sub_(lr,(grad+mu*(p.data.clone()-global_param[ind].data.clone())))
        ind+=1
    return(p)

# %%
def ClientUpdate(args, device, client,key_np,key,snr,csi,mu,head):
    gc=False
    client['model'].train()
    #simulating a wireless channel
    poptim=max((1/mu-1/csi),0)
    #print(mu,csi)
    print("Power Allocated=",poptim)
    print("CSI=",csi)
    
    snr__=10**(snr/10)
    
    absh=csi*poptim/snr__
    x=random.uniform(0,absh)
    #print(x)
    y=math.sqrt(absh*absh-x*x)
    #x=x*100
    #y=y*100
    #x=random.random()
    #y=random.random()
    #snr=10*math.log(poptim/(std*std),10)
    std=math.sqrt(poptim/snr__*absh*absh) #channel noise
    
    #print(x,y)
    h=complex(x,y)
    #std=math.sqrt(abs(h)/csi)
    #snr=poptim/(std*std)
    #print(std)
    print("SNR=",snr)
    #print("csi",abs(h)/(std*std))
    
    
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data

    
    #print(client['model'].conv1.weight.size)
    client['model'].send(client['hook'])
    head['model'].send(client['hook'])
    print("Client:",client['hook'].id)
    
    key_np_received=h*key_np+(np.random.randn(len(key_np))*std*2)
    #print(key_np_received)
    key_np_received=(key_np_received/(h)).real
    
    for o in range (len(key_np_received)):  #demodulation bpsk
        if(key_np_received[o]>=0):
            key_np_received[o]=0
        else:
            key_np_received[o]=1
    
    key_np_received=key_np_received.tolist()
    key_np_received = [int(item) for item in key_np_received]
    #key_np=key_np.tolist()
    
    
    if(sum(np.bitwise_xor(key,key_np_received))/len(key)==0 and poptim>0): #...............................................checking if channel is good enough for transmission by checking BER..................................#
        gc=True #considering the client model for training
        for epoch in range(1, args.epochs + 1):
            for batch_idx, (data, target) in enumerate(client['trainset']): 
                data = data.send(client['hook'])
                target = target.send(client['hook'])
                #client['optim'].zero_grad()
                #train model on client
                data, target = data.to(device), target.to(device) #send data to cpu/gpu (data is stored locally)
                output = client['model'](data)
                loss = F.nll_loss(output, target)
                loss.backward()
                client['optim'].step()
                params=client['model'].parameters()
                gp=head['model'].parameters()
#                 params=fedprox(params,gp) 
                
                if batch_idx % args.log_interval == 0:
                    loss = loss.get() 
                    print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                        client['hook'].id,
                        epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                        100. * batch_idx / len(client['trainset']), loss))
    else:
        print("Poor Channel, client not taken for averaging in this round")
            
                    
    client['model'].get()
    head['model'].get()
    # print()
         #CHANGE
    if(poptim!=0):
        data=client['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv1.weight.data=data
        
        
        
        data=client['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client['model'].conv2.weight.data=data
    #CHANGE ENDS
    print()
    return gc

# %%
def test(args, model, device, test_loader, name,fed_round):
    model.eval()    #no need to train the model while testing
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            if(use_cuda and fed_round==0):
                data,target=data.cuda(),target.cuda()
                #model.cuda()
            else:
                data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    return([100. * correct / len(test_loader.dataset),test_loss])

# %%
torch.manual_seed(args.torch_seed)

# %%
def distort(neighbours,snrs):
    ind=0
    poptim=2
    csi=random.random()
    distorted_models=[]
    for client in neighbours:
        client_temp=copy.deepcopy(client)
        snr=snrs[ind]
        ind+=1
        snr__=10**(snr/10)
        absh=csi*poptim/snr__
        x=random.uniform(0,absh)
        y=math.sqrt(absh*absh-x*x)
        std=math.sqrt(poptim/snr__*absh*absh) #channel noise
        h=complex(x,y)
        data=client_temp['model'].conv1.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        #print(power)
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client_temp['model'].conv1.weight.data=data
        
        
        
        
        data=client_temp['model'].conv2.weight
        #data=data.cuda()
        data=data*math.sqrt(poptim) #transmitted signal
        if(use_cuda):
            data=h*data+(torch.randn(data.size())*std).cuda() #channel affecting data
        else:
            data=h*data+(torch.randn(data.size())*std)
        data=data/(math.sqrt(poptim)*(h))  #demodulating received data
        data=data.real #demodulating received data
        client_temp['model'].conv2.weight.data=data
        
        distorted_models.append(client_temp)
    return(distorted_models)

# %%
def decentralized(clients,snrs,weights):
    big_daddy_of_distorted_models=[]
    for client in clients:
        distorted_models=[]
        snr_list=[]
        for snr in snrs:
            if(client['hook'].id in snr):
                snr_list.append(snr[2])
        neighbours_c = [x for x in clients if x != client]
        neighbours={}
        jjj=[jkl for jkl in range(len(neighbours_c))]
        
        dictionary = dict(zip(jjj, neighbours_c))
        #for jjj in range(len(neighbours_c)):
        #   neighbours[jjj].append(neighbours_c[jjj])
        distorted_models=distort(neighbours,snr_list)
        distorted_models.append(client)
        big_daddy_of_distorted_models.append(distorted_models)
    
    
    weight_final1=[]
    for oho in big_daddy_of_distorted_models:
        weight_final=[]
        for comeon in oho:
            for w in weights:
                if(comeon['hook'].id==w[0]):
                    weight_final.append(w[1])
        weight_final1.append(weight_final)
    
    final_heads=[]
    nets=[]
    ind=0
    for client in clients:
        for oof in big_daddy_of_distorted_models:
            if(client==oof[0]):
#                 print(client)
#                 print("shut up")
#                 print(distorted_models)
#                 print("shut up")
#                 print(weight_final1)
                
                overall=Net()
                overall=averageModelscluster(overall,distorted_models,weight_final1[ind])
                client['model'].load_state_dict(overall.state_dict())
                ind+=1
                final_heads.append(client)
                nets.append(overall)
    
    return(final_heads,nets)

# %%
for client in clients: #give the model and optimizer to every client
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    #client['model'] = torch.quantization.quantize_dynamic(
    #client['model'],  # the original model
    #{torch.nn.Linear},  # a set of layers to dynamically quantize
    #dtype=torch.fp)  # the target dtype for quantized weights
    client['optim'] = optim.SGD(client['model'].parameters(), lr=args.lr)

final_acc=[]
final_loss=[]
    
for fed_round in range(args.rounds):
    overall=Net()
    if(fed_round==0): #fed_round==0
        arranged_clusters,head_snr_list=cluster_former(args.numclusters,args.clients)
        temp=deepcopy(arranged_clusters)
        temp2=deepcopy(head_snr_list)
    else:
        #print(temp)
        arranged_clusters=deepcopy(temp)
        head_snr_list=deepcopy(temp2)
#     print(arranged_clusters)
    
    no=1
    heads_list=[]
    weights=[]
    weight_head_list=[]
    head_acc=[]
    head_loss=[]
    for cluster in arranged_clusters:
        
        head=cluster['Cluster Head']
        members=cluster['Members']
        snrs=cluster['SNR']
        csis=cluster['CSI']
        weights.append(sum(snrs))
        weight_head_list.append([head,sum(snrs)])
        new_members=[]
        
        for ij in members:
        #print(ij)
            cl_no=int(ij[6:])
            new_members.append(clients[cl_no-1])
#         print(head)
        head=clients[int(head[6:])-1]
        cluster['Members']=new_members
#         print(head)

        smallmu1=0
        gsmall1=3.402823466E+38 
        
        #water filling algorithm
        mu=1e-15
        while(mu<=1):
            g1=0
            pn1=0
            for jj in csis:
                pn=max(1/mu-1/jj,0)
                g1+=math.log(1+pn*jj) #capacity of a channel (shannon's law)
                pn1+=pn
            g=g1-mu*(pn1-P*30)
            if(g<gsmall1):
                smallmu1=mu
                gsmall1=g
            mu+=0.00002
        
        print(smallmu1)
        good_mem=[]
#         print(len(snrs))
#         print(len(csis))
#         print(len(new_members))
        index=0
        for client in new_members:
            goodchannel=ClientUpdate(args, device, client,key_np,key,snrs[index],csis[index],smallmu1,head)
            index+=1
            if(goodchannel):
                good_mem.append(client)
        
        head['model']=averageModels(head['model'], good_mem)
        arr=test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)
        ac=arr[0]#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[0]
        no+=1
        heads_list.append(head)
        head_acc.append(ac)
        head_loss.append(arr[1])#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[1])
    
    final_acc.append(head_acc)
    final_loss.append(head_loss)
    fig,ax=plt.subplots()
    clor = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(args.numclusters)]
    #ax.plot([i for i in range(fed_round)],head_acc[0])
    for jj in range(0,args.numclusters):
        
        ax.plot([i for i in range(len(final_acc))],[final_acc[j][jj] for j in range(len(final_acc))], color = clor[jj])
        
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][0] for j in range(len(final_acc))], color ="red")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][1] for j in range(len(final_acc))],color ="blue")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][2] for j in range(len(final_acc))],color ="green")
    #ax.plot([i for i in range(len(final_acc))],[final_acc[j][3] for j in range(len(final_acc))],color ="black")
    #ax.plot([i for i in range(len(final_acc))],head_acc[1], fed_round, color ="blue")
    #ax.plot([i for i in range(len(final_acc))],head_acc[2], fed_round, color ="green")
    #ax.plot([i for i in range(len(final_acc))],head_acc[3], fed_round, color ="black")
    
    
    plt.show()
    weightsum=sum(weights)
    
    weights[:] = [x / weightsum for x in weights]
    for aah in range(len(weight_head_list)):
        weight_head_list[aah][1]=weights[aah]
    final_heads,nets=decentralized(heads_list,head_snr_list,weight_head_list)
    
    for head in range(len(final_heads)):
        for cluster in arranged_clusters:
            head1=cluster['Cluster Head']
            if(head1==final_heads[head]['hook'].id):
                for mem in cluster['Members']:
                    mem['model'].load_state_dict(nets[head].state_dict())
    print("ROUND",fed_round)
# Out:
# 0.17423999999999884
# Power Allocated= 4.232841907977913
# CSI= 0.6638482428842264
# SNR= 31.12848627144143
# Client: client10
# Model client10 Train Epoch: 1 [0/768 (0%)]	Loss: 2.308034
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:414: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   response = command_method(*args_, **kwargs_)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client10 Train Epoch: 2 [0/768 (0%)]	Loss: 2.274018
# Model client10 Train Epoch: 3 [0/768 (0%)]	Loss: 2.113640
#
# Power Allocated= 4.323890080804603
# CSI= 0.7065538930854759
# SNR= 43.49172464969907
# Client: client11
# Model client11 Train Epoch: 1 [0/768 (0%)]	Loss: 2.312489
# Model client11 Train Epoch: 2 [0/768 (0%)]	Loss: 2.283857
# Model client11 Train Epoch: 3 [0/768 (0%)]	Loss: 2.200503
#
# Power Allocated= 4.30470566839422
# CSI= 0.6971047626181567
# SNR= 25.06863214623701
# Client: client12
# Model client12 Train Epoch: 1 [0/768 (0%)]	Loss: 2.345109
# Model client12 Train Epoch: 2 [0/768 (0%)]	Loss: 2.241357
# Model client12 Train Epoch: 3 [0/768 (0%)]	Loss: 1.958373
#
# Power Allocated= 3.203419250265502
# CSI= 0.39435426122833594
# SNR= 30.44213751847669
# Client: client18
# Model client18 Train Epoch: 1 [0/768 (0%)]	Loss: 2.304263
# Model client18 Train Epoch: 2 [0/768 (0%)]	Loss: 2.269956
# Model client18 Train Epoch: 3 [0/768 (0%)]	Loss: 2.246846
#
# Power Allocated= 0
# CSI= 0.043447674071728226
# SNR= 26.715948794837562
# Client: client20
# /tmp/ipykernel_675669/2319741324.py:66: RuntimeWarning: invalid value encountered in true_divide
#   key_np_received=(key_np_received/(h)).real
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.786314394534468
# CSI= 0.3386506118764112
# SNR= 27.683396600074676
# Client: client22
# Model client22 Train Epoch: 1 [0/768 (0%)]	Loss: 2.326784
# Model client22 Train Epoch: 2 [0/768 (0%)]	Loss: 2.267264
# Model client22 Train Epoch: 3 [0/768 (0%)]	Loss: 2.027715
#
# Power Allocated= 4.322351481581514
# CSI= 0.7057866301312518
# SNR= 26.273657785411167
# Client: client23
# Model client23 Train Epoch: 1 [0/768 (0%)]	Loss: 2.321525
# Model client23 Train Epoch: 2 [0/768 (0%)]	Loss: 2.273551
# Model client23 Train Epoch: 3 [0/768 (0%)]	Loss: 2.130621
#
# Power Allocated= 0
# CSI= 0.04524553694455713
# SNR= 23.089418630542742
# Client: client28
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.294902153869475
# CSI= 0.6923730322346734
# SNR= 47.559025732733886
# Client: client36
# Model client36 Train Epoch: 1 [0/768 (0%)]	Loss: 2.329772
# Model client36 Train Epoch: 2 [0/768 (0%)]	Loss: 2.324906
# Model client36 Train Epoch: 3 [0/768 (0%)]	Loss: 2.178026
#
# Power Allocated= 2.546340033420653
# CSI= 0.3131978193007732
# SNR= 28.44049228670389
# Client: client37
# Model client37 Train Epoch: 1 [0/768 (0%)]	Loss: 2.344187
# Model client37 Train Epoch: 2 [0/768 (0%)]	Loss: 2.255847
# Model client37 Train Epoch: 3 [0/768 (0%)]	Loss: 2.131278
#
# Power Allocated= 4.345111016871234
# CSI= 0.7173090346590927
# SNR= 25.541954599169042
# Client: client39
# Model client39 Train Epoch: 1 [0/768 (0%)]	Loss: 2.328260
# Model client39 Train Epoch: 2 [0/768 (0%)]	Loss: 2.256467
# Model client39 Train Epoch: 3 [0/768 (0%)]	Loss: 2.193042
#
# Power Allocated= 0.9589398406060203
# CSI= 0.20919318513513152
# SNR= 21.19862142709524
# Client: client49
# Model client49 Train Epoch: 1 [0/768 (0%)]	Loss: 2.302151
# Model client49 Train Epoch: 2 [0/768 (0%)]	Loss: 2.243524
# Model client49 Train Epoch: 3 [0/768 (0%)]	Loss: 2.132500
#
# Power Allocated= 1.8523121464288512
# CSI= 0.2572745578698977
# SNR= 21.024748896417773
# Client: client50
# Model client50 Train Epoch: 1 [0/768 (0%)]	Loss: 2.285262
# Model client50 Train Epoch: 2 [0/768 (0%)]	Loss: 2.252396
# Model client50 Train Epoch: 3 [0/768 (0%)]	Loss: 2.065160
#
# Power Allocated= 0.9106615321354656
# CSI= 0.20710156431084115
# SNR= 26.096316055464435
# Client: client58
# Model client58 Train Epoch: 1 [0/768 (0%)]	Loss: 2.335301
# Model client58 Train Epoch: 2 [0/768 (0%)]	Loss: 2.296052
# Model client58 Train Epoch: 3 [0/768 (0%)]	Loss: 2.223182
#
# Power Allocated= 4.326046664128514
# CSI= 0.707632142143921
# SNR= 38.142983751184616
# Client: client64
# Model client64 Train Epoch: 1 [0/768 (0%)]	Loss: 2.301563
# Model client64 Train Epoch: 2 [0/768 (0%)]	Loss: 2.241738
# Model client64 Train Epoch: 3 [0/768 (0%)]	Loss: 2.198455
#
# Power Allocated= 4.236128515413135
# CSI= 0.6652997996894218
# SNR= 26.78771101045409
# Client: client68
# Model client68 Train Epoch: 1 [0/768 (0%)]	Loss: 2.344550
# Model client68 Train Epoch: 2 [0/768 (0%)]	Loss: 2.242902
# Model client68 Train Epoch: 3 [0/768 (0%)]	Loss: 2.188823
#
# Power Allocated= 4.664184030168346
# CSI= 0.9302098398223207
# SNR= 31.663490254536818
# Client: client69
# Model client69 Train Epoch: 1 [0/768 (0%)]	Loss: 2.286783
# Model client69 Train Epoch: 2 [0/768 (0%)]	Loss: 2.272453
# Model client69 Train Epoch: 3 [0/768 (0%)]	Loss: 2.096254
#
# Power Allocated= 3.986635404982856
# CSI= 0.5705890296575744
# SNR= 31.71767693682327
# Client: client77
# Model client77 Train Epoch: 1 [0/768 (0%)]	Loss: 2.325776
# Model client77 Train Epoch: 2 [0/768 (0%)]	Loss: 2.292760
# Model client77 Train Epoch: 3 [0/768 (0%)]	Loss: 2.133919
#
# Power Allocated= 4.70207478440549
# CSI= 0.9641941672519254
# SNR= 22.529258214789273
# Client: client79
# Model client79 Train Epoch: 1 [0/768 (0%)]	Loss: 2.349466
# Model client79 Train Epoch: 2 [0/768 (0%)]	Loss: 2.266212
# Model client79 Train Epoch: 3 [0/768 (0%)]	Loss: 2.185499
#
#
# Test set: Average loss for Cluster1 model: 1.1569, Accuracy: 6696/10000 (67%)
#
# 0.14280000000001103
# Power Allocated= 5.868777331490039
# CSI= 0.8818157165108546
# SNR= 35.5133901536242
# Client: client2
# Model client2 Train Epoch: 1 [0/768 (0%)]	Loss: 2.320918
# Model client2 Train Epoch: 2 [0/768 (0%)]	Loss: 2.261834
# Model client2 Train Epoch: 3 [0/768 (0%)]	Loss: 2.127864
#
# Power Allocated= 5.131229522933003
# CSI= 0.5343103097567604
# SNR= 28.17115490157559
# Client: client5
# Model client5 Train Epoch: 1 [0/768 (0%)]	Loss: 2.314162
# Model client5 Train Epoch: 2 [0/768 (0%)]	Loss: 2.279294
# Model client5 Train Epoch: 3 [0/768 (0%)]	Loss: 2.180644
#
# Power Allocated= 0
# CSI= 0.10030356006242258
# SNR= 23.785149595537163
# Client: client7
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.1388143217736182
# SNR= 47.295001562523815
# Client: client13
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.3040787358134915
# CSI= 0.3705457092192035
# SNR= 40.68020181233974
# Client: client27
# Model client27 Train Epoch: 1 [0/768 (0%)]	Loss: 2.311024
# Model client27 Train Epoch: 2 [0/768 (0%)]	Loss: 2.281316
# Model client27 Train Epoch: 3 [0/768 (0%)]	Loss: 2.140448
#
# Power Allocated= 5.60514942610661
# CSI= 0.7154858424662697
# SNR= 30.016700897000003
# Client: client30
# Model client30 Train Epoch: 1 [0/768 (0%)]	Loss: 2.324635
# Model client30 Train Epoch: 2 [0/768 (0%)]	Loss: 2.280287
# Model client30 Train Epoch: 3 [0/768 (0%)]	Loss: 2.149268
#
# Power Allocated= 1.9274860100125322
# CSI= 0.19703210110914082
# SNR= 25.164537290113532
# Client: client31
# Model client31 Train Epoch: 1 [0/768 (0%)]	Loss: 2.289820
# Model client31 Train Epoch: 2 [0/768 (0%)]	Loss: 2.286104
# Model client31 Train Epoch: 3 [0/768 (0%)]	Loss: 2.210166
#
# Power Allocated= 5.906072322615572
# CSI= 0.9118024455788221
# SNR= 28.71635373055322
# Client: client35
# Model client35 Train Epoch: 1 [0/768 (0%)]	Loss: 2.306331
# Model client35 Train Epoch: 2 [0/768 (0%)]	Loss: 2.226450
# Model client35 Train Epoch: 3 [0/768 (0%)]	Loss: 2.054771
#
# Power Allocated= 5.218457343911867
# CSI= 0.5604301217904646
# SNR= 28.019230221678846
# Client: client38
# Model client38 Train Epoch: 1 [0/768 (0%)]	Loss: 2.322068
# Model client38 Train Epoch: 2 [0/768 (0%)]	Loss: 2.295809
# Model client38 Train Epoch: 3 [0/768 (0%)]	Loss: 2.107064
#
# Power Allocated= 2.077395122543341
# CSI= 0.20302894835988916
# SNR= 28.85186974424753
# Client: client43
# Model client43 Train Epoch: 1 [0/768 (0%)]	Loss: 2.313601
# Model client43 Train Epoch: 2 [0/768 (0%)]	Loss: 2.277308
# Model client43 Train Epoch: 3 [0/768 (0%)]	Loss: 2.107241
#
# Power Allocated= 5.691657942360541
# CSI= 0.7626932105606936
# SNR= 24.997144075637465
# Client: client47
# Model client47 Train Epoch: 1 [0/768 (0%)]	Loss: 2.302326
# Model client47 Train Epoch: 2 [0/768 (0%)]	Loss: 2.291937
# Model client47 Train Epoch: 3 [0/768 (0%)]	Loss: 2.159555
#
# Power Allocated= 5.08882197419884
# CSI= 0.5224717322338109
# SNR= 35.24881694283354
# Client: client52
# Model client52 Train Epoch: 1 [0/768 (0%)]	Loss: 2.321438
# Model client52 Train Epoch: 2 [0/768 (0%)]	Loss: 2.284488
# Model client52 Train Epoch: 3 [0/768 (0%)]	Loss: 2.225698
#
# Power Allocated= 4.671136539923616
# CSI= 0.42887815355296877
# SNR= 33.77178620188203
# Client: client59
# Model client59 Train Epoch: 1 [0/768 (0%)]	Loss: 2.314044
# Model client59 Train Epoch: 2 [0/768 (0%)]	Loss: 2.259392
# Model client59 Train Epoch: 3 [0/768 (0%)]	Loss: 2.108217
#
# Power Allocated= 2.587483667617329
# CSI= 0.22648428129646248
# SNR= 18.812070965171706
# Client: client66
# Model client66 Train Epoch: 1 [0/768 (0%)]	Loss: 2.287220
# Model client66 Train Epoch: 2 [0/768 (0%)]	Loss: 2.267053
# Model client66 Train Epoch: 3 [0/768 (0%)]	Loss: 2.163756
#
# Power Allocated= 0
# CSI= 0.08376662532616774
# SNR= 20.367489075397618
# Client: client72
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.925297995649724
# CSI= 0.9280715544908978
# SNR= 34.55852922400609
# Client: client73
# Model client73 Train Epoch: 1 [0/768 (0%)]	Loss: 2.313833
# Model client73 Train Epoch: 2 [0/768 (0%)]	Loss: 2.279786
# Model client73 Train Epoch: 3 [0/768 (0%)]	Loss: 2.173322
#
# Power Allocated= 0
# CSI= 0.04163443755156626
# SNR= 25.571327011277198
# Client: client74
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.12091986542958388
# SNR= 31.18796306602946
# Client: client76
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.042821071517115006
# SNR= 22.835045783721142
# Client: client80
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster2 model: 1.6715, Accuracy: 6234/10000 (62%)
#
# 0.17455999999999872
# Power Allocated= 4.457955813107289
# CSI= 0.7869470894448848
# SNR= 33.281988928390255
# Client: client3
# Model client3 Train Epoch: 1 [0/768 (0%)]	Loss: 2.311933
# Model client3 Train Epoch: 2 [0/768 (0%)]	Loss: 2.248059
# Model client3 Train Epoch: 3 [0/768 (0%)]	Loss: 2.080331
#
# Power Allocated= 1.189311680264649
# CSI= 0.22029451812135925
# SNR= 34.4817790151137
# Client: client8
# Model client8 Train Epoch: 1 [0/768 (0%)]	Loss: 2.287286
# Model client8 Train Epoch: 2 [0/768 (0%)]	Loss: 2.290214
# Model client8 Train Epoch: 3 [0/768 (0%)]	Loss: 2.162315
#
# Power Allocated= 0
# CSI= 0.11616007971463926
# SNR= 22.8668343700286
# Client: client15
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.491662090840107
# CSI= 0.8083896716923498
# SNR= 26.17697066850277
# Client: client16
# Model client16 Train Epoch: 1 [0/768 (0%)]	Loss: 2.311538
# Model client16 Train Epoch: 2 [0/768 (0%)]	Loss: 2.254912
# Model client16 Train Epoch: 3 [0/768 (0%)]	Loss: 2.185003
#
# Power Allocated= 1.6693634197358058
# CSI= 0.2463463233637726
# SNR= 35.19946190077926
# Client: client19
# Model client19 Train Epoch: 1 [0/768 (0%)]	Loss: 2.276648
# Model client19 Train Epoch: 2 [0/768 (0%)]	Loss: 2.260219
# Model client19 Train Epoch: 3 [0/768 (0%)]	Loss: 2.155488
#
# Power Allocated= 4.60153930235034
# CSI= 0.8871933846179657
# SNR= 28.891822148832517
# Client: client24
# Model client24 Train Epoch: 1 [0/768 (0%)]	Loss: 2.339858
# Model client24 Train Epoch: 2 [0/768 (0%)]	Loss: 2.278327
# Model client24 Train Epoch: 3 [0/768 (0%)]	Loss: 2.196436
#
# Power Allocated= 4.146869691175163
# CSI= 0.6321833473682303
# SNR= 33.07958900429599
# Client: client26
# Model client26 Train Epoch: 1 [0/768 (0%)]	Loss: 2.304986
# Model client26 Train Epoch: 2 [0/768 (0%)]	Loss: 2.260531
# Model client26 Train Epoch: 3 [0/768 (0%)]	Loss: 2.182685
#
# Power Allocated= 2.827129056761362
# CSI= 0.3446421664476179
# SNR= 27.444682611048393
# Client: client29
# Model client29 Train Epoch: 1 [0/768 (0%)]	Loss: 2.304671
# Model client29 Train Epoch: 2 [0/768 (0%)]	Loss: 2.259143
# Model client29 Train Epoch: 3 [0/768 (0%)]	Loss: 2.175622
#
# Power Allocated= 4.542045700660914
# CSI= 0.8427130276282103
# SNR= 28.879476756284458
# Client: client34
# Model client34 Train Epoch: 1 [0/768 (0%)]	Loss: 2.319811
# Model client34 Train Epoch: 2 [0/768 (0%)]	Loss: 2.264861
# Model client34 Train Epoch: 3 [0/768 (0%)]	Loss: 2.194888
#
# Power Allocated= 4.390656130393803
# CSI= 0.7473656413992504
# SNR= 28.059230122150108
# Client: client40
# Model client40 Train Epoch: 1 [0/768 (0%)]	Loss: 2.325424
# Model client40 Train Epoch: 2 [0/768 (0%)]	Loss: 2.285414
# Model client40 Train Epoch: 3 [0/768 (0%)]	Loss: 2.091993
#
# Power Allocated= 2.729228596966281
# CSI= 0.33339326867174846
# SNR= 26.670809867367296
# Client: client41
# Model client41 Train Epoch: 1 [0/768 (0%)]	Loss: 2.311292
# Model client41 Train Epoch: 2 [0/768 (0%)]	Loss: 2.257804
# Model client41 Train Epoch: 3 [0/768 (0%)]	Loss: 2.152385
#
# Power Allocated= 4.139916789280618
# CSI= 0.6294167405502923
# SNR= 39.92949831019219
# Client: client44
# Model client44 Train Epoch: 1 [0/768 (0%)]	Loss: 2.322069
# Model client44 Train Epoch: 2 [0/768 (0%)]	Loss: 2.285545
# Model client44 Train Epoch: 3 [0/768 (0%)]	Loss: 2.168405
#
# Power Allocated= 4.399199353182363
# CSI= 0.7521681683458008
# SNR= 24.732058394509984
# Client: client45
# Model client45 Train Epoch: 1 [0/768 (0%)]	Loss: 2.300251
# Model client45 Train Epoch: 2 [0/768 (0%)]	Loss: 2.270719
# Model client45 Train Epoch: 3 [0/768 (0%)]	Loss: 2.188153
#
# Power Allocated= 3.567735520904029
# CSI= 0.46275863039224163
# SNR= 24.697159165748566
# Client: client46
# Model client46 Train Epoch: 1 [0/768 (0%)]	Loss: 2.346551
# Model client46 Train Epoch: 2 [0/768 (0%)]	Loss: 2.265533
# Model client46 Train Epoch: 3 [0/768 (0%)]	Loss: 2.148719
#
# Power Allocated= 4.380147671410592
# CSI= 0.7415418231633155
# SNR= 27.42181814133243
# Client: client53
# Model client53 Train Epoch: 1 [0/768 (0%)]	Loss: 2.292256
# Model client53 Train Epoch: 2 [0/768 (0%)]	Loss: 2.267834
# Model client53 Train Epoch: 3 [0/768 (0%)]	Loss: 2.034098
#
# Power Allocated= 4.009732941986857
# CSI= 0.5817483436168447
# SNR= 35.51120843119492
# Client: client60
# Model client60 Train Epoch: 1 [0/768 (0%)]	Loss: 2.298103
# Model client60 Train Epoch: 2 [0/768 (0%)]	Loss: 2.262234
# Model client60 Train Epoch: 3 [0/768 (0%)]	Loss: 2.115287
#
# Power Allocated= 0
# CSI= 0.0540332703855988
# SNR= 30.61837344205931
# Client: client61
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.461417164933827
# CSI= 0.7890965100167425
# SNR= 29.252546797634803
# Client: client62
# Model client62 Train Epoch: 1 [0/768 (0%)]	Loss: 2.368090
# Model client62 Train Epoch: 2 [0/768 (0%)]	Loss: 2.266006
# Model client62 Train Epoch: 3 [0/768 (0%)]	Loss: 2.109165
#
# Power Allocated= 0
# CSI= 0.17016856492018562
# SNR= 29.13305397748135
# Client: client63
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster3 model: 1.2347, Accuracy: 6538/10000 (65%)
#
# 0.18551999999999447
# Power Allocated= 3.4501198928201067
# CSI= 0.5154281757198738
# SNR= 32.96079299274537
# Client: client4
# Model client4 Train Epoch: 1 [0/768 (0%)]	Loss: 2.294453
# Model client4 Train Epoch: 2 [0/768 (0%)]	Loss: 2.284959
# Model client4 Train Epoch: 3 [0/768 (0%)]	Loss: 2.104544
#
# Power Allocated= 3.499432126229476
# CSI= 0.528870430230244
# SNR= 24.24922471074111
# Client: client6
# Model client6 Train Epoch: 1 [0/768 (0%)]	Loss: 2.316022
# Model client6 Train Epoch: 2 [0/768 (0%)]	Loss: 2.268262
# Model client6 Train Epoch: 3 [0/768 (0%)]	Loss: 2.157796
#
# Power Allocated= 4.013749688203292
# CSI= 0.7264777061015619
# SNR= 32.36332506645626
# Client: client17
# Model client17 Train Epoch: 1 [0/768 (0%)]	Loss: 2.318625
# Model client17 Train Epoch: 2 [0/768 (0%)]	Loss: 2.259548
# Model client17 Train Epoch: 3 [0/768 (0%)]	Loss: 2.136624
#
# Power Allocated= 3.7434296652628753
# CSI= 0.6072291524147578
# SNR= 27.579218034052065
# Client: client21
# Model client21 Train Epoch: 1 [0/768 (0%)]	Loss: 2.302227
# Model client21 Train Epoch: 2 [0/768 (0%)]	Loss: 2.269856
# Model client21 Train Epoch: 3 [0/768 (0%)]	Loss: 2.194405
#
# Power Allocated= 0.7098859739348722
# CSI= 0.2136583928213689
# SNR= 21.919537012130636
# Client: client25
# Model client25 Train Epoch: 1 [0/768 (0%)]	Loss: 2.302730
# Model client25 Train Epoch: 2 [0/768 (0%)]	Loss: 2.247454
# Model client25 Train Epoch: 3 [0/768 (0%)]	Loss: 2.158004
#
# Power Allocated= 4.229481541435025
# CSI= 0.8614949732704805
# SNR= 30.172244750677486
# Client: client32
# Model client32 Train Epoch: 1 [0/768 (0%)]	Loss: 2.317849
# Model client32 Train Epoch: 2 [0/768 (0%)]	Loss: 2.257420
# Model client32 Train Epoch: 3 [0/768 (0%)]	Loss: 2.186985
#
# Power Allocated= 2.324719087331062
# CSI= 0.3262072987188529
# SNR= 34.726443908949776
# Client: client42
# Model client42 Train Epoch: 1 [0/768 (0%)]	Loss: 2.298130
# Model client42 Train Epoch: 2 [0/768 (0%)]	Loss: 2.265743
# Model client42 Train Epoch: 3 [0/768 (0%)]	Loss: 2.223819
#
# Power Allocated= 3.7600210697838072
# CSI= 0.613409117082531
# SNR= 30.575693780985624
# Client: client48
# Model client48 Train Epoch: 1 [0/768 (0%)]	Loss: 2.339164
# Model client48 Train Epoch: 2 [0/768 (0%)]	Loss: 2.268189
# Model client48 Train Epoch: 3 [0/768 (0%)]	Loss: 2.068613
#
# Power Allocated= 4.343200602928784
# CSI= 0.9550607463413642
# SNR= 24.849884488723752
# Client: client51
# Model client51 Train Epoch: 1 [0/768 (0%)]	Loss: 2.355384
# Model client51 Train Epoch: 2 [0/768 (0%)]	Loss: 2.247328
# Model client51 Train Epoch: 3 [0/768 (0%)]	Loss: 2.073697
#
# Power Allocated= 4.0335616374267556
# CSI= 0.7370865481401184
# SNR= 24.244011540534178
# Client: client54
# Model client54 Train Epoch: 1 [0/768 (0%)]	Loss: 2.292558
# Model client54 Train Epoch: 2 [0/768 (0%)]	Loss: 2.235584
# Model client54 Train Epoch: 3 [0/768 (0%)]	Loss: 2.012699
#
# Power Allocated= 3.687296110277093
# CSI= 0.5872134357520203
# SNR= 22.84609697900034
# Client: client55
# Model client55 Train Epoch: 1 [0/768 (0%)]	Loss: 2.343651
# Model client55 Train Epoch: 2 [0/768 (0%)]	Loss: 2.232498
# Model client55 Train Epoch: 3 [0/768 (0%)]	Loss: 1.934259
#
# Power Allocated= 3.9157351337905464
# CSI= 0.6781871280671696
# SNR= 25.43369171633348
# Client: client56
# Model client56 Train Epoch: 1 [0/768 (0%)]	Loss: 2.289785
# Model client56 Train Epoch: 2 [0/768 (0%)]	Loss: 2.264192
# Model client56 Train Epoch: 3 [0/768 (0%)]	Loss: 2.180039
#
# Power Allocated= 4.356777276494116
# CSI= 0.9676072724735655
# SNR= 29.009722239274236
# Client: client57
# Model client57 Train Epoch: 1 [0/768 (0%)]	Loss: 2.313385
# Model client57 Train Epoch: 2 [0/768 (0%)]	Loss: 2.281850
# Model client57 Train Epoch: 3 [0/768 (0%)]	Loss: 2.081046
#
# Power Allocated= 1.1558358894238792
# CSI= 0.2361599338320175
# SNR= 36.36705036567167
# Client: client65
# Model client65 Train Epoch: 1 [0/768 (0%)]	Loss: 2.331934
# Model client65 Train Epoch: 2 [0/768 (0%)]	Loss: 2.289175
# Model client65 Train Epoch: 3 [0/768 (0%)]	Loss: 2.195760
#
# Power Allocated= 3.6252019687656762
# CSI= 0.5665554013965479
# SNR= 26.79536341716591
# Client: client67
# Model client67 Train Epoch: 1 [0/768 (0%)]	Loss: 2.322596
# Model client67 Train Epoch: 2 [0/768 (0%)]	Loss: 2.231801
# Model client67 Train Epoch: 3 [0/768 (0%)]	Loss: 2.148512
#
# Power Allocated= 0.9091752787347644
# CSI= 0.22316053086169974
# SNR= 26.19782764495052
# Client: client70
# Model client70 Train Epoch: 1 [0/768 (0%)]	Loss: 2.334727
# Model client70 Train Epoch: 2 [0/768 (0%)]	Loss: 2.268248
# Model client70 Train Epoch: 3 [0/768 (0%)]	Loss: 2.144043
#
# Power Allocated= 3.9733634813120102
# CSI= 0.7057706226280043
# SNR= 27.89126538389184
# Client: client71
# Model client71 Train Epoch: 1 [0/768 (0%)]	Loss: 2.344896
# Model client71 Train Epoch: 2 [0/768 (0%)]	Loss: 2.298415
# Model client71 Train Epoch: 3 [0/768 (0%)]	Loss: 2.135894
#
# Power Allocated= 0
# CSI= 0.12003508842710076
# SNR= 22.51863771620458
# Client: client75
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.270454102131584
# CSI= 0.8930163566087345
# SNR= 24.896953422252142
# Client: client78
# Model client78 Train Epoch: 1 [0/768 (0%)]	Loss: 2.305676
# Model client78 Train Epoch: 2 [0/768 (0%)]	Loss: 2.216829
# Model client78 Train Epoch: 3 [0/768 (0%)]	Loss: 2.148641
#
#
# Test set: Average loss for Cluster4 model: 1.0945, Accuracy: 6479/10000 (65%)
# ROUND 0
# 0.17423999999999884
# Power Allocated= 4.232841907977913
# CSI= 0.6638482428842264
# SNR= 31.12848627144143
# Client: client10
# Model client10 Train Epoch: 1 [0/768 (0%)]	Loss: 2.286937
# Model client10 Train Epoch: 2 [0/768 (0%)]	Loss: 1.950454
# Model client10 Train Epoch: 3 [0/768 (0%)]	Loss: 1.288039
#
# Power Allocated= 4.323890080804603
# CSI= 0.7065538930854759
# SNR= 43.49172464969907
# Client: client11
# Model client11 Train Epoch: 1 [0/768 (0%)]	Loss: 2.298142
# Model client11 Train Epoch: 2 [0/768 (0%)]	Loss: 1.984154
# Model client11 Train Epoch: 3 [0/768 (0%)]	Loss: 1.343594
#
# Power Allocated= 4.30470566839422
# CSI= 0.6971047626181567
# SNR= 25.06863214623701
# Client: client12
# Model client12 Train Epoch: 1 [0/768 (0%)]	Loss: 2.292506
# Model client12 Train Epoch: 2 [0/768 (0%)]	Loss: 2.119474
# Model client12 Train Epoch: 3 [0/768 (0%)]	Loss: 1.515855
#
# Power Allocated= 3.203419250265502
# CSI= 0.39435426122833594
# SNR= 30.44213751847669
# Client: client18
# Model client18 Train Epoch: 1 [0/768 (0%)]	Loss: 2.288671
# Model client18 Train Epoch: 2 [0/768 (0%)]	Loss: 2.063705
# Model client18 Train Epoch: 3 [0/768 (0%)]	Loss: 1.767729
#
# Power Allocated= 0
# CSI= 0.043447674071728226
# SNR= 26.715948794837562
# Client: client20
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.786314394534468
# CSI= 0.3386506118764112
# SNR= 27.683396600074676
# Client: client22
# Model client22 Train Epoch: 1 [0/768 (0%)]	Loss: 2.296287
# Model client22 Train Epoch: 2 [0/768 (0%)]	Loss: 2.056014
# Model client22 Train Epoch: 3 [0/768 (0%)]	Loss: 1.382633
#
# Power Allocated= 4.322351481581514
# CSI= 0.7057866301312518
# SNR= 26.273657785411167
# Client: client23
# Model client23 Train Epoch: 1 [0/768 (0%)]	Loss: 2.289542
# Model client23 Train Epoch: 2 [0/768 (0%)]	Loss: 1.960368
# Model client23 Train Epoch: 3 [0/768 (0%)]	Loss: 1.252130
#
# Power Allocated= 0
# CSI= 0.04524553694455713
# SNR= 23.089418630542742
# Client: client28
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.294902153869475
# CSI= 0.6923730322346734
# SNR= 47.559025732733886
# Client: client36
# Model client36 Train Epoch: 1 [0/768 (0%)]	Loss: 2.291884
# Model client36 Train Epoch: 2 [0/768 (0%)]	Loss: 1.955506
# Model client36 Train Epoch: 3 [0/768 (0%)]	Loss: 1.181657
#
# Power Allocated= 2.546340033420653
# CSI= 0.3131978193007732
# SNR= 28.44049228670389
# Client: client37
# Model client37 Train Epoch: 1 [0/768 (0%)]	Loss: 2.299802
# Model client37 Train Epoch: 2 [0/768 (0%)]	Loss: 2.168273
# Model client37 Train Epoch: 3 [0/768 (0%)]	Loss: 1.669030
#
# Power Allocated= 4.345111016871234
# CSI= 0.7173090346590927
# SNR= 25.541954599169042
# Client: client39
# Model client39 Train Epoch: 1 [0/768 (0%)]	Loss: 2.290864
# Model client39 Train Epoch: 2 [0/768 (0%)]	Loss: 1.987208
# Model client39 Train Epoch: 3 [0/768 (0%)]	Loss: 1.743217
#
# Power Allocated= 0.9589398406060203
# CSI= 0.20919318513513152
# SNR= 21.19862142709524
# Client: client49
# Model client49 Train Epoch: 1 [0/768 (0%)]	Loss: 2.291295
# Model client49 Train Epoch: 2 [0/768 (0%)]	Loss: 2.044355
# Model client49 Train Epoch: 3 [0/768 (0%)]	Loss: 1.098937
#
# Power Allocated= 1.8523121464288512
# CSI= 0.2572745578698977
# SNR= 21.024748896417773
# Client: client50
# Model client50 Train Epoch: 1 [0/768 (0%)]	Loss: 2.301767
# Model client50 Train Epoch: 2 [0/768 (0%)]	Loss: 2.209700
# Model client50 Train Epoch: 3 [0/768 (0%)]	Loss: 1.216989
#
# Power Allocated= 0.9106615321354656
# CSI= 0.20710156431084115
# SNR= 26.096316055464435
# Client: client58
# Model client58 Train Epoch: 1 [0/768 (0%)]	Loss: 2.292211
# Model client58 Train Epoch: 2 [0/768 (0%)]	Loss: 2.017758
# Model client58 Train Epoch: 3 [0/768 (0%)]	Loss: 1.356447
#
# Power Allocated= 4.326046664128514
# CSI= 0.707632142143921
# SNR= 38.142983751184616
# Client: client64
# Model client64 Train Epoch: 1 [0/768 (0%)]	Loss: 2.287517
# Model client64 Train Epoch: 2 [0/768 (0%)]	Loss: 2.052638
# Model client64 Train Epoch: 3 [0/768 (0%)]	Loss: 1.255676
#
# Power Allocated= 4.236128515413135
# CSI= 0.6652997996894218
# SNR= 26.78771101045409
# Client: client68
# Model client68 Train Epoch: 1 [0/768 (0%)]	Loss: 2.290949
# Model client68 Train Epoch: 2 [0/768 (0%)]	Loss: 2.062343
# Model client68 Train Epoch: 3 [0/768 (0%)]	Loss: 1.561509
#
# Power Allocated= 4.664184030168346
# CSI= 0.9302098398223207
# SNR= 31.663490254536818
# Client: client69
# Model client69 Train Epoch: 1 [0/768 (0%)]	Loss: 2.285913
# Model client69 Train Epoch: 2 [0/768 (0%)]	Loss: 1.979354
# Model client69 Train Epoch: 3 [0/768 (0%)]	Loss: 1.070011
#
# Power Allocated= 3.986635404982856
# CSI= 0.5705890296575744
# SNR= 31.71767693682327
# Client: client77
# Model client77 Train Epoch: 1 [0/768 (0%)]	Loss: 2.290497
# Model client77 Train Epoch: 2 [0/768 (0%)]	Loss: 2.094705
# Model client77 Train Epoch: 3 [0/768 (0%)]	Loss: 1.646659
#
# Power Allocated= 4.70207478440549
# CSI= 0.9641941672519254
# SNR= 22.529258214789273
# Client: client79
# Model client79 Train Epoch: 1 [0/768 (0%)]	Loss: 2.291711
# Model client79 Train Epoch: 2 [0/768 (0%)]	Loss: 2.002127
# Model client79 Train Epoch: 3 [0/768 (0%)]	Loss: 1.340495
#
#
# Test set: Average loss for Cluster1 model: 0.7915, Accuracy: 7625/10000 (76%)
#
# 0.14280000000001103
# Power Allocated= 5.868777331490039
# CSI= 0.8818157165108546
# SNR= 35.5133901536242
# Client: client2
# Model client2 Train Epoch: 1 [0/768 (0%)]	Loss: 2.294964
# Model client2 Train Epoch: 2 [0/768 (0%)]	Loss: 1.929133
# Model client2 Train Epoch: 3 [0/768 (0%)]	Loss: 1.799476
#
# Power Allocated= 5.131229522933003
# CSI= 0.5343103097567604
# SNR= 28.17115490157559
# Client: client5
# Model client5 Train Epoch: 1 [0/768 (0%)]	Loss: 2.296126
# Model client5 Train Epoch: 2 [0/768 (0%)]	Loss: 2.032489
# Model client5 Train Epoch: 3 [0/768 (0%)]	Loss: 1.239279
#
# Power Allocated= 0
# CSI= 0.10030356006242258
# SNR= 23.785149595537163
# Client: client7
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.1388143217736182
# SNR= 47.295001562523815
# Client: client13
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.3040787358134915
# CSI= 0.3705457092192035
# SNR= 40.68020181233974
# Client: client27
# Model client27 Train Epoch: 1 [0/768 (0%)]	Loss: 2.298433
# Model client27 Train Epoch: 2 [0/768 (0%)]	Loss: 1.995404
# Model client27 Train Epoch: 3 [0/768 (0%)]	Loss: 1.486697
#
# Power Allocated= 5.60514942610661
# CSI= 0.7154858424662697
# SNR= 30.016700897000003
# Client: client30
# Model client30 Train Epoch: 1 [0/768 (0%)]	Loss: 2.285998
# Model client30 Train Epoch: 2 [0/768 (0%)]	Loss: 1.957445
# Model client30 Train Epoch: 3 [0/768 (0%)]	Loss: 1.238494
#
# Power Allocated= 1.9274860100125322
# CSI= 0.19703210110914082
# SNR= 25.164537290113532
# Client: client31
# Model client31 Train Epoch: 1 [0/768 (0%)]	Loss: 2.296495
# Model client31 Train Epoch: 2 [0/768 (0%)]	Loss: 2.200996
# Model client31 Train Epoch: 3 [0/768 (0%)]	Loss: 1.334788
#
# Power Allocated= 5.906072322615572
# CSI= 0.9118024455788221
# SNR= 28.71635373055322
# Client: client35
# Model client35 Train Epoch: 1 [0/768 (0%)]	Loss: 2.298681
# Model client35 Train Epoch: 2 [0/768 (0%)]	Loss: 2.023058
# Model client35 Train Epoch: 3 [0/768 (0%)]	Loss: 1.650623
#
# Power Allocated= 5.218457343911867
# CSI= 0.5604301217904646
# SNR= 28.019230221678846
# Client: client38
# Model client38 Train Epoch: 1 [0/768 (0%)]	Loss: 2.297647
# Model client38 Train Epoch: 2 [0/768 (0%)]	Loss: 2.060910
# Model client38 Train Epoch: 3 [0/768 (0%)]	Loss: 1.429706
#
# Power Allocated= 2.077395122543341
# CSI= 0.20302894835988916
# SNR= 28.85186974424753
# Client: client43
# Model client43 Train Epoch: 1 [0/768 (0%)]	Loss: 2.297136
# Model client43 Train Epoch: 2 [0/768 (0%)]	Loss: 2.078226
# Model client43 Train Epoch: 3 [0/768 (0%)]	Loss: 1.308334
#
# Power Allocated= 5.691657942360541
# CSI= 0.7626932105606936
# SNR= 24.997144075637465
# Client: client47
# Model client47 Train Epoch: 1 [0/768 (0%)]	Loss: 2.291792
# Model client47 Train Epoch: 2 [0/768 (0%)]	Loss: 1.933626
# Model client47 Train Epoch: 3 [0/768 (0%)]	Loss: 1.413971
#
# Power Allocated= 5.08882197419884
# CSI= 0.5224717322338109
# SNR= 35.24881694283354
# Client: client52
# Model client52 Train Epoch: 1 [0/768 (0%)]	Loss: 2.300015
# Model client52 Train Epoch: 2 [0/768 (0%)]	Loss: 2.029978
# Model client52 Train Epoch: 3 [0/768 (0%)]	Loss: 1.526358
#
# Power Allocated= 4.671136539923616
# CSI= 0.42887815355296877
# SNR= 33.77178620188203
# Client: client59
# Model client59 Train Epoch: 1 [0/768 (0%)]	Loss: 2.302298
# Model client59 Train Epoch: 2 [0/768 (0%)]	Loss: 2.023239
# Model client59 Train Epoch: 3 [0/768 (0%)]	Loss: 1.140133
#
# Power Allocated= 2.587483667617329
# CSI= 0.22648428129646248
# SNR= 18.812070965171706
# Client: client66
# Model client66 Train Epoch: 1 [0/768 (0%)]	Loss: 2.284041
# Model client66 Train Epoch: 2 [0/768 (0%)]	Loss: 1.940107
# Model client66 Train Epoch: 3 [0/768 (0%)]	Loss: 1.596453
#
# Power Allocated= 0
# CSI= 0.08376662532616774
# SNR= 20.367489075397618
# Client: client72
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.925297995649724
# CSI= 0.9280715544908978
# SNR= 34.55852922400609
# Client: client73
# Model client73 Train Epoch: 1 [0/768 (0%)]	Loss: 2.289847
# Model client73 Train Epoch: 2 [0/768 (0%)]	Loss: 2.145617
# Model client73 Train Epoch: 3 [0/768 (0%)]	Loss: 1.463861
#
# Power Allocated= 0
# CSI= 0.04163443755156626
# SNR= 25.571327011277198
# Client: client74
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.12091986542958388
# SNR= 31.18796306602946
# Client: client76
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.042821071517115006
# SNR= 22.835045783721142
# Client: client80
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster2 model: 1.1843, Accuracy: 7546/10000 (75%)
#
# 0.17455999999999872
# Power Allocated= 4.457955813107289
# CSI= 0.7869470894448848
# SNR= 33.281988928390255
# Client: client3
# Model client3 Train Epoch: 1 [0/768 (0%)]	Loss: 2.296455
# Model client3 Train Epoch: 2 [0/768 (0%)]	Loss: 2.016677
# Model client3 Train Epoch: 3 [0/768 (0%)]	Loss: 1.742677
#
# Power Allocated= 1.189311680264649
# CSI= 0.22029451812135925
# SNR= 34.4817790151137
# Client: client8
# Model client8 Train Epoch: 1 [0/768 (0%)]	Loss: 2.292344
# Model client8 Train Epoch: 2 [0/768 (0%)]	Loss: 1.988270
# Model client8 Train Epoch: 3 [0/768 (0%)]	Loss: 1.543067
#
# Power Allocated= 0
# CSI= 0.11616007971463926
# SNR= 22.8668343700286
# Client: client15
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.491662090840107
# CSI= 0.8083896716923498
# SNR= 26.17697066850277
# Client: client16
# Model client16 Train Epoch: 1 [0/768 (0%)]	Loss: 2.287721
# Model client16 Train Epoch: 2 [0/768 (0%)]	Loss: 2.085828
# Model client16 Train Epoch: 3 [0/768 (0%)]	Loss: 1.351803
#
# Power Allocated= 1.6693634197358058
# CSI= 0.2463463233637726
# SNR= 35.19946190077926
# Client: client19
# Model client19 Train Epoch: 1 [0/768 (0%)]	Loss: 2.291109
# Model client19 Train Epoch: 2 [0/768 (0%)]	Loss: 2.036820
# Model client19 Train Epoch: 3 [0/768 (0%)]	Loss: 1.045200
#
# Power Allocated= 4.60153930235034
# CSI= 0.8871933846179657
# SNR= 28.891822148832517
# Client: client24
# Model client24 Train Epoch: 1 [0/768 (0%)]	Loss: 2.289643
# Model client24 Train Epoch: 2 [0/768 (0%)]	Loss: 2.152492
# Model client24 Train Epoch: 3 [0/768 (0%)]	Loss: 1.501870
#
# Power Allocated= 4.146869691175163
# CSI= 0.6321833473682303
# SNR= 33.07958900429599
# Client: client26
# Model client26 Train Epoch: 1 [0/768 (0%)]	Loss: 2.290106
# Model client26 Train Epoch: 2 [0/768 (0%)]	Loss: 1.963449
# Model client26 Train Epoch: 3 [0/768 (0%)]	Loss: 1.694213
#
# Power Allocated= 2.827129056761362
# CSI= 0.3446421664476179
# SNR= 27.444682611048393
# Client: client29
# Model client29 Train Epoch: 1 [0/768 (0%)]	Loss: 2.294408
# Model client29 Train Epoch: 2 [0/768 (0%)]	Loss: 1.897921
# Model client29 Train Epoch: 3 [0/768 (0%)]	Loss: 1.320466
#
# Power Allocated= 4.542045700660914
# CSI= 0.8427130276282103
# SNR= 28.879476756284458
# Client: client34
# Model client34 Train Epoch: 1 [0/768 (0%)]	Loss: 2.292074
# Model client34 Train Epoch: 2 [0/768 (0%)]	Loss: 2.043164
# Model client34 Train Epoch: 3 [0/768 (0%)]	Loss: 1.380248
#
# Power Allocated= 4.390656130393803
# CSI= 0.7473656413992504
# SNR= 28.059230122150108
# Client: client40
# Model client40 Train Epoch: 1 [0/768 (0%)]	Loss: 2.288872
# Model client40 Train Epoch: 2 [0/768 (0%)]	Loss: 2.177206
# Model client40 Train Epoch: 3 [0/768 (0%)]	Loss: 1.403300
#
# Power Allocated= 2.729228596966281
# CSI= 0.33339326867174846
# SNR= 26.670809867367296
# Client: client41
# Model client41 Train Epoch: 1 [0/768 (0%)]	Loss: 2.289740
# Model client41 Train Epoch: 2 [0/768 (0%)]	Loss: 1.846556
# Model client41 Train Epoch: 3 [0/768 (0%)]	Loss: 1.436827
#
# Power Allocated= 4.139916789280618
# CSI= 0.6294167405502923
# SNR= 39.92949831019219
# Client: client44
# Model client44 Train Epoch: 1 [0/768 (0%)]	Loss: 2.286001
# Model client44 Train Epoch: 2 [0/768 (0%)]	Loss: 2.172218
# Model client44 Train Epoch: 3 [0/768 (0%)]	Loss: 1.296770
#
# Power Allocated= 4.399199353182363
# CSI= 0.7521681683458008
# SNR= 24.732058394509984
# Client: client45
# Model client45 Train Epoch: 1 [0/768 (0%)]	Loss: 2.290061
# Model client45 Train Epoch: 2 [0/768 (0%)]	Loss: 1.950223
# Model client45 Train Epoch: 3 [0/768 (0%)]	Loss: 1.288043
#
# Power Allocated= 3.567735520904029
# CSI= 0.46275863039224163
# SNR= 24.697159165748566
# Client: client46
# Model client46 Train Epoch: 1 [0/768 (0%)]	Loss: 2.287043
# Model client46 Train Epoch: 2 [0/768 (0%)]	Loss: 2.042068
# Model client46 Train Epoch: 3 [0/768 (0%)]	Loss: 1.618540
#
# Power Allocated= 4.380147671410592
# CSI= 0.7415418231633155
# SNR= 27.42181814133243
# Client: client53
# Model client53 Train Epoch: 1 [0/768 (0%)]	Loss: 2.299118
# Model client53 Train Epoch: 2 [0/768 (0%)]	Loss: 2.126937
# Model client53 Train Epoch: 3 [0/768 (0%)]	Loss: 1.189280
#
# Power Allocated= 4.009732941986857
# CSI= 0.5817483436168447
# SNR= 35.51120843119492
# Client: client60
# Model client60 Train Epoch: 1 [0/768 (0%)]	Loss: 2.290915
# Model client60 Train Epoch: 2 [0/768 (0%)]	Loss: 1.905574
# Model client60 Train Epoch: 3 [0/768 (0%)]	Loss: 1.209985
#
# Power Allocated= 0
# CSI= 0.0540332703855988
# SNR= 30.61837344205931
# Client: client61
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.461417164933827
# CSI= 0.7890965100167425
# SNR= 29.252546797634803
# Client: client62
# Model client62 Train Epoch: 1 [0/768 (0%)]	Loss: 2.285841
# Model client62 Train Epoch: 2 [0/768 (0%)]	Loss: 2.065562
# Model client62 Train Epoch: 3 [0/768 (0%)]	Loss: 1.602173
#
# Power Allocated= 0
# CSI= 0.17016856492018562
# SNR= 29.13305397748135
# Client: client63
# Poor Channel, client not taken for averaging in this round
#
#
# Test set: Average loss for Cluster3 model: 0.7718, Accuracy: 7670/10000 (77%)
#
# 0.18551999999999447
# Power Allocated= 3.4501198928201067
# CSI= 0.5154281757198738
# SNR= 32.96079299274537
# Client: client4
# Model client4 Train Epoch: 1 [0/768 (0%)]	Loss: 2.282060
# Model client4 Train Epoch: 2 [0/768 (0%)]	Loss: 2.147215
# Model client4 Train Epoch: 3 [0/768 (0%)]	Loss: 1.801075
#
# Power Allocated= 3.499432126229476
# CSI= 0.528870430230244
# SNR= 24.24922471074111
# Client: client6
# Model client6 Train Epoch: 1 [0/768 (0%)]	Loss: 2.299397
# Model client6 Train Epoch: 2 [0/768 (0%)]	Loss: 1.982638
# Model client6 Train Epoch: 3 [0/768 (0%)]	Loss: 1.550884
#
# Power Allocated= 4.013749688203292
# CSI= 0.7264777061015619
# SNR= 32.36332506645626
# Client: client17
# Model client17 Train Epoch: 1 [0/768 (0%)]	Loss: 2.300179
# Model client17 Train Epoch: 2 [0/768 (0%)]	Loss: 2.027879
# Model client17 Train Epoch: 3 [0/768 (0%)]	Loss: 1.298887
#
# Power Allocated= 3.7434296652628753
# CSI= 0.6072291524147578
# SNR= 27.579218034052065
# Client: client21
# Model client21 Train Epoch: 1 [0/768 (0%)]	Loss: 2.294787
# Model client21 Train Epoch: 2 [0/768 (0%)]	Loss: 2.078223
# Model client21 Train Epoch: 3 [0/768 (0%)]	Loss: 1.646255
#
# Power Allocated= 0.7098859739348722
# CSI= 0.2136583928213689
# SNR= 21.919537012130636
# Client: client25
# Model client25 Train Epoch: 1 [0/768 (0%)]	Loss: 2.289059
# Model client25 Train Epoch: 2 [0/768 (0%)]	Loss: 1.749896
# Model client25 Train Epoch: 3 [0/768 (0%)]	Loss: 1.622631
#
# Power Allocated= 4.229481541435025
# CSI= 0.8614949732704805
# SNR= 30.172244750677486
# Client: client32
# Model client32 Train Epoch: 1 [0/768 (0%)]	Loss: 2.296621
# Model client32 Train Epoch: 2 [0/768 (0%)]	Loss: 1.875771
# Model client32 Train Epoch: 3 [0/768 (0%)]	Loss: 1.423000
#
# Power Allocated= 2.324719087331062
# CSI= 0.3262072987188529
# SNR= 34.726443908949776
# Client: client42
# Model client42 Train Epoch: 1 [0/768 (0%)]	Loss: 2.300725
# Model client42 Train Epoch: 2 [0/768 (0%)]	Loss: 1.874348
# Model client42 Train Epoch: 3 [0/768 (0%)]	Loss: 1.824574
#
# Power Allocated= 3.7600210697838072
# CSI= 0.613409117082531
# SNR= 30.575693780985624
# Client: client48
# Model client48 Train Epoch: 1 [0/768 (0%)]	Loss: 2.300017
# Model client48 Train Epoch: 2 [0/768 (0%)]	Loss: 2.164389
# Model client48 Train Epoch: 3 [0/768 (0%)]	Loss: 1.375811
#
# Power Allocated= 4.343200602928784
# CSI= 0.9550607463413642
# SNR= 24.849884488723752
# Client: client51
# Model client51 Train Epoch: 1 [0/768 (0%)]	Loss: 2.291528
# Model client51 Train Epoch: 2 [0/768 (0%)]	Loss: 2.166780
# Model client51 Train Epoch: 3 [0/768 (0%)]	Loss: 1.366881
#
# Power Allocated= 4.0335616374267556
# CSI= 0.7370865481401184
# SNR= 24.244011540534178
# Client: client54
# Model client54 Train Epoch: 1 [0/768 (0%)]	Loss: 2.295215
# Model client54 Train Epoch: 2 [0/768 (0%)]	Loss: 1.751962
# Model client54 Train Epoch: 3 [0/768 (0%)]	Loss: 1.286946
#
# Power Allocated= 3.687296110277093
# CSI= 0.5872134357520203
# SNR= 22.84609697900034
# Client: client55
# Model client55 Train Epoch: 1 [0/768 (0%)]	Loss: 2.293847
# Model client55 Train Epoch: 2 [0/768 (0%)]	Loss: 2.190141
# Model client55 Train Epoch: 3 [0/768 (0%)]	Loss: 1.813821
#
# Power Allocated= 3.9157351337905464
# CSI= 0.6781871280671696
# SNR= 25.43369171633348
# Client: client56
# Model client56 Train Epoch: 1 [0/768 (0%)]	Loss: 2.285091
# Model client56 Train Epoch: 2 [0/768 (0%)]	Loss: 2.069777
# Model client56 Train Epoch: 3 [0/768 (0%)]	Loss: 1.514876
#
# Power Allocated= 4.356777276494116
# CSI= 0.9676072724735655
# SNR= 29.009722239274236
# Client: client57
# Model client57 Train Epoch: 1 [0/768 (0%)]	Loss: 2.294857
# Model client57 Train Epoch: 2 [0/768 (0%)]	Loss: 1.981855
# Model client57 Train Epoch: 3 [0/768 (0%)]	Loss: 1.698891
#
# Power Allocated= 1.1558358894238792
# CSI= 0.2361599338320175
# SNR= 36.36705036567167
# Client: client65
# Model client65 Train Epoch: 1 [0/768 (0%)]	Loss: 2.292140
# Model client65 Train Epoch: 2 [0/768 (0%)]	Loss: 1.966483
# Model client65 Train Epoch: 3 [0/768 (0%)]	Loss: 1.374227
#
# Power Allocated= 3.6252019687656762
# CSI= 0.5665554013965479
# SNR= 26.79536341716591
# Client: client67
# Model client67 Train Epoch: 1 [0/768 (0%)]	Loss: 2.294016
# Model client67 Train Epoch: 2 [0/768 (0%)]	Loss: 2.108068
# Model client67 Train Epoch: 3 [0/768 (0%)]	Loss: 1.556272
#
# Power Allocated= 0.9091752787347644
# CSI= 0.22316053086169974
# SNR= 26.19782764495052
# Client: client70
# Model client70 Train Epoch: 1 [0/768 (0%)]	Loss: 2.302056
# Model client70 Train Epoch: 2 [0/768 (0%)]	Loss: 1.974271
# Model client70 Train Epoch: 3 [0/768 (0%)]	Loss: 1.830627
#
# Power Allocated= 3.9733634813120102
# CSI= 0.7057706226280043
# SNR= 27.89126538389184
# Client: client71
# Model client71 Train Epoch: 1 [0/768 (0%)]	Loss: 2.292337
# Model client71 Train Epoch: 2 [0/768 (0%)]	Loss: 2.120600
# Model client71 Train Epoch: 3 [0/768 (0%)]	Loss: 1.909269
#
# Power Allocated= 0
# CSI= 0.12003508842710076
# SNR= 22.51863771620458
# Client: client75
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.270454102131584
# CSI= 0.8930163566087345
# SNR= 24.896953422252142
# Client: client78
# Model client78 Train Epoch: 1 [0/768 (0%)]	Loss: 2.297205
# Model client78 Train Epoch: 2 [0/768 (0%)]	Loss: 2.090666
# Model client78 Train Epoch: 3 [0/768 (0%)]	Loss: 1.423919
#
#
# Test set: Average loss for Cluster4 model: 0.8922, Accuracy: 7371/10000 (74%)
# ROUND 1
# 0.17423999999999884
# Power Allocated= 4.232841907977913
# CSI= 0.6638482428842264
# SNR= 31.12848627144143
# Client: client10
# Model client10 Train Epoch: 1 [0/768 (0%)]	Loss: 2.276700
# Model client10 Train Epoch: 2 [0/768 (0%)]	Loss: 2.169282
# Model client10 Train Epoch: 3 [0/768 (0%)]	Loss: 1.185866
#
# Power Allocated= 4.323890080804603
# CSI= 0.7065538930854759
# SNR= 43.49172464969907
# Client: client11
# Model client11 Train Epoch: 1 [0/768 (0%)]	Loss: 2.283538
# Model client11 Train Epoch: 2 [0/768 (0%)]	Loss: 2.075475
# Model client11 Train Epoch: 3 [0/768 (0%)]	Loss: 1.604749
#
# Power Allocated= 4.30470566839422
# CSI= 0.6971047626181567
# SNR= 25.06863214623701
# Client: client12
# Model client12 Train Epoch: 1 [0/768 (0%)]	Loss: 2.270066
# Model client12 Train Epoch: 2 [0/768 (0%)]	Loss: 2.153266
# Model client12 Train Epoch: 3 [0/768 (0%)]	Loss: 1.770508
#
# Power Allocated= 3.203419250265502
# CSI= 0.39435426122833594
# SNR= 30.44213751847669
# Client: client18
# Model client18 Train Epoch: 1 [0/768 (0%)]	Loss: 2.284606
# Model client18 Train Epoch: 2 [0/768 (0%)]	Loss: 2.077848
# Model client18 Train Epoch: 3 [0/768 (0%)]	Loss: 1.520136
#
# Power Allocated= 0
# CSI= 0.043447674071728226
# SNR= 26.715948794837562
# Client: client20
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 2.786314394534468
# CSI= 0.3386506118764112
# SNR= 27.683396600074676
# Client: client22
# Model client22 Train Epoch: 1 [0/768 (0%)]	Loss: 2.296930
# Model client22 Train Epoch: 2 [0/768 (0%)]	Loss: 2.107557
# Model client22 Train Epoch: 3 [0/768 (0%)]	Loss: 1.616238
#
# Power Allocated= 4.322351481581514
# CSI= 0.7057866301312518
# SNR= 26.273657785411167
# Client: client23
# Model client23 Train Epoch: 1 [0/768 (0%)]	Loss: 2.276686
# Model client23 Train Epoch: 2 [0/768 (0%)]	Loss: 2.088194
# Model client23 Train Epoch: 3 [0/768 (0%)]	Loss: 1.632851
#
# Power Allocated= 0
# CSI= 0.04524553694455713
# SNR= 23.089418630542742
# Client: client28
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.294902153869475
# CSI= 0.6923730322346734
# SNR= 47.559025732733886
# Client: client36
# Model client36 Train Epoch: 1 [0/768 (0%)]	Loss: 2.291628
# Model client36 Train Epoch: 2 [0/768 (0%)]	Loss: 1.872851
# Model client36 Train Epoch: 3 [0/768 (0%)]	Loss: 1.368353
#
# Power Allocated= 2.546340033420653
# CSI= 0.3131978193007732
# SNR= 28.44049228670389
# Client: client37
# Model client37 Train Epoch: 1 [0/768 (0%)]	Loss: 2.278049
# Model client37 Train Epoch: 2 [0/768 (0%)]	Loss: 2.071132
# Model client37 Train Epoch: 3 [0/768 (0%)]	Loss: 1.476200
#
# Power Allocated= 4.345111016871234
# CSI= 0.7173090346590927
# SNR= 25.541954599169042
# Client: client39
# Model client39 Train Epoch: 1 [0/768 (0%)]	Loss: 2.276767
# Model client39 Train Epoch: 2 [0/768 (0%)]	Loss: 2.005223
# Model client39 Train Epoch: 3 [0/768 (0%)]	Loss: 1.522636
#
# Power Allocated= 0.9589398406060203
# CSI= 0.20919318513513152
# SNR= 21.19862142709524
# Client: client49
# Model client49 Train Epoch: 1 [0/768 (0%)]	Loss: 2.286089
# Model client49 Train Epoch: 2 [0/768 (0%)]	Loss: 2.080598
# Model client49 Train Epoch: 3 [0/768 (0%)]	Loss: 1.942133
#
# Power Allocated= 1.8523121464288512
# CSI= 0.2572745578698977
# SNR= 21.024748896417773
# Client: client50
# Model client50 Train Epoch: 1 [0/768 (0%)]	Loss: 2.285973
# Model client50 Train Epoch: 2 [0/768 (0%)]	Loss: 1.995025
# Model client50 Train Epoch: 3 [0/768 (0%)]	Loss: 1.636428
#
# Power Allocated= 0.9106615321354656
# CSI= 0.20710156431084115
# SNR= 26.096316055464435
# Client: client58
# Model client58 Train Epoch: 1 [0/768 (0%)]	Loss: 2.275096
# Model client58 Train Epoch: 2 [0/768 (0%)]	Loss: 2.135887
# Model client58 Train Epoch: 3 [0/768 (0%)]	Loss: 1.512973
#
# Power Allocated= 4.326046664128514
# CSI= 0.707632142143921
# SNR= 38.142983751184616
# Client: client64
# Model client64 Train Epoch: 1 [0/768 (0%)]	Loss: 2.284132
# Model client64 Train Epoch: 2 [0/768 (0%)]	Loss: 1.974198
# Model client64 Train Epoch: 3 [0/768 (0%)]	Loss: 1.699721
#
# Power Allocated= 4.236128515413135
# CSI= 0.6652997996894218
# SNR= 26.78771101045409
# Client: client68
# Model client68 Train Epoch: 1 [0/768 (0%)]	Loss: 2.273154
# Model client68 Train Epoch: 2 [0/768 (0%)]	Loss: 2.150983
# Model client68 Train Epoch: 3 [0/768 (0%)]	Loss: 1.871301
#
# Power Allocated= 4.664184030168346
# CSI= 0.9302098398223207
# SNR= 31.663490254536818
# Client: client69
# Model client69 Train Epoch: 1 [0/768 (0%)]	Loss: 2.282101
# Model client69 Train Epoch: 2 [0/768 (0%)]	Loss: 2.007125
# Model client69 Train Epoch: 3 [0/768 (0%)]	Loss: 1.672578
#
# Power Allocated= 3.986635404982856
# CSI= 0.5705890296575744
# SNR= 31.71767693682327
# Client: client77
# Model client77 Train Epoch: 1 [0/768 (0%)]	Loss: 2.284670
# Model client77 Train Epoch: 2 [0/768 (0%)]	Loss: 2.113478
# Model client77 Train Epoch: 3 [0/768 (0%)]	Loss: 1.726998
#
# Power Allocated= 4.70207478440549
# CSI= 0.9641941672519254
# SNR= 22.529258214789273
# Client: client79
# Model client79 Train Epoch: 1 [0/768 (0%)]	Loss: 2.282670
# Model client79 Train Epoch: 2 [0/768 (0%)]	Loss: 2.073564
# Model client79 Train Epoch: 3 [0/768 (0%)]	Loss: 1.192120
#
#
# Test set: Average loss for Cluster1 model: 1.3518, Accuracy: 6183/10000 (62%)
#
# 0.14280000000001103
# Power Allocated= 5.868777331490039
# CSI= 0.8818157165108546
# SNR= 35.5133901536242
# Client: client2
# Model client2 Train Epoch: 1 [0/768 (0%)]	Loss: 2.283100
# Model client2 Train Epoch: 2 [0/768 (0%)]	Loss: 2.047052
# Model client2 Train Epoch: 3 [0/768 (0%)]	Loss: 1.383099
#
# Power Allocated= 5.131229522933003
# CSI= 0.5343103097567604
# SNR= 28.17115490157559
# Client: client5
# Model client5 Train Epoch: 1 [0/768 (0%)]	Loss: 2.282657
# Model client5 Train Epoch: 2 [0/768 (0%)]	Loss: 2.152960
# Model client5 Train Epoch: 3 [0/768 (0%)]	Loss: 1.722335
#
# Power Allocated= 0
# CSI= 0.10030356006242258
# SNR= 23.785149595537163
# Client: client7
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.1388143217736182
# SNR= 47.295001562523815
# Client: client13
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.3040787358134915
# CSI= 0.3705457092192035
# SNR= 40.68020181233974
# Client: client27
# Model client27 Train Epoch: 1 [0/768 (0%)]	Loss: 2.287437
# Model client27 Train Epoch: 2 [0/768 (0%)]	Loss: 2.161259
# Model client27 Train Epoch: 3 [0/768 (0%)]	Loss: 1.394801
#
# Power Allocated= 5.60514942610661
# CSI= 0.7154858424662697
# SNR= 30.016700897000003
# Client: client30
# Model client30 Train Epoch: 1 [0/768 (0%)]	Loss: 2.278391
# Model client30 Train Epoch: 2 [0/768 (0%)]	Loss: 2.151621
# Model client30 Train Epoch: 3 [0/768 (0%)]	Loss: 1.153747
#
# Power Allocated= 1.9274860100125322
# CSI= 0.19703210110914082
# SNR= 25.164537290113532
# Client: client31
# Model client31 Train Epoch: 1 [0/768 (0%)]	Loss: 2.273682
# Model client31 Train Epoch: 2 [0/768 (0%)]	Loss: 2.119406
# Model client31 Train Epoch: 3 [0/768 (0%)]	Loss: 1.570259
#
# Power Allocated= 5.906072322615572
# CSI= 0.9118024455788221
# SNR= 28.71635373055322
# Client: client35
# Model client35 Train Epoch: 1 [0/768 (0%)]	Loss: 2.276672
# Model client35 Train Epoch: 2 [0/768 (0%)]	Loss: 2.157574
# Model client35 Train Epoch: 3 [0/768 (0%)]	Loss: 1.730252
#
# Power Allocated= 5.218457343911867
# CSI= 0.5604301217904646
# SNR= 28.019230221678846
# Client: client38
# Model client38 Train Epoch: 1 [0/768 (0%)]	Loss: 2.273631
# Model client38 Train Epoch: 2 [0/768 (0%)]	Loss: 1.981462
# Model client38 Train Epoch: 3 [0/768 (0%)]	Loss: 1.398659
# ...
# Model client68 Train Epoch: 3 [0/768 (0%)]	Loss: 2.149254
#
# Power Allocated= 4.664184030168346
# CSI= 0.9302098398223207
# SNR= 31.663490254536818
# Client: client69
# Model client69 Train Epoch: 1 [0/768 (0%)]	Loss: 2.307367
# Model client69 Train Epoch: 2 [0/768 (0%)]	Loss: 2.310889
# Model client69 Train Epoch: 3 [0/768 (0%)]	Loss: 2.292419
#
# Power Allocated= 3.986635404982856
# CSI= 0.5705890296575744
# SNR= 31.71767693682327
# Client: client77
# Model client77 Train Epoch: 1 [0/768 (0%)]	Loss: 2.306553
# Model client77 Train Epoch: 2 [0/768 (0%)]	Loss: 2.326424
# Model client77 Train Epoch: 3 [0/768 (0%)]	Loss: 2.307400
#
# Power Allocated= 4.70207478440549
# CSI= 0.9641941672519254
# SNR= 22.529258214789273
# Client: client79
# Model client79 Train Epoch: 1 [0/768 (0%)]	Loss: 2.302783
# Model client79 Train Epoch: 2 [0/768 (0%)]	Loss: 2.259823
# Model client79 Train Epoch: 3 [0/768 (0%)]	Loss: 2.017211
#
#
# Test set: Average loss for Cluster1 model: 2.3055, Accuracy: 1035/10000 (10%)
#
# 0.14280000000001103
# Power Allocated= 5.868777331490039
# CSI= 0.8818157165108546
# SNR= 35.5133901536242
# Client: client2
# Model client2 Train Epoch: 1 [0/768 (0%)]	Loss: 2.307720
# Model client2 Train Epoch: 2 [0/768 (0%)]	Loss: 2.210401
# Model client2 Train Epoch: 3 [0/768 (0%)]	Loss: 1.728285
#
# Power Allocated= 5.131229522933003
# CSI= 0.5343103097567604
# SNR= 28.17115490157559
# Client: client5
# Model client5 Train Epoch: 1 [0/768 (0%)]	Loss: 2.306282
# Model client5 Train Epoch: 2 [0/768 (0%)]	Loss: 2.301095
# Model client5 Train Epoch: 3 [0/768 (0%)]	Loss: 2.295905
#
# Power Allocated= 0
# CSI= 0.10030356006242258
# SNR= 23.785149595537163
# Client: client7
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.1388143217736182
# SNR= 47.295001562523815
# Client: client13
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 4.3040787358134915
# CSI= 0.3705457092192035
# SNR= 40.68020181233974
# Client: client27
# Model client27 Train Epoch: 1 [0/768 (0%)]	Loss: 2.302920
# Model client27 Train Epoch: 2 [0/768 (0%)]	Loss: 2.288805
# Model client27 Train Epoch: 3 [0/768 (0%)]	Loss: 2.274035
#
# Power Allocated= 5.60514942610661
# CSI= 0.7154858424662697
# SNR= 30.016700897000003
# Client: client30
# Model client30 Train Epoch: 1 [0/768 (0%)]	Loss: 2.308833
# Model client30 Train Epoch: 2 [0/768 (0%)]	Loss: 2.231624
# Model client30 Train Epoch: 3 [0/768 (0%)]	Loss: 1.998704
#
# Power Allocated= 1.9274860100125322
# CSI= 0.19703210110914082
# SNR= 25.164537290113532
# Client: client31
# Model client31 Train Epoch: 1 [0/768 (0%)]	Loss: 2.298544
# Model client31 Train Epoch: 2 [0/768 (0%)]	Loss: 2.205764
# Model client31 Train Epoch: 3 [0/768 (0%)]	Loss: 1.998219
#
# Power Allocated= 5.906072322615572
# CSI= 0.9118024455788221
# SNR= 28.71635373055322
# Client: client35
# Model client35 Train Epoch: 1 [0/768 (0%)]	Loss: 2.301866
# Model client35 Train Epoch: 2 [0/768 (0%)]	Loss: 2.289695
# Model client35 Train Epoch: 3 [0/768 (0%)]	Loss: 2.278733
#
# Power Allocated= 5.218457343911867
# CSI= 0.5604301217904646
# SNR= 28.019230221678846
# Client: client38
# Model client38 Train Epoch: 1 [0/768 (0%)]	Loss: 2.312035
# Model client38 Train Epoch: 2 [0/768 (0%)]	Loss: 2.279727
# Model client38 Train Epoch: 3 [0/768 (0%)]	Loss: 2.174167
#
# Power Allocated= 2.077395122543341
# CSI= 0.20302894835988916
# SNR= 28.85186974424753
# Client: client43
# Model client43 Train Epoch: 1 [0/768 (0%)]	Loss: 2.308566
# Model client43 Train Epoch: 2 [0/768 (0%)]	Loss: 2.237471
# Model client43 Train Epoch: 3 [0/768 (0%)]	Loss: 2.302962
#
# Power Allocated= 5.691657942360541
# CSI= 0.7626932105606936
# SNR= 24.997144075637465
# Client: client47
# Model client47 Train Epoch: 1 [0/768 (0%)]	Loss: 2.304165
# Model client47 Train Epoch: 2 [0/768 (0%)]	Loss: 2.279419
# Model client47 Train Epoch: 3 [0/768 (0%)]	Loss: 2.268278
#
# Power Allocated= 5.08882197419884
# CSI= 0.5224717322338109
# SNR= 35.24881694283354
# Client: client52
# Model client52 Train Epoch: 1 [0/768 (0%)]	Loss: 2.307446
# Model client52 Train Epoch: 2 [0/768 (0%)]	Loss: 2.315175
# Model client52 Train Epoch: 3 [0/768 (0%)]	Loss: 2.332417
#
# Power Allocated= 4.671136539923616
# CSI= 0.42887815355296877
# SNR= 33.77178620188203
# Client: client59
# Model client59 Train Epoch: 1 [0/768 (0%)]	Loss: 2.303775
# Model client59 Train Epoch: 2 [0/768 (0%)]	Loss: 2.313069
# Model client59 Train Epoch: 3 [0/768 (0%)]	Loss: 2.297123
#
# Power Allocated= 2.587483667617329
# CSI= 0.22648428129646248
# SNR= 18.812070965171706
# Client: client66
# Model client66 Train Epoch: 1 [0/768 (0%)]	Loss: 2.302410
# Model client66 Train Epoch: 2 [0/768 (0%)]	Loss: 2.317669
# Model client66 Train Epoch: 3 [0/768 (0%)]	Loss: 2.258515
#
# Power Allocated= 0
# CSI= 0.08376662532616774
# SNR= 20.367489075397618
# Client: client72
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 5.925297995649724
# CSI= 0.9280715544908978
# SNR= 34.55852922400609
# Client: client73
# Model client73 Train Epoch: 1 [0/768 (0%)]	Loss: 2.294375
# Model client73 Train Epoch: 2 [0/768 (0%)]	Loss: 2.301644
# Model client73 Train Epoch: 3 [0/768 (0%)]	Loss: 2.151112
#
# Power Allocated= 0
# CSI= 0.04163443755156626
# SNR= 25.571327011277198
# Client: client74
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.12091986542958388
# SNR= 31.18796306602946
# Client: client76
# Poor Channel, client not taken for averaging in this round
#
# Power Allocated= 0
# CSI= 0.042821071517115006
# SNR= 22.835045783721142
# Client: client80
# Poor Channel, client not taken for averaging in this round
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/iiitd/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_675669/982425597.py", line 81, in <module>
#     arr=test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)
#   File "/tmp/ipykernel_675669/1363616412.py", line 6, in test
#     for data, target in test_loader:
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 363, in __next__
#     data = self._next_data()
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 403, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/site-packages/torchvision/datasets/mnist.py", line 97, in __getitem__
#     img = self.transform(img)
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/site-packages/torchvision/transforms/transforms.py", line 61, in __call__
#     img = t(img)
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/site-packages/torchvision/transforms/transforms.py", line 92, in __call__
#     return F.to_tensor(pic)
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/site-packages/torchvision/transforms/functional.py", line 84, in to_tensor
#     return img.float().div(255)
#   File "/home/iiitd/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook.py", line 169, in overloaded_native_method
#     raise route_method_exception(e, self, args, kwargs)
#   File "/home/iiitd/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook.py", line 165, in overloaded_native_method
#     response = method(*args, **kwargs)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/iiitd/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/iiitd/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/iiitd/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/iiitd/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/posixpath.py", line 425, in _joinrealpath
#     if not islink(newpath):
#   File "/home/iiitd/anaconda3/envs/FL/lib/python3.8/posixpath.py", line 170, in islink
#     return stat.S_ISLNK(st.st_mode)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_675669/982425597.py in <module>
#      80         head['model']=averageModels(head['model'], good_mem)
# ---> 81         arr=test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)
#      82         ac=arr[0]#test(args,head['model'], device, global_test_loader, 'Cluster'+str(no),fed_round)[0]
#
# /tmp/ipykernel_675669/1363616412.py in test(args, model, device, test_loader, name, fed_round)
#       5     with torch.no_grad():
# ----> 6         for data, target in test_loader:
#       7             if(use_cuda and fed_round==0):
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     362     def __next__(self):
# --> 363         data = self._next_data()
#     364         self._num_yielded += 1
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     402         index = self._next_index()  # may raise StopIteration
# --> 403         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     404         if self._pin_memory:
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#      96         if self.transform is not None:
# ---> 97             img = self.transform(img)
#      98
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      60         for t in self.transforms:
# ---> 61             img = t(img)
#      62         return img
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#      91         """
# ---> 92         return F.to_tensor(pic)
#      93
#
# ~/anaconda3/envs/FL/lib/python3.8/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#      83     if isinstance(img, torch.ByteTensor):
# ---> 84         return img.float().div(255)
#      85     else:
#
# ~/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook.py in overloaded_native_method(self, *args, **kwargs)
#     168                     # we can make some errors more descriptive with this method
# --> 169                     raise route_method_exception(e, self, args, kwargs)
#     170
#
# ~/.local/lib/python3.8/site-packages/syft/generic/frameworks/hook/hook.py in overloaded_native_method(self, *args, **kwargs)
#     164                 try:
# --> 165                     response = method(*args, **kwargs)
#     166
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2063                         # in the engines. This should return a list of strings.
# -> 2064                         stb = value._render_traceback_()
#    2065                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2064                         stb = value._render_traceback_()
#    2065                     except Exception:
# -> 2066                         stb = self.InteractiveTB.structured_traceback(etype,
#    2067                                             value, tb, tb_offset=tb_offset)
#    2068
#
# ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
print(final_acc)
